# %% [markdown]
# # Calculate 20 frequent keywords for each category
#
# Count keywords from word-pos pair for each category and save them

# %%
import pandas as pd

# %%
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')

# %%
df.head(2)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
# 1  aipl_20250304_2  2025-03-04       政治  力挺友邦瓜地馬拉  台灣採購咖啡增加5成創新高
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
# 1  由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
# 1  [('咖啡', 28), ('台灣', 18), ('瓜地馬拉', 9), ('瓜國', 6...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
# 1  ['由', '外交部', '中美洲', '經貿', '辦事處', '籌組', '的', '台...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
# 1  ['外交部', '中美洲', '經貿', '辦事處', '台灣', '咖啡', '考察團',...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
# 1  [NerToken(word='外交部中美洲經貿辦事處', ner='ORG', idx=(...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
# 1  [('由', 'P'), ('外交部', 'Nc'), ('中美洲', 'Nc'), ('經...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
# 1  /news/aipl/202503040019.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 1  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %%
df.shape
# Out:
# (12, 14)

# %%
df.groupby('category').count()
# Out:
#           item_id  date  title  content  sentiment  summary  top_key_freq  \
# category
# 政治              4     4      4        4          4        4             4
# 科技              4     4      4        4          4        4             4
# 運動              4     4      4        4          4        4             4
#
#           tokens  tokens_v2  entities  token_pos  link  photo_link
# category
# 政治             4          4         4          4     4           3
# 科技             4          4         4          4     4           1
# 運動             4          4         4          4     4           4

# %% [markdown]
# ## Filter category

# %%
# df_group = df[df.category == '政治']
df_group = df.query('category == "政治"')

# %%
df_group
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
# 1  aipl_20250304_2  2025-03-04       政治  力挺友邦瓜地馬拉  台灣採購咖啡增加5成創新高
# 2  aipl_20250303_3  2025-03-03       政治  民團告發傅崐萁涉外患與強制罪 高檢署：依法辦理
# 3  aipl_20250303_4  2025-03-03       政治     民眾黨公聽會 學者：不認同超徵後普發現金
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
# 1  由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...        暫無      暫無
# 2  經民連與台灣東社今天分別告發國民黨立委傅崐萁涉犯外患罪、反滲透法與強制罪；高檢署表示，已收到...        暫無      暫無
# 3  台灣去年度稅收高於預算，國民黨主張普發現金新台幣1萬元。民眾黨團今天舉行公聽會，會中學者認為...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
# 1  [('咖啡', 28), ('台灣', 18), ('瓜地馬拉', 9), ('瓜國', 6...
# 2  [('傅崐萁', 6), ('台灣', 5), ('中國', 3), ('官員', 3), ...
# 3  [('政府', 12), ('現金', 8), ('稅收', 7), ('民眾黨', 5),...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
# 1  ['由', '外交部', '中美洲', '經貿', '辦事處', '籌組', '的', '台...
# 2  ['經民連', '與', '台灣', '東社', '今天', '分別', '告發', '國民...
# 3  ['台灣', '去年度', '稅收', '高於', '預算', '，', '國民黨', '主...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
# 1  ['外交部', '中美洲', '經貿', '辦事處', '台灣', '咖啡', '考察團',...
# 2  ['台灣', '東社', '國民黨', '立委', '傅崐萁', '外患罪', '滲透法',...
# 3  ['台灣', '稅收', '預算', '國民黨', '現金', '新台幣', '民眾', '...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
# 1  [NerToken(word='外交部中美洲經貿辦事處', ner='ORG', idx=(...
# 2  [NerToken(word='民連', ner='ORG', idx=(1, 3)), N...
# 3  [NerToken(word='台灣', ner='GPE', idx=(0, 2)), N...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
# 1  [('由', 'P'), ('外交部', 'Nc'), ('中美洲', 'Nc'), ('經...
# 2  [('經民連', 'P'), ('與', 'Caa'), ('台灣', 'Nc'), ('東...
# 3  [('台灣', 'Nc'), ('去年度', 'Nd'), ('稅收', 'Na'), ('...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
# 1  /news/aipl/202503040019.aspx
# 2  /news/aipl/202503030336.aspx
# 3  /news/aipl/202503030327.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 1  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 2  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 3                                                NaN

# %%
df_group['token_pos']
# Out:
# 0    [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
# 1    [('由', 'P'), ('外交部', 'Nc'), ('中美洲', 'Nc'), ('經...
# 2    [('經民連', 'P'), ('與', 'Caa'), ('台灣', 'Nc'), ('東...
# 3    [('台灣', 'Nc'), ('去年度', 'Nd'), ('稅收', 'Na'), ('...
# Name: token_pos, dtype: object

# %%
len(df_group['token_pos'])
# Out:
# 4

# %% [markdown]
# # Count top 20 word frequency for each category
#
# ## You can try it out step by step by yourself!

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
top_cate_words={} # final result
counter_all = Counter() # counter for category '全部'
for category in news_categories:
    
    # df yesterday-->This is your homework
    # df=df[(df.date >= start_date) & (df.date <= end_date)]
    
    # df category
    df_group = df[df.category == category]
    
    # concatenate all filtered words in the same category
    words_group = []
    for row in df_group.token_pos:
        
        # filter words for each news
        filtered_words =[]
        for (word, pos) in eval(row):
            if (len(word) >= 2) & (pos in allowedPOS):
                filtered_words.append(word)
                
        # concatenate filtered words  
        words_group += filtered_words

    # now we can count word frequency
    counter = Counter( words_group )
    
    # concatenate all counters 
    counter_all += counter
    topwords = counter.most_common(10)

    # store topwords
    top_cate_words[category]= topwords

# Process category '全部'
top_cate_words['全部'] = counter_all.most_common(10)

# %%
words_group
# Out:
# ['中職',
#  '統一7-ELEVEn',
#  '獅隊',
#  '野手',
#  '陳傑憲',
#  '公司',
#  '律師',
#  '聲明',
#  '負責人',
#  '股東',
#  '帳務',
#  '糾紛',
#  '陳傑憲',
#  '聲明',
#  '運動',
#  '行銷',
#  '律師',
#  '聲明',
#  '公司',
#  '詹姓',
#  '負責人',
#  '丈夫',
#  '蔡姓',
#  '股東',
#  '公司',
#  '時期',
#  '金流',
#  '詹姓',
#  '負責人',
#  '期間',
#  '帳目',
#  '球員',
#  '費用',
#  '合約',
#  '內容',
#  '詹姓',
#  '負責人',
#  '期間',
#  '義務',
#  '公司',
#  '資產',
#  '律師',
#  '程序',
#  '中華職',
#  '棒球員工會',
#  '工會',
#  '會員',
#  '權益',
#  '狀況',
#  '球團',
#  '單位',
#  '市場',
#  '環境',
#  '整體',
#  '市場',
#  '需求',
#  '前提下',
#  '規範',
#  '陳傑憲新',
#  '合約',
#  '獅隊',
#  '合約',
#  '新台幣',
#  '合約',
#  '陳傑憲',
#  '陳傑憲',
#  '公司',
#  '獅隊',
#  '領隊',
#  '蘇泰安',
#  '陳傑憲',
#  '蔡姓',
#  '經紀人',
#  '合約',
#  '陳傑憲也',
#  '聲明',
#  '經紀',
#  '經紀人Lio',
#  '團隊',
#  '合約',
#  '進展',
#  '台灣',
#  '超馬',
#  '運動員',
#  '陳彥博',
#  '北極圈',
#  '長征賽',
#  '賽程',
#  '雙腳',
#  '水泡',
#  '狀況',
#  '加拿大',
#  '北極圈',
#  '長征賽',
#  '環境',
#  '攝氏',
#  '冰雪',
#  '荒野',
#  '亞洲',
#  '選手',
#  '亞洲',
#  '選手',
#  '陳彥博',
#  '加拿大',
#  '台北',
#  '高雄',
#  '雪橇',
#  '訓練',
#  '陽明山',
#  '訓練',
#  '挑戰',
#  '決心',
#  '毅力',
#  '行動',
#  '心全意',
#  '夢想',
#  '陳彥',
#  '群位置',
#  '檢查站',
#  '賽程',
#  '排名',
#  '英國',
#  '選手',
#  '貝爾奇爾',
#  '澳洲',
#  '選手',
#  '庫克斯',
#  '低溫',
#  '距離',
#  '陳彥博',
#  '雙腳',
#  '水泡',
#  '灼熱感',
#  '人員',
#  '檢查站',
#  '小時',
#  '傷口',
#  '沿途',
#  '襪子',
#  '中職',
#  '兄弟',
#  '總冠軍',
#  '球團',
#  '球員',
#  '結果',
#  '整體',
#  '薪資',
#  '調幅',
#  '許基宏',
#  '月薪',
#  '新台幣',
#  '合約',
#  '野手',
#  '王威晨',
#  '投手',
#  '李振昌',
#  '複數',
#  '年約',
#  '兄弟',
#  '新聞稿',
#  '球員',
#  '結果',
#  '薪資',
#  '中信',
#  '兄弟',
#  '球團',
#  '球員',
#  '球隊',
#  '兄弟',
#  '野手',
#  '許基宏',
#  '團隊',
#  '球團',
#  '規劃',
#  '兄弟',
#  '球團',
#  '許基宏',
#  '月薪',
#  '合約',
#  '共識',
#  '月薪',
#  '調幅',
#  '許基宏',
#  '中信',
#  '兄弟',
#  '能力',
#  '野手',
#  '王威晨',
#  '投手',
#  '李振昌',
#  '球團',
#  '複數年合約',
#  '王威晨',
#  '月薪',
#  '李振昌',
#  '月薪',
#  '團隊',
#  '球隊',
#  '學弟',
#  '正面',
#  '影響力',
#  '選秀',
#  '兄弟',
#  '曾頌恩',
#  '生涯',
#  '佳績',
#  '總冠軍賽',
#  '殊榮',
#  '年度',
#  '進步',
#  '獎」',
#  '兄弟',
#  '球團',
#  '曾頌恩',
#  '月薪',
#  '調幅',
#  '曾頌恩',
#  '表現',
#  '高峰',
#  '戰役',
#  '兄弟',
#  '後援防線',
#  '投手',
#  '呂彥青',
#  '吳俊偉',
#  '呂彥青',
#  '月薪',
#  '調幅',
#  '吳俊偉',
#  '月薪',
#  '調幅',
#  '野手',
#  '岳東華',
#  '月薪',
#  '調幅',
#  '野手',
#  '岳政華',
#  '月薪',
#  '調幅',
#  '捕手',
#  '高宇杰',
#  '月薪',
#  '調幅',
#  '野手',
#  '王政順',
#  '月薪',
#  '調幅',
#  '捕手',
#  '林吳晉瑋',
#  '月薪',
#  '調幅',
#  '投手',
#  '謝榮豪',
#  '月薪',
#  '調幅',
#  '投手',
#  '黃恩賜',
#  '月薪',
#  '調幅',
#  '投手',
#  '魏碩成',
#  '月薪',
#  '調幅',
#  '野手',
#  '宋晟睿',
#  '兄弟',
#  '球團',
#  '選手',
#  '球員',
#  '投手',
#  '鄭浩均',
#  '月薪',
#  '吳哲源',
#  '月薪',
#  '楊志龍',
#  '月薪',
#  '江忠城',
#  '月薪',
#  '美國',
#  '職棒',
#  '奧克蘭',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '名單',
#  '球員',
#  '台灣',
#  '投手',
#  '莊陳仲敖',
#  '捕手',
#  '林家正',
#  '球員',
#  '春訓',
#  '投手',
#  '莊陳仲敖',
#  '世界',
#  '棒球',
#  '經典賽',
#  '資格賽',
#  '台灣',
#  '代表隊',
#  '成員',
#  '西班牙',
#  '關鍵',
#  '安打',
#  '台灣',
#  '莊陳仲敖',
#  '莊陳仲敖',
#  '資格賽',
#  '大聯盟',
#  '春訓',
#  '紀錄',
#  '聯盟',
#  '春訓',
#  '莊陳仲敖',
#  '層級',
#  '聯盟',
#  '戰績',
#  '防禦率',
#  '捕手',
#  '林家正',
#  '世界',
#  '棒球賽',
#  '世界',
#  '棒球',
#  '經典賽',
#  '資格賽',
#  '名單',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '資格賽',
#  '台灣隊',
#  '林家正',
#  '大聯盟',
#  '春訓',
#  '身賽',
#  '安打',
#  '林家正',
#  '層級',
#  '聯盟',
#  '打數',
#  '安打',
#  '全壘打',
#  '打擊率',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '名單',
#  '球員',
#  '球員',
#  '台灣',
#  '球員',
#  '莊陳仲敖',
#  '林家正']

# %%
top_cate_words
# Out:
# {'政治': [('台灣', 45),
#   ('咖啡', 28),
#   ('政府', 14),
#   ('瓜地馬拉', 9),
#   ('現金', 8),
#   ('教友', 7),
#   ('稅收', 7),
#   ('中國', 6),
#   ('瓜國', 6),
#   ('傅崐萁', 6)],
#  '科技': [('火箭', 9),
#   ('星艦', 8),
#   ('市場', 7),
#   ('方案', 7),
#   ('太空', 7),
#   ('印度', 6),
#   ('衛星', 6),
#   ('企業', 5),
#   ('雲達', 5),
#   ('科技', 5)],
#  '運動': [('月薪', 20),
#   ('調幅', 13),
#   ('球員', 10),
#   ('兄弟', 10),
#   ('投手', 9),
#   ('野手', 8),
#   ('合約', 8),
#   ('球團', 8),
#   ('春訓', 7),
#   ('莊陳仲敖', 6)],
#  '全部': [('台灣', 53),
#   ('咖啡', 28),
#   ('月薪', 20),
#   ('政府', 14),
#   ('調幅', 13),
#   ('市場', 11),
#   ('球員', 10),
#   ('兄弟', 10),
#   ('瓜地馬拉', 9),
#   ('火箭', 9)]}

# %%
list(top_cate_words.items())
# Out:
# [('政治',
#   [('台灣', 45),
#    ('咖啡', 28),
#    ('政府', 14),
#    ('瓜地馬拉', 9),
#    ('現金', 8),
#    ('教友', 7),
#    ('稅收', 7),
#    ('中國', 6),
#    ('瓜國', 6),
#    ('傅崐萁', 6)]),
#  ('科技',
#   [('火箭', 9),
#    ('星艦', 8),
#    ('市場', 7),
#    ('方案', 7),
#    ('太空', 7),
#    ('印度', 6),
#    ('衛星', 6),
#    ('企業', 5),
#    ('雲達', 5),
#    ('科技', 5)]),
#  ('運動',
#   [('月薪', 20),
#    ('調幅', 13),
#    ('球員', 10),
#    ('兄弟', 10),
#    ('投手', 9),
#    ('野手', 8),
#    ('合約', 8),
#    ('球團', 8),
#    ('春訓', 7),
#    ('莊陳仲敖', 6)]),
#  ('全部',
#   [('台灣', 53),
#    ('咖啡', 28),
#    ('月薪', 20),
#    ('政府', 14),
#    ('調幅', 13),
#    ('市場', 11),
#    ('球員', 10),
#    ('兄弟', 10),
#    ('瓜地馬拉', 9),
#    ('火箭', 9)])]

# %% [markdown]
# ## Concatenate two list
#
# 兩個list合併:使用"+"即可!

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Concatenate two Counter objects
#
# Counter套件會自動幫我們將關鍵字的頻率累加起來

# %%
counter_all = Counter([1,2,3]) + Counter([1,2,5])
counter_all
# Out:
# Counter({1: 2, 2: 2, 3: 1, 5: 1})

# %% [markdown]
# ## All-in-one function

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
# All-in-one function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(10)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(10)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# %%
# %%time
result = get_top_words()
# Out:
# CPU times: total: 31.2 ms
# Wall time: 37 ms

# %%
result[0:3]
# Out:
# [('政治',
#   [('台灣', 45),
#    ('咖啡', 28),
#    ('政府', 14),
#    ('瓜地馬拉', 9),
#    ('現金', 8),
#    ('教友', 7),
#    ('稅收', 7),
#    ('中國', 6),
#    ('瓜國', 6),
#    ('傅崐萁', 6)]),
#  ('科技',
#   [('火箭', 9),
#    ('星艦', 8),
#    ('市場', 7),
#    ('方案', 7),
#    ('太空', 7),
#    ('印度', 6),
#    ('衛星', 6),
#    ('企業', 5),
#    ('雲達', 5),
#    ('科技', 5)]),
#  ('運動',
#   [('月薪', 20),
#    ('調幅', 13),
#    ('球員', 10),
#    ('兄弟', 10),
#    ('投手', 9),
#    ('野手', 8),
#    ('合約', 8),
#    ('球團', 8),
#    ('春訓', 7),
#    ('莊陳仲敖', 6)])]

# %% [markdown]
# # Save top 20 word frequency for each category

# %%
import pandas as pd

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#   category                                           top_keys
# 0       政治  [(台灣, 45), (咖啡, 28), (政府, 14), (瓜地馬拉, 9), (現金,...
# 1       科技  [(火箭, 9), (星艦, 8), (市場, 7), (方案, 7), (太空, 7), ...
# 2       運動  [(月薪, 20), (調幅, 13), (球員, 10), (兄弟, 10), (投手, ...
# 3       全部  [(台灣, 53), (咖啡, 28), (月薪, 20), (政府, 14), (調幅, ...

# %%
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)

# %% [markdown]
# # Another way (using list) to get the same result (for reference)
#
# 統計分類的熱門關鍵字

# %% [raw]
# # 過濾條件:兩個字以上 特定的詞性
# allowedPOS=['Na','Nb','Nc']
# from collections import Counter
#
# def word_frequency( token_pos_list ):
#     filtered_words =[]
#     for word, pos in token_pos_list:
#         if (pos in allowedPOS) & (len(word) >= 2):
#             filtered_words.append(word)
#         #print('%s %s' % (word, pos))
#     counter = Counter( filtered_words )
#     return counter.most_common( 200 )

# %% [raw]
# %%time
# top_words_group=[]
# group_token_pos_all=[]
# for category in news_categories:
#     df_group = df[df.category == category]
#     group_token_pos =[]
#
#     for gtp in df_group.token_pos:
#         group_token_pos += eval(gtp)
#
#     group_token_pos_all += group_token_pos
#
#     topwords = word_frequency( group_token_pos )
#     d = pd.DataFrame(topwords, columns = ['key','freq'])
#     top_words_group.append([category, topwords])

# %% [markdown]
# # Put them together

# %%
from collections import Counter
import pandas as pd

# 
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')
news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# 
# get topk keyword function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(100)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(100)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# Save top 20 word frequency for each category
top_group_words = get_top_words()
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)

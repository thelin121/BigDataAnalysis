# %% [markdown]
# # News Preprocessing Using Ckiplab NLP Package
#
# 多篇新聞熱門斷詞關鍵字統計新聞摘要-整理並存檔

# %% [markdown]
# # All-in-one
#
# 一鍵完工

# %%
# %%time
import pandas as pd
import numpy
from collections import Counter
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

df = pd.read_csv('cna_category_news.csv', sep='|')

# ckiplab word segment (中研院斷詞)
# Initialize drivers
# It takes time to download ckiplab models

# default參數是model="bert-base"
# ws = CkipWordSegmenter() 
# pos = CkipPosTagger()
# ner = CkipNerChunker()

# model="albert-tiny" 模型小，斷詞速度比較快，犧牲一些精確度
ws = CkipWordSegmenter(model="albert-tiny") 
pos = CkipPosTagger(model="albert-tiny")
ner = CkipNerChunker(model="albert-tiny")


## Word Segmentation
tokens = ws(df.content)

## POS
tokens_pos = pos(tokens)

## word pos pair 詞性關鍵字
word_pos_pair = [list(zip(article_word, article_pos)) for article_word, article_pos in zip(tokens, tokens_pos)]

## NER命名實體辨識
entity_list = ner(df.content)

# Remove stop words and filter using POS tag (tokens_v2)
#with open('stops_chinese_traditional.txt', 'r', encoding='utf8') as f:
#    stops = f.read().split('\n')

# 過濾條件:兩個字以上 特定的詞性
# allowPOS 過濾條件: 特定的詞性
allowPOS = ['Na', 'Nb', 'Nc']

tokens_v2 = []
for wp in word_pos_pair:
    tokens_v2.append([w for w, p in wp if (len(w) >= 2) and p in allowPOS])

# Insert tokens into dataframe (新增斷詞資料欄位)
df['tokens'] = tokens
df['tokens_v2'] = tokens_v2
df['entities'] = entity_list
df['token_pos'] = word_pos_pair

# Calculate word count (frequency) 計算字頻(次數)


def word_frequency(wp_pair):
    filtered_words = []
    for word, pos in wp_pair:
        if (pos in allowPOS) & (len(word) >= 2):
            filtered_words.append(word)
        #print('%s %s' % (word, pos))
    counter = Counter(filtered_words)
    return counter.most_common(200)


keyfreqs = []
for wp in word_pos_pair:
    topwords = word_frequency(wp)
    keyfreqs.append(topwords)

df['top_key_freq'] = keyfreqs

# Abstract (summary) and sentimental score(摘要與情緒分數)
summary = []
sentiment = []
for text in df.content:
    summary.append("暫無")
    sentiment.append("暫無")

df['summary'] = summary
df['sentiment'] = sentiment

# Rearrange the colmun order for readability
df = df[[
    'item_id', 'date','category', 'title', 'content', 'sentiment', 'summary',
    'top_key_freq', 'tokens', 'tokens_v2', 'entities', 'token_pos', 'link',
    'photo_link'
]]

# Save data to disk
df.to_csv('cna_news_preprocessed.csv', sep='|', index=False)

## Read it out 讀出看看
#df = pd.read_csv('cna_dataset_preprocessed.csv', sep='|')
#df.head(1)

print("Tokenize OK!")
# Out:
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 2000.38it/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.14it/s]
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 2999.86it/s]
# Inference: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s]
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 2000.07it/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
# Tokenize OK!
# CPU times: total: 24.2 s
# Wall time: 8.55 s

# %%
## Read it out 讀出看看
df = pd.read_csv('cna_news_preprocessed.csv', sep='|')
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %% [markdown]
# # Demonstration Step by Step

# %% [markdown]
# # Read data from file

# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv('cna_category_news.csv', sep='|')

# %%
df.shape
# Out:
# (12, 7)

# %%
df.head()
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
# 1  aipl_20250304_2  2025-03-04       政治  力挺友邦瓜地馬拉  台灣採購咖啡增加5成創新高
# 2  aipl_20250303_3  2025-03-03       政治  民團告發傅崐萁涉外患與強制罪 高檢署：依法辦理
# 3  aipl_20250303_4  2025-03-03       政治     民眾黨公聽會 學者：不認同超徵後普發現金
# 4   ait_20250303_1  2025-03-03       科技       印度推動碳市場 計劃2026年中上路
#
#                                              content  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
# 1  由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...
# 2  經民連與台灣東社今天分別告發國民黨立委傅崐萁涉犯外患罪、反滲透法與強制罪；高檢署表示，已收到...
# 3  台灣去年度稅收高於預算，國民黨主張普發現金新台幣1萬元。民眾黨團今天舉行公聽會，會中學者認為...
# 4  印度電力部長卡塔爾表示，印度正積極準備在2026年底前推出備受期待的碳市場。這項政策預計發揮...
#
#                                             link  \
# 0                   /news/aipl/202503040022.aspx
# 1                   /news/aipl/202503040019.aspx
# 2                   /news/aipl/202503030336.aspx
# 3                   /news/aipl/202503030327.aspx
# 4  https://netzero.cna.com.tw/news/202503030214/
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 1  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 2  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 3                                                NaN
# 4  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %%
df.content[0:5]
# Out:
# 0    梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
# 1    由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...
# 2    經民連與台灣東社今天分別告發國民黨立委傅崐萁涉犯外患罪、反滲透法與強制罪；高檢署表示，已收到...
# 3    台灣去年度稅收高於預算，國民黨主張普發現金新台幣1萬元。民眾黨團今天舉行公聽會，會中學者認為...
# 4    印度電力部長卡塔爾表示，印度正積極準備在2026年底前推出備受期待的碳市場。這項政策預計發揮...
# Name: content, dtype: object

# %%
df['content'][0:5]
# Out:
# 0    梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
# 1    由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...
# 2    經民連與台灣東社今天分別告發國民黨立委傅崐萁涉犯外患罪、反滲透法與強制罪；高檢署表示，已收到...
# 3    台灣去年度稅收高於預算，國民黨主張普發現金新台幣1萬元。民眾黨團今天舉行公聽會，會中學者認為...
# 4    印度電力部長卡塔爾表示，印度正積極準備在2026年底前推出備受期待的碳市場。這項政策預計發揮...
# Name: content, dtype: object

# %% [markdown]
# # Ckiplab word segment (中研院斷詞)

# %% [markdown]
# # Load tokenization models

# %%
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

# %%
# model="albert-tiny" 模型小，斷詞速度比較快，犧牲一些精確度
ws = CkipWordSegmenter(model="albert-tiny") 
pos = CkipPosTagger(model="albert-tiny")
ner = CkipNerChunker(model="albert-tiny")

# %% [markdown]
# ## Word Segmentation

# %%
# %%time
# It takes time.
tokens = ws(df.content)
# Out:
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 1999.35it/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.05it/s]
# CPU times: total: 3.09 s
# Wall time: 264 ms

# %%
len(tokens)
# Out:
# 12

# %%
len(tokens[0])
# Out:
# 492

# %%
tokens[0]
# Out:
# ['梵蒂岡',
#  '宗座',
#  '圖書館',
#  '總',
#  '館長',
#  '札尼',
#  '今天',
#  '率領',
#  '數十',
#  '位',
#  '北義',
#  '的',
#  '社會',
#  '菁英',
#  '教友',
#  '拜會',
#  '駐',
#  '教廷',
#  '大使館',
#  '。',
#  '曾',
#  '訪',
#  '台',
#  '的',
#  '札尼',
#  '致詞',
#  '時',
#  '向',
#  '教友',
#  '力',
#  '推',
#  '「',
#  '台灣',
#  '是',
#  '個',
#  '卓越',
#  '國家',
#  '，',
#  '非常',
#  '值得',
#  '前往',
#  '」',
#  '，',
#  '多',
#  '位',
#  '教友',
#  '對',
#  '台灣',
#  '高度',
#  '好奇',
#  '，',
#  '熱情',
#  '表示',
#  '「',
#  '下',
#  '次',
#  '旅遊',
#  '地點',
#  '將',
#  '鎖定',
#  '台灣',
#  '」',
#  '。',
#  '札尼',
#  '（',
#  'Angelo Vincenzo',
#  ' Zani',
#  '）',
#  '於',
#  '2023年',
#  '曾',
#  '訪',
#  '台',
#  '參加',
#  '故宮',
#  '「',
#  '梵蒂岡',
#  '宗座',
#  '圖書館',
#  '珍藏',
#  '」',
#  '暨',
#  '「',
#  '明清',
#  '宮廷',
#  '藏書',
#  '」',
#  '特展',
#  '，',
#  '對',
#  '台灣',
#  '留下',
#  '深刻',
#  '印象',
#  '。',
#  '他',
#  '今天',
#  '率領',
#  '北義',
#  '家鄉',
#  '布雷西亞',
#  '（',
#  'Brescia',
#  '）',
#  '約',
#  '40',
#  '位',
#  '教友',
#  '到',
#  '羅馬',
#  '朝聖',
#  '，',
#  '特別',
#  '安',
#  '排教友',
#  '參觀',
#  '台灣',
#  '使館',
#  '。',
#  '這',
#  '群',
#  '教友',
#  '皆',
#  '為',
#  '布雷西亞',
#  '扶輪社',
#  '成員',
#  '，',
#  '職業',
#  '包括',
#  '中',
#  '小企業家',
#  '、',
#  '大學',
#  '教授',
#  '、',
#  '律師',
#  '和',
#  '高階',
#  '憲警',
#  '等',
#  '。',
#  '札尼',
#  '致詞',
#  '時',
#  '盛讚',
#  '，',
#  '台灣',
#  '長期',
#  '與',
#  '教廷',
#  '攜手',
#  '推動',
#  '人道',
#  '援助',
#  '，',
#  '包括',
#  '協助',
#  '他',
#  '在',
#  '非洲',
#  '剛果',
#  '推動',
#  '的',
#  '教育',
#  '與',
#  '醫療',
#  '工作',
#  '，',
#  '在COVID-19',
#  '（',
#  '2019',
#  '冠狀',
#  '病毒',
#  '疾病',
#  '）',
#  '疫情',
#  '期間',
#  '，',
#  '台灣',
#  '也',
#  '曾',
#  '向',
#  '布雷西亞',
#  '醫院',
#  '捐贈',
#  '呼吸器',
#  '，',
#  '因此',
#  '他',
#  '一直',
#  '想',
#  '向',
#  '家鄉教友',
#  '介紹',
#  '開放',
#  '、',
#  '多元',
#  '又',
#  '好客',
#  '的',
#  '台灣',
#  '，',
#  '盼',
#  '促進',
#  '彼此',
#  '更',
#  '多',
#  '交流',
#  '機會',
#  '。',
#  '駐',
#  '教廷',
#  '大使',
#  '李世明',
#  '致詞',
#  '介紹',
#  '台灣',
#  '時',
#  '，',
#  '引用',
#  '「',
#  '時事哏',
#  '」',
#  '開場',
#  '博',
#  '得',
#  '眾人鼓掌大笑',
#  '。',
#  '他',
#  '表示',
#  '，',
#  '日前',
#  '美國',
#  '總統',
#  '川普',
#  '（',
#  'Donald',
#  ' Trump',
#  '）',
#  '與',
#  '烏克蘭',
#  '總統',
#  '澤倫斯基',
#  '（',
#  'Volodymyr Zelenskyy',
#  '）',
#  '在',
#  '白宮',
#  '會晤',
#  '後',
#  '，',
#  '有',
#  '句',
#  '流行語',
#  '在',
#  '國際社會',
#  '很',
#  '夯',
#  '，',
#  '就是',
#  '「',
#  '你',
#  '手',
#  '上',
#  '有',
#  '什麼',
#  '牌',
#  '可',
#  '打',
#  '」',
#  '，',
#  '台灣',
#  '論',
#  '領土',
#  '面積',
#  '雖',
#  '小',
#  '，',
#  '但',
#  '台灣',
#  '對',
#  '國際',
#  '很',
#  '重要',
#  '，',
#  '可',
#  '說',
#  '手',
#  '上',
#  '有',
#  '很多',
#  '牌',
#  '，',
#  '其',
#  '重要性',
#  '可',
#  '分',
#  '3',
#  '個',
#  '主要',
#  '方面',
#  '闡釋',
#  '。',
#  '李世明',
#  '說',
#  '，',
#  '首先',
#  '台灣',
#  '具有',
#  '地緣',
#  '戰略',
#  '重要性',
#  '，',
#  '台灣',
#  '海峽',
#  '是',
#  '全球',
#  '貨運',
#  '通過',
#  '的',
#  '重要',
#  '管道',
#  '；',
#  '第二',
#  '，',
#  '台灣',
#  '半導體',
#  '產業',
#  '位居',
#  '世界',
#  '關鍵',
#  '地位',
#  '，',
#  '先進',
#  '晶片',
#  '製程',
#  '在',
#  '全球',
#  '市占率',
#  '超過',
#  '9成',
#  '。',
#  '李世明',
#  '表示',
#  '，',
#  '第三',
#  '點',
#  '最',
#  '重要',
#  '，',
#  '教宗方',
#  '濟各',
#  '（',
#  'Pope',
#  ' ',
#  'Francis',
#  '）',
#  '說',
#  '今年',
#  '是',
#  '希望',
#  '禧年',
#  '，',
#  '台灣',
#  '作為',
#  '自由',
#  '民主',
#  '國家',
#  '，',
#  '是',
#  '所有',
#  '受到',
#  '中國',
#  '共產',
#  '威權',
#  '統治',
#  '下',
#  '人民',
#  '的',
#  '希望',
#  '，',
#  '因為',
#  '在',
#  '中國',
#  '，',
#  '人民',
#  '無法',
#  '享受',
#  '自由',
#  '與',
#  '公平',
#  '正義',
#  '，',
#  '「',
#  '台灣',
#  '扮演',
#  '了',
#  '帶來',
#  '希望',
#  '的',
#  '角色',
#  '」',
#  '。',
#  '李世明',
#  '鼓勵',
#  '北義菁英',
#  '教友',
#  '到',
#  '台灣',
#  '訪問',
#  '，',
#  '現',
#  '在',
#  '羅馬',
#  '、',
#  '米蘭',
#  '都',
#  '有',
#  '直飛',
#  '台灣',
#  '班機',
#  '，',
#  '非常',
#  '方便',
#  '。',
#  '在',
#  '場',
#  '的',
#  '布雷西亞',
#  '扶輪社',
#  '幹部',
#  '對',
#  '此',
#  '反應',
#  '熱烈',
#  '，',
#  '當場',
#  '表示',
#  '要',
#  '公開',
#  '徵求',
#  '「',
#  '台灣',
#  '扶輪社',
#  '姊妹社',
#  '」',
#  '，',
#  '下',
#  '次',
#  '立刻',
#  '安排',
#  '整團',
#  '訪',
#  '台',
#  '，',
#  '不少',
#  '教友',
#  '也',
#  '直',
#  '喊',
#  '「',
#  '報名',
#  '」',
#  '、',
#  '「',
#  '加',
#  '一',
#  '」',
#  '，',
#  '並',
#  '開始',
#  '向',
#  '使館',
#  '人員',
#  '打探',
#  '台灣',
#  '有',
#  '哪些',
#  '美食',
#  '、',
#  '登山',
#  '、',
#  '海灘',
#  '景點',
#  '，',
#  '展現',
#  '義大利人',
#  '熱情',
#  '的',
#  '民族性',
#  '。']

# %%
tokens[0][0]
# Out:
# '梵蒂岡'

# %% [markdown]
# ## POS

# %%
# %%time
tokens_pos = pos(tokens)
# Out:
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 2400.63it/s]
# Inference: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s]
# CPU times: total: 12.2 s
# Wall time: 844 ms

# %%
len(tokens_pos)
# Out:
# 12

# %%
len(tokens_pos[0])
# Out:
# 492

# %%
tokens_pos[0]
# Out:
# ['Nc',
#  'Na',
#  'Nc',
#  'Nc',
#  'Na',
#  'Nb',
#  'Nd',
#  'VF',
#  'Neu',
#  'Nf',
#  'Nc',
#  'DE',
#  'Na',
#  'Na',
#  'Na',
#  'VC',
#  'VCL',
#  'Nc',
#  'Nc',
#  'PERIODCATEGORY',
#  'D',
#  'VC',
#  'Nc',
#  'DE',
#  'Nb',
#  'VA',
#  'Ng',
#  'P',
#  'Na',
#  'VC',
#  'VC',
#  'PARENTHESISCATEGORY',
#  'Nc',
#  'SHI',
#  'Nf',
#  'VH',
#  'Na',
#  'COMMACATEGORY',
#  'Dfa',
#  'VH',
#  'VCL',
#  'PARENTHESISCATEGORY',
#  'COMMACATEGORY',
#  'Neqa',
#  'Nf',
#  'Na',
#  'P',
#  'Nc',
#  'A',
#  'VH',
#  'COMMACATEGORY',
#  'VH',
#  'VE',
#  'PARENTHESISCATEGORY',
#  'Nes',
#  'Nf',
#  'Nv',
#  'Na',
#  'D',
#  'VC',
#  'Nc',
#  'PARENTHESISCATEGORY',
#  'PERIODCATEGORY',
#  'Nb',
#  'PARENTHESISCATEGORY',
#  'FW',
#  'FW',
#  'PARENTHESISCATEGORY',
#  'P',
#  'Neu',
#  'D',
#  'VC',
#  'Nc',
#  'VC',
#  'Nc',
#  'PARENTHESISCATEGORY',
#  'Nb',
#  'Nb',
#  'Nc',
#  'VC',
#  'PARENTHESISCATEGORY',
#  'Caa',
#  'PARENTHESISCATEGORY',
#  'Nd',
#  'Nc',
#  'Na',
#  'PARENTHESISCATEGORY',
#  'Na',
#  'COMMACATEGORY',
#  'P',
#  'Nc',
#  'VC',
#  'VH',
#  'Na',
#  'PERIODCATEGORY',
#  'Nh',
#  'Nd',
#  'VF',
#  'Nc',
#  'Nc',
#  'Nc',
#  'PARENTHESISCATEGORY',
#  'FW',
#  'PARENTHESISCATEGORY',
#  'Da',
#  'Neu',
#  'Nf',
#  'Na',
#  'VCL',
#  'Nc',
#  'VA',
#  'COMMACATEGORY',
#  'VH',
#  'VE',
#  'VC',
#  'VC',
#  'Nc',
#  'Nc',
#  'PERIODCATEGORY',
#  'Nep',
#  'Nf',
#  'Na',
#  'D',
#  'VG',
#  'Nc',
#  'Nc',
#  'Na',
#  'COMMACATEGORY',
#  'Na',
#  'VK',
#  'Na',
#  'VH',
#  'PAUSECATEGORY',
#  'Nc',
#  'Na',
#  'PAUSECATEGORY',
#  'Na',
#  'Caa',
#  'A',
#  'Na',
#  'Cab',
#  'PERIODCATEGORY',
#  'Nb',
#  'VA',
#  'Ng',
#  'VE',
#  'COMMACATEGORY',
#  'Nc',
#  'Nd',
#  'P',
#  'Nc',
#  'D',
#  'VC',
#  'Na',
#  'Na',
#  'COMMACATEGORY',
#  'VK',
#  'VC',
#  'Nh',
#  'P',
#  'Nc',
#  'Nc',
#  'VC',
#  'DE',
#  'Na',
#  'Caa',
#  'VC',
#  'Na',
#  'COMMACATEGORY',
#  'P',
#  'PARENTHESISCATEGORY',
#  'Neu',
#  'Na',
#  'Na',
#  'Na',
#  'PARENTHESISCATEGORY',
#  'Na',
#  'Na',
#  'COMMACATEGORY',
#  'Nc',
#  'D',
#  'D',
#  'P',
#  'Nc',
#  'Nc',
#  'VD',
#  'Na',
#  'COMMACATEGORY',
#  'Cbb',
#  'Nh',
#  'D',
#  'VE',
#  'P',
#  'Nc',
#  'VE',
#  'VH',
#  'PAUSECATEGORY',
#  'VH',
#  'Caa',
#  'VH',
#  'DE',
#  'Nc',
#  'COMMACATEGORY',
#  'VK',
#  'VK',
#  'Nh',
#  'Neqa',
#  'VH',
#  'VH',
#  'Na',
#  'PERIODCATEGORY',
#  'VCL',
#  'Nc',
#  'Na',
#  'Nb',
#  'VA',
#  'VE',
#  'Nc',
#  'Ng',
#  'COMMACATEGORY',
#  'VC',
#  'PARENTHESISCATEGORY',
#  'Na',
#  'PARENTHESISCATEGORY',
#  'VA',
#  'VJ',
#  'DE',
#  'Na',
#  'PERIODCATEGORY',
#  'Nh',
#  'VE',
#  'COMMACATEGORY',
#  'Nd',
#  'Nc',
#  'Na',
#  'Nb',
#  'PARENTHESISCATEGORY',
#  'FW',
#  'FW',
#  'PARENTHESISCATEGORY',
#  'P',
#  'Nc',
#  'Na',
#  'Nb',
#  'PARENTHESISCATEGORY',
#  'FW',
#  'PARENTHESISCATEGORY',
#  'P',
#  'Nc',
#  'VC',
#  'Ng',
#  'COMMACATEGORY',
#  'V_2',
#  'Nf',
#  'Na',
#  'P',
#  'Nc',
#  'Dfa',
#  'VH',
#  'COMMACATEGORY',
#  'Cbb',
#  'PARENTHESISCATEGORY',
#  'Nh',
#  'Na',
#  'Ncd',
#  'V_2',
#  'Nep',
#  'Na',
#  'D',
#  'VC',
#  'PARENTHESISCATEGORY',
#  'COMMACATEGORY',
#  'Na',
#  'VC',
#  'Na',
#  'Na',
#  'Cbb',
#  'VH',
#  'COMMACATEGORY',
#  'Cbb',
#  'Nc',
#  'P',
#  'Nc',
#  'Dfa',
#  'VH',
#  'COMMACATEGORY',
#  'D',
#  'VE',
#  'Na',
#  'Ncd',
#  'V_2',
#  'Neqa',
#  'Na',
#  'COMMACATEGORY',
#  'Nep',
#  'Na',
#  'D',
#  'VC',
#  'Neu',
#  'Nf',
#  'A',
#  'Na',
#  'VC',
#  'PERIODCATEGORY',
#  'Nb',
#  'VE',
#  'COMMACATEGORY',
#  'D',
#  'Nc',
#  'VJ',
#  'Na',
#  'Na',
#  'Na',
#  'COMMACATEGORY',
#  'Nc',
#  'Na',
#  'SHI',
#  'Nc',
#  'Na',
#  'VC',
#  'DE',
#  'VH',
#  'Na',
#  'SEMICOLONCATEGORY',
#  'Neu',
#  'COMMACATEGORY',
#  'Nc',
#  'Na',
#  'Na',
#  'VCL',
#  'Nc',
#  'Na',
#  'Na',
#  'COMMACATEGORY',
#  'VH',
#  'Na',
#  'Na',
#  'P',
#  'Nc',
#  'Na',
#  'VJ',
#  'Neqa',
#  'PERIODCATEGORY',
#  'Nb',
#  'VE',
#  'COMMACATEGORY',
#  'Neu',
#  'Nf',
#  'Dfa',
#  'VH',
#  'COMMACATEGORY',
#  'Na',
#  'Nb',
#  'PARENTHESISCATEGORY',
#  'FW',
#  'WHITESPACE',
#  'FW',
#  'PARENTHESISCATEGORY',
#  'VE',
#  'Nd',
#  'SHI',
#  'VK',
#  'Nd',
#  'COMMACATEGORY',
#  'Nc',
#  'VG',
#  'VH',
#  'VH',
#  'Na',
#  'COMMACATEGORY',
#  'SHI',
#  'Neqa',
#  'VJ',
#  'Nc',
#  'A',
#  'Na',
#  'VC',
#  'Ng',
#  'Na',
#  'DE',
#  'Na',
#  'COMMACATEGORY',
#  'Cbb',
#  'P',
#  'Nc',
#  'COMMACATEGORY',
#  'Na',
#  'D',
#  'VJ',
#  'Na',
#  'Caa',
#  'VH',
#  'Na',
#  'COMMACATEGORY',
#  'PARENTHESISCATEGORY',
#  'Nc',
#  'VC',
#  'Di',
#  'VC',
#  'Na',
#  'DE',
#  'Na',
#  'PARENTHESISCATEGORY',
#  'PERIODCATEGORY',
#  'Nb',
#  'VF',
#  'Nb',
#  'Na',
#  'VCL',
#  'Nc',
#  'VC',
#  'COMMACATEGORY',
#  'Nd',
#  'P',
#  'Nc',
#  'PAUSECATEGORY',
#  'Nc',
#  'D',
#  'V_2',
#  'VCL',
#  'Nc',
#  'Na',
#  'COMMACATEGORY',
#  'Dfa',
#  'VH',
#  'PERIODCATEGORY',
#  'VA',
#  'Nc',
#  'DE',
#  'Nc',
#  'Nc',
#  'Na',
#  'P',
#  'Nep',
#  'Na',
#  'VH',
#  'COMMACATEGORY',
#  'D',
#  'VE',
#  'D',
#  'VHC',
#  'VC',
#  'PARENTHESISCATEGORY',
#  'Nc',
#  'Nc',
#  'Nc',
#  'PARENTHESISCATEGORY',
#  'COMMACATEGORY',
#  'Nes',
#  'Nf',
#  'D',
#  'VE',
#  'Neqa',
#  'VC',
#  'Nc',
#  'COMMACATEGORY',
#  'Neqa',
#  'Na',
#  'D',
#  'D',
#  'VE',
#  'PARENTHESISCATEGORY',
#  'VA',
#  'PARENTHESISCATEGORY',
#  'PAUSECATEGORY',
#  'PARENTHESISCATEGORY',
#  'VC',
#  'Neu',
#  'PARENTHESISCATEGORY',
#  'COMMACATEGORY',
#  'Cbb',
#  'VL',
#  'P',
#  'Nc',
#  'Na',
#  'VC',
#  'Nc',
#  'V_2',
#  'Neqa',
#  'Na',
#  'PAUSECATEGORY',
#  'VA',
#  'PAUSECATEGORY',
#  'Na',
#  'Na',
#  'COMMACATEGORY',
#  'VC',
#  'Na',
#  'VH',
#  'DE',
#  'Na',
#  'PERIODCATEGORY']

# %% [markdown]
# ## word pos pair 詞性關鍵字
#
# tokens and tokens_pos are two dimentional list with serveral articles.

# %%
for article_word, article_pos in zip(tokens,tokens_pos):
    print(article_word)
    print(article_pos)
# Out:
# ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率領', '數十', '位', '北義', '的', '社會', '菁英', '教友', '拜會', '駐', '教廷', '大使館', '。', '曾', '訪', '台', '的', '札尼', '致詞', '時', '向', '教友', '力', '推', '「', '台灣', '是', '個', '卓越', '國家', '，', '非常', '值得', '前往', '」', '，', '多', '位', '教友', '對', '台灣', '高度', '好奇', '，', '熱情', '表示', '「', '下', '次', '旅遊', '地點', '將', '鎖定', '台灣', '」', '。', '札尼', '（', 'Angelo Vincenzo', ' Zani', '）', '於', '2023年', '曾', '訪', '台', '參加', '故宮', '「', '梵蒂岡', '宗座', '圖書館', '珍藏', '」', '暨', '「', '明清', '宮廷', '藏書', '」', '特展', '，', '對', '台灣', '留下', '深刻', '印象', '。', '他', '今天', '率領', '北義', '家鄉', '布雷西亞', '（', 'Brescia', '）', '約', '40', '位', '教友', '到', '羅馬', '朝聖', '，', '特別', '安', '排教友', '參觀', '台灣', '使館', '。', '這', '群', '教友', '皆', '為', '布雷西亞', '扶輪社', '成員', '，', '職業', '包括', '中', '小企業家', '、', '大學', '教授', '、', '律師', '和', '高階', '憲警', '等', '。', '札尼', '致詞', '時', '盛讚', '，', '台灣', '長期', '與', '教廷', '攜手', '推動', '人道', '援助', '，', '包括', '協助', '他', '在', '非洲', '剛果', '推動', '的', '教育', '與', '醫療', '工作', '，', '在COVID-19', '（', '2019', '冠狀', '病毒', '疾病', '）', '疫情', '期間', '，', '台灣', '也', '曾', '向', '布雷西亞', '醫院', '捐贈', '呼吸器', '，', '因此', '他', '一直', '想', '向', '家鄉教友', '介紹', '開放', '、', '多元', '又', '好客', '的', '台灣', '，', '盼', '促進', '彼此', '更', '多', '交流', '機會', '。', '駐', '教廷', '大使', '李世明', '致詞', '介紹', '台灣', '時', '，', '引用', '「', '時事哏', '」', '開場', '博', '得', '眾人鼓掌大笑', '。', '他', '表示', '，', '日前', '美國', '總統', '川普', '（', 'Donald', ' Trump', '）', '與', '烏克蘭', '總統', '澤倫斯基', '（', 'Volodymyr Zelenskyy', '）', '在', '白宮', '會晤', '後', '，', '有', '句', '流行語', '在', '國際社會', '很', '夯', '，', '就是', '「', '你', '手', '上', '有', '什麼', '牌', '可', '打', '」', '，', '台灣', '論', '領土', '面積', '雖', '小', '，', '但', '台灣', '對', '國際', '很', '重要', '，', '可', '說', '手', '上', '有', '很多', '牌', '，', '其', '重要性', '可', '分', '3', '個', '主要', '方面', '闡釋', '。', '李世明', '說', '，', '首先', '台灣', '具有', '地緣', '戰略', '重要性', '，', '台灣', '海峽', '是', '全球', '貨運', '通過', '的', '重要', '管道', '；', '第二', '，', '台灣', '半導體', '產業', '位居', '世界', '關鍵', '地位', '，', '先進', '晶片', '製程', '在', '全球', '市占率', '超過', '9成', '。', '李世明', '表示', '，', '第三', '點', '最', '重要', '，', '教宗方', '濟各', '（', 'Pope', ' ', 'Francis', '）', '說', '今年', '是', '希望', '禧年', '，', '台灣', '作為', '自由', '民主', '國家', '，', '是', '所有', '受到', '中國', '共產', '威權', '統治', '下', '人民', '的', '希望', '，', '因為', '在', '中國', '，', '人民', '無法', '享受', '自由', '與', '公平', '正義', '，', '「', '台灣', '扮演', '了', '帶來', '希望', '的', '角色', '」', '。', '李世明', '鼓勵', '北義菁英', '教友', '到', '台灣', '訪問', '，', '現', '在', '羅馬', '、', '米蘭', '都', '有', '直飛', '台灣', '班機', '，', '非常', '方便', '。', '在', '場', '的', '布雷西亞', '扶輪社', '幹部', '對', '此', '反應', '熱烈', '，', '當場', '表示', '要', '公開', '徵求', '「', '台灣', '扶輪社', '姊妹社', '」', '，', '下', '次', '立刻', '安排', '整團', '訪', '台', '，', '不少', '教友', '也', '直', '喊', '「', '報名', '」', '、', '「', '加', '一', '」', '，', '並', '開始', '向', '使館', '人員', '打探', '台灣', '有', '哪些', '美食', '、', '登山', '、', '海灘', '景點', '，', '展現', '義大利人', '熱情', '的', '民族性', '。']
# ['Nc', 'Na', 'Nc', 'Nc', 'Na', 'Nb', 'Nd', 'VF', 'Neu', 'Nf', 'Nc', 'DE', 'Na', 'Na', 'Na', 'VC', 'VCL', 'Nc', 'Nc', 'PERIODCATEGORY', 'D', 'VC', 'Nc', 'DE', 'Nb', 'VA', 'Ng', 'P', 'Na', 'VC', 'VC', 'PARENTHESISCATEGORY', 'Nc', 'SHI', 'Nf', 'VH', 'Na', 'COMMACATEGORY', 'Dfa', 'VH', 'VCL', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Neqa', 'Nf', 'Na', 'P', 'Nc', 'A', 'VH', 'COMMACATEGORY', 'VH', 'VE', 'PARENTHESISCATEGORY', 'Nes', 'Nf', 'Nv', 'Na', 'D', 'VC', 'Nc', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'FW', 'PARENTHESISCATEGORY', 'P', 'Neu', 'D', 'VC', 'Nc', 'VC', 'Nc', 'PARENTHESISCATEGORY', 'Nb', 'Nb', 'Nc', 'VC', 'PARENTHESISCATEGORY', 'Caa', 'PARENTHESISCATEGORY', 'Nd', 'Nc', 'Na', 'PARENTHESISCATEGORY', 'Na', 'COMMACATEGORY', 'P', 'Nc', 'VC', 'VH', 'Na', 'PERIODCATEGORY', 'Nh', 'Nd', 'VF', 'Nc', 'Nc', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Da', 'Neu', 'Nf', 'Na', 'VCL', 'Nc', 'VA', 'COMMACATEGORY', 'VH', 'VE', 'VC', 'VC', 'Nc', 'Nc', 'PERIODCATEGORY', 'Nep', 'Nf', 'Na', 'D', 'VG', 'Nc', 'Nc', 'Na', 'COMMACATEGORY', 'Na', 'VK', 'Na', 'VH', 'PAUSECATEGORY', 'Nc', 'Na', 'PAUSECATEGORY', 'Na', 'Caa', 'A', 'Na', 'Cab', 'PERIODCATEGORY', 'Nb', 'VA', 'Ng', 'VE', 'COMMACATEGORY', 'Nc', 'Nd', 'P', 'Nc', 'D', 'VC', 'Na', 'Na', 'COMMACATEGORY', 'VK', 'VC', 'Nh', 'P', 'Nc', 'Nc', 'VC', 'DE', 'Na', 'Caa', 'VC', 'Na', 'COMMACATEGORY', 'P', 'PARENTHESISCATEGORY', 'Neu', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Na', 'Na', 'COMMACATEGORY', 'Nc', 'D', 'D', 'P', 'Nc', 'Nc', 'VD', 'Na', 'COMMACATEGORY', 'Cbb', 'Nh', 'D', 'VE', 'P', 'Nc', 'VE', 'VH', 'PAUSECATEGORY', 'VH', 'Caa', 'VH', 'DE', 'Nc', 'COMMACATEGORY', 'VK', 'VK', 'Nh', 'Neqa', 'VH', 'VH', 'Na', 'PERIODCATEGORY', 'VCL', 'Nc', 'Na', 'Nb', 'VA', 'VE', 'Nc', 'Ng', 'COMMACATEGORY', 'VC', 'PARENTHESISCATEGORY', 'Na', 'PARENTHESISCATEGORY', 'VA', 'VJ', 'DE', 'Na', 'PERIODCATEGORY', 'Nh', 'VE', 'COMMACATEGORY', 'Nd', 'Nc', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'FW', 'PARENTHESISCATEGORY', 'P', 'Nc', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'P', 'Nc', 'VC', 'Ng', 'COMMACATEGORY', 'V_2', 'Nf', 'Na', 'P', 'Nc', 'Dfa', 'VH', 'COMMACATEGORY', 'Cbb', 'PARENTHESISCATEGORY', 'Nh', 'Na', 'Ncd', 'V_2', 'Nep', 'Na', 'D', 'VC', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Na', 'VC', 'Na', 'Na', 'Cbb', 'VH', 'COMMACATEGORY', 'Cbb', 'Nc', 'P', 'Nc', 'Dfa', 'VH', 'COMMACATEGORY', 'D', 'VE', 'Na', 'Ncd', 'V_2', 'Neqa', 'Na', 'COMMACATEGORY', 'Nep', 'Na', 'D', 'VC', 'Neu', 'Nf', 'A', 'Na', 'VC', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'D', 'Nc', 'VJ', 'Na', 'Na', 'Na', 'COMMACATEGORY', 'Nc', 'Na', 'SHI', 'Nc', 'Na', 'VC', 'DE', 'VH', 'Na', 'SEMICOLONCATEGORY', 'Neu', 'COMMACATEGORY', 'Nc', 'Na', 'Na', 'VCL', 'Nc', 'Na', 'Na', 'COMMACATEGORY', 'VH', 'Na', 'Na', 'P', 'Nc', 'Na', 'VJ', 'Neqa', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'Neu', 'Nf', 'Dfa', 'VH', 'COMMACATEGORY', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'WHITESPACE', 'FW', 'PARENTHESISCATEGORY', 'VE', 'Nd', 'SHI', 'VK', 'Nd', 'COMMACATEGORY', 'Nc', 'VG', 'VH', 'VH', 'Na', 'COMMACATEGORY', 'SHI', 'Neqa', 'VJ', 'Nc', 'A', 'Na', 'VC', 'Ng', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'Cbb', 'P', 'Nc', 'COMMACATEGORY', 'Na', 'D', 'VJ', 'Na', 'Caa', 'VH', 'Na', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'Nc', 'VC', 'Di', 'VC', 'Na', 'DE', 'Na', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Nb', 'VF', 'Nb', 'Na', 'VCL', 'Nc', 'VC', 'COMMACATEGORY', 'Nd', 'P', 'Nc', 'PAUSECATEGORY', 'Nc', 'D', 'V_2', 'VCL', 'Nc', 'Na', 'COMMACATEGORY', 'Dfa', 'VH', 'PERIODCATEGORY', 'VA', 'Nc', 'DE', 'Nc', 'Nc', 'Na', 'P', 'Nep', 'Na', 'VH', 'COMMACATEGORY', 'D', 'VE', 'D', 'VHC', 'VC', 'PARENTHESISCATEGORY', 'Nc', 'Nc', 'Nc', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Nes', 'Nf', 'D', 'VE', 'Neqa', 'VC', 'Nc', 'COMMACATEGORY', 'Neqa', 'Na', 'D', 'D', 'VE', 'PARENTHESISCATEGORY', 'VA', 'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PARENTHESISCATEGORY', 'VC', 'Neu', 'PARENTHESISCATEGORY', 'COMMACATEGOR ...
# ['由', '外交部', '中美洲', '經貿', '辦事處', '籌組', '的', '台灣', '咖啡', '考察團', '，', '力挺', '友邦', '瓜地馬拉', '，', '預計', '採購', '38', '個', '貨櫃', '、', '72萬', '公斤', '咖啡', '生豆', '，', '除', '比', '去年', '增加', '近', '5成', '，', '考察團', '規模', '和', '採購量', '更', '創下', '歷年', '新高', '。', '台灣', '「', '2025年', '中美洲', '咖啡', '經', '貿', '考察團', '」', '日前', '抵達', '瓜地馬拉', '，', '實地', '考察', '咖啡', '生產', '鏈', '。', '3日', '上午', '也', '前往', '瓜地馬拉', '咖啡', '協會', '（', 'ANACAFE', '）', '拜訪', '，', '並且', '親身', '杯測', '瓜國', '各', '個', '產區', '，', '不同', '品種', '風味', '的', '咖啡', '。', '中美洲', '經貿', '辦事處', '主任', '徐韶慧', '表示', '，', '相較', '去年', '1', '1', '家', '台灣', '業者', '組團', '考察', '，', '下單', '採購', '總價值', '260萬', '美元', '，', '26', '個', '貨櫃', '的', '咖啡', '生豆', '；', '今年', '增加到', '1', '3', '家', '台灣', '業者', '參與', '，', '更', '大幅', '採購', '總計', '38', '個', '貨櫃', '、', '共', '72萬', '公斤', '咖啡', '生', '豆', '，', '顯示', '台灣', '消費者', '對', '瓜地馬拉', '咖啡', '的', '喜愛', '，', '更', '凸顯', '台', '瓜', '蓬勃商機', '發展', '。', '徐韶慧', '強調', '，', '根據', '統計', '，', '2024年', '瓜地馬拉', '進口', '的', '咖啡豆', '占', '台灣', '咖啡', '消費', '總量', '的', '10%', '以上', '，', '是', '台灣', '第4', '大', '的', '咖啡', '進口國', '。', '換句', '話', '說', '，', '台灣', '每', '賣', '出', '1', '0', '杯', '咖啡', '，', '就', '有', '超過', '1', '杯', '是', '來自', '瓜地馬拉', '。', '此外', '，', '台灣', '在', '整', '個', '亞洲', '的', '咖啡', '消費國中', '也', '位居第3', '，', '僅', '次於', '日本', '和', '韓國', '。', '去年', '5月', '底', '，', '中國', '突然', '宣布', '禁止', '瓜地馬拉', '夏威夷豆', '和', '咖啡豆', '進口', '，', '作為', '外交', '勒索', '手段', '，', '引起', '瓜國政府', '和', '業者', '不滿', '。', '台灣', '外交部', '和', '台灣', '咖啡', '進口商', '第一', '時間', '伸出', '援手', '，', '將', '這', '一', '批', '咖啡貨櫃', '轉運往', '台灣', '。', '中美洲', '經貿', '辦事處', '也', '別出心裁', '，', '將', '這', '批', '瓜國', '咖啡', '豆', '製作成', '濾掛式', '咖啡包', '，', '在', '此', '次', '參訪', '行程', '更', '將', '致贈', '瓜國', '友人', '「', '限定版', '友誼', '咖啡', '」', '禮盒', '，', '成為', '台灣', '力挺', '瓜國', '另', '一', '種', '象徵', '。', '根據', '瓜地', '馬拉', '中央', '銀行', '數據', '，', '2024年', '瓜地', '馬拉', '對', '台灣', '的', '咖啡', '出口', '超過', '1800萬', '美元', '，', '相比於', '2023年', '，', '出口量', '增長', '了', '13%', '；', '而', '咖啡', '也', '僅', '次於', '糖', '，', '成為', '瓜國', '出口', '台灣', '的', '第二', '大', '商品', '。', '出席', '活動', '的', '瓜地', '馬拉', '外交部', '次長', '歐洛斯柯', '（', 'Julio Orozco', '）', '特別', '感謝', '台灣', '和', '瓜地馬拉', '共同', '推廣', '咖啡', '，', '不只', '進', '一', '步', '提升', '全球', '市場', '地位', '，', '更', '讓', '台瓜人民', '及', '瓜國', '咖啡', '農', '都', '能夠', '受惠', '。', '除了', '政治', '因素', '干擾', '，', '近年來', '全球', '咖啡', '受到', '氣候', '變遷', '影響', '，', '產量', '供應', '不', '穩', '，', '市場', '價格', '也', '大幅', '波動', '。', '台灣', '咖啡', '考察團', '業者', '張正仁', '指出', '，', '過', '去', '咖啡', '價格', '雖然', '每', '十', '年', '就', '會', '有', '一', '次', '上漲', '，', '但', '基本', '上', '2', '、', '3', '個', '月', '後', '就', '恢復', '平穩', '。', '不過', '自', 'COVID-19', '（', '2019', '冠狀', '病毒', '疾病', '）', '疫情', '後', '，', '咖啡', '價格', '卻', '持續', '走揚', '，', '這', '種', '情況', '是', '過數十', '年', '罕見', '的', '，', '自然', '也', '造成', '進口商', '的', '成本', '壓力', '。', '張正仁', '強調', '，', '現在', '只能', '觀察', '3', '、', '4', '月', '後', '，', '全', '世界', '第一', '大', '咖啡', '生產國', '巴西', '氣候', '是否', '穩定', '，', '產量', '回穩', '，', '未來', '咖啡', '價格', '波動', '才', '會', '明朗', '。', '中美洲', '經貿', '辦', '事處', '（', 'CATO', '）', '表示', '，', '瓜地馬拉', '因', '地理', '條件', '與', '多樣化', '的', '微型', '氣候', '，', '本身', '擁有', '8', '大', '咖啡', '產區', '，', '其中', '以', '安', '地瓜', '（', 'Antigua', '）', '與', '維維特南戈', '（', 'Huehu', 'etenango', '）', '尤', '為', '出名', '。', '台灣', '考察團', '此', '次', '也', '將', '深入', '位於', '內陸', '高海拔', '，', '地處', '偏遠', '交通', '不便', '的', '維維特', '南戈', '產區', '，', '親自', '探訪', '並', '了解', '當地', '咖啡', '從', '種植', '、', '採收', '、', '處理', '到', '烘焙', '的', '完整', '生產', '流程', '，', '並', '與', '咖啡農', '、', '處理', '廠', '及', '出口商', '交流', '。']
# ['P', 'Nc', 'Nc', 'Na', 'Nc', 'VC', 'DE', 'Nc', 'Na', 'Na', 'COMMACATEGORY', 'VC', 'Nc', 'Nc', 'COMMACATEGORY', 'VE', 'VC', 'Neu', 'Nf', 'Na', 'PAUSECATEGORY', 'Neu', 'Nf', 'Na', 'VC', 'COMMACATEGORY', 'P', 'P', 'Nd', 'VHC', 'Nes', 'Neqa', 'COMMACATEGORY', 'Na', 'Na', 'Caa', 'Na', 'Dfa', 'VC', 'Nd', 'Na', 'PERIODCATEGORY', 'Nc', 'PARENTHESISCATEGORY', 'Neu', 'Nc', 'Na', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Nd', 'VCL', 'Nc', 'COMMACATEGORY', 'D', 'VC', 'Na', 'Na', 'Na', 'PERIODCATEGORY', 'Nd', 'Nd', 'D', 'VCL', 'Nc', 'Nc', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VC', 'COMMACATEGORY', 'Cbb', 'Na', 'Na', 'Nc', 'Nes', 'Nf', 'Nc', 'COMMACATEGORY', 'VH', 'Na', 'Na', 'DE', 'Na', 'PERIODCATEGORY', 'Nc', 'Na', 'Nc', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'VB', 'Nd', 'Neu', 'Neu', 'Nf', 'Nc', 'Na', 'VA', 'VC', 'COMMACATEGORY', 'Na', 'VC', 'Na', 'Neu', 'Nf', 'COMMACATEGORY', 'Neu', 'Nf', 'Na', 'DE', 'Na', 'VC', 'SEMICOLONCATEGORY', 'Nd', 'VHC', 'Neu', 'Neu', 'Nf', 'Nc', 'Na', 'VC', 'COMMACATEGORY', 'Dfa', 'D', 'VC', 'Da', 'Neu', 'Nf', 'Na', 'PAUSECATEGORY', 'Da', 'Neu', 'Nf', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'VK', 'Nc', 'Na', 'P', 'Nc', 'Na', 'DE', 'Nv', 'COMMACATEGORY', 'Dfa', 'VJ', 'Nc', 'Nc', 'VH', 'VC', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'P', 'Na', 'COMMACATEGORY', 'Neu', 'Nc', 'VC', 'DE', 'Na', 'VJ', 'Nc', 'Na', 'Na', 'Na', 'DE', 'Neqa', 'Ng', 'COMMACATEGORY', 'SHI', 'Nc', 'Neu', 'VH', 'DE', 'Na', 'Na', 'PERIODCATEGORY', 'Dk', 'Na', 'VE', 'COMMACATEGORY', 'Nc', 'D', 'VC', 'VC', 'Neu', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'D', 'V_2', 'VJ', 'Neu', 'Nf', 'SHI', 'VJ', 'Nc', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'Nc', 'P', 'Neqa', 'Nf', 'Nc', 'DE', 'Na', 'Na', 'D', 'VCL', 'COMMACATEGORY', 'Da', 'VJ', 'Nc', 'Caa', 'Nc', 'PERIODCATEGORY', 'Nd', 'Nd', 'Ng', 'COMMACATEGORY', 'Nc', 'D', 'VE', 'VE', 'Nc', 'Nc', 'Caa', 'Na', 'VC', 'COMMACATEGORY', 'VG', 'Na', 'Nv', 'Na', 'COMMACATEGORY', 'VC', 'Nc', 'Caa', 'Na', 'VK', 'PERIODCATEGORY', 'Nc', 'Nc', 'Caa', 'Nc', 'Na', 'Na', 'Neu', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'P', 'Nep', 'Neu', 'Nf', 'Na', 'VCL', 'Nc', 'PERIODCATEGORY', 'Nc', 'Na', 'Nc', 'D', 'VH', 'COMMACATEGORY', 'P', 'Nep', 'Nf', 'Nc', 'Na', 'Na', 'VG', 'A', 'Na', 'COMMACATEGORY', 'P', 'Nep', 'Nf', 'VC', 'Na', 'Dfa', 'D', 'VD', 'Nc', 'Na', 'PARENTHESISCATEGORY', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Na', 'COMMACATEGORY', 'VG', 'Nc', 'VC', 'Nc', 'Nes', 'Neu', 'Nf', 'Na', 'PERIODCATEGORY', 'P', 'Nc', 'Na', 'Nc', 'Nc', 'Na', 'COMMACATEGORY', 'Neu', 'Nc', 'Na', 'P', 'Nc', 'DE', 'Na', 'VC', 'VJ', 'Neu', 'Nf', 'COMMACATEGORY', 'VB', 'Neu', 'COMMACATEGORY', 'Na', 'VHC', 'Di', 'Neqa', 'SEMICOLONCATEGORY', 'Cbb', 'Na', 'D', 'Da', 'VJ', 'Na', 'COMMACATEGORY', 'VG', 'Nc', 'VC', 'Nc', 'DE', 'Neu', 'VH', 'Na', 'PERIODCATEGORY', 'Nv', 'Na', 'DE', 'Nc', 'Na', 'Nc', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VH', 'VK', 'Nc', 'Caa', 'Nc', 'A', 'VC', 'Na', 'COMMACATEGORY', 'Da', 'D', 'Neu', 'Nf', 'VC', 'Nc', 'Nc', 'Na', 'COMMACATEGORY', 'Dfa', 'VL', 'Nc', 'Caa', 'Nc', 'Na', 'Na', 'D', 'D', 'VH', 'PERIODCATEGORY', 'P', 'Na', 'Na', 'VC', 'COMMACATEGORY', 'Nd', 'Nc', 'Na', 'VJ', 'Na', 'VH', 'VC', 'COMMACATEGORY', 'Na', 'VD', 'D', 'VH', 'COMMACATEGORY', 'Nc', 'Na', 'D', 'D', 'VAC', 'PERIODCATEGORY', 'Nc', 'Na', 'Na', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Nd', 'VJ', 'Na', 'Na', 'Cbb', 'Nes', 'Neu', 'Nf', 'D', 'D', 'V_2', 'Neu', 'Nf', 'Nv', 'COMMACATEGORY', 'Cbb', 'Na', 'Ng', 'Neu', 'PAUSECATEGORY', 'Neu', 'Nf', 'Na', 'Ng', 'D', 'VHC', 'VH', 'PERIODCATEGORY', 'Cbb', 'P', 'FW', 'PARENTHESISCATEGORY', 'Neu', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Na', 'Ng', 'COMMACATEGORY', 'Na', 'Na', 'D', 'VL', 'VH', 'COMMACATEGORY', 'Nep', 'Nf', 'Na', 'SHI', 'VCL', 'Nf', 'VH', 'T', 'COMMACATEGORY', 'D', 'D', 'VK', 'Na', 'DE', 'Na', 'Na', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'Nd', 'Da', 'VE', 'Nd', 'PAUSECATEGORY', 'Nd', 'Na', 'Ng', 'COMMACATEGORY', 'Neqa', 'Nc', 'Neu', 'VH', 'Na', 'Na', 'Nc', 'Na', 'D',  ...
# ['經民連', '與', '台灣', '東社', '今天', '分別', '告發', '國民黨', '立委', '傅崐萁', '涉犯', '外患罪', '、', '反', '滲透法', '與', '強制罪', '；', '高檢署', '表示', '，', '已', '收到', '告發狀', '，', '後續', '依法辦理', '。', '至', '晚間', '9時', '止', '，', '尚', '無法', '取得', '傅崐萁', '對', '此', '事', '的', '回應', '。', '台灣', '經濟', '民主', '連合智庫', '召集人', '賴中強', '等', '人', '今天', '在', '台灣', '高等', '檢察署', '前', '舉行', '記者會', '，', '現場', '發放', '的', '新聞', '資料', '指稱', '中國', '國民黨', '立法院', '黨團', '總召集人', '傅崐萁', '未', '獲', '行政院', '授權', '，', '2月', '到', '香港', '與', '多', '名', '香港區', '議員', '、', '香港', '旅遊業', '監管局', '官員', '等', '會商', '，', '宣稱', '代表', '「', '台灣', '的', '中央', '政府', '」', '，', '承諾', '台灣', '政府', '願', '提供', '補助', '進行', '在', '台', '跨', '縣市', '觀光合', '作', '。', '經民連說', '，', '傅崐萁', '去年', '率', '國民黨團', '17', '名', '成員', '訪問', '中國', '，', '會', '見', '中國', '人民', '政治', '協商', '會議', '全國委員會', '主席', '王滬寧', '等', '官員', '，', '返', '台', '後', '即', '遊說', '行政院', '官員', '等', '，', '開放', '福', '建', '平潭', '與', '台', '灣', '間', '海上', '客運', '直航', '復航', '。', '另外', '，', '傅崐萁', '昨天', '在', '花蓮', '一', '場', '活動', '中', '致詞', '時', '，', '近', '80', '歲', '的', '退休', '教師', '葉春蓮', '起身', '「', '嗆聲', '」', '被', '請', '出場', '，', '引發', '許多', '民眾', '及', '曾', '被', '葉春蓮', '教', '過', '的', '學生', '不滿', '。', '台灣東社', '發言人', '陳財能', '上午', '到', '花蓮縣', '警察局', '花蓮', '分局', '軒', '轅', '派出所', '，', '告發', '傅崐萁', '等', '違反', '中華民國', '刑法', '強制', '罪', '，', '要求', '警方', '做好', '證據保全', '及', '即刻', '調查', '，', '維護', '花蓮人', '人身自由', '及', '權利', '。']
# ['P', 'Caa', 'Nc', 'Nc', 'Nd', 'D', 'VC', 'Nb', 'Na', 'Nb', 'VH', 'Na', 'PAUSECATEGORY', 'Na', 'Na', 'Caa', 'Na', 'SEMICOLONCATEGORY', 'Nc', 'VE', 'COMMACATEGORY', 'D', 'VC', 'Na', 'COMMACATEGORY', 'A', 'D', 'PERIODCATEGORY', 'P', 'Nd', 'Neu', 'Ng', 'COMMACATEGORY', 'D', 'D', 'VC', 'Nb', 'P', 'Nep', 'Na', 'DE', 'VC', 'PERIODCATEGORY', 'Nc', 'Na', 'Na', 'Nb', 'Na', 'Nb', 'Cab', 'Na', 'Nd', 'P', 'Nc', 'A', 'Nc', 'Ng', 'VC', 'Na', 'COMMACATEGORY', 'Nc', 'VD', 'DE', 'Na', 'Na', 'VE', 'Nc', 'Nb', 'Nc', 'Na', 'Na', 'Nb', 'D', 'VJ', 'Nc', 'VE', 'COMMACATEGORY', 'Nd', 'VCL', 'Nc', 'Caa', 'Neqa', 'Nf', 'Nc', 'Na', 'PAUSECATEGORY', 'Nc', 'Na', 'Nc', 'Na', 'Cab', 'VE', 'COMMACATEGORY', 'VE', 'VK', 'PARENTHESISCATEGORY', 'Nc', 'DE', 'Nc', 'Na', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'VE', 'Nc', 'Na', 'VK', 'VD', 'VD', 'VC', 'P', 'Nc', 'VC', 'Nc', 'VA', 'VC', 'PERIODCATEGORY', 'P', 'COMMACATEGORY', 'Nb', 'Nd', 'VF', 'Na', 'Neu', 'Nf', 'Na', 'VC', 'Nc', 'COMMACATEGORY', 'VC', 'VC', 'Nc', 'Na', 'Na', 'Nv', 'Na', 'Neqa', 'Na', 'Nb', 'Cab', 'Na', 'COMMACATEGORY', 'VA', 'Nc', 'Ng', 'D', 'VF', 'Nc', 'Na', 'Cab', 'COMMACATEGORY', 'VC', 'Nc', 'VC', 'Nc', 'Caa', 'Nc', 'Nc', 'Ncd', 'Na', 'Na', 'VCL', 'VA', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'Nb', 'Nd', 'P', 'Nc', 'Neu', 'Nf', 'Na', 'Ng', 'VA', 'Ng', 'COMMACATEGORY', 'Da', 'Neu', 'Nf', 'DE', 'VH', 'Na', 'Nb', 'VA', 'PARENTHESISCATEGORY', 'VA', 'PARENTHESISCATEGORY', 'P', 'VF', 'VA', 'COMMACATEGORY', 'VC', 'Neqa', 'Na', 'Caa', 'D', 'P', 'Nb', 'VC', 'Di', 'DE', 'Na', 'VK', 'PERIODCATEGORY', 'Nc', 'Na', 'Nb', 'Nd', 'VCL', 'Nc', 'Nc', 'Nc', 'Nc', 'Nc', 'Nb', 'Nc', 'COMMACATEGORY', 'VC', 'Nb', 'Cab', 'VJ', 'Nc', 'Na', 'Nv', 'Na', 'COMMACATEGORY', 'VF', 'Na', 'VC', 'Na', 'Caa', 'D', 'VE', 'COMMACATEGORY', 'VC', 'Nc', 'Na', 'Caa', 'Na', 'PERIODCATEGORY']
# ['台灣', '去年度', '稅收', '高於', '預算', '，', '國民黨', '主張', '普發', '現金', '新台幣', '1萬', '元', '。', '民眾', '黨團', '今天', '舉行', '公聽會', '，', '會', '中', '學者', '認為', '，', '目前', '的', '租稅', '制度', '不', '公', '、', '財務', '模型', '有', '檢討', '必要', '，', '但', '普遍', '不', '認同', '超徵', '後', '直接', '以', '普發', '現金', '處理', '。', '台灣', '民眾黨', '立法院', '黨團', '今天', '舉行', '「', '檢討', '連年', '超徵', '，', '共享', '經濟', '成果', '」', '公聽會', '，', '邀', '學者', '專家', '、', '政府', '代表', '出席', '。', '民眾黨', '立法院', '黨團', '總召', '黃國昌', '說', '，', '執政黨', '年', '年', '超徵', '數千億', '，', '不', '知', '是', '能力', '問題', '，', '還是', '故意', '讓', '人民', '產生', '錯覺', '，', '以為', '政府', '年年賸餘', '，', '但', '若', '將', '特別', '預算', '納入', '，', '歲出', '大幅', '超過', '賸餘', '，', '顯示', '過去', '蔡', '政府', '將', '特別', '預', '算常態化', '、', '甚至', '病態', '化', '。', '黃國昌', '指出', '，', '民進黨', '政府', '政策', '前後矛盾', '，', '過去', '蔡政府', '時', '，', '前行政院長', '蘇貞昌力', '推', '普發', '現金', '6000', '元', '，', '如今', '賴', '政府', '卻', '說', '要', '先', '還', '債', '，', '施', '政', '毫', '無', '一', '貫', '邏輯', '；', '民眾黨', '有', '責任', '和', '擔當', '，', '主張', '建立', '制度化', '解決', '機制', '，', '讓', '國家', '走向', '正軌', '。', '民眾', '黨團', '副', '總召', '張啓楷', '說', '，', '民進黨', '政府', '4', '年', '超', '徵', '1.8兆元', '，', '民眾黨', '要', '「', '追', '責任', '、', '修', '法令', '」', '，', '上游', '的', '主計', '總處', '、', '國發會', '和', '財政部', '等', '部會', '，', '有', '沒', '有', '問題', '；', '下游', '針對', '立委', '審', '的', '預算法', '、', '公債法', '，', '有', '問題', '都', '要', '修法', '、', '補破網', '。', '政治', '大學', '財政學系', '教授', '陳國樑', '說', '，', '政府', '當務', '之', '急', '要', '先', '提', '高', '稅收', '預測', '的', '精準度', '，', '第二則', '是', '稅收', '超徵時', '的', '法制化', '處理', '方式', '。', '建議', '參酌', '歐盟', '「', '債務', '調整', '制度', '」', '，', '把', '政府', '赤字', '跟', '債務', '還本', '能力', '連結', '，', '在', '景氣', '衰退期', '間', '適度', '減', '輕', '還本', '壓力', '，', '並', '允許', '在', '稅收', '低於', '預期', '時', '，', '增加', '舉債', '額度', '。', '台北', '商業', '大學', '財稅系', '教授', '黃耀輝', '指出', '，', '政府', '財政', '管理', '與', '支出', '都', '出', '問題', '，', '政府', '超收', '即', '超', '花', '，', '並', '未', '有效', '償還', '公共', '債務', '；', '建議', '超徵稅收', '應', '優先', '用', '於', '還債', '，', '更', '應', '提出', '具體', '稅制', '改革', '方案', '，', '確保', '財政', '公', '平', '與', '穩健', '。', '財政部', '賦稅署長', '宋秀玲', '說', '，', '觀察', '疫情', '期間', '，', '2020年', '到', '2023', '年', '稅收', '數字', '確實', '有', '落差', '，', '聽', '專家', '學者', '建議', '成立', '稅收', '估測', '專家', '小組', '，', '發現', '營利', '事業', '所得', '稅', '和', '綜合', '所', '得', '稅', '占', '比', '達', '50%', '，', '財政部', '委請', '陳國樑', '團隊', '做', '研究', '報告', '，', '但', '因', '時', '間', '落差', '的', '關係', '，', '才', '導致', '稅收', '誤差', '。', '黃國昌', '也', '質疑', '，', '政府', '對', '普發', '現金', '前', '後立場', '不一', '，', '針對', '普發', '現金', '所', '帶來', '的', '經濟', '效益', '，', '是否', '有', '做', '評估', '。', '國家', '發展', '委員會', '經濟', '發展處', '副處長', '陳美菊', '說', '，', '過去', '普發', '現金', '是', '為', '疫後', '振興', '經濟', '、', '強化', '社會', '韌性', '；', '黃國昌', '則', '要求', '提供', '評估', '報告', '。', '民眾黨', '指出', '，', '公聽會', '中', '學者', '一致', '認為', '，', '目前', '的', '租稅', '制度', '不公', '、', '財務', '模型', '有', '檢討', '必', '要', '，', '普遍', '不認同', '超徵後', '直接', '以', '普發', '現金', '處理', '，', '因為', '超徵', '並', '非', '多餘', '資金', '，', '若', '將', '超徵款', '普發', '現金', '或', '以', '其他', '形式', '退還，', '每', '發', '1元', '都', '可能', '需要', '舉借新債', '，', '造', '成債留', '子孫', '；', '但', '若', '政府', '不', '多', '還債', '，', '仍', '可', '考慮', '將', '部分', '超徵稅收', '以', '普發', '現金', '方式', '返還給', '民眾', '。']
# ['Nc', 'Nd', 'Na', 'VJ', 'Na', 'COMMACATEGORY', 'Nb', 'VE', 'VH', 'Na', 'Na', 'Neu', 'Nf', 'PERIODCATEGORY', 'Na', 'Na', 'Nd', 'VC', 'Na', 'COMMACATEGORY', 'Na', 'Ng', 'Na', 'VE', 'COMMACATEGORY', 'Nd', 'DE', 'Na', 'Na', 'VH', 'A', 'PAUSECATEGORY', 'Na', 'Na', 'V_2', 'VC', 'Na', 'COMMACATEGORY', 'Cbb', 'VH', 'D', 'VJ', 'VC', 'Ng', 'VH', 'P', 'Na', 'Na', 'VC', 'PERIODCATEGORY', 'Nc', 'Nb', 'Nc', 'Na', 'Nd', 'VC', 'PARENTHESISCATEGORY', 'VE', 'D', 'VC', 'COMMACATEGORY', 'VJ', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Na', 'COMMACATEGORY', 'VF', 'Na', 'Na', 'PAUSECATEGORY', 'Na', 'Na', 'VC', 'PERIODCATEGORY', 'Nb', 'Nc', 'Na', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Na', 'D', 'Nf', 'VC', 'Neu', 'COMMACATEGORY', 'D', 'VK', 'SHI', 'Na', 'Na', 'COMMACATEGORY', 'D', 'VL', 'VL', 'Na', 'VHC', 'Na', 'COMMACATEGORY', 'VE', 'Na', 'D', 'COMMACATEGORY', 'Cbb', 'Cbb', 'P', 'VH', 'Na', 'VJ', 'COMMACATEGORY', 'VJ', 'D', 'VJ', 'Nf', 'COMMACATEGORY', 'VK', 'Nd', 'Nb', 'Na', 'P', 'VH', 'Na', 'VF', 'PAUSECATEGORY', 'D', 'VHC', 'VHC', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'Nb', 'Na', 'Na', 'D', 'COMMACATEGORY', 'Nd', 'Nb', 'Ng', 'COMMACATEGORY', 'Nes', 'Nb', 'VC', 'Na', 'Na', 'Neu', 'Nf', 'COMMACATEGORY', 'Nd', 'Nb', 'Na', 'D', 'VE', 'D', 'D', 'VA', 'Na', 'COMMACATEGORY', 'VA', 'Na', 'VJ', 'VJ', 'A', 'Na', 'Na', 'SEMICOLONCATEGORY', 'Nb', 'V_2', 'Na', 'Caa', 'VC', 'COMMACATEGORY', 'VE', 'VC', 'VHC', 'VC', 'Na', 'COMMACATEGORY', 'VL', 'Na', 'VCL', 'Na', 'PERIODCATEGORY', 'Na', 'Na', 'Na', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Nb', 'Na', 'Neu', 'Nf', 'VC', 'VC', 'Neu', 'COMMACATEGORY', 'Nb', 'D', 'PARENTHESISCATEGORY', 'VC', 'Na', 'PAUSECATEGORY', 'VA', 'Na', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Nc', 'DE', 'A', 'Nc', 'PAUSECATEGORY', 'Nc', 'Caa', 'Nc', 'Cab', 'Na', 'COMMACATEGORY', 'V_2', 'D', 'V_2', 'Na', 'SEMICOLONCATEGORY', 'Nc', 'P', 'Na', 'VC', 'DE', 'Na', 'PAUSECATEGORY', 'Na', 'COMMACATEGORY', 'V_2', 'Na', 'D', 'D', 'VA', 'PAUSECATEGORY', 'VC', 'PERIODCATEGORY', 'Na', 'Nc', 'Na', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Na', 'Na', 'DE', 'VH', 'D', 'D', 'VC', 'VH', 'Na', 'VE', 'DE', 'VH', 'COMMACATEGORY', 'Neu', 'SHI', 'Na', 'VJ', 'DE', 'VHC', 'Nv', 'Na', 'PERIODCATEGORY', 'VE', 'VC', 'Nb', 'PARENTHESISCATEGORY', 'Na', 'Nv', 'Na', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'P', 'Na', 'Na', 'P', 'Na', 'VC', 'Na', 'VC', 'COMMACATEGORY', 'P', 'Na', 'VH', 'Ng', 'A', 'VHC', 'VH', 'A', 'Na', 'COMMACATEGORY', 'Cbb', 'VE', 'P', 'Na', 'VJ', 'Na', 'Ng', 'COMMACATEGORY', 'VHC', 'VA', 'Na', 'PERIODCATEGORY', 'Nc', 'Na', 'Nc', 'Nc', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Na', 'Na', 'Na', 'Caa', 'Na', 'D', 'VC', 'Na', 'COMMACATEGORY', 'Na', 'VH', 'D', 'VH', 'Na', 'COMMACATEGORY', 'D', 'D', 'VH', 'VD', 'A', 'Na', 'SEMICOLONCATEGORY', 'VE', 'VJ', 'D', 'D', 'VCL', 'P', 'VA', 'COMMACATEGORY', 'Dfa', 'D', 'VC', 'VH', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'VE', 'Na', 'VH', 'VH', 'Caa', 'VH', 'PERIODCATEGORY', 'Nc', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'VE', 'Na', 'Na', 'COMMACATEGORY', 'Nd', 'Caa', 'Neu', 'Nf', 'Na', 'Na', 'D', 'V_2', 'Na', 'COMMACATEGORY', 'VE', 'Na', 'Na', 'VE', 'VC', 'Na', 'Nv', 'Na', 'Na', 'COMMACATEGORY', 'VE', 'VA', 'Na', 'Na', 'Na', 'Caa', 'A', 'Na', 'VJ', 'Na', 'Na', 'Na', 'VJ', 'Neqa', 'COMMACATEGORY', 'Nc', 'VF', 'Nb', 'Na', 'VC', 'VE', 'Na', 'COMMACATEGORY', 'Cbb', 'Cbb', 'Na', 'Ng', 'VH', 'DE', 'Na', 'COMMACATEGORY', 'Da', 'VL', 'Na', 'Na', 'PERIODCATEGORY', 'Nb', 'D', 'VE', 'COMMACATEGORY', 'Na', 'P', 'VH', 'Nd', 'D', 'Ncd', 'VH', 'COMMACATEGORY', 'P', 'VH', 'Na', 'D', 'VC', 'DE', 'Na', 'Na', 'COMMACATEGORY', 'D', 'V_2', 'VC', 'VE', 'PERIODCATEGORY', 'Na', 'Nv', 'Nc', 'Na', 'Nc', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Nd', 'VH', 'Na', 'SHI', 'P', 'Na', 'VC', 'Na', 'PAUSECATEGORY', 'VHC', 'Na', 'Na', 'SEMICOLONCATEGORY', 'Nb', 'D', 'VF', 'VD', 'VE', 'Na', 'PERIODCATEGORY', 'Nb', 'VE', 'COMMACATEGORY', 'Na', 'Ng', 'Na', 'VH', 'VE', 'COMMACATEGORY', 'Nd', 'DE', 'Na', 'Na', 'VH', 'PAUSECATEGORY', 'Na', 'Na', 'V_2', 'VC', 'Na', 'VF', 'COMMACATEGORY', 'VH',  ...
# ['印度', '電力部長', '卡塔爾', '表示', '，', '印度', '正', '積極', '準備', '在', '2026年', '底', '前', '推出', '備受', '期待', '的', '碳', '市場', '。', '這', '項', '政策', '預計', '發揮', '重要', '作用', '，', '在', '協助', '產業', '綠色', '轉型', '的', '同時', '，', '確保', '符合', '國際', '碳', '規範', '。', '碳', '產業', '新聞', '網站', 'Carbon Herald', '報導', '，', '卡塔爾', '（', 'Manohar', ' ', 'Lal', ' ', 'Khattar', '）', '2月', '底', '談及', '此事', '時', '說', '：', '「', '我國', '很', '快', '就', '會', '推出', '獨立', '的', '碳', '市場', '…', '預計', '2026年', '中', '推出', '。', '」', '「', '根據', '這', '項', '計畫', '，', '使用', '化石', '燃料', '或', '排', '碳者', '必須', '購買', '碳信用', '額度', '，', '反之', '使用', '非', '化石', '燃料', '能源', '的', '人', '，', '將', '取得', '可', '在', '碳', '市場', '出售', '的', '碳', '信用', '額度', '。', '目前', '印度', '尚未', '建立', '的', '碳', '交易', '市場', '將', '於', '2026年', '啟動', '」', '。', '碳', '市場', '對於', '印度', '出口商', '尤為', '重要', '，', '因為', '他們', '必須', '符合', '全球', '碳', '排', '規範', '來', '維持', '競', '爭力', '。', '卡', '塔爾', '強調', '，', '符合', '國際', '碳', '規範', '對', '企業', '來說', '非常', '重要', '，', '「', '尤其', '是', '要', '外銷到', '環保', '嚴格', '市場', '的', '業者', '」', '。', '由於', '歐', '盟', '的', '碳', '邊境', '調整', '機制', '（', 'CBAM', '）', '對', '碳', '密集', '進口', '商品', '徵收', '碳稅', '，', '鋼鐵', '和', '水泥', '等', '產業', '都', '對', '此', '表示', '擔憂', '。', '引入', '碳', '信用', '額度', '將', '激勵', '印度', '製造商', '採用', '綠色', '能源', '方案', '，', '以', '減少', '碳排並', '確保更', '符合', '歐盟', '法規。', '印度', '碳', '市場', '的', '基礎', '於', '2022年', '奠定', '，', '當年', '通過', '的', '「', '節能', '修正法', '」', '（', 'E', 'nergy', ' ', 'Conservation ', '(', 'A', 'mendment)', ' Bill', '）', '為', '碳', '交易制度', '鋪路', '，', '讓', '企業', '能', '買賣', '碳', '信用', '額度', '，', '並', '透過', '財務', '獎勵', '促進', '永續', '發展', '，', '鼓勵', '企業', '減排', '。']
# ['Nc', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'Nc', 'D', 'VH', 'VC', 'P', 'Neu', 'Ng', 'Ng', 'VC', 'VJ', 'VK', 'DE', 'Na', 'Nc', 'PERIODCATEGORY', 'Nep', 'Nf', 'Na', 'VE', 'VJ', 'VH', 'Na', 'COMMACATEGORY', 'P', 'VC', 'Na', 'Na', 'VH', 'DE', 'Nd', 'COMMACATEGORY', 'VE', 'VJ', 'Nc', 'Na', 'Na', 'PERIODCATEGORY', 'Na', 'Na', 'Na', 'Nc', 'FW', 'VE', 'COMMACATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'WHITESPACE', 'FW', 'WHITESPACE', 'FW', 'PARENTHESISCATEGORY', 'Nd', 'Ng', 'VE', 'Nep', 'Ng', 'VE', 'COLONCATEGORY', 'PARENTHESISCATEGORY', 'Nc', 'Dfa', 'VH', 'D', 'D', 'VC', 'VH', 'DE', 'Na', 'Nc', 'FW', 'VE', 'Neu', 'Ng', 'VC', 'PERIODCATEGORY', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'P', 'Nep', 'Nf', 'Na', 'COMMACATEGORY', 'VC', 'Na', 'Na', 'Caa', 'VC', 'Na', 'D', 'VC', 'Na', 'Na', 'COMMACATEGORY', 'Dk', 'VC', 'Na', 'Na', 'Na', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'D', 'VC', 'D', 'P', 'Na', 'Nc', 'VC', 'DE', 'Na', 'Na', 'Na', 'PERIODCATEGORY', 'Nd', 'Nc', 'D', 'VC', 'DE', 'Na', 'Na', 'Nc', 'D', 'P', 'Neu', 'VC', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Na', 'Nc', 'P', 'Nc', 'Na', 'D', 'VH', 'COMMACATEGORY', 'Cbb', 'Nh', 'D', 'VJ', 'Nc', 'Na', 'Na', 'Na', 'D', 'VJ', 'Na', 'VA', 'PERIODCATEGORY', 'Nb', 'Nb', 'VE', 'COMMACATEGORY', 'VJ', 'Nc', 'Na', 'Na', 'P', 'Na', 'Ng', 'Dfa', 'VH', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'D', 'SHI', 'D', 'VCL', 'Na', 'VH', 'Nc', 'DE', 'Na', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Cbb', 'Nb', 'Na', 'DE', 'Nc', 'Nc', 'VC', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'P', 'Na', 'VH', 'VC', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'Na', 'Caa', 'Na', 'Cab', 'Na', 'D', 'P', 'Nep', 'VE', 'VK', 'PERIODCATEGORY', 'VC', 'Na', 'Na', 'Na', 'D', 'VC', 'Nc', 'Na', 'VC', 'Na', 'Na', 'Na', 'COMMACATEGORY', 'P', 'VHC', 'Na', 'VE', 'VJ', 'Nb', 'Na', 'Nc', 'Na', 'Nc', 'DE', 'Na', 'P', 'Neu', 'VC', 'COMMACATEGORY', 'Nd', 'P', 'DE', 'PARENTHESISCATEGORY', 'VH', 'VC', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'FW', 'FW', 'WHITESPACE', 'FW', 'PARENTHESISCATEGORY', 'FW', 'FW', 'FW', 'PARENTHESISCATEGORY', 'P', 'Na', 'Na', 'VA', 'COMMACATEGORY', 'VL', 'Na', 'D', 'VC', 'Na', 'Na', 'Na', 'COMMACATEGORY', 'Cbb', 'P', 'Na', 'VC', 'VK', 'VH', 'VC', 'COMMACATEGORY', 'VF', 'Na', 'VA', 'PERIODCATEGORY']
# ['2025年', '世界', '行動', '通訊', '大會', '（', 'MWC', '）', '今天', '起', '在', '西班牙', '巴塞隆納', '登場', '，', '吸引', '全球', '科技業', '目光', '，', '代工廠', '廣達', '子公司', '雲達', '科技', '、', '板卡廠技', '嘉都', '親自', '與會', '，', '展示', '人工', '智慧', '（', 'AI', '）', '、', '邊緣', '運算', '及', '機器人', '等', '最', '新', '技術', '。', '雲達', '發布', '新聞稿', '說明', '，', '在', '今年', 'MWC', '大會', '上', '，', '將', '展示', '與', 'Red Hat', '、', 'Samsung', ' Electronics', ' Co., Ltd.', '、', 'Solomon', '、', '新加坡', '科技', '設計', '大學', '、', '台灣', '大哥大', '、', '達明', '機器人', '、', 'Viavi', '、', 'Vossic', '、', 'Wind River', '等', '廠商', '和', '開放', '社群', '的', '最', '新合作', '成果', '。', '雲達', '也', '將', '展示', '最', '新取得', '認證', '的', '邊緣伺服器', '、', 'OmniPOD端', '到', '端', '5G', '企業', '專網', '解決', '方案', '，', '以及', '與', '夥伴', '的', '多', '項', '合作', '，', '包括', '人工', '智慧/', '機器', '學習', '（', 'A', 'I/ML', '）', '節能', '模型', '、', '數位', '孿生', '模擬', '、', '遠距', '人工', '智慧物', '聯網', '（', 'AIoT', '）', '、', '自動化', '機器人', '、', '智慧', '校園', '等', '。', '雲達', '科技', '總經理', '楊麒令', '表示', '，', '藉由', '與', '生態系統', '合作', '夥伴', '密切', '合作', '，', '雲達', '能夠', '創新', '並', '提供', '推動', '產業', '前進', '的', '尖', '端', '解決', '方案', '。', '透過', '在', 'AI', '、', '邊緣', '運算', '和', '機器人', '技術', '方面', '的', '最', '新', '努力', '，', '可以', '確保', '能夠', '滿足', '客戶', '不斷', '變化', '的', '需求', '。', '技嘉將', '在', 'MWC 2025', '展示', '從', 'A', 'I', '開發到', '部署', '的', '運算解決', '方案', '，', '呼應', '大會', '「', '企業', '再創', '」', '及', '「', 'A', 'I', '加乘', '」', '主題', '。', '技嘉', '的', 'AI', '開發', '解決', '方案', '包括新世代', 'G893 AI', '伺服器', '，', '可', '支援', 'NVID', 'IA B200', '、', 'AMD MI325X', '、', 'Intel', ' Gaudi-3', '等', '繪圖', '處理器', '（', 'GPU', '）', '；', '另', '將', '展示', '叢集式', '運算', '產品', 'GIGAPOD', '，', '提供', '一站式', 'AI', '訓練', '解決', '方案', '。', '針對', 'AI', '部署', '方案', '，', '技嘉', '將', '展出', 'R', '系列', '伺服器', '，', '採用', 'CXL', '記憶體', '互連', '技術', '，', '可', '降低', '傳輸', '延遲', '與', '布建成本', '；', '另', '將', '首度', '公開', '3', 'U刀鋒式', '終端', '伺服器', '，', '提供', '高密度', '運算', '架構', '。']
# ['Nd', 'Nc', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Nd', 'VC', 'P', 'Nc', 'Nc', 'VA', 'COMMACATEGORY', 'VJ', 'Nc', 'Na', 'Na', 'COMMACATEGORY', 'Nc', 'Nb', 'Nc', 'Nb', 'Na', 'PAUSECATEGORY', 'Na', 'Nc', 'D', 'VA', 'COMMACATEGORY', 'VC', 'Na', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'Nc', 'VC', 'Caa', 'Na', 'Cab', 'Dfa', 'VH', 'Na', 'PERIODCATEGORY', 'Nb', 'VC', 'Na', 'VE', 'COMMACATEGORY', 'P', 'Nd', 'FW', 'Na', 'Ng', 'COMMACATEGORY', 'P', 'VC', 'Caa', 'FW', 'PAUSECATEGORY', 'FW', 'FW', 'FW', 'PAUSECATEGORY', 'FW', 'PAUSECATEGORY', 'Nc', 'Na', 'Na', 'Na', 'PAUSECATEGORY', 'Nc', 'Na', 'PAUSECATEGORY', 'Nb', 'Na', 'PAUSECATEGORY', 'FW', 'PAUSECATEGORY', 'FW', 'PAUSECATEGORY', 'FW', 'Cab', 'Na', 'Caa', 'VC', 'Na', 'DE', 'Dfa', 'VH', 'Na', 'PERIODCATEGORY', 'Nb', 'D', 'D', 'VC', 'Dfa', 'D', 'VA', 'DE', 'Nc', 'PAUSECATEGORY', 'FW', 'P', 'Ncd', 'FW', 'Na', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'Caa', 'P', 'Na', 'DE', 'Neqa', 'Nf', 'Nv', 'COMMACATEGORY', 'VK', 'Na', 'Na', 'Na', 'VC', 'PARENTHESISCATEGORY', 'FW', 'FW', 'PARENTHESISCATEGORY', 'VH', 'Na', 'PAUSECATEGORY', 'A', 'A', 'VC', 'PAUSECATEGORY', 'A', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'VHC', 'Na', 'PAUSECATEGORY', 'Na', 'Nc', 'Cab', 'PERIODCATEGORY', 'Nb', 'Na', 'Na', 'Nb', 'VE', 'COMMACATEGORY', 'P', 'P', 'Na', 'VH', 'Na', 'VH', 'VH', 'COMMACATEGORY', 'Nb', 'D', 'VC', 'Cbb', 'VD', 'VC', 'Na', 'VA', 'DE', 'A', 'VC', 'VC', 'Na', 'PERIODCATEGORY', 'P', 'P', 'FW', 'PAUSECATEGORY', 'Nc', 'VC', 'Caa', 'Na', 'Na', 'Na', 'DE', 'Dfa', 'VH', 'Nv', 'COMMACATEGORY', 'D', 'VE', 'D', 'VHC', 'Na', 'D', 'VHC', 'DE', 'Na', 'PERIODCATEGORY', 'Nb', 'P', 'FW', 'VC', 'P', 'FW', 'FW', 'VC', 'VC', 'DE', 'VC', 'Na', 'COMMACATEGORY', 'VC', 'Na', 'PARENTHESISCATEGORY', 'Na', 'D', 'PARENTHESISCATEGORY', 'Caa', 'PARENTHESISCATEGORY', 'FW', 'FW', 'VC', 'PARENTHESISCATEGORY', 'Na', 'PERIODCATEGORY', 'Nb', 'DE', 'FW', 'VC', 'VC', 'Na', 'VK', 'FW', 'Na', 'COMMACATEGORY', 'D', 'VC', 'FW', 'FW', 'PAUSECATEGORY', 'FW', 'PAUSECATEGORY', 'FW', 'FW', 'Cab', 'VA', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'SEMICOLONCATEGORY', 'Cbb', 'D', 'VC', 'A', 'VC', 'Na', 'FW', 'COMMACATEGORY', 'VD', 'A', 'FW', 'Na', 'VC', 'Na', 'PERIODCATEGORY', 'P', 'FW', 'VC', 'Na', 'COMMACATEGORY', 'Nb', 'D', 'VC', 'FW', 'Na', 'Na', 'COMMACATEGORY', 'VC', 'FW', 'Na', 'D', 'Na', 'COMMACATEGORY', 'D', 'VHC', 'VC', 'VHC', 'Caa', 'Na', 'SEMICOLONCATEGORY', 'Cbb', 'D', 'D', 'VHC', 'Neu', 'Nf', 'Nc', 'Na', 'COMMACATEGORY', 'VD', 'VH', 'Nv', 'Na', 'PERIODCATEGORY']
# ['歐洲', '新', '的', '重型', '載運', '火箭', '「', '阿利安6型', '」', '預計', '今天', '執行', '首', '趟', '商業', '飛行', '任務', '。', '在', '美國', '與', '俄羅斯', '關係', '出乎', '預料', '破冰', '之', '際', '，', '歐洲', '國家', '試圖', '確保', '自己', '有', '能力', '獨力', '進入', '太空', '。', '法新社', '報導', '，', '「', '阿利安', '6型', '」', '（', 'Ariane 6', '）', '經過', '數', '次', '延宕', '後', '，', '將', '於', '當地', '時間', '今天', '下午', '1時', '24分', '（', '台灣', '時間', '4日', '凌晨', '0時', '24分', '）', '從', '法屬', '圭亞那', '的', '庫魯', '（', 'Kourou', '）', '發射場', '發射', '升空', '。', '這', '將', '是', '「', '阿利安', '6型', '」', '自', '去年', '7月', '首次', '試射', '以來', '，', '第2', '次', '升空', '。', '「', '阿利安6型', '」', '將', '載運', '法國', '軍用', '衛星', 'CSO-3', '，', '預計', '將', '該', '顆', '衛星', '放', '置離', '地表', '約', '800', '公里', '高', '的', '軌道', '上', '。', 'CSO-3', '有望', '提', '升', '法國', '的', '軍事', '自主', '程度', '及', '強化', '法軍', '的', '情蒐', '能力', '。', '法國', '執行', '這', '項', '引人注目', '的', '太空', '任務', '之', '際', '，', '法國', '總統', '馬', '克宏', '（', 'E', 'mmanuel', ' Macron', '）', '正', '呼籲', '歐洲', '降低', '對', '美國', '的', '安全', '依賴', '；', '歐洲', '太空產業', '面對', '美國', '億萬富豪', '馬斯克', '（', 'Elon Musk', '）', '旗下', '太空', '探索', '科技', '公司', '（', 'SpaceX', '）', '時', '，', '也', '正', '努力', '維持', '競爭力', '。', 'CSO-3', '將', '完成', '由', '法國', '3顆', '軍用', '衛星', '組成', '的', '偵察', '網絡', '；', '前', '2顆', '衛星', '分別', '在', '2018年', '和', '2020年', '由', '俄羅斯聯合號', '（', 'Soyuz', '）', '火箭', '載運', '升空', '。', '不過', '，', '自', '2022年', '俄羅斯', '入侵', '烏克蘭', '後', '，', '歐洲', '一直', '未', '能', '使用', '聯合號', '火箭', '執行', '衛星', '發射任務', '，', '而', '「', '阿利安6型', '」', '的', '前身', '、', '「', '阿利安5型」', '（', 'Ariane 5）', '已', '在', '2023年', '退役', '。']
# ['Nc', 'VH', 'DE', 'Na', 'VC', 'Na', 'PARENTHESISCATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'VE', 'Nd', 'VC', 'Nes', 'Nf', 'Na', 'Nv', 'Na', 'PERIODCATEGORY', 'P', 'Nc', 'Caa', 'Nc', 'Na', 'VJ', 'VE', 'VH', 'DE', 'Nd', 'COMMACATEGORY', 'Nc', 'Na', 'VF', 'VE', 'Nh', 'V_2', 'Na', 'D', 'VCL', 'Na', 'PERIODCATEGORY', 'Nc', 'VE', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'Nb', 'Neu', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VCL', 'Neu', 'Nf', 'VH', 'Ng', 'COMMACATEGORY', 'D', 'P', 'Nc', 'Na', 'Nd', 'Nd', 'Neu', 'Nd', 'PARENTHESISCATEGORY', 'Nc', 'Na', 'Nd', 'Nd', 'Nd', 'Nd', 'PARENTHESISCATEGORY', 'P', 'A', 'Nb', 'DE', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Nc', 'VC', 'VA', 'PERIODCATEGORY', 'Nep', 'D', 'SHI', 'PARENTHESISCATEGORY', 'Nb', 'Neu', 'PARENTHESISCATEGORY', 'P', 'Nd', 'Nd', 'Nes', 'VC', 'Ng', 'COMMACATEGORY', 'Neu', 'Nf', 'VA', 'PERIODCATEGORY', 'PARENTHESISCATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'D', 'VC', 'Nc', 'A', 'Na', 'FW', 'COMMACATEGORY', 'VE', 'P', 'Nes', 'Nf', 'Na', 'VC', 'VC', 'Nc', 'Da', 'Neu', 'Nf', 'VH', 'DE', 'Na', 'Ncd', 'PERIODCATEGORY', 'FW', 'VH', 'VC', 'VC', 'Nc', 'DE', 'Na', 'VH', 'Na', 'Caa', 'VHC', 'Na', 'DE', 'Nv', 'Na', 'PERIODCATEGORY', 'Nc', 'VC', 'Nep', 'Nf', 'VH', 'DE', 'Na', 'Na', 'DE', 'Nd', 'COMMACATEGORY', 'Nc', 'Na', 'Nb', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'FW', 'FW', 'PARENTHESISCATEGORY', 'D', 'VE', 'Nc', 'VHC', 'P', 'Nc', 'DE', 'VH', 'VK', 'SEMICOLONCATEGORY', 'Nc', 'Na', 'VC', 'Nc', 'Neu', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Na', 'Na', 'Nv', 'Na', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Ng', 'COMMACATEGORY', 'D', 'D', 'VH', 'VJ', 'Na', 'PERIODCATEGORY', 'FW', 'D', 'VC', 'P', 'Nc', 'Neu', 'A', 'Na', 'VG', 'DE', 'VC', 'Na', 'SEMICOLONCATEGORY', 'Nes', 'Neu', 'Na', 'D', 'P', 'Neu', 'Caa', 'Neu', 'P', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Na', 'VC', 'VA', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'P', 'Nd', 'Nc', 'VCL', 'Nc', 'Ng', 'COMMACATEGORY', 'Nc', 'D', 'D', 'D', 'VC', 'Na', 'Na', 'VC', 'Na', 'Nv', 'COMMACATEGORY', 'Cbb', 'PARENTHESISCATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'DE', 'Na', 'PAUSECATEGORY', 'PARENTHESISCATEGORY', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'D', 'P', 'Neu', 'VH', 'PERIODCATEGORY']
# ['美國', '太空', '探索', '科技', '公司', '（', 'SpaceX', '）', '的', '「', '星艦', '」', '（', 'Starship', '）', '火箭', '預計', '於', '德州', '時間', '今天', '下午', '5時30分', '（', '台灣', '時間', '4日', '早上', '7時', '30分', '）', '進行', '第8', '次', '試射', '，', '屆時', '將', '全', '程', '網路', '直播', '。', '法新社', '報導', '，', '星艦', '將', '於', '當地', '時間', '下午', '5時30分', '，', '在', 'SpaceX', '位於', '德州', '波卡契卡', '（', 'Boca', ' ', 'Chica', '）', '的', '私有', '太空港', '「', '星際', '基地', '」', '（', 'Starbase', '）', '發射', '。', '星艦', '上', '次', '發射', '後', '在', '加勒比海', '上空', '爆炸', '。', '高聳', '的', '星艦', '比', '93', '公尺', '高', '的', '自由', '女', '神像', '還要', '高', '約', '30', '公尺', '，', '目標', '是', '能夠', '完', '全重複', '使用', '。', '這', '款', '火箭', '在', 'SpaceX', '執行', '長馬斯克', '（', 'Elon', ' Musk', '）', '與', 'SpaceX', '的', '火星', '殖民', '願景', '中', '扮', '演', '關鍵', '角色', '。', '星艦', '今年', '1月', '16日', '進行', '第7', '度', '試射', '時', '，', '上', '節', '火箭', '在', '英屬', '土克凱可', '群島', '（', 'Turks', ' and Caicos', ' Islands', '）', '上空', '爆炸解體', '，', '隨即', '遭', '美國', '聯邦', '航空', '總署', '（', 'Federal Aviation', ' Administration', '，', 'FAA', '）', '下令', '停飛', '。', '不過', '，', 'FAA', '於', '2月28日', '表示', '，', '在', '該', '署', '完成', 'SpaceX', '「', '事故', '調查', '」', '之前', '，', '星艦', '可', '恢復', '飛行', '。', '事發後', 'SpaceX', '已', '針對', '上節', '火箭', '進行', '多', '項', '升級', '，', '以', '強化', '其', '可靠性', '並', '提升', '性能', '。', '最', '新', '的', '試射任務', '預計', '將', '持續', '約1', '小時', '，', '包括', '將', '再度', '使用', '發射塔', '的', '大型', '機器', '手臂', '「', '筷子', '」', '（', 'chopstick', '）', '接住', '助推器', '。', '包括', '上', '次', '試射', '在', '內', '，', 'Space', 'X', '過去', '一共', '2', '度', '成功', '執行', '這', '項', '功能', '。', '此外', '，', 'SpaceX', '還', '將', '部署', '模仿', '次', '世代', '星鏈', '（', 'Starlink', '）', '衛星', '的', '模擬器', '，', '模擬器', '在', '重新', '進入', '大氣層', '時', '會', '自行', '燒毀', '。', 'SpaceX', '的', '最終', '目標', '是', '回收', '上節', '火箭', '，', '但', '根據', '目前', '的', '計畫', '，', '上節', '火箭', '將', '在', '澳洲', '西部', '外海', '濺落', '，', '就', '和', '之前', '的', '試射', '行動', '一樣', '。', 'SpaceX', '實現', '太空', '探險', '目標', '之前', '，', '必須', '證明', '星艦', '具備', '飛行', '能力', '和', '適合', '載人', '任務', '的', '安全性', '，', '而且', '還', '必須', '展示', '複雜', '的', '太空', '加油', '技術', '，', '利用', '其他', '的', '星艦', '作', '為', '加油機', '，', '以', '達成', '長', '距離', '太空', '旅行', '的', '目標', '。']
# ['Nc', 'Na', 'VE', 'Na', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'DE', 'PARENTHESISCATEGORY', 'Na', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Na', 'VE', 'P', 'Nc', 'Na', 'Nd', 'Nd', 'Nd', 'PARENTHESISCATEGORY', 'Nc', 'Na', 'Nd', 'Nd', 'Neu', 'Neu', 'PARENTHESISCATEGORY', 'VC', 'Neu', 'Nf', 'VC', 'COMMACATEGORY', 'D', 'P', 'D', 'Na', 'Na', 'VC', 'PERIODCATEGORY', 'Nc', 'VE', 'COMMACATEGORY', 'Na', 'D', 'P', 'Nc', 'Na', 'Nd', 'Nd', 'COMMACATEGORY', 'P', 'FW', 'VCL', 'Nc', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'WHITESPACE', 'FW', 'PARENTHESISCATEGORY', 'DE', 'A', 'Nc', 'PARENTHESISCATEGORY', 'Nc', 'Nc', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VC', 'PERIODCATEGORY', 'Na', 'Nes', 'Nf', 'VC', 'Ng', 'P', 'Nc', 'Nc', 'VH', 'PERIODCATEGORY', 'VH', 'DE', 'Na', 'P', 'Neu', 'Nf', 'VH', 'DE', 'VH', 'Na', 'Na', 'Dfa', 'VH', 'Da', 'Neu', 'Nf', 'COMMACATEGORY', 'Na', 'SHI', 'D', 'D', 'Neqa', 'VC', 'PERIODCATEGORY', 'Nep', 'Nf', 'Na', 'P', 'FW', 'VC', 'VH', 'PARENTHESISCATEGORY', 'FW', 'FW', 'PARENTHESISCATEGORY', 'Caa', 'FW', 'DE', 'Nb', 'VA', 'Na', 'Ng', 'VC', 'VC', 'Na', 'Na', 'PERIODCATEGORY', 'Na', 'Nd', 'Nd', 'Nd', 'VC', 'Neu', 'Nf', 'VC', 'Ng', 'COMMACATEGORY', 'Nes', 'Nf', 'Na', 'P', 'A', 'Nb', 'Na', 'PARENTHESISCATEGORY', 'FW', 'FW', 'FW', 'PARENTHESISCATEGORY', 'Nc', 'Nv', 'COMMACATEGORY', 'D', 'P', 'Nc', 'Na', 'Na', 'Nc', 'PARENTHESISCATEGORY', 'FW', 'FW', 'COMMACATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VE', 'VA', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'FW', 'P', 'Nd', 'VE', 'COMMACATEGORY', 'P', 'Nes', 'Nc', 'VC', 'FW', 'PARENTHESISCATEGORY', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Ng', 'COMMACATEGORY', 'Na', 'D', 'VHC', 'VA', 'PERIODCATEGORY', 'VH', 'FW', 'D', 'P', 'Nes', 'Na', 'VC', 'Neqa', 'Nf', 'VH', 'COMMACATEGORY', 'Cbb', 'VHC', 'Nep', 'Na', 'Cbb', 'VC', 'Na', 'PERIODCATEGORY', 'Dfa', 'VH', 'DE', 'Nv', 'VE', 'D', 'VL', 'Da', 'Na', 'COMMACATEGORY', 'VK', 'D', 'D', 'VC', 'Na', 'DE', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'Na', 'PARENTHESISCATEGORY', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'VC', 'Na', 'PERIODCATEGORY', 'VK', 'Nes', 'Nf', 'VC', 'P', 'Ncd', 'COMMACATEGORY', 'FW', 'FW', 'Nd', 'Da', 'Neu', 'Nf', 'VH', 'VC', 'Nep', 'Nf', 'Na', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'FW', 'D', 'D', 'VC', 'VC', 'Nes', 'Na', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'Na', 'P', 'D', 'VCL', 'Nc', 'Ng', 'D', 'D', 'VC', 'PERIODCATEGORY', 'FW', 'DE', 'A', 'Na', 'SHI', 'VC', 'A', 'Na', 'COMMACATEGORY', 'Cbb', 'P', 'Nd', 'DE', 'Na', 'COMMACATEGORY', 'Ncd', 'Na', 'D', 'P', 'Nc', 'Ncd', 'Nc', 'VC', 'COMMACATEGORY', 'D', 'P', 'Nd', 'DE', 'Nv', 'Na', 'VH', 'PERIODCATEGORY', 'FW', 'VC', 'Na', 'VA', 'Na', 'Ng', 'COMMACATEGORY', 'D', 'VE', 'Na', 'VJ', 'Nv', 'Na', 'Caa', 'VH', 'VC', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'Cbb', 'D', 'D', 'VC', 'VH', 'DE', 'Na', 'VB', 'Na', 'COMMACATEGORY', 'VC', 'Neqa', 'DE', 'Na', 'VG', 'VG', 'Na', 'COMMACATEGORY', 'Cbb', 'VC', 'VH', 'P', 'Na', 'VA', 'DE', 'Na', 'PERIODCATEGORY']
# ['中職', '統一7-ELEVEn', '獅隊', '野手', '陳傑憲', '的', '前', '經紀', '公司', '躍樂', '3日', '發', '律師', '聲明', '，', '指', '前', '負責人', '及', '股東', '有', '帳務', '糾紛', '；', '陳傑憲', '隨後', '發', '聲明', '表示', '與', '躍樂合約', '已經', '到期', '，', '談約', '正常', '順利', '進行', '、', '沒有', '任何', '耽擱', '。', '躍樂', '運動', '行銷', '3日', '發出', '律師', '聲明', '表示', '，', '接手', '公司', '後', '發現', '前', '詹姓', '負責人', '和', '其', '丈夫', '蔡姓', '股東', '經營', '公司', '時期', '，', '有', '多', '筆', '不明', '金流', '。', '另外', '也', '提及', '，', '在', '詹姓', '負責人', '任職', '期間', '，', '有', '數', '筆', '帳目', '均', '無法', '核對', '，', '給付', '球員', '之', '相關', '費用', '與', '合約', '內容', '不符', '，', '認為', '詹姓', '負責人', '於', '任職', '期間', '恐', '已', '違反', '忠實', '義務', '，', '更', '有', '挪移', '、', '侵占', '公司', '資產', '之', '嫌', '，', '已', '委請', '律師', '協助', '後續法律', '程序', '。', '中華職', '棒球員工會', '也', '發布', '聲', '明', '啟動', '調查', '與', '協助', '，', '確保', '工會', '會員', '的', '權益', '不', '受', '影響', '，', '「', '將', '持續', '監督', '並', '釐清', '相關', '狀況', '，', '並', '與', '聯', '盟', '、', '各', '球團', '及', '相關', '單位', '保持', '溝通', '，', '維持', '市場', '環境', '穩定', '，', '以', '確保', '整體', '經紀', '市場', '能', '在', '符合業界', '需求', '的', '前提下', '，', '依循', '規範', '正常', '運作', '。', '」', '陳傑憲新', '合約', '受到', '矚目', '，', '先前', '獅隊', '透露', '已', '開出', '合約', '總', '值', '超過', '新台幣', '1.6億元', '的', '合約', '，', '就', '等', '陳傑憲', '回覆', '，', '外界', '關心', '陳傑憲', '談約', '是否', '會', '受', '經紀', '公司', '影響', '，', '獅隊', '領隊', '蘇泰安', '回覆', '，', '陳傑憲', '有表達繼續', '委由', '原本', '的', '蔡姓', '經紀人', '洽談', '合約', '。', '陳傑憲也', '在', '個人社群', '發出', '聲明', '，', '澄清與', '躍樂', '的', '經紀', '約', '在', '去年', '1', '2月3', '1日', '到期', '，', '目前', '不隸屬於躍樂，', '並', '提及', '與', '經紀人Lio', '以及', '團隊', '多', '年', '來', '一直', '都', '是', '相當', '順利', '，', '也', '相當', '信任', '，', '「', '未來', '也', '再', '麻煩', '他們', '多多', '照顧', '」', '，', '另外', '也', '表示', '，', '「', '合約', '一直', '都', '正常', '順利', '的', '進行', '中', '，', '並', '無', '任何', '耽擱', '！', '有', '任何', '進展', '會', '向', '大家', '報告', '！', '」']
# ['Nc', 'Nb', 'Na', 'Na', 'Nb', 'DE', 'Nes', 'A', 'Nc', 'Nv', 'Nd', 'VD', 'Na', 'Na', 'COMMACATEGORY', 'VG', 'Ncd', 'Na', 'Caa', 'Na', 'V_2', 'Na', 'Na', 'SEMICOLONCATEGORY', 'Nb', 'Nd', 'VJ', 'Na', 'VE', 'Caa', 'VA', 'D', 'VH', 'COMMACATEGORY', 'VE', 'VH', 'VH', 'VC', 'PAUSECATEGORY', 'VJ', 'Neqa', 'VC', 'PERIODCATEGORY', 'VA', 'Na', 'Na', 'Nd', 'VC', 'Na', 'Na', 'VE', 'COMMACATEGORY', 'VC', 'Nc', 'Ng', 'VE', 'Nes', 'Nb', 'Na', 'Caa', 'Nep', 'Na', 'Nb', 'Na', 'VC', 'Nc', 'Na', 'COMMACATEGORY', 'V_2', 'Neqa', 'Nf', 'VH', 'Na', 'PERIODCATEGORY', 'Cbb', 'D', 'VE', 'COMMACATEGORY', 'P', 'Nb', 'Na', 'VG', 'Na', 'COMMACATEGORY', 'V_2', 'Neu', 'Nf', 'Na', 'D', 'D', 'VC', 'COMMACATEGORY', 'VD', 'Na', 'DE', 'VH', 'Na', 'Caa', 'Na', 'Na', 'VJ', 'COMMACATEGORY', 'VE', 'Nb', 'Na', 'P', 'VG', 'Na', 'VK', 'D', 'VJ', 'VH', 'Na', 'COMMACATEGORY', 'Dfa', 'V_2', 'VC', 'PAUSECATEGORY', 'VC', 'Nc', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'D', 'VF', 'Na', 'VC', 'A', 'Na', 'PERIODCATEGORY', 'Nc', 'Nc', 'D', 'VC', 'Na', 'VE', 'VC', 'VE', 'Caa', 'VC', 'COMMACATEGORY', 'VE', 'Nc', 'Na', 'DE', 'Na', 'D', 'P', 'VC', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'D', 'VL', 'VC', 'Cbb', 'VC', 'VH', 'Na', 'COMMACATEGORY', 'Cbb', 'P', 'Na', 'Na', 'PAUSECATEGORY', 'Nes', 'Na', 'Caa', 'VH', 'Na', 'VJ', 'VC', 'COMMACATEGORY', 'VJ', 'Nc', 'Na', 'VHC', 'COMMACATEGORY', 'Cbb', 'VE', 'Na', 'A', 'Nc', 'D', 'P', 'VJ', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'VJ', 'Na', 'VH', 'VA', 'PERIODCATEGORY', 'PARENTHESISCATEGORY', 'Nb', 'Na', 'VJ', 'VB', 'COMMACATEGORY', 'Nd', 'Nb', 'VE', 'D', 'VC', 'Na', 'Na', 'Na', 'VJ', 'Na', 'Neu', 'DE', 'Na', 'COMMACATEGORY', 'D', 'VC', 'Nb', 'VD', 'COMMACATEGORY', 'Ncd', 'VK', 'Nb', 'VE', 'D', 'D', 'P', 'A', 'Nc', 'VC', 'COMMACATEGORY', 'Nb', 'Na', 'Nb', 'VD', 'COMMACATEGORY', 'Nb', 'V_2', 'VF', 'A', 'DE', 'Nb', 'Na', 'VE', 'Na', 'PERIODCATEGORY', 'Nb', 'P', 'Nh', 'VC', 'Na', 'COMMACATEGORY', 'VE', 'VA', 'DE', 'Na', 'Da', 'P', 'Nd', 'Nd', 'Nd', 'Nd', 'VH', 'COMMACATEGORY', 'Nd', 'D', 'Cbb', 'VE', 'P', 'Na', 'Caa', 'Na', 'Neqa', 'Nf', 'Ng', 'D', 'D', 'SHI', 'Dfa', 'VH', 'COMMACATEGORY', 'D', 'Dfa', 'VJ', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'Nd', 'D', 'D', 'VHC', 'Nh', 'D', 'VC', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Cbb', 'D', 'VE', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'Na', 'D', 'D', 'VH', 'VH', 'DE', 'VC', 'Ng', 'COMMACATEGORY', 'D', 'VJ', 'Neqa', 'VC', 'EXCLAMATIONCATEGORY', 'V_2', 'Neqa', 'Na', 'D', 'P', 'Nh', 'VE', 'EXCLAMATIONCATEGORY', 'PARENTHESISCATEGORY']
# ['台灣', '極', '地', '超馬', '運動員', '陳彥博', '征戰', '北極圈', '617', '公里', '不', '休息', '長征賽', '，', '目前', '完成', '接近', '一半', '賽程', '，', '卻', '出現', '雙腳', '水泡', '導致', '發炎', '狀況', '，', '但', '他', '仍', '堅持', '比賽', '，', '期望', '平安', '完賽', '。', '在', '加拿大', '舉行', '的', '北極圈', '617', '公里', '不', '休息', '長征賽', '，', '以', '極', '端', '環境', '與', '嚴苛', '挑戰', '著稱', '，', '參賽', '者', '除了', '須', '9', '天', '內', '徒步', '完成', '不', '間斷', '的', '長征', '，', '而且', '全', '程', '自給自足', '，', '並', '在', '平均', '攝氏', '零下', '30', '度', '的', '嚴寒', '中', '，', '橫越', '冰雪', '覆蓋', '的', '荒野', '，', '導致', '完', '賽', '率', '僅', '30%', '，', '至今', '尚', '未', '有', '亞洲', '選手', '成功', '完賽', '。', '身為', '今年', '唯一', '參賽', '的', '亞洲', '選手', '，', '現年', '38', '歲', '的', '陳彥博', '啟程', '赴', '加拿大', '前', '做足準備', '，', '包含', '從', '台北', '到', '高雄', '拉', '著', '雪橇', '的', '模擬體', '能', '訓練', '、', '寒', '流', '襲', '捲', '時', '到', '陽明山', '進行', '低溫', '訓練', '等', '，', '展現', '面對', '極', '地', '挑戰', '的', '決心', '與', '毅力', '，', '並', '希望', '以', '行動', '激勵', '更', '多', '人', '勇敢', '追', '夢', '，', '「', '當', '你', '全', '心全意', '投入', '時', '，', '夢想', '也', '會', '向', '你', '靠近', '。', '」', '陳彥', '博', '從', '開賽', '即', '始終', '保持', '在', '領先', '群位置', '，', '目前', '已', '經通過', '第4', '檢查站', '，', '完成', '接近', '一半', '的', '賽程', '，', '總', '排名', '則', '暫居', '第3', '名', '，', '落後', '給', '英國', '選手', '貝爾奇爾', '（', 'Guy Belchier', '）', '、', '澳洲', '選手', '庫克斯', '（', 'Aaron Crook', '）', '。', '然而', '，', '在', '連續', '低溫', '及', '長', '距離', '移動', '下', '，', '陳彥博', '的', '雙腳', '因為', '水泡', '產生', '發炎', '與', '灼熱感', '，', '經', '醫療', '人員', '診斷', '可能', '是', '感染', '所', '致', '，', '但', '他', '仍', '選擇', '堅持比賽', '，', '在', '檢查站', '短暫', '休息', '2', '小時', '，', '並', '自行', '處理', '傷口', '確保', '不', '會', '惡化', '。', '他', '說', '，', '「', '現在', '只', '想', '平安完賽', '，', '不', '想', '再', '衝', '太', '快', '，', '沿途', '我', '會', '一直', '換', '襪子', '，', '確保', '腳', '的', '乾燥', '。', '」']
# ['Nc', 'Nc', 'DE', 'Nb', 'Na', 'Nb', 'VC', 'Nc', 'Neu', 'Nf', 'D', 'VA', 'Na', 'COMMACATEGORY', 'Nd', 'VC', 'VC', 'Neqa', 'Na', 'COMMACATEGORY', 'D', 'VH', 'Na', 'Na', 'VL', 'VH', 'Na', 'COMMACATEGORY', 'Cbb', 'Nh', 'D', 'VK', 'VA', 'COMMACATEGORY', 'VK', 'VH', 'VH', 'PERIODCATEGORY', 'P', 'Nc', 'VC', 'DE', 'Nc', 'Neu', 'Nf', 'D', 'VA', 'Na', 'COMMACATEGORY', 'P', 'VH', 'VH', 'Na', 'Caa', 'VH', 'VC', 'VI', 'COMMACATEGORY', 'VA', 'Na', 'P', 'D', 'Neu', 'Nf', 'Ng', 'VA', 'VC', 'D', 'VHC', 'DE', 'VCL', 'COMMACATEGORY', 'Cbb', 'D', 'Na', 'VH', 'COMMACATEGORY', 'Cbb', 'P', 'VH', 'Na', 'A', 'Neu', 'Nf', 'DE', 'VH', 'Ng', 'COMMACATEGORY', 'VCL', 'Na', 'VC', 'DE', 'Nc', 'COMMACATEGORY', 'VL', 'VH', 'Na', 'Na', 'Da', 'Neqa', 'COMMACATEGORY', 'D', 'D', 'D', 'V_2', 'Nc', 'Na', 'VH', 'VH', 'PERIODCATEGORY', 'VG', 'Nd', 'A', 'VA', 'DE', 'Nc', 'Na', 'COMMACATEGORY', 'VJ', 'Neu', 'Nf', 'DE', 'Nb', 'VA', 'VCL', 'Nc', 'Ncd', 'VC', 'COMMACATEGORY', 'VJ', 'P', 'Nc', 'P', 'Nc', 'VC', 'Di', 'Na', 'DE', 'Nv', 'D', 'Na', 'PAUSECATEGORY', 'Na', 'Na', 'VCL', 'VCL', 'Ng', 'VCL', 'Nc', 'VC', 'VH', 'Na', 'Cab', 'COMMACATEGORY', 'VC', 'VC', 'Na', 'DE', 'Na', 'DE', 'Na', 'Caa', 'Na', 'COMMACATEGORY', 'Cbb', 'VK', 'P', 'Na', 'VC', 'Neqa', 'VH', 'Na', 'VH', 'VC', 'Na', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'P', 'Nh', 'D', 'Na', 'VC', 'Ng', 'COMMACATEGORY', 'Na', 'D', 'D', 'P', 'Nh', 'VC', 'PERIODCATEGORY', 'PARENTHESISCATEGORY', 'Nb', 'Dfa', 'P', 'VH', 'D', 'D', 'VJ', 'P', 'VJ', 'Na', 'COMMACATEGORY', 'Nd', 'D', 'P', 'Neu', 'Nc', 'COMMACATEGORY', 'VC', 'VC', 'Neqa', 'DE', 'Na', 'COMMACATEGORY', 'Na', 'Na', 'D', 'VJ', 'Neu', 'Nf', 'COMMACATEGORY', 'VJ', 'P', 'Nc', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'Nc', 'Na', 'Nb', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Cbb', 'COMMACATEGORY', 'P', 'D', 'Na', 'Caa', 'VH', 'Na', 'VAC', 'Ng', 'COMMACATEGORY', 'Nb', 'DE', 'Na', 'Cbb', 'Na', 'VHC', 'VH', 'Caa', 'Na', 'COMMACATEGORY', 'P', 'VC', 'Na', 'VC', 'D', 'SHI', 'VJ', 'VH', 'VL', 'COMMACATEGORY', 'Cbb', 'Nh', 'D', 'VC', 'VK', 'COMMACATEGORY', 'P', 'Nc', 'VH', 'VA', 'Neu', 'Na', 'COMMACATEGORY', 'Cbb', 'D', 'VC', 'Na', 'VE', 'D', 'D', 'VH', 'PERIODCATEGORY', 'Nh', 'VE', 'COMMACATEGORY', 'PARENTHESISCATEGORY', 'Nd', 'Da', 'VJ', 'VH', 'COMMACATEGORY', 'D', 'VE', 'D', 'VJ', 'Dfa', 'VH', 'COMMACATEGORY', 'Nc', 'Nh', 'D', 'D', 'VC', 'Na', 'COMMACATEGORY', 'VE', 'Na', 'DE', 'VH', 'PERIODCATEGORY', 'PARENTHESISCATEGORY']
# ['中職', '中信', '兄弟', '近', '4', '年', '奪', '3', '座', '總冠軍', '，', '球團', '今天', '公布', '球員', '調薪', '結果', '，', '整體', '薪資', '調幅', '超過', '11.4%', '，', '許基宏', '簽下', '5', '年', '平均', '月薪', '新台幣', '80萬', '元', '合約', '，', '野手', '王威晨', '、', '投手', '李振昌', '獲', '複數', '年約', '。', '兄弟', '今天', '發布', '新聞稿', '公布', '新球季', '球員', '談薪', '結果', '，', '2025年', '球', '季', '全', '隊', '薪資', '微幅', '調整', '超過', '11.4%', '。', '中信', '兄弟', '球團', '感謝', '球員', '們', '為', '球隊', '的', '付出', '，', '也', '期盼', '今年', '能夠', '一起', '邁向', '「', '連霸', '」', '之', '路', '，', '共同', '「', '進化', '」', '。', '兄弟', '野手', '許基宏', '於', '2014年', '季中', '加入', '團隊', '，', '在', '去年', '球季', '結束', '後', '，', '積極', '與', '球團', '討論', '留隊', '的', '規劃', '，', '兄弟', '球團', '與', '許基宏', '達成', '5', '年', '平均', '月薪', '80萬', '元', '的', '合約', '共識', '，', '今年', '月薪', '也', '由', '5', '2萬', '元', '調升至', '64萬', '元', '、', '調幅', '23.1%', '，', '期待', '許基宏', '在', '接下來', '的', '5年', '持續', '披上', '黃', '衫', '，', '為', '中信', '兄弟', '努力', '奮戰', '。', '兼', '俱', '領導', '能力', '的', '野手', '王威晨', '與', '投手', '李振昌', '，', '今年', '皆', '與', '球團', '簽訂', '複數年合約', '，', '王威晨', '今年', '月薪', '77萬元', '，', '李振昌', '則', '是', '月薪', '63萬', '元', '，', '期待', '兩', '人', '持續', '用', '表現', '帶領', '團隊', '，', '也', '為', '球隊', '帶給', '學弟', '們', '更多', '正面', '影響力', '。', '2019年', '季中', '選秀', '加入', '兄弟', '的', '曾頌恩', '，', '2024年', '迎來', '個人', '生涯', '年，', '在', '攻守', '兩端', '都', '呈現破繭', '而出', '的', '佳績', '，', '更', '一舉', '拿下', '總冠軍賽', 'MVP', '的', '殊榮', '，', '入圍', '「', '年度', '最', '佳', '進步', '獎」', '。', '兄弟', '球團', '公布，', '曾頌恩', '今年', '月薪', '也', '由', '1', '3萬元', '調升至', '24萬元', '、', '調幅', '84.6%', '，', '期待', '曾頌恩', '能夠', '繼續', '以高水準', '的', '表現', '再創生涯', '高峰', '，', '迎接', '未來', '每', '場', '艱難', '戰役', '。', '近年', '兄弟', '後援防線', '最', '倚重', '的', '兩', '名', '投手', '呂彥青', '與', '吳俊偉', '，', '在', '今年', '也', '雙雙', '獲得加薪', '。', '呂彥青', '今年', '月薪', '由', '50萬', '元', '調升', '至', '62萬', '元', '、', '調幅', '24%', '；', '吳俊偉', '則', '是', '由', '月薪', '38萬', '元', '調升至', '50萬', '元', '、', '調幅', '31.6%', '。', '其他', '調薪', '部分', '，', '野手', '岳東華', '月薪', '由', '36萬', '元', '調升至', '48萬', '元', '、', '調幅', '33.3%', '；', '野手', '岳政華', '月薪', '30萬', '元', '調升至', '42萬', '元', '、', '調幅', '40%', '；', '捕手', '高宇杰', '月薪', '由', '26萬', '元', '調升', '至', '38萬', '元', '、', '調幅', '46.2%', '；', '野手', '王政順', '月薪', '由', '16.5萬元', '調升至', '20萬', '元', '、', '調幅', '21.2%', '；', '捕手', '林吳晉瑋', '月薪', '由', '1', '1萬元', '調升至', '15萬', '元', '，', '調幅', '36.4%', '；', '投手', '謝榮豪', '月薪', '由', '21', '元', '萬', '調升至', '28萬', '元', '、', '調幅', '33.3%', '；', '投手', '黃恩賜', '月薪', '由', '16萬', '元', '調升至', '22萬', '元', '、', '調幅', '37.5%', '；', '投手', '魏碩成', '月薪', '由', '15萬元', '調升至', '19萬元', '、', '調幅', '26.7%', '；', '野手', '宋晟睿', '本季', '也', '獲', '加薪', '6萬元', '。', '兄弟', '球團', '對於', '表現', '優異', '選手', '給予', '加薪', '肯定', '，', '而', '表現差', '強人意', '的', '球員', '則', '小幅', '降薪', '。', '小幅扣薪', '部分', '，', '投手', '鄭浩均', '月薪', '38萬元', '調降至', '35萬', '元', '、', '吳哲源', '月薪', '22萬元', '調降至', '20萬元', '、', '楊志龍', '月薪', '15萬元', '調降至', '12.5萬', '元', '、', '江忠城', '月薪', '13.5萬元', '調降至', '1', '0萬元', '。']
# ['Na', 'Ng', 'Na', 'Da', 'Neu', 'Nf', 'VC', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'Na', 'Nd', 'VE', 'Na', 'VH', 'Na', 'COMMACATEGORY', 'Na', 'Na', 'Na', 'VJ', 'Neu', 'COMMACATEGORY', 'Nb', 'VC', 'Neu', 'Nf', 'VH', 'Na', 'Na', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'Na', 'Nb', 'PAUSECATEGORY', 'Na', 'Nb', 'VJ', 'Na', 'Na', 'PERIODCATEGORY', 'Na', 'Nd', 'VC', 'Na', 'VC', 'VH', 'Na', 'VE', 'Na', 'COMMACATEGORY', 'Neu', 'Nd', 'Nd', 'Neqa', 'Nf', 'Na', 'D', 'VC', 'VJ', 'Neu', 'PERIODCATEGORY', 'Nb', 'Na', 'Na', 'VK', 'Na', 'Na', 'P', 'Na', 'DE', 'VC', 'COMMACATEGORY', 'D', 'VK', 'Nd', 'D', 'D', 'VCL', 'PARENTHESISCATEGORY', 'VH', 'PARENTHESISCATEGORY', 'DE', 'Na', 'COMMACATEGORY', 'A', 'PARENTHESISCATEGORY', 'VH', 'PARENTHESISCATEGORY', 'PERIODCATEGORY', 'Na', 'Na', 'Nb', 'P', 'Neu', 'Nd', 'VC', 'Na', 'COMMACATEGORY', 'P', 'Nd', 'Nd', 'VHC', 'Ng', 'COMMACATEGORY', 'VH', 'P', 'Na', 'VE', 'VC', 'DE', 'Na', 'COMMACATEGORY', 'Na', 'Na', 'Caa', 'Nb', 'VC', 'Neu', 'Nf', 'VH', 'Na', 'Neu', 'Nf', 'DE', 'Na', 'Na', 'COMMACATEGORY', 'Nd', 'Na', 'D', 'P', 'FW', 'Neu', 'Nf', 'VHC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neu', 'COMMACATEGORY', 'VK', 'Nb', 'P', 'D', 'DE', 'Neu', 'VL', 'VC', 'Na', 'Na', 'COMMACATEGORY', 'P', 'Nb', 'Na', 'VH', 'VA', 'PERIODCATEGORY', 'VG', 'D', 'VC', 'Na', 'DE', 'Na', 'Nb', 'Caa', 'Na', 'Nb', 'COMMACATEGORY', 'Nd', 'D', 'P', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'Nb', 'Nd', 'Na', 'Neu', 'COMMACATEGORY', 'Nb', 'D', 'SHI', 'Na', 'Neu', 'Nf', 'COMMACATEGORY', 'VK', 'Neu', 'Na', 'VL', 'P', 'VC', 'VF', 'Na', 'COMMACATEGORY', 'D', 'P', 'Na', 'VD', 'Na', 'Na', 'Neqa', 'Na', 'Na', 'PERIODCATEGORY', 'Neu', 'Nd', 'Na', 'VC', 'Na', 'DE', 'Na', 'COMMACATEGORY', 'Neu', 'VC', 'Nh', 'Na', 'Nd', 'P', 'VA', 'Neu', 'D', 'VJ', 'Cbb', 'DE', 'Na', 'COMMACATEGORY', 'Dfa', 'D', 'VC', 'Na', 'FW', 'DE', 'Na', 'COMMACATEGORY', 'VJ', 'PARENTHESISCATEGORY', 'Na', 'A', 'VH', 'Na', 'Na', 'PERIODCATEGORY', 'Na', 'Na', 'VE', 'Nb', 'Nd', 'Na', 'D', 'P', 'Neu', 'Neu', 'VHC', 'Neu', 'PAUSECATEGORY', 'Na', 'Neu', 'COMMACATEGORY', 'VK', 'Nb', 'D', 'VF', 'P', 'DE', 'Na', 'D', 'Na', 'COMMACATEGORY', 'VC', 'Nd', 'Nes', 'Nf', 'VH', 'Na', 'PERIODCATEGORY', 'Nd', 'Na', 'Na', 'Dfa', 'VJ', 'DE', 'Neu', 'Nf', 'Na', 'Nb', 'Caa', 'Nb', 'COMMACATEGORY', 'P', 'Nd', 'D', 'D', 'VJ', 'PERIODCATEGORY', 'Nb', 'Nd', 'Na', 'P', 'Neu', 'Nf', 'VC', 'P', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'SEMICOLONCATEGORY', 'Nb', 'D', 'SHI', 'P', 'Na', 'Neu', 'Nf', 'VHC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'PERIODCATEGORY', 'Neqa', 'VH', 'Neqa', 'COMMACATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'Nf', 'VHC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'Neu', 'Nf', 'VC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neu', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'Nf', 'VC', 'P', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'VC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'Neu', 'VC', 'Neu', 'Nf', 'COMMACATEGORY', 'Na', 'Neu', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'Nf', 'VH', 'VC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neqa', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'Nf', 'VC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Na', 'Neu', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Na', 'P', 'Neu', 'VC', 'Neu', 'PAUSECATEGORY', 'Na', 'Neu', 'SEMICOLONCATEGORY', 'Na', 'Nb', 'Nes', 'D', 'VJ', 'VB', 'Neu', 'PERIODCATEGORY', 'Na', 'Na', 'P', 'VC', 'VH', 'Na', 'VD', 'VB', 'VK', 'COMMACATEGORY', 'Cbb', 'VC', 'VH', 'DE', 'Na', 'D', 'D', 'VB', 'PERIODCATEGORY', 'D', 'Neqa', 'COMMACATEGORY', 'Na', 'Nb', 'Na', 'Neu', 'VHC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Nb', 'Na', 'Neu', 'VHC', 'Neu', 'PAUSECATEGORY', 'Nb', 'Na', 'Neu', 'VHC', 'Neu', 'Nf', 'PAUSECATEGORY', 'Nb', 'Na', 'Neu', 'VHC', 'Neu', 'Neu', 'PERIODCATEGORY']
# ['美國', '職棒', '奧克蘭', '運動家隊', '公布', '大聯盟', '春訓', '名單', '異動', '，', '下放', '7', '名', '球員', '包括', '台灣', '投手', '莊陳仲敖', '、', '捕手', '林家正', '，', '下放', '球員', '將', '回到', '小聯盟', '春訓', '。', '24', '歲', '投手', '莊陳仲敖', '為', '今年', '世界', '棒球', '經典賽', '資格賽', '（', 'WBCQ', '）', '台灣', '代表隊', '成員', '，', '在', '2月', '25日', '與', '西班牙', '決勝', '關鍵', '一', '役', '扛', '先發', '，', '投', '3', '局', '被', '敲', '4', '支', '安打', '，', '投出', '1', '次', '三振', '，', '失掉', '2', '分', '責', '失分', '，', '台灣', '以', '6', '比', '3', '獲勝', '，', '莊陳仲敖', '為', '勝', '投', '。', '莊陳仲敖', '結束', '資格賽', '結束', '隔天', '返', '美', '投入', '大聯盟', '春訓', '，', '但', '還', '沒', '有', '出賽', '紀錄', '，', '將', '回到', '小', '聯盟', '春訓', '。', '莊陳仲敖', '去年', '最', '高', '層級', '上', '到', '小', '聯盟', '2', 'A', '，', '在', '2A', '有5', '場', '出賽', '（', '4', '場', '先發', '）', '，', '戰績', '1', '勝', '、', '防禦率', '2.05', '。', '捕手', '林家正', '去年', '世界', '1', '2', '強', '棒球賽', '表現', '亮', '眼', '，', '今年', '也', '有', '被', '選入', '世界', '棒球', '經典賽', '資格賽', '集訓', '名單', '，', '但', '後來', '因', '與', '運動家隊', '簽約', '獲邀', '大聯盟', '春訓', '，', '辭退', '資格賽', '台灣隊', '。', '林家正', '在', '大聯盟', '春訓', '熱', '身賽', '有', '3', '場', '出賽', '，', '總計', '2打數', '沒有', '敲出', '安打', '；', '林家正', '去年', '球季', '最', '高', '層級', '也', '上到', '小', '聯盟', '2', 'A', '，', '在', '2A', '總計', '14', '場', '出賽', '，', '共', '4', '4', '打數', '敲出', '18', '支', '安打', '，', '包括', '1', '發', '全壘打', '，', '打擊率', '4成09', '。', '運動家隊', '大聯盟', '春訓', '除了', '40', '人', '名單', '外', '，', '另', '有', '16', '名', '球員', '受', '邀', '，', '今天', '公告', '7', '名', '球員', '下放回', '小聯盟', '，', '包括', '台灣', '球員', '莊陳仲敖', '和', '林家正', '。']
# ['Nc', 'Na', 'Nb', 'Na', 'VE', 'Na', 'Na', 'Na', 'VH', 'COMMACATEGORY', 'Nes', 'Neu', 'Nf', 'Na', 'VK', 'Nc', 'Na', 'Nb', 'PAUSECATEGORY', 'Na', 'Nb', 'COMMACATEGORY', 'A', 'Na', 'D', 'VCL', 'VH', 'Na', 'PERIODCATEGORY', 'Neu', 'Nf', 'Na', 'Nb', 'P', 'Nd', 'Nc', 'Na', 'Na', 'Na', 'PARENTHESISCATEGORY', 'FW', 'PARENTHESISCATEGORY', 'Nc', 'Na', 'Na', 'COMMACATEGORY', 'P', 'Nd', 'Nd', 'Caa', 'Nc', 'VA', 'Na', 'Neu', 'Na', 'VC', 'VA', 'COMMACATEGORY', 'VC', 'Neu', 'Nc', 'P', 'VC', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'VC', 'Neu', 'Nf', 'VC', 'COMMACATEGORY', 'VJ', 'Neu', 'Nf', 'Na', 'VH', 'COMMACATEGORY', 'Nc', 'P', 'Neu', 'Caa', 'Neu', 'VH', 'COMMACATEGORY', 'Nb', 'VG', 'Na', 'VC', 'PERIODCATEGORY', 'Nb', 'VHC', 'Na', 'VHC', 'Nd', 'VCL', 'Nc', 'VC', 'Na', 'Na', 'COMMACATEGORY', 'Cbb', 'D', 'D', 'V_2', 'VA', 'Na', 'COMMACATEGORY', 'D', 'VCL', 'VH', 'Na', 'Na', 'PERIODCATEGORY', 'Nb', 'Nd', 'Dfa', 'VH', 'Na', 'VCL', 'P', 'VH', 'Na', 'Neu', 'FW', 'COMMACATEGORY', 'P', 'Neu', 'V_2', 'Nf', 'VA', 'PARENTHESISCATEGORY', 'Neu', 'Nf', 'VA', 'PARENTHESISCATEGORY', 'COMMACATEGORY', 'Na', 'Neu', 'VH', 'PAUSECATEGORY', 'Na', 'Neu', 'PERIODCATEGORY', 'Na', 'Nb', 'Nd', 'Nc', 'Neu', 'Neu', 'VH', 'Na', 'VC', 'VH', 'Na', 'COMMACATEGORY', 'Nd', 'D', 'V_2', 'P', 'VCL', 'Nc', 'Na', 'Na', 'Na', 'Nv', 'Na', 'COMMACATEGORY', 'Cbb', 'Nd', 'Cbb', 'P', 'Na', 'VA', 'VJ', 'Na', 'Na', 'COMMACATEGORY', 'VC', 'Na', 'Nb', 'PERIODCATEGORY', 'Nc', 'P', 'Na', 'Na', 'Na', 'Na', 'V_2', 'Neu', 'Nf', 'VA', 'COMMACATEGORY', 'Da', 'Neu', 'D', 'VC', 'Na', 'SEMICOLONCATEGORY', 'Nb', 'Nd', 'Nd', 'Dfa', 'VH', 'Na', 'D', 'VCL', 'VH', 'Na', 'Neu', 'FW', 'COMMACATEGORY', 'P', 'Neu', 'Da', 'Neu', 'Nf', 'VA', 'COMMACATEGORY', 'Da', 'Cbb', 'Cbb', 'Na', 'VC', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'VK', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'Na', 'Neqa', 'PERIODCATEGORY', 'Na', 'Na', 'Na', 'P', 'Neu', 'Na', 'Na', 'Ng', 'COMMACATEGORY', 'Nes', 'V_2', 'Neu', 'Nf', 'Na', 'P', 'VF', 'COMMACATEGORY', 'Nd', 'VE', 'Neu', 'Nf', 'Na', 'Ncd', 'VH', 'COMMACATEGORY', 'VK', 'Nc', 'Na', 'Nb', 'Caa', 'Nb', 'PERIODCATEGORY']

# %%
word_pos_pair = [list(zip(article_word,article_pos)) for article_word, article_pos in zip(tokens, tokens_pos)]

# %%
len(word_pos_pair)
# Out:
# 12

# %%
word_pos_pair
# Out:
# [[('梵蒂岡', 'Nc'),
#   ('宗座', 'Na'),
#   ('圖書館', 'Nc'),
#   ('總', 'Nc'),
#   ('館長', 'Na'),
#   ('札尼', 'Nb'),
#   ('今天', 'Nd'),
#   ('率領', 'VF'),
#   ('數十', 'Neu'),
#   ('位', 'Nf'),
#   ('北義', 'Nc'),
#   ('的', 'DE'),
#   ('社會', 'Na'),
#   ('菁英', 'Na'),
#   ('教友', 'Na'),
#   ('拜會', 'VC'),
#   ('駐', 'VCL'),
#   ('教廷', 'Nc'),
#   ('大使館', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('曾', 'D'),
#   ('訪', 'VC'),
#   ('台', 'Nc'),
#   ('的', 'DE'),
#   ('札尼', 'Nb'),
#   ('致詞', 'VA'),
#   ('時', 'Ng'),
#   ('向', 'P'),
#   ('教友', 'Na'),
#   ('力', 'VC'),
#   ('推', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('是', 'SHI'),
#   ('個', 'Nf'),
#   ('卓越', 'VH'),
#   ('國家', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('非常', 'Dfa'),
#   ('值得', 'VH'),
#   ('前往', 'VCL'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('多', 'Neqa'),
#   ('位', 'Nf'),
#   ('教友', 'Na'),
#   ('對', 'P'),
#   ('台灣', 'Nc'),
#   ('高度', 'A'),
#   ('好奇', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('熱情', 'VH'),
#   ('表示', 'VE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('下', 'Nes'),
#   ('次', 'Nf'),
#   ('旅遊', 'Nv'),
#   ('地點', 'Na'),
#   ('將', 'D'),
#   ('鎖定', 'VC'),
#   ('台灣', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('札尼', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Angelo Vincenzo', 'FW'),
#   (' Zani', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('於', 'P'),
#   ('2023年', 'Neu'),
#   ('曾', 'D'),
#   ('訪', 'VC'),
#   ('台', 'Nc'),
#   ('參加', 'VC'),
#   ('故宮', 'Nc'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('梵蒂岡', 'Nb'),
#   ('宗座', 'Nb'),
#   ('圖書館', 'Nc'),
#   ('珍藏', 'VC'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('暨', 'Caa'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('明清', 'Nd'),
#   ('宮廷', 'Nc'),
#   ('藏書', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('特展', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('對', 'P'),
#   ('台灣', 'Nc'),
#   ('留下', 'VC'),
#   ('深刻', 'VH'),
#   ('印象', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('他', 'Nh'),
#   ('今天', 'Nd'),
#   ('率領', 'VF'),
#   ('北義', 'Nc'),
#   ('家鄉', 'Nc'),
#   ('布雷西亞', 'Nc'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Brescia', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('約', 'Da'),
#   ('40', 'Neu'),
#   ('位', 'Nf'),
#   ('教友', 'Na'),
#   ('到', 'VCL'),
#   ('羅馬', 'Nc'),
#   ('朝聖', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('特別', 'VH'),
#   ('安', 'VE'),
#   ('排教友', 'VC'),
#   ('參觀', 'VC'),
#   ('台灣', 'Nc'),
#   ('使館', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('這', 'Nep'),
#   ('群', 'Nf'),
#   ('教友', 'Na'),
#   ('皆', 'D'),
#   ('為', 'VG'),
#   ('布雷西亞', 'Nc'),
#   ('扶輪社', 'Nc'),
#   ('成員', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('職業', 'Na'),
#   ('包括', 'VK'),
#   ('中', 'Na'),
#   ('小企業家', 'VH'),
#   ('、', 'PAUSECATEGORY'),
#   ('大學', 'Nc'),
#   ('教授', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('律師', 'Na'),
#   ('和', 'Caa'),
#   ('高階', 'A'),
#   ('憲警', 'Na'),
#   ('等', 'Cab'),
#   ('。', 'PERIODCATEGORY'),
#   ('札尼', 'Nb'),
#   ('致詞', 'VA'),
#   ('時', 'Ng'),
#   ('盛讚', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('長期', 'Nd'),
#   ('與', 'P'),
#   ('教廷', 'Nc'),
#   ('攜手', 'D'),
#   ('推動', 'VC'),
#   ('人道', 'Na'),
#   ('援助', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('包括', 'VK'),
#   ('協助', 'VC'),
#   ('他', 'Nh'),
#   ('在', 'P'),
#   ('非洲', 'Nc'),
#   ('剛果', 'Nc'),
#   ('推動', 'VC'),
#   ('的', 'DE'),
#   ('教育', 'Na'),
#   ('與', 'Caa'),
#   ('醫療', 'VC'),
#   ('工作', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('在COVID-19', 'P'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('2019', 'Neu'),
#   ('冠狀', 'Na'),
#   ('病毒', 'Na'),
#   ('疾病', 'Na'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('疫情', 'Na'),
#   ('期間', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('也', 'D'),
#   ('曾', 'D'),
#   ('向', 'P'),
#   ('布雷西亞', 'Nc'),
#   ('醫院', 'Nc'),
#   ('捐贈', 'VD'),
#   ('呼吸器', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('因此', 'Cbb'),
#   ('他', 'Nh'),
#   ('一直', 'D'),
#   ('想', 'VE'),
#   ('向', 'P'),
#   ('家鄉教友', 'Nc'),
#   ('介紹', 'VE'),
#   ('開放', 'VH'),
#   ('、', 'PAUSECATEGORY'),
#   ('多元', 'VH'),
#   ('又', 'Caa'),
#   ('好客', 'VH'),
#   ('的', 'DE'),
#   ('台灣', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('盼', 'VK'),
#   ('促進', 'VK'),
#   ('彼此', 'Nh'),
#   ('更', 'Neqa'),
#   ('多', 'VH'),
#   ('交流', 'VH'),
#   ('機會', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('駐', 'VCL'),
#   ('教廷', 'Nc'),
#   ('大使', 'Na'),
#   ('李世明', 'Nb'),
#   ('致詞', 'VA'),
#   ('介紹', 'VE'),
#   ('台灣', 'Nc'),
#   ('時', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('引用', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('時事哏', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('開場', 'VA'),
#   ('博', 'VJ'),
#   ('得', 'DE'),
#   ('眾人鼓掌大笑', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('他', 'Nh'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('日前', 'Nd'),
#   ('美國', 'Nc'),
#   ('總統', 'Na'),
#   ('川普', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Donald', 'FW'),
#   (' Trump', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('與', 'P'),
#   ('烏克蘭', 'Nc'),
#   ('總統', 'Na'),
#   ('澤倫斯基', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Volodymyr Zelenskyy', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('在', 'P'),
#   ('白宮', 'Nc'),
#   ('會晤', 'VC'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('有', 'V_2'),
#   ('句', 'Nf'),
#   ('流行語', 'Na'),
#   ('在', 'P'),
#   ('國際社會', 'Nc'),
#   ('很', 'Dfa'),
#   ('夯', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('就是', 'Cbb'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('你', 'Nh'),
#   ('手', 'Na'),
#   ('上', 'Ncd'),
#   ('有', 'V_2'),
#   ('什麼', 'Nep'),
#   ('牌', 'Na'),
#   ('可', 'D'),
#   ('打', 'VC'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Na'),
#   ('論', 'VC'),
#   ('領土', 'Na'),
#   ('面積', 'Na'),
#   ('雖', 'Cbb'),
#   ('小', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('台灣', 'Nc'),
#   ('對', 'P'),
#   ('國際', 'Nc'),
#   ('很', 'Dfa'),
#   ('重要', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('可', 'D'),
#   ('說', 'VE'),
#   ('手', 'Na'),
#   ('上', 'Ncd'),
#   ('有', 'V_2'),
#   ('很多', 'Neqa'),
#   ('牌', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('其', 'Nep'),
#   ('重要性', 'Na'),
#   ('可', 'D'),
#   ('分', 'VC'),
#   ('3', 'Neu'),
#   ('個', 'Nf'),
#   ('主要', 'A'),
#   ('方面', 'Na'),
#   ('闡釋', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('李世明', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('首先', 'D'),
#   ('台灣', 'Nc'),
#   ('具有', 'VJ'),
#   ('地緣', 'Na'),
#   ('戰略', 'Na'),
#   ('重要性', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('海峽', 'Na'),
#   ('是', 'SHI'),
#   ('全球', 'Nc'),
#   ('貨運', 'Na'),
#   ('通過', 'VC'),
#   ('的', 'DE'),
#   ('重要', 'VH'),
#   ('管道', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('第二', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('半導體', 'Na'),
#   ('產業', 'Na'),
#   ('位居', 'VCL'),
#   ('世界', 'Nc'),
#   ('關鍵', 'Na'),
#   ('地位', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('先進', 'VH'),
#   ('晶片', 'Na'),
#   ('製程', 'Na'),
#   ('在', 'P'),
#   ('全球', 'Nc'),
#   ('市占率', 'Na'),
#   ('超過', 'VJ'),
#   ('9成', 'Neqa'),
#   ('。', 'PERIODCATEGORY'),
#   ('李世明', 'Nb'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('第三', 'Neu'),
#   ('點', 'Nf'),
#   ('最', 'Dfa'),
#   ('重要', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('教宗方', 'Na'),
#   ('濟各', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Pope', 'FW'),
#   (' ', 'WHITESPACE'),
#   ('Francis', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('說', 'VE'),
#   ('今年', 'Nd'),
#   ('是', 'SHI'),
#   ('希望', 'VK'),
#   ('禧年', 'Nd'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('作為', 'VG'),
#   ('自由', 'VH'),
#   ('民主', 'VH'),
#   ('國家', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('是', 'SHI'),
#   ('所有', 'Neqa'),
#   ('受到', 'VJ'),
#   ('中國', 'Nc'),
#   ('共產', 'A'),
#   ('威權', 'Na'),
#   ('統治', 'VC'),
#   ('下', 'Ng'),
#   ('人民', 'Na'),
#   ('的', 'DE'),
#   ('希望', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('因為', 'Cbb'),
#   ('在', 'P'),
#   ('中國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('人民', 'Na'),
#   ('無法', 'D'),
#   ('享受', 'VJ'),
#   ('自由', 'Na'),
#   ('與', 'Caa'),
#   ('公平', 'VH'),
#   ('正義', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('扮演', 'VC'),
#   ('了', 'Di'),
#   ('帶來', 'VC'),
#   ('希望', 'Na'),
#   ('的', 'DE'),
#   ('角色', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('李世明', 'Nb'),
#   ('鼓勵', 'VF'),
#   ('北義菁英', 'Nb'),
#   ('教友', 'Na'),
#   ('到', 'VCL'),
#   ('台灣', 'Nc'),
#   ('訪問', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('現', 'Nd'),
#   ('在', 'P'),
#   ('羅馬', 'Nc'),
#   ('、', 'PAUSECATEGORY'),
#   ('米蘭', 'Nc'),
#   ('都', 'D'),
#   ('有', 'V_2'),
#   ('直飛', 'VCL'),
#   ('台灣', 'Nc'),
#   ('班機', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('非常', 'Dfa'),
#   ('方便', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('在', 'VA'),
#   ('場', 'Nc'),
#   ('的', 'DE'),
#   ('布雷西亞', 'Nc'),
#   ('扶輪社', 'Nc'),
#   ('幹部', 'Na'),
#   ('對', 'P'),
#   ('此', 'Nep'),
#   ('反應', 'Na'),
#   ('熱烈', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('當場', 'D'),
#   ('表示', 'VE'),
#   ('要', 'D'),
#   ('公開', 'VHC'),
#   ('徵求', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('扶輪社', 'Nc'),
#   ('姊妹社', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('下', 'Nes'),
#   ('次', 'Nf'),
#   ('立刻', 'D'),
#   ('安排', 'VE'),
#   ('整團', 'Neqa'),
#   ('訪', 'VC'),
#   ('台', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('不少', 'Neqa'),
#   ('教友', 'Na'),
#   ('也', 'D'),
#   ('直', 'D'),
#   ('喊', 'VE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('報名', 'VA'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('、', 'PAUSECATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('加', 'VC'),
#   ('一', 'Neu'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'Cbb'),
#   ('開始', 'VL'),
#   ('向', 'P'),
#   ('使館', 'Nc'),
#   ('人員', 'Na'),
#   ('打探', 'VC'),
#   ('台灣', 'Nc'),
#   ('有', 'V_2'),
#   ('哪些', 'Neqa'),
#   ('美食', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('登山', 'VA'),
#   ('、', 'PAUSECATEGORY'),
#   ('海灘', 'Na'),
#   ('景點', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('展現', 'VC'),
#   ('義大利人', 'Na'),
#   ('熱情', 'VH'),
#   ('的', 'DE'),
#   ('民族性', 'Na'),
#   ('。', 'PERIODCATEGORY')],
#  [('由', 'P'),
#   ('外交部', 'Nc'),
#   ('中美洲', 'Nc'),
#   ('經貿', 'Na'),
#   ('辦事處', 'Nc'),
#   ('籌組', 'VC'),
#   ('的', 'DE'),
#   ('台灣', 'Nc'),
#   ('咖啡', 'Na'),
#   ('考察團', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('力挺', 'VC'),
#   ('友邦', 'Nc'),
#   ('瓜地馬拉', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('預計', 'VE'),
#   ('採購', 'VC'),
#   ('38', 'Neu'),
#   ('個', 'Nf'),
#   ('貨櫃', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('72萬', 'Neu'),
#   ('公斤', 'Nf'),
#   ('咖啡', 'Na'),
#   ('生豆', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('除', 'P'),
#   ('比', 'P'),
#   ('去年', 'Nd'),
#   ('增加', 'VHC'),
#   ('近', 'Nes'),
#   ('5成', 'Neqa'),
#   ('，', 'COMMACATEGORY'),
#   ('考察團', 'Na'),
#   ('規模', 'Na'),
#   ('和', 'Caa'),
#   ('採購量', 'Na'),
#   ('更', 'Dfa'),
#   ('創下', 'VC'),
#   ('歷年', 'Nd'),
#   ('新高', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('2025年', 'Neu'),
#   ('中美洲', 'Nc'),
#   ('咖啡', 'Na'),
#   ('經', 'Na'),
#   ('貿', 'Na'),
#   ('考察團', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('日前', 'Nd'),
#   ('抵達', 'VCL'),
#   ('瓜地馬拉', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('實地', 'D'),
#   ('考察', 'VC'),
#   ('咖啡', 'Na'),
#   ('生產', 'Na'),
#   ('鏈', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('3日', 'Nd'),
#   ('上午', 'Nd'),
#   ('也', 'D'),
#   ('前往', 'VCL'),
#   ('瓜地馬拉', 'Nc'),
#   ('咖啡', 'Nc'),
#   ('協會', 'Nc'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('ANACAFE', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('拜訪', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('並且', 'Cbb'),
#   ('親身', 'Na'),
#   ('杯測', 'Na'),
#   ('瓜國', 'Nc'),
#   ('各', 'Nes'),
#   ('個', 'Nf'),
#   ('產區', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('不同', 'VH'),
#   ('品種', 'Na'),
#   ('風味', 'Na'),
#   ('的', 'DE'),
#   ('咖啡', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('中美洲', 'Nc'),
#   ('經貿', 'Na'),
#   ('辦事處', 'Nc'),
#   ('主任', 'Na'),
#   ('徐韶慧', 'Nb'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('相較', 'VB'),
#   ('去年', 'Nd'),
#   ('1', 'Neu'),
#   ('1', 'Neu'),
#   ('家', 'Nf'),
#   ('台灣', 'Nc'),
#   ('業者', 'Na'),
#   ('組團', 'VA'),
#   ('考察', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('下單', 'Na'),
#   ('採購', 'VC'),
#   ('總價值', 'Na'),
#   ('260萬', 'Neu'),
#   ('美元', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('26', 'Neu'),
#   ('個', 'Nf'),
#   ('貨櫃', 'Na'),
#   ('的', 'DE'),
#   ('咖啡', 'Na'),
#   ('生豆', 'VC'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('今年', 'Nd'),
#   ('增加到', 'VHC'),
#   ('1', 'Neu'),
#   ('3', 'Neu'),
#   ('家', 'Nf'),
#   ('台灣', 'Nc'),
#   ('業者', 'Na'),
#   ('參與', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('更', 'Dfa'),
#   ('大幅', 'D'),
#   ('採購', 'VC'),
#   ('總計', 'Da'),
#   ('38', 'Neu'),
#   ('個', 'Nf'),
#   ('貨櫃', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('共', 'Da'),
#   ('72萬', 'Neu'),
#   ('公斤', 'Nf'),
#   ('咖啡', 'Na'),
#   ('生', 'VC'),
#   ('豆', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('顯示', 'VK'),
#   ('台灣', 'Nc'),
#   ('消費者', 'Na'),
#   ('對', 'P'),
#   ('瓜地馬拉', 'Nc'),
#   ('咖啡', 'Na'),
#   ('的', 'DE'),
#   ('喜愛', 'Nv'),
#   ('，', 'COMMACATEGORY'),
#   ('更', 'Dfa'),
#   ('凸顯', 'VJ'),
#   ('台', 'Nc'),
#   ('瓜', 'Nc'),
#   ('蓬勃商機', 'VH'),
#   ('發展', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('徐韶慧', 'Nb'),
#   ('強調', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('根據', 'P'),
#   ('統計', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('2024年', 'Neu'),
#   ('瓜地馬拉', 'Nc'),
#   ('進口', 'VC'),
#   ('的', 'DE'),
#   ('咖啡豆', 'Na'),
#   ('占', 'VJ'),
#   ('台灣', 'Nc'),
#   ('咖啡', 'Na'),
#   ('消費', 'Na'),
#   ('總量', 'Na'),
#   ('的', 'DE'),
#   ('10%', 'Neqa'),
#   ('以上', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('是', 'SHI'),
#   ('台灣', 'Nc'),
#   ('第4', 'Neu'),
#   ('大', 'VH'),
#   ('的', 'DE'),
#   ('咖啡', 'Na'),
#   ('進口國', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('換句', 'Dk'),
#   ('話', 'Na'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('每', 'D'),
#   ('賣', 'VC'),
#   ('出', 'VC'),
#   ('1', 'Neu'),
#   ('0', 'Neu'),
#   ('杯', 'Nf'),
#   ('咖啡', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('就', 'D'),
#   ('有', 'V_2'),
#   ('超過', 'VJ'),
#   ('1', 'Neu'),
#   ('杯', 'Nf'),
#   ('是', 'SHI'),
#   ('來自', 'VJ'),
#   ('瓜地馬拉', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('此外', 'Cbb'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('在', 'P'),
#   ('整', 'Neqa'),
#   ('個', 'Nf'),
#   ('亞洲', 'Nc'),
#   ('的', 'DE'),
#   ('咖啡', 'Na'),
#   ('消費國中', 'Na'),
#   ('也', 'D'),
#   ('位居第3', 'VCL'),
#   ('，', 'COMMACATEGORY'),
#   ('僅', 'Da'),
#   ('次於', 'VJ'),
#   ('日本', 'Nc'),
#   ('和', 'Caa'),
#   ('韓國', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('去年', 'Nd'),
#   ('5月', 'Nd'),
#   ('底', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('中國', 'Nc'),
#   ('突然', 'D'),
#   ('宣布', 'VE'),
#   ('禁止', 'VE'),
#   ('瓜地馬拉', 'Nc'),
#   ('夏威夷豆', 'Nc'),
#   ('和', 'Caa'),
#   ('咖啡豆', 'Na'),
#   ('進口', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('作為', 'VG'),
#   ('外交', 'Na'),
#   ('勒索', 'Nv'),
#   ('手段', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('引起', 'VC'),
#   ('瓜國政府', 'Nc'),
#   ('和', 'Caa'),
#   ('業者', 'Na'),
#   ('不滿', 'VK'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('外交部', 'Nc'),
#   ('和', 'Caa'),
#   ('台灣', 'Nc'),
#   ('咖啡', 'Na'),
#   ('進口商', 'Na'),
#   ('第一', 'Neu'),
#   ('時間', 'Na'),
#   ('伸出', 'VC'),
#   ('援手', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'P'),
#   ('這', 'Nep'),
#   ('一', 'Neu'),
#   ('批', 'Nf'),
#   ('咖啡貨櫃', 'Na'),
#   ('轉運往', 'VCL'),
#   ('台灣', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('中美洲', 'Nc'),
#   ('經貿', 'Na'),
#   ('辦事處', 'Nc'),
#   ('也', 'D'),
#   ('別出心裁', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'P'),
#   ('這', 'Nep'),
#   ('批', 'Nf'),
#   ('瓜國', 'Nc'),
#   ('咖啡', 'Na'),
#   ('豆', 'Na'),
#   ('製作成', 'VG'),
#   ('濾掛式', 'A'),
#   ('咖啡包', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('此', 'Nep'),
#   ('次', 'Nf'),
#   ('參訪', 'VC'),
#   ('行程', 'Na'),
#   ('更', 'Dfa'),
#   ('將', 'D'),
#   ('致贈', 'VD'),
#   ('瓜國', 'Nc'),
#   ('友人', 'Na'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('限定版', 'Na'),
#   ('友誼', 'Na'),
#   ('咖啡', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('禮盒', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('成為', 'VG'),
#   ('台灣', 'Nc'),
#   ('力挺', 'VC'),
#   ('瓜國', 'Nc'),
#   ('另', 'Nes'),
#   ('一', 'Neu'),
#   ('種', 'Nf'),
#   ('象徵', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('根據', 'P'),
#   ('瓜地', 'Nc'),
#   ('馬拉', 'Na'),
#   ('中央', 'Nc'),
#   ('銀行', 'Nc'),
#   ('數據', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('2024年', 'Neu'),
#   ('瓜地', 'Nc'),
#   ('馬拉', 'Na'),
#   ('對', 'P'),
#   ('台灣', 'Nc'),
#   ('的', 'DE'),
#   ('咖啡', 'Na'),
#   ('出口', 'VC'),
#   ('超過', 'VJ'),
#   ('1800萬', 'Neu'),
#   ('美元', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('相比於', 'VB'),
#   ('2023年', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('出口量', 'Na'),
#   ('增長', 'VHC'),
#   ('了', 'Di'),
#   ('13%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('而', 'Cbb'),
#   ('咖啡', 'Na'),
#   ('也', 'D'),
#   ('僅', 'Da'),
#   ('次於', 'VJ'),
#   ('糖', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('成為', 'VG'),
#   ('瓜國', 'Nc'),
#   ('出口', 'VC'),
#   ('台灣', 'Nc'),
#   ('的', 'DE'),
#   ('第二', 'Neu'),
#   ('大', 'VH'),
#   ('商品', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('出席', 'Nv'),
#   ('活動', 'Na'),
#   ('的', 'DE'),
#   ('瓜地', 'Nc'),
#   ('馬拉', 'Na'),
#   ('外交部', 'Nc'),
#   ('次長', 'Na'),
#   ('歐洛斯柯', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Julio Orozco', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('特別', 'VH'),
#   ('感謝', 'VK'),
#   ('台灣', 'Nc'),
#   ('和', 'Caa'),
#   ('瓜地馬拉', 'Nc'),
#   ('共同', 'A'),
#   ('推廣', 'VC'),
#   ('咖啡', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('不只', 'Da'),
#   ('進', 'D'),
#   ('一', 'Neu'),
#   ('步', 'Nf'),
#   ('提升', 'VC'),
#   ('全球', 'Nc'),
#   ('市場', 'Nc'),
#   ('地位', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('更', 'Dfa'),
#   ('讓', 'VL'),
#   ('台瓜人民', 'Nc'),
#   ('及', 'Caa'),
#   ('瓜國', 'Nc'),
#   ('咖啡', 'Na'),
#   ('農', 'Na'),
#   ('都', 'D'),
#   ('能夠', 'D'),
#   ('受惠', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('除了', 'P'),
#   ('政治', 'Na'),
#   ('因素', 'Na'),
#   ('干擾', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('近年來', 'Nd'),
#   ('全球', 'Nc'),
#   ('咖啡', 'Na'),
#   ('受到', 'VJ'),
#   ('氣候', 'Na'),
#   ('變遷', 'VH'),
#   ('影響', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('產量', 'Na'),
#   ('供應', 'VD'),
#   ('不', 'D'),
#   ('穩', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('市場', 'Nc'),
#   ('價格', 'Na'),
#   ('也', 'D'),
#   ('大幅', 'D'),
#   ('波動', 'VAC'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('咖啡', 'Na'),
#   ('考察團', 'Na'),
#   ('業者', 'Na'),
#   ('張正仁', 'Nb'),
#   ('指出', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('過', 'Nd'),
#   ('去', 'VJ'),
#   ('咖啡', 'Na'),
#   ('價格', 'Na'),
#   ('雖然', 'Cbb'),
#   ('每', 'Nes'),
#   ('十', 'Neu'),
#   ('年', 'Nf'),
#   ('就', 'D'),
#   ('會', 'D'),
#   ('有', 'V_2'),
#   ('一', 'Neu'),
#   ('次', 'Nf'),
#   ('上漲', 'Nv'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('基本', 'Na'),
#   ('上', 'Ng'),
#   ('2', 'Neu'),
#   ('、', 'PAUSECATEGORY'),
#   ('3', 'Neu'),
#   ('個', 'Nf'),
#   ('月', 'Na'),
#   ('後', 'Ng'),
#   ('就', 'D'),
#   ('恢復', 'VHC'),
#   ('平穩', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('不過', 'Cbb'),
#   ('自', 'P'),
#   ('COVID-19', 'FW'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('2019', 'Neu'),
#   ('冠狀', 'Na'),
#   ('病毒', 'Na'),
#   ('疾病', 'Na'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('疫情', 'Na'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('咖啡', 'Na'),
#   ('價格', 'Na'),
#   ('卻', 'D'),
#   ('持續', 'VL'),
#   ('走揚', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('種', 'Nf'),
#   ('情況', 'Na'),
#   ('是', 'SHI'),
#   ('過數十', 'VCL'),
#   ('年', 'Nf'),
#   ('罕見', 'VH'),
#   ('的', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('自然', 'D'),
#   ('也', 'D'),
#   ('造成', 'VK'),
#   ('進口商', 'Na'),
#   ('的', 'DE'),
#   ('成本', 'Na'),
#   ('壓力', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('張正仁', 'Nb'),
#   ('強調', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('現在', 'Nd'),
#   ('只能', 'Da'),
#   ('觀察', 'VE'),
#   ('3', 'Nd'),
#   ('、', 'PAUSECATEGORY'),
#   ('4', 'Nd'),
#   ('月', 'Na'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('全', 'Neqa'),
#   ('世界', 'Nc'),
#   ('第一', 'Neu'),
#   ('大', 'VH'),
#   ('咖啡', 'Na'),
#   ('生產國', 'Na'),
#   ('巴西', 'Nc'),
#   ('氣候', 'Na'),
#   ('是否', 'D'),
#   ('穩定', 'VHC'),
#   ('，', 'COMMACATEGORY'),
#   ('產量', 'Na'),
#   ('回穩', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('未來', 'Nd'),
#   ('咖啡', 'Na'),
#   ('價格', 'Na'),
#   ('波動', 'VAC'),
#   ('才', 'Da'),
#   ('會', 'D'),
#   ('明朗', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('中美洲', 'Nc'),
#   ('經貿', 'Na'),
#   ('辦', 'Nc'),
#   ('事處', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('CATO', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('瓜地馬拉', 'Nc'),
#   ('因', 'Cbb'),
#   ('地理', 'Na'),
#   ('條件', 'Na'),
#   ('與', 'Caa'),
#   ('多樣化', 'VHC'),
#   ('的', 'DE'),
#   ('微型', 'A'),
#   ('氣候', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('本身', 'Nh'),
#   ('擁有', 'VJ'),
#   ('8', 'Neu'),
#   ('大', 'VH'),
#   ('咖啡', 'Na'),
#   ('產區', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('其中', 'Nep'),
#   ('以', 'P'),
#   ('安', 'Nc'),
#   ('地瓜', 'Nc'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Antigua', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('與', 'Caa'),
#   ('維維特南戈', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Huehu', 'FW'),
#   ('etenango', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('尤', 'D'),
#   ('為', 'VG'),
#   ('出名', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('考察團', 'Na'),
#   ('此', 'Nep'),
#   ('次', 'Nf'),
#   ('也', 'D'),
#   ('將', 'D'),
#   ('深入', 'VH'),
#   ('位於', 'VCL'),
#   ('內陸', 'Nc'),
#   ('高海拔', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('地處', 'VJ'),
#   ('偏遠', 'VH'),
#   ('交通', 'Na'),
#   ('不便', 'VH'),
#   ('的', 'DE'),
#   ('維維特', 'Nb'),
#   ('南戈', 'Nc'),
#   ('產區', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('親自', 'D'),
#   ('探訪', 'VC'),
#   ('並', 'D'),
#   ('了解', 'VC'),
#   ('當地', 'Nc'),
#   ('咖啡', 'Na'),
#   ('從', 'P'),
#   ('種植', 'VC'),
#   ('、', 'PAUSECATEGORY'),
#   ('採收', 'VC'),
#   ('、', 'PAUSECATEGORY'),
#   ('處理', 'VC'),
#   ('到', 'P'),
#   ('烘焙', 'VC'),
#   ('的', 'DE'),
#   ('完整', 'VH'),
#   ('生產', 'Nv'),
#   ('流程', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'Cbb'),
#   ('與', 'P'),
#   ('咖啡農', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('處理', 'Nc'),
#   ('廠', 'Nc'),
#   ('及', 'Caa'),
#   ('出口商', 'Na'),
#   ('交流', 'VH'),
#   ('。', 'PERIODCATEGORY')],
#  [('經民連', 'P'),
#   ('與', 'Caa'),
#   ('台灣', 'Nc'),
#   ('東社', 'Nc'),
#   ('今天', 'Nd'),
#   ('分別', 'D'),
#   ('告發', 'VC'),
#   ('國民黨', 'Nb'),
#   ('立委', 'Na'),
#   ('傅崐萁', 'Nb'),
#   ('涉犯', 'VH'),
#   ('外患罪', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('反', 'Na'),
#   ('滲透法', 'Na'),
#   ('與', 'Caa'),
#   ('強制罪', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('高檢署', 'Nc'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('已', 'D'),
#   ('收到', 'VC'),
#   ('告發狀', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('後續', 'A'),
#   ('依法辦理', 'D'),
#   ('。', 'PERIODCATEGORY'),
#   ('至', 'P'),
#   ('晚間', 'Nd'),
#   ('9時', 'Neu'),
#   ('止', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('尚', 'D'),
#   ('無法', 'D'),
#   ('取得', 'VC'),
#   ('傅崐萁', 'Nb'),
#   ('對', 'P'),
#   ('此', 'Nep'),
#   ('事', 'Na'),
#   ('的', 'DE'),
#   ('回應', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('經濟', 'Na'),
#   ('民主', 'Na'),
#   ('連合智庫', 'Nb'),
#   ('召集人', 'Na'),
#   ('賴中強', 'Nb'),
#   ('等', 'Cab'),
#   ('人', 'Na'),
#   ('今天', 'Nd'),
#   ('在', 'P'),
#   ('台灣', 'Nc'),
#   ('高等', 'A'),
#   ('檢察署', 'Nc'),
#   ('前', 'Ng'),
#   ('舉行', 'VC'),
#   ('記者會', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('現場', 'Nc'),
#   ('發放', 'VD'),
#   ('的', 'DE'),
#   ('新聞', 'Na'),
#   ('資料', 'Na'),
#   ('指稱', 'VE'),
#   ('中國', 'Nc'),
#   ('國民黨', 'Nb'),
#   ('立法院', 'Nc'),
#   ('黨團', 'Na'),
#   ('總召集人', 'Na'),
#   ('傅崐萁', 'Nb'),
#   ('未', 'D'),
#   ('獲', 'VJ'),
#   ('行政院', 'Nc'),
#   ('授權', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('2月', 'Nd'),
#   ('到', 'VCL'),
#   ('香港', 'Nc'),
#   ('與', 'Caa'),
#   ('多', 'Neqa'),
#   ('名', 'Nf'),
#   ('香港區', 'Nc'),
#   ('議員', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('香港', 'Nc'),
#   ('旅遊業', 'Na'),
#   ('監管局', 'Nc'),
#   ('官員', 'Na'),
#   ('等', 'Cab'),
#   ('會商', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('宣稱', 'VE'),
#   ('代表', 'VK'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('的', 'DE'),
#   ('中央', 'Nc'),
#   ('政府', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('承諾', 'VE'),
#   ('台灣', 'Nc'),
#   ('政府', 'Na'),
#   ('願', 'VK'),
#   ('提供', 'VD'),
#   ('補助', 'VD'),
#   ('進行', 'VC'),
#   ('在', 'P'),
#   ('台', 'Nc'),
#   ('跨', 'VC'),
#   ('縣市', 'Nc'),
#   ('觀光合', 'VA'),
#   ('作', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('經民連說', 'P'),
#   ('，', 'COMMACATEGORY'),
#   ('傅崐萁', 'Nb'),
#   ('去年', 'Nd'),
#   ('率', 'VF'),
#   ('國民黨團', 'Na'),
#   ('17', 'Neu'),
#   ('名', 'Nf'),
#   ('成員', 'Na'),
#   ('訪問', 'VC'),
#   ('中國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('會', 'VC'),
#   ('見', 'VC'),
#   ('中國', 'Nc'),
#   ('人民', 'Na'),
#   ('政治', 'Na'),
#   ('協商', 'Nv'),
#   ('會議', 'Na'),
#   ('全國委員會', 'Neqa'),
#   ('主席', 'Na'),
#   ('王滬寧', 'Nb'),
#   ('等', 'Cab'),
#   ('官員', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('返', 'VA'),
#   ('台', 'Nc'),
#   ('後', 'Ng'),
#   ('即', 'D'),
#   ('遊說', 'VF'),
#   ('行政院', 'Nc'),
#   ('官員', 'Na'),
#   ('等', 'Cab'),
#   ('，', 'COMMACATEGORY'),
#   ('開放', 'VC'),
#   ('福', 'Nc'),
#   ('建', 'VC'),
#   ('平潭', 'Nc'),
#   ('與', 'Caa'),
#   ('台', 'Nc'),
#   ('灣', 'Nc'),
#   ('間', 'Ncd'),
#   ('海上', 'Na'),
#   ('客運', 'Na'),
#   ('直航', 'VCL'),
#   ('復航', 'VA'),
#   ('。', 'PERIODCATEGORY'),
#   ('另外', 'Cbb'),
#   ('，', 'COMMACATEGORY'),
#   ('傅崐萁', 'Nb'),
#   ('昨天', 'Nd'),
#   ('在', 'P'),
#   ('花蓮', 'Nc'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('活動', 'Na'),
#   ('中', 'Ng'),
#   ('致詞', 'VA'),
#   ('時', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('近', 'Da'),
#   ('80', 'Neu'),
#   ('歲', 'Nf'),
#   ('的', 'DE'),
#   ('退休', 'VH'),
#   ('教師', 'Na'),
#   ('葉春蓮', 'Nb'),
#   ('起身', 'VA'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('嗆聲', 'VA'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('被', 'P'),
#   ('請', 'VF'),
#   ('出場', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('引發', 'VC'),
#   ('許多', 'Neqa'),
#   ('民眾', 'Na'),
#   ('及', 'Caa'),
#   ('曾', 'D'),
#   ('被', 'P'),
#   ('葉春蓮', 'Nb'),
#   ('教', 'VC'),
#   ('過', 'Di'),
#   ('的', 'DE'),
#   ('學生', 'Na'),
#   ('不滿', 'VK'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣東社', 'Nc'),
#   ('發言人', 'Na'),
#   ('陳財能', 'Nb'),
#   ('上午', 'Nd'),
#   ('到', 'VCL'),
#   ('花蓮縣', 'Nc'),
#   ('警察局', 'Nc'),
#   ('花蓮', 'Nc'),
#   ('分局', 'Nc'),
#   ('軒', 'Nc'),
#   ('轅', 'Nb'),
#   ('派出所', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('告發', 'VC'),
#   ('傅崐萁', 'Nb'),
#   ('等', 'Cab'),
#   ('違反', 'VJ'),
#   ('中華民國', 'Nc'),
#   ('刑法', 'Na'),
#   ('強制', 'Nv'),
#   ('罪', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('要求', 'VF'),
#   ('警方', 'Na'),
#   ('做好', 'VC'),
#   ('證據保全', 'Na'),
#   ('及', 'Caa'),
#   ('即刻', 'D'),
#   ('調查', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('維護', 'VC'),
#   ('花蓮人', 'Nc'),
#   ('人身自由', 'Na'),
#   ('及', 'Caa'),
#   ('權利', 'Na'),
#   ('。', 'PERIODCATEGORY')],
#  [('台灣', 'Nc'),
#   ('去年度', 'Nd'),
#   ('稅收', 'Na'),
#   ('高於', 'VJ'),
#   ('預算', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('國民黨', 'Nb'),
#   ('主張', 'VE'),
#   ('普發', 'VH'),
#   ('現金', 'Na'),
#   ('新台幣', 'Na'),
#   ('1萬', 'Neu'),
#   ('元', 'Nf'),
#   ('。', 'PERIODCATEGORY'),
#   ('民眾', 'Na'),
#   ('黨團', 'Na'),
#   ('今天', 'Nd'),
#   ('舉行', 'VC'),
#   ('公聽會', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('會', 'Na'),
#   ('中', 'Ng'),
#   ('學者', 'Na'),
#   ('認為', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('目前', 'Nd'),
#   ('的', 'DE'),
#   ('租稅', 'Na'),
#   ('制度', 'Na'),
#   ('不', 'VH'),
#   ('公', 'A'),
#   ('、', 'PAUSECATEGORY'),
#   ('財務', 'Na'),
#   ('模型', 'Na'),
#   ('有', 'V_2'),
#   ('檢討', 'VC'),
#   ('必要', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('普遍', 'VH'),
#   ('不', 'D'),
#   ('認同', 'VJ'),
#   ('超徵', 'VC'),
#   ('後', 'Ng'),
#   ('直接', 'VH'),
#   ('以', 'P'),
#   ('普發', 'Na'),
#   ('現金', 'Na'),
#   ('處理', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('台灣', 'Nc'),
#   ('民眾黨', 'Nb'),
#   ('立法院', 'Nc'),
#   ('黨團', 'Na'),
#   ('今天', 'Nd'),
#   ('舉行', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('檢討', 'VE'),
#   ('連年', 'D'),
#   ('超徵', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('共享', 'VJ'),
#   ('經濟', 'Na'),
#   ('成果', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('公聽會', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('邀', 'VF'),
#   ('學者', 'Na'),
#   ('專家', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('政府', 'Na'),
#   ('代表', 'Na'),
#   ('出席', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('民眾黨', 'Nb'),
#   ('立法院', 'Nc'),
#   ('黨團', 'Na'),
#   ('總召', 'Na'),
#   ('黃國昌', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('執政黨', 'Na'),
#   ('年', 'D'),
#   ('年', 'Nf'),
#   ('超徵', 'VC'),
#   ('數千億', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('不', 'D'),
#   ('知', 'VK'),
#   ('是', 'SHI'),
#   ('能力', 'Na'),
#   ('問題', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('還是', 'D'),
#   ('故意', 'VL'),
#   ('讓', 'VL'),
#   ('人民', 'Na'),
#   ('產生', 'VHC'),
#   ('錯覺', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('以為', 'VE'),
#   ('政府', 'Na'),
#   ('年年賸餘', 'D'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('若', 'Cbb'),
#   ('將', 'P'),
#   ('特別', 'VH'),
#   ('預算', 'Na'),
#   ('納入', 'VJ'),
#   ('，', 'COMMACATEGORY'),
#   ('歲出', 'VJ'),
#   ('大幅', 'D'),
#   ('超過', 'VJ'),
#   ('賸餘', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('顯示', 'VK'),
#   ('過去', 'Nd'),
#   ('蔡', 'Nb'),
#   ('政府', 'Na'),
#   ('將', 'P'),
#   ('特別', 'VH'),
#   ('預', 'Na'),
#   ('算常態化', 'VF'),
#   ('、', 'PAUSECATEGORY'),
#   ('甚至', 'D'),
#   ('病態', 'VHC'),
#   ('化', 'VHC'),
#   ('。', 'PERIODCATEGORY'),
#   ('黃國昌', 'Nb'),
#   ('指出', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('民進黨', 'Nb'),
#   ('政府', 'Na'),
#   ('政策', 'Na'),
#   ('前後矛盾', 'D'),
#   ('，', 'COMMACATEGORY'),
#   ('過去', 'Nd'),
#   ('蔡政府', 'Nb'),
#   ('時', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('前行政院長', 'Nes'),
#   ('蘇貞昌力', 'Nb'),
#   ('推', 'VC'),
#   ('普發', 'Na'),
#   ('現金', 'Na'),
#   ('6000', 'Neu'),
#   ('元', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('如今', 'Nd'),
#   ('賴', 'Nb'),
#   ('政府', 'Na'),
#   ('卻', 'D'),
#   ('說', 'VE'),
#   ('要', 'D'),
#   ('先', 'D'),
#   ('還', 'VA'),
#   ('債', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('施', 'VA'),
#   ('政', 'Na'),
#   ('毫', 'VJ'),
#   ('無', 'VJ'),
#   ('一', 'A'),
#   ('貫', 'Na'),
#   ('邏輯', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('民眾黨', 'Nb'),
#   ('有', 'V_2'),
#   ('責任', 'Na'),
#   ('和', 'Caa'),
#   ('擔當', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('主張', 'VE'),
#   ('建立', 'VC'),
#   ('制度化', 'VHC'),
#   ('解決', 'VC'),
#   ('機制', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('讓', 'VL'),
#   ('國家', 'Na'),
#   ('走向', 'VCL'),
#   ('正軌', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('民眾', 'Na'),
#   ('黨團', 'Na'),
#   ('副', 'Na'),
#   ('總召', 'Na'),
#   ('張啓楷', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('民進黨', 'Nb'),
#   ('政府', 'Na'),
#   ('4', 'Neu'),
#   ('年', 'Nf'),
#   ('超', 'VC'),
#   ('徵', 'VC'),
#   ('1.8兆元', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('民眾黨', 'Nb'),
#   ('要', 'D'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('追', 'VC'),
#   ('責任', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('修', 'VA'),
#   ('法令', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('上游', 'Nc'),
#   ('的', 'DE'),
#   ('主計', 'A'),
#   ('總處', 'Nc'),
#   ('、', 'PAUSECATEGORY'),
#   ('國發會', 'Nc'),
#   ('和', 'Caa'),
#   ('財政部', 'Nc'),
#   ('等', 'Cab'),
#   ('部會', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('有', 'V_2'),
#   ('沒', 'D'),
#   ('有', 'V_2'),
#   ('問題', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('下游', 'Nc'),
#   ('針對', 'P'),
#   ('立委', 'Na'),
#   ('審', 'VC'),
#   ('的', 'DE'),
#   ('預算法', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('公債法', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('有', 'V_2'),
#   ('問題', 'Na'),
#   ('都', 'D'),
#   ('要', 'D'),
#   ('修法', 'VA'),
#   ('、', 'PAUSECATEGORY'),
#   ('補破網', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('政治', 'Na'),
#   ('大學', 'Nc'),
#   ('財政學系', 'Na'),
#   ('教授', 'Na'),
#   ('陳國樑', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('政府', 'Na'),
#   ('當務', 'Na'),
#   ('之', 'DE'),
#   ('急', 'VH'),
#   ('要', 'D'),
#   ('先', 'D'),
#   ('提', 'VC'),
#   ('高', 'VH'),
#   ('稅收', 'Na'),
#   ('預測', 'VE'),
#   ('的', 'DE'),
#   ('精準度', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('第二則', 'Neu'),
#   ('是', 'SHI'),
#   ('稅收', 'Na'),
#   ('超徵時', 'VJ'),
#   ('的', 'DE'),
#   ('法制化', 'VHC'),
#   ('處理', 'Nv'),
#   ('方式', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('建議', 'VE'),
#   ('參酌', 'VC'),
#   ('歐盟', 'Nb'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('債務', 'Na'),
#   ('調整', 'Nv'),
#   ('制度', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('把', 'P'),
#   ('政府', 'Na'),
#   ('赤字', 'Na'),
#   ('跟', 'P'),
#   ('債務', 'Na'),
#   ('還本', 'VC'),
#   ('能力', 'Na'),
#   ('連結', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('景氣', 'Na'),
#   ('衰退期', 'VH'),
#   ('間', 'Ng'),
#   ('適度', 'A'),
#   ('減', 'VHC'),
#   ('輕', 'VH'),
#   ('還本', 'A'),
#   ('壓力', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'Cbb'),
#   ('允許', 'VE'),
#   ('在', 'P'),
#   ('稅收', 'Na'),
#   ('低於', 'VJ'),
#   ('預期', 'Na'),
#   ('時', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('增加', 'VHC'),
#   ('舉債', 'VA'),
#   ('額度', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('台北', 'Nc'),
#   ('商業', 'Na'),
#   ('大學', 'Nc'),
#   ('財稅系', 'Nc'),
#   ('教授', 'Na'),
#   ('黃耀輝', 'Nb'),
#   ('指出', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('政府', 'Na'),
#   ('財政', 'Na'),
#   ('管理', 'Na'),
#   ('與', 'Caa'),
#   ('支出', 'Na'),
#   ('都', 'D'),
#   ('出', 'VC'),
#   ('問題', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('政府', 'Na'),
#   ('超收', 'VH'),
#   ('即', 'D'),
#   ('超', 'VH'),
#   ('花', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'D'),
#   ('未', 'D'),
#   ('有效', 'VH'),
#   ('償還', 'VD'),
#   ('公共', 'A'),
#   ('債務', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('建議', 'VE'),
#   ('超徵稅收', 'VJ'),
#   ('應', 'D'),
#   ('優先', 'D'),
#   ('用', 'VCL'),
#   ('於', 'P'),
#   ('還債', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('更', 'Dfa'),
#   ('應', 'D'),
#   ('提出', 'VC'),
#   ('具體', 'VH'),
#   ('稅制', 'Na'),
#   ('改革', 'VC'),
#   ('方案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('確保', 'VE'),
#   ('財政', 'Na'),
#   ('公', 'VH'),
#   ('平', 'VH'),
#   ('與', 'Caa'),
#   ('穩健', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('財政部', 'Nc'),
#   ('賦稅署長', 'Na'),
#   ('宋秀玲', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('觀察', 'VE'),
#   ('疫情', 'Na'),
#   ('期間', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('2020年', 'Nd'),
#   ('到', 'Caa'),
#   ('2023', 'Neu'),
#   ('年', 'Nf'),
#   ('稅收', 'Na'),
#   ('數字', 'Na'),
#   ('確實', 'D'),
#   ('有', 'V_2'),
#   ('落差', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('聽', 'VE'),
#   ('專家', 'Na'),
#   ('學者', 'Na'),
#   ('建議', 'VE'),
#   ('成立', 'VC'),
#   ('稅收', 'Na'),
#   ('估測', 'Nv'),
#   ('專家', 'Na'),
#   ('小組', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('發現', 'VE'),
#   ('營利', 'VA'),
#   ('事業', 'Na'),
#   ('所得', 'Na'),
#   ('稅', 'Na'),
#   ('和', 'Caa'),
#   ('綜合', 'A'),
#   ('所', 'Na'),
#   ('得', 'VJ'),
#   ('稅', 'Na'),
#   ('占', 'Na'),
#   ('比', 'Na'),
#   ('達', 'VJ'),
#   ('50%', 'Neqa'),
#   ('，', 'COMMACATEGORY'),
#   ('財政部', 'Nc'),
#   ('委請', 'VF'),
#   ('陳國樑', 'Nb'),
#   ('團隊', 'Na'),
#   ('做', 'VC'),
#   ('研究', 'VE'),
#   ('報告', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('因', 'Cbb'),
#   ('時', 'Na'),
#   ('間', 'Ng'),
#   ('落差', 'VH'),
#   ('的', 'DE'),
#   ('關係', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('才', 'Da'),
#   ('導致', 'VL'),
#   ('稅收', 'Na'),
#   ('誤差', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('黃國昌', 'Nb'),
#   ('也', 'D'),
#   ('質疑', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('政府', 'Na'),
#   ('對', 'P'),
#   ('普發', 'VH'),
#   ('現金', 'Nd'),
#   ('前', 'D'),
#   ('後立場', 'Ncd'),
#   ('不一', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('針對', 'P'),
#   ('普發', 'VH'),
#   ('現金', 'Na'),
#   ('所', 'D'),
#   ('帶來', 'VC'),
#   ('的', 'DE'),
#   ('經濟', 'Na'),
#   ('效益', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('是否', 'D'),
#   ('有', 'V_2'),
#   ('做', 'VC'),
#   ('評估', 'VE'),
#   ('。', 'PERIODCATEGORY'),
#   ('國家', 'Na'),
#   ('發展', 'Nv'),
#   ('委員會', 'Nc'),
#   ('經濟', 'Na'),
#   ('發展處', 'Nc'),
#   ('副處長', 'Na'),
#   ('陳美菊', 'Nb'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('過去', 'Nd'),
#   ('普發', 'VH'),
#   ('現金', 'Na'),
#   ('是', 'SHI'),
#   ('為', 'P'),
#   ('疫後', 'Na'),
#   ('振興', 'VC'),
#   ('經濟', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('強化', 'VHC'),
#   ('社會', 'Na'),
#   ('韌性', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('黃國昌', 'Nb'),
#   ('則', 'D'),
#   ('要求', 'VF'),
#   ('提供', 'VD'),
#   ('評估', 'VE'),
#   ('報告', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('民眾黨', 'Nb'),
#   ('指出', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('公聽會', 'Na'),
#   ('中', 'Ng'),
#   ('學者', 'Na'),
#   ('一致', 'VH'),
#   ('認為', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('目前', 'Nd'),
#   ('的', 'DE'),
#   ('租稅', 'Na'),
#   ('制度', 'Na'),
#   ('不公', 'VH'),
#   ('、', 'PAUSECATEGORY'),
#   ('財務', 'Na'),
#   ('模型', 'Na'),
#   ('有', 'V_2'),
#   ('檢討', 'VC'),
#   ('必', 'Na'),
#   ('要', 'VF'),
#   ('，', 'COMMACATEGORY'),
#   ('普遍', 'VH'),
#   ('不認同', 'D'),
#   ('超徵後', 'VC'),
#   ('直接', 'VH'),
#   ('以', 'P'),
#   ('普發', 'Na'),
#   ('現金', 'Na'),
#   ('處理', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('因為', 'Cbb'),
#   ('超徵', 'A'),
#   ('並', 'D'),
#   ('非', 'VG'),
#   ('多餘', 'A'),
#   ('資金', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('若', 'Cbb'),
#   ('將', 'P'),
#   ('超徵款', 'Na'),
#   ('普發', 'VH'),
#   ('現金', 'Na'),
#   ('或', 'Caa'),
#   ('以', 'P'),
#   ('其他', 'Neqa'),
#   ('形式', 'Na'),
#   ('退還，', 'VD'),
#   ('每', 'Nes'),
#   ('發', 'Nf'),
#   ('1元', 'Neu'),
#   ('都', 'D'),
#   ('可能', 'D'),
#   ('需要', 'VK'),
#   ('舉借新債', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('造', 'VG'),
#   ('成債留', 'VG'),
#   ('子孫', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('但', 'Cbb'),
#   ('若', 'Cbb'),
#   ('政府', 'Na'),
#   ('不', 'D'),
#   ('多', 'D'),
#   ('還債', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('仍', 'D'),
#   ('可', 'D'),
#   ('考慮', 'VE'),
#   ('將', 'P'),
#   ('部分', 'Neqa'),
#   ('超徵稅收', 'VC'),
#   ('以', 'P'),
#   ('普發', 'Na'),
#   ('現金', 'Na'),
#   ('方式', 'Na'),
#   ('返還給', 'VD'),
#   ('民眾', 'Na'),
#   ('。', 'PERIODCATEGORY')],
#  [('印度', 'Nc'),
#   ('電力部長', 'Na'),
#   ('卡塔爾', 'Nb'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('印度', 'Nc'),
#   ('正', 'D'),
#   ('積極', 'VH'),
#   ('準備', 'VC'),
#   ('在', 'P'),
#   ('2026年', 'Neu'),
#   ('底', 'Ng'),
#   ('前', 'Ng'),
#   ('推出', 'VC'),
#   ('備受', 'VJ'),
#   ('期待', 'VK'),
#   ('的', 'DE'),
#   ('碳', 'Na'),
#   ('市場', 'Nc'),
#   ('。', 'PERIODCATEGORY'),
#   ('這', 'Nep'),
#   ('項', 'Nf'),
#   ('政策', 'Na'),
#   ('預計', 'VE'),
#   ('發揮', 'VJ'),
#   ('重要', 'VH'),
#   ('作用', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('協助', 'VC'),
#   ('產業', 'Na'),
#   ('綠色', 'Na'),
#   ('轉型', 'VH'),
#   ('的', 'DE'),
#   ('同時', 'Nd'),
#   ('，', 'COMMACATEGORY'),
#   ('確保', 'VE'),
#   ('符合', 'VJ'),
#   ('國際', 'Nc'),
#   ('碳', 'Na'),
#   ('規範', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('碳', 'Na'),
#   ('產業', 'Na'),
#   ('新聞', 'Na'),
#   ('網站', 'Nc'),
#   ('Carbon Herald', 'FW'),
#   ('報導', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('卡塔爾', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Manohar', 'FW'),
#   (' ', 'WHITESPACE'),
#   ('Lal', 'FW'),
#   (' ', 'WHITESPACE'),
#   ('Khattar', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('2月', 'Nd'),
#   ('底', 'Ng'),
#   ('談及', 'VE'),
#   ('此事', 'Nep'),
#   ('時', 'Ng'),
#   ('說', 'VE'),
#   ('：', 'COLONCATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('我國', 'Nc'),
#   ('很', 'Dfa'),
#   ('快', 'VH'),
#   ('就', 'D'),
#   ('會', 'D'),
#   ('推出', 'VC'),
#   ('獨立', 'VH'),
#   ('的', 'DE'),
#   ('碳', 'Na'),
#   ('市場', 'Nc'),
#   ('…', 'FW'),
#   ('預計', 'VE'),
#   ('2026年', 'Neu'),
#   ('中', 'Ng'),
#   ('推出', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('根據', 'P'),
#   ('這', 'Nep'),
#   ('項', 'Nf'),
#   ('計畫', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('使用', 'VC'),
#   ('化石', 'Na'),
#   ('燃料', 'Na'),
#   ('或', 'Caa'),
#   ('排', 'VC'),
#   ('碳者', 'Na'),
#   ('必須', 'D'),
#   ('購買', 'VC'),
#   ('碳信用', 'Na'),
#   ('額度', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('反之', 'Dk'),
#   ('使用', 'VC'),
#   ('非', 'Na'),
#   ('化石', 'Na'),
#   ('燃料', 'Na'),
#   ('能源', 'Na'),
#   ('的', 'DE'),
#   ('人', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'D'),
#   ('取得', 'VC'),
#   ('可', 'D'),
#   ('在', 'P'),
#   ('碳', 'Na'),
#   ('市場', 'Nc'),
#   ('出售', 'VC'),
#   ('的', 'DE'),
#   ('碳', 'Na'),
#   ('信用', 'Na'),
#   ('額度', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('目前', 'Nd'),
#   ('印度', 'Nc'),
#   ('尚未', 'D'),
#   ('建立', 'VC'),
#   ('的', 'DE'),
#   ('碳', 'Na'),
#   ('交易', 'Na'),
#   ('市場', 'Nc'),
#   ('將', 'D'),
#   ('於', 'P'),
#   ('2026年', 'Neu'),
#   ('啟動', 'VC'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('碳', 'Na'),
#   ('市場', 'Nc'),
#   ('對於', 'P'),
#   ('印度', 'Nc'),
#   ('出口商', 'Na'),
#   ('尤為', 'D'),
#   ('重要', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('因為', 'Cbb'),
#   ('他們', 'Nh'),
#   ('必須', 'D'),
#   ('符合', 'VJ'),
#   ('全球', 'Nc'),
#   ('碳', 'Na'),
#   ('排', 'Na'),
#   ('規範', 'Na'),
#   ('來', 'D'),
#   ('維持', 'VJ'),
#   ('競', 'Na'),
#   ('爭力', 'VA'),
#   ('。', 'PERIODCATEGORY'),
#   ('卡', 'Nb'),
#   ('塔爾', 'Nb'),
#   ('強調', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('符合', 'VJ'),
#   ('國際', 'Nc'),
#   ('碳', 'Na'),
#   ('規範', 'Na'),
#   ('對', 'P'),
#   ('企業', 'Na'),
#   ('來說', 'Ng'),
#   ('非常', 'Dfa'),
#   ('重要', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('尤其', 'D'),
#   ('是', 'SHI'),
#   ('要', 'D'),
#   ('外銷到', 'VCL'),
#   ('環保', 'Na'),
#   ('嚴格', 'VH'),
#   ('市場', 'Nc'),
#   ('的', 'DE'),
#   ('業者', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('由於', 'Cbb'),
#   ('歐', 'Nb'),
#   ('盟', 'Na'),
#   ('的', 'DE'),
#   ('碳', 'Nc'),
#   ('邊境', 'Nc'),
#   ('調整', 'VC'),
#   ('機制', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('CBAM', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('對', 'P'),
#   ('碳', 'Na'),
#   ('密集', 'VH'),
#   ('進口', 'VC'),
#   ('商品', 'Na'),
#   ('徵收', 'VC'),
#   ('碳稅', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('鋼鐵', 'Na'),
#   ('和', 'Caa'),
#   ('水泥', 'Na'),
#   ('等', 'Cab'),
#   ('產業', 'Na'),
#   ('都', 'D'),
#   ('對', 'P'),
#   ('此', 'Nep'),
#   ('表示', 'VE'),
#   ('擔憂', 'VK'),
#   ('。', 'PERIODCATEGORY'),
#   ('引入', 'VC'),
#   ('碳', 'Na'),
#   ('信用', 'Na'),
#   ('額度', 'Na'),
#   ('將', 'D'),
#   ('激勵', 'VC'),
#   ('印度', 'Nc'),
#   ('製造商', 'Na'),
#   ('採用', 'VC'),
#   ('綠色', 'Na'),
#   ('能源', 'Na'),
#   ('方案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('以', 'P'),
#   ('減少', 'VHC'),
#   ('碳排並', 'Na'),
#   ('確保更', 'VE'),
#   ('符合', 'VJ'),
#   ('歐盟', 'Nb'),
#   ('法規。', 'Na'),
#   ('印度', 'Nc'),
#   ('碳', 'Na'),
#   ('市場', 'Nc'),
#   ('的', 'DE'),
#   ('基礎', 'Na'),
#   ('於', 'P'),
#   ('2022年', 'Neu'),
#   ('奠定', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('當年', 'Nd'),
#   ('通過', 'P'),
#   ('的', 'DE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('節能', 'VH'),
#   ('修正法', 'VC'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('E', 'FW'),
#   ('nergy', 'FW'),
#   (' ', 'WHITESPACE'),
#   ('Conservation ', 'FW'),
#   ('(', 'PARENTHESISCATEGORY'),
#   ('A', 'FW'),
#   ('mendment)', 'FW'),
#   (' Bill', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('為', 'P'),
#   ('碳', 'Na'),
#   ('交易制度', 'Na'),
#   ('鋪路', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('讓', 'VL'),
#   ('企業', 'Na'),
#   ('能', 'D'),
#   ('買賣', 'VC'),
#   ('碳', 'Na'),
#   ('信用', 'Na'),
#   ('額度', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'Cbb'),
#   ('透過', 'P'),
#   ('財務', 'Na'),
#   ('獎勵', 'VC'),
#   ('促進', 'VK'),
#   ('永續', 'VH'),
#   ('發展', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('鼓勵', 'VF'),
#   ('企業', 'Na'),
#   ('減排', 'VA'),
#   ('。', 'PERIODCATEGORY')],
#  [('2025年', 'Nd'),
#   ('世界', 'Nc'),
#   ('行動', 'Na'),
#   ('通訊', 'Na'),
#   ('大會', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('MWC', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('今天', 'Nd'),
#   ('起', 'VC'),
#   ('在', 'P'),
#   ('西班牙', 'Nc'),
#   ('巴塞隆納', 'Nc'),
#   ('登場', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('吸引', 'VJ'),
#   ('全球', 'Nc'),
#   ('科技業', 'Na'),
#   ('目光', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('代工廠', 'Nc'),
#   ('廣達', 'Nb'),
#   ('子公司', 'Nc'),
#   ('雲達', 'Nb'),
#   ('科技', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('板卡廠技', 'Na'),
#   ('嘉都', 'Nc'),
#   ('親自', 'D'),
#   ('與會', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('展示', 'VC'),
#   ('人工', 'Na'),
#   ('智慧', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('AI', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('、', 'PAUSECATEGORY'),
#   ('邊緣', 'Nc'),
#   ('運算', 'VC'),
#   ('及', 'Caa'),
#   ('機器人', 'Na'),
#   ('等', 'Cab'),
#   ('最', 'Dfa'),
#   ('新', 'VH'),
#   ('技術', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('雲達', 'Nb'),
#   ('發布', 'VC'),
#   ('新聞稿', 'Na'),
#   ('說明', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('今年', 'Nd'),
#   ('MWC', 'FW'),
#   ('大會', 'Na'),
#   ('上', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'P'),
#   ('展示', 'VC'),
#   ('與', 'Caa'),
#   ('Red Hat', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('Samsung', 'FW'),
#   (' Electronics', 'FW'),
#   (' Co., Ltd.', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('Solomon', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('新加坡', 'Nc'),
#   ('科技', 'Na'),
#   ('設計', 'Na'),
#   ('大學', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('台灣', 'Nc'),
#   ('大哥大', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('達明', 'Nb'),
#   ('機器人', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('Viavi', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('Vossic', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('Wind River', 'FW'),
#   ('等', 'Cab'),
#   ('廠商', 'Na'),
#   ('和', 'Caa'),
#   ('開放', 'VC'),
#   ('社群', 'Na'),
#   ('的', 'DE'),
#   ('最', 'Dfa'),
#   ('新合作', 'VH'),
#   ('成果', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('雲達', 'Nb'),
#   ('也', 'D'),
#   ('將', 'D'),
#   ('展示', 'VC'),
#   ('最', 'Dfa'),
#   ('新取得', 'D'),
#   ('認證', 'VA'),
#   ('的', 'DE'),
#   ('邊緣伺服器', 'Nc'),
#   ('、', 'PAUSECATEGORY'),
#   ('OmniPOD端', 'FW'),
#   ('到', 'P'),
#   ('端', 'Ncd'),
#   ('5G', 'FW'),
#   ('企業', 'Na'),
#   ('專網', 'Na'),
#   ('解決', 'VC'),
#   ('方案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('以及', 'Caa'),
#   ('與', 'P'),
#   ('夥伴', 'Na'),
#   ('的', 'DE'),
#   ('多', 'Neqa'),
#   ('項', 'Nf'),
#   ('合作', 'Nv'),
#   ('，', 'COMMACATEGORY'),
#   ('包括', 'VK'),
#   ('人工', 'Na'),
#   ('智慧/', 'Na'),
#   ('機器', 'Na'),
#   ('學習', 'VC'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('A', 'FW'),
#   ('I/ML', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('節能', 'VH'),
#   ('模型', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('數位', 'A'),
#   ('孿生', 'A'),
#   ('模擬', 'VC'),
#   ('、', 'PAUSECATEGORY'),
#   ('遠距', 'A'),
#   ('人工', 'Na'),
#   ('智慧物', 'Na'),
#   ('聯網', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('AIoT', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('、', 'PAUSECATEGORY'),
#   ('自動化', 'VHC'),
#   ('機器人', 'Na'),
#   ('、', 'PAUSECATEGORY'),
#   ('智慧', 'Na'),
#   ('校園', 'Nc'),
#   ('等', 'Cab'),
#   ('。', 'PERIODCATEGORY'),
#   ('雲達', 'Nb'),
#   ('科技', 'Na'),
#   ('總經理', 'Na'),
#   ('楊麒令', 'Nb'),
#   ('表示', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('藉由', 'P'),
#   ('與', 'P'),
#   ('生態系統', 'Na'),
#   ('合作', 'VH'),
#   ('夥伴', 'Na'),
#   ('密切', 'VH'),
#   ('合作', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('雲達', 'Nb'),
#   ('能夠', 'D'),
#   ('創新', 'VC'),
#   ('並', 'Cbb'),
#   ('提供', 'VD'),
#   ('推動', 'VC'),
#   ('產業', 'Na'),
#   ('前進', 'VA'),
#   ('的', 'DE'),
#   ('尖', 'A'),
#   ('端', 'VC'),
#   ('解決', 'VC'),
#   ('方案', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('透過', 'P'),
#   ('在', 'P'),
#   ('AI', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('邊緣', 'Nc'),
#   ('運算', 'VC'),
#   ('和', 'Caa'),
#   ('機器人', 'Na'),
#   ('技術', 'Na'),
#   ('方面', 'Na'),
#   ('的', 'DE'),
#   ('最', 'Dfa'),
#   ('新', 'VH'),
#   ('努力', 'Nv'),
#   ('，', 'COMMACATEGORY'),
#   ('可以', 'D'),
#   ('確保', 'VE'),
#   ('能夠', 'D'),
#   ('滿足', 'VHC'),
#   ('客戶', 'Na'),
#   ('不斷', 'D'),
#   ('變化', 'VHC'),
#   ('的', 'DE'),
#   ('需求', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('技嘉將', 'Nb'),
#   ('在', 'P'),
#   ('MWC 2025', 'FW'),
#   ('展示', 'VC'),
#   ('從', 'P'),
#   ('A', 'FW'),
#   ('I', 'FW'),
#   ('開發到', 'VC'),
#   ('部署', 'VC'),
#   ('的', 'DE'),
#   ('運算解決', 'VC'),
#   ('方案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('呼應', 'VC'),
#   ('大會', 'Na'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('企業', 'Na'),
#   ('再創', 'D'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('及', 'Caa'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('A', 'FW'),
#   ('I', 'FW'),
#   ('加乘', 'VC'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('主題', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('技嘉', 'Nb'),
#   ('的', 'DE'),
#   ('AI', 'FW'),
#   ('開發', 'VC'),
#   ('解決', 'VC'),
#   ('方案', 'Na'),
#   ('包括新世代', 'VK'),
#   ('G893 AI', 'FW'),
#   ('伺服器', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('可', 'D'),
#   ('支援', 'VC'),
#   ('NVID', 'FW'),
#   ('IA B200', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('AMD MI325X', 'FW'),
#   ('、', 'PAUSECATEGORY'),
#   ('Intel', 'FW'),
#   (' Gaudi-3', 'FW'),
#   ('等', 'Cab'),
#   ('繪圖', 'VA'),
#   ('處理器', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('GPU', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('另', 'Cbb'),
#   ('將', 'D'),
#   ('展示', 'VC'),
#   ('叢集式', 'A'),
#   ('運算', 'VC'),
#   ('產品', 'Na'),
#   ('GIGAPOD', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('提供', 'VD'),
#   ('一站式', 'A'),
#   ('AI', 'FW'),
#   ('訓練', 'Na'),
#   ('解決', 'VC'),
#   ('方案', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('針對', 'P'),
#   ('AI', 'FW'),
#   ('部署', 'VC'),
#   ('方案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('技嘉', 'Nb'),
#   ('將', 'D'),
#   ('展出', 'VC'),
#   ('R', 'FW'),
#   ('系列', 'Na'),
#   ('伺服器', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('採用', 'VC'),
#   ('CXL', 'FW'),
#   ('記憶體', 'Na'),
#   ('互連', 'D'),
#   ('技術', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('可', 'D'),
#   ('降低', 'VHC'),
#   ('傳輸', 'VC'),
#   ('延遲', 'VHC'),
#   ('與', 'Caa'),
#   ('布建成本', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('另', 'Cbb'),
#   ('將', 'D'),
#   ('首度', 'D'),
#   ('公開', 'VHC'),
#   ('3', 'Neu'),
#   ('U刀鋒式', 'Nf'),
#   ('終端', 'Nc'),
#   ('伺服器', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('提供', 'VD'),
#   ('高密度', 'VH'),
#   ('運算', 'Nv'),
#   ('架構', 'Na'),
#   ('。', 'PERIODCATEGORY')],
#  [('歐洲', 'Nc'),
#   ('新', 'VH'),
#   ('的', 'DE'),
#   ('重型', 'Na'),
#   ('載運', 'VC'),
#   ('火箭', 'Na'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('阿利安6型', 'Nb'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('預計', 'VE'),
#   ('今天', 'Nd'),
#   ('執行', 'VC'),
#   ('首', 'Nes'),
#   ('趟', 'Nf'),
#   ('商業', 'Na'),
#   ('飛行', 'Nv'),
#   ('任務', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('在', 'P'),
#   ('美國', 'Nc'),
#   ('與', 'Caa'),
#   ('俄羅斯', 'Nc'),
#   ('關係', 'Na'),
#   ('出乎', 'VJ'),
#   ('預料', 'VE'),
#   ('破冰', 'VH'),
#   ('之', 'DE'),
#   ('際', 'Nd'),
#   ('，', 'COMMACATEGORY'),
#   ('歐洲', 'Nc'),
#   ('國家', 'Na'),
#   ('試圖', 'VF'),
#   ('確保', 'VE'),
#   ('自己', 'Nh'),
#   ('有', 'V_2'),
#   ('能力', 'Na'),
#   ('獨力', 'D'),
#   ('進入', 'VCL'),
#   ('太空', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('法新社', 'Nc'),
#   ('報導', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('阿利安', 'Nb'),
#   ('6型', 'Neu'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Ariane 6', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('經過', 'VCL'),
#   ('數', 'Neu'),
#   ('次', 'Nf'),
#   ('延宕', 'VH'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'D'),
#   ('於', 'P'),
#   ('當地', 'Nc'),
#   ('時間', 'Na'),
#   ('今天', 'Nd'),
#   ('下午', 'Nd'),
#   ('1時', 'Neu'),
#   ('24分', 'Nd'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('時間', 'Na'),
#   ('4日', 'Nd'),
#   ('凌晨', 'Nd'),
#   ('0時', 'Nd'),
#   ('24分', 'Nd'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('從', 'P'),
#   ('法屬', 'A'),
#   ('圭亞那', 'Nb'),
#   ('的', 'DE'),
#   ('庫魯', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Kourou', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('發射場', 'Nc'),
#   ('發射', 'VC'),
#   ('升空', 'VA'),
#   ('。', 'PERIODCATEGORY'),
#   ('這', 'Nep'),
#   ('將', 'D'),
#   ('是', 'SHI'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('阿利安', 'Nb'),
#   ('6型', 'Neu'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('自', 'P'),
#   ('去年', 'Nd'),
#   ('7月', 'Nd'),
#   ('首次', 'Nes'),
#   ('試射', 'VC'),
#   ('以來', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('第2', 'Neu'),
#   ('次', 'Nf'),
#   ('升空', 'VA'),
#   ('。', 'PERIODCATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('阿利安6型', 'Nb'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('將', 'D'),
#   ('載運', 'VC'),
#   ('法國', 'Nc'),
#   ('軍用', 'A'),
#   ('衛星', 'Na'),
#   ('CSO-3', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('預計', 'VE'),
#   ('將', 'P'),
#   ('該', 'Nes'),
#   ('顆', 'Nf'),
#   ('衛星', 'Na'),
#   ('放', 'VC'),
#   ('置離', 'VC'),
#   ('地表', 'Nc'),
#   ('約', 'Da'),
#   ('800', 'Neu'),
#   ('公里', 'Nf'),
#   ('高', 'VH'),
#   ('的', 'DE'),
#   ('軌道', 'Na'),
#   ('上', 'Ncd'),
#   ('。', 'PERIODCATEGORY'),
#   ('CSO-3', 'FW'),
#   ('有望', 'VH'),
#   ('提', 'VC'),
#   ('升', 'VC'),
#   ('法國', 'Nc'),
#   ('的', 'DE'),
#   ('軍事', 'Na'),
#   ('自主', 'VH'),
#   ('程度', 'Na'),
#   ('及', 'Caa'),
#   ('強化', 'VHC'),
#   ('法軍', 'Na'),
#   ('的', 'DE'),
#   ('情蒐', 'Nv'),
#   ('能力', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('法國', 'Nc'),
#   ('執行', 'VC'),
#   ('這', 'Nep'),
#   ('項', 'Nf'),
#   ('引人注目', 'VH'),
#   ('的', 'DE'),
#   ('太空', 'Na'),
#   ('任務', 'Na'),
#   ('之', 'DE'),
#   ('際', 'Nd'),
#   ('，', 'COMMACATEGORY'),
#   ('法國', 'Nc'),
#   ('總統', 'Na'),
#   ('馬', 'Nb'),
#   ('克宏', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('E', 'FW'),
#   ('mmanuel', 'FW'),
#   (' Macron', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('正', 'D'),
#   ('呼籲', 'VE'),
#   ('歐洲', 'Nc'),
#   ('降低', 'VHC'),
#   ('對', 'P'),
#   ('美國', 'Nc'),
#   ('的', 'DE'),
#   ('安全', 'VH'),
#   ('依賴', 'VK'),
#   ('；', 'SEMICOLONCATEGORY'),
# ...
#   ('心全意', 'Na'),
#   ('投入', 'VC'),
#   ('時', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('夢想', 'Na'),
#   ('也', 'D'),
#   ('會', 'D'),
#   ('向', 'P'),
#   ('你', 'Nh'),
#   ('靠近', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('陳彥', 'Nb'),
#   ('博', 'Dfa'),
#   ('從', 'P'),
#   ('開賽', 'VH'),
#   ('即', 'D'),
#   ('始終', 'D'),
#   ('保持', 'VJ'),
#   ('在', 'P'),
#   ('領先', 'VJ'),
#   ('群位置', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('目前', 'Nd'),
#   ('已', 'D'),
#   ('經通過', 'P'),
#   ('第4', 'Neu'),
#   ('檢查站', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('完成', 'VC'),
#   ('接近', 'VC'),
#   ('一半', 'Neqa'),
#   ('的', 'DE'),
#   ('賽程', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('總', 'Na'),
#   ('排名', 'Na'),
#   ('則', 'D'),
#   ('暫居', 'VJ'),
#   ('第3', 'Neu'),
#   ('名', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('落後', 'VJ'),
#   ('給', 'P'),
#   ('英國', 'Nc'),
#   ('選手', 'Na'),
#   ('貝爾奇爾', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Guy Belchier', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('、', 'PAUSECATEGORY'),
#   ('澳洲', 'Nc'),
#   ('選手', 'Na'),
#   ('庫克斯', 'Nb'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('Aaron Crook', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('然而', 'Cbb'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('連續', 'D'),
#   ('低溫', 'Na'),
#   ('及', 'Caa'),
#   ('長', 'VH'),
#   ('距離', 'Na'),
#   ('移動', 'VAC'),
#   ('下', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('陳彥博', 'Nb'),
#   ('的', 'DE'),
#   ('雙腳', 'Na'),
#   ('因為', 'Cbb'),
#   ('水泡', 'Na'),
#   ('產生', 'VHC'),
#   ('發炎', 'VH'),
#   ('與', 'Caa'),
#   ('灼熱感', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('經', 'P'),
#   ('醫療', 'VC'),
#   ('人員', 'Na'),
#   ('診斷', 'VC'),
#   ('可能', 'D'),
#   ('是', 'SHI'),
#   ('感染', 'VJ'),
#   ('所', 'VH'),
#   ('致', 'VL'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('他', 'Nh'),
#   ('仍', 'D'),
#   ('選擇', 'VC'),
#   ('堅持比賽', 'VK'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('檢查站', 'Nc'),
#   ('短暫', 'VH'),
#   ('休息', 'VA'),
#   ('2', 'Neu'),
#   ('小時', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('並', 'Cbb'),
#   ('自行', 'D'),
#   ('處理', 'VC'),
#   ('傷口', 'Na'),
#   ('確保', 'VE'),
#   ('不', 'D'),
#   ('會', 'D'),
#   ('惡化', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('他', 'Nh'),
#   ('說', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('現在', 'Nd'),
#   ('只', 'Da'),
#   ('想', 'VJ'),
#   ('平安完賽', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('不', 'D'),
#   ('想', 'VE'),
#   ('再', 'D'),
#   ('衝', 'VJ'),
#   ('太', 'Dfa'),
#   ('快', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('沿途', 'Nc'),
#   ('我', 'Nh'),
#   ('會', 'D'),
#   ('一直', 'D'),
#   ('換', 'VC'),
#   ('襪子', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('確保', 'VE'),
#   ('腳', 'Na'),
#   ('的', 'DE'),
#   ('乾燥', 'VH'),
#   ('。', 'PERIODCATEGORY'),
#   ('」', 'PARENTHESISCATEGORY')],
#  [('中職', 'Na'),
#   ('中信', 'Ng'),
#   ('兄弟', 'Na'),
#   ('近', 'Da'),
#   ('4', 'Neu'),
#   ('年', 'Nf'),
#   ('奪', 'VC'),
#   ('3', 'Neu'),
#   ('座', 'Nf'),
#   ('總冠軍', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('球團', 'Na'),
#   ('今天', 'Nd'),
#   ('公布', 'VE'),
#   ('球員', 'Na'),
#   ('調薪', 'VH'),
#   ('結果', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('整體', 'Na'),
#   ('薪資', 'Na'),
#   ('調幅', 'Na'),
#   ('超過', 'VJ'),
#   ('11.4%', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('許基宏', 'Nb'),
#   ('簽下', 'VC'),
#   ('5', 'Neu'),
#   ('年', 'Nf'),
#   ('平均', 'VH'),
#   ('月薪', 'Na'),
#   ('新台幣', 'Na'),
#   ('80萬', 'Neu'),
#   ('元', 'Nf'),
#   ('合約', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('野手', 'Na'),
#   ('王威晨', 'Nb'),
#   ('、', 'PAUSECATEGORY'),
#   ('投手', 'Na'),
#   ('李振昌', 'Nb'),
#   ('獲', 'VJ'),
#   ('複數', 'Na'),
#   ('年約', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('兄弟', 'Na'),
#   ('今天', 'Nd'),
#   ('發布', 'VC'),
#   ('新聞稿', 'Na'),
#   ('公布', 'VC'),
#   ('新球季', 'VH'),
#   ('球員', 'Na'),
#   ('談薪', 'VE'),
#   ('結果', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('2025年', 'Neu'),
#   ('球', 'Nd'),
#   ('季', 'Nd'),
#   ('全', 'Neqa'),
#   ('隊', 'Nf'),
#   ('薪資', 'Na'),
#   ('微幅', 'D'),
#   ('調整', 'VC'),
#   ('超過', 'VJ'),
#   ('11.4%', 'Neu'),
#   ('。', 'PERIODCATEGORY'),
#   ('中信', 'Nb'),
#   ('兄弟', 'Na'),
#   ('球團', 'Na'),
#   ('感謝', 'VK'),
#   ('球員', 'Na'),
#   ('們', 'Na'),
#   ('為', 'P'),
#   ('球隊', 'Na'),
#   ('的', 'DE'),
#   ('付出', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('也', 'D'),
#   ('期盼', 'VK'),
#   ('今年', 'Nd'),
#   ('能夠', 'D'),
#   ('一起', 'D'),
#   ('邁向', 'VCL'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('連霸', 'VH'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('之', 'DE'),
#   ('路', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('共同', 'A'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('進化', 'VH'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('。', 'PERIODCATEGORY'),
#   ('兄弟', 'Na'),
#   ('野手', 'Na'),
#   ('許基宏', 'Nb'),
#   ('於', 'P'),
#   ('2014年', 'Neu'),
#   ('季中', 'Nd'),
#   ('加入', 'VC'),
#   ('團隊', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('去年', 'Nd'),
#   ('球季', 'Nd'),
#   ('結束', 'VHC'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('積極', 'VH'),
#   ('與', 'P'),
#   ('球團', 'Na'),
#   ('討論', 'VE'),
#   ('留隊', 'VC'),
#   ('的', 'DE'),
#   ('規劃', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('兄弟', 'Na'),
#   ('球團', 'Na'),
#   ('與', 'Caa'),
#   ('許基宏', 'Nb'),
#   ('達成', 'VC'),
#   ('5', 'Neu'),
#   ('年', 'Nf'),
#   ('平均', 'VH'),
#   ('月薪', 'Na'),
#   ('80萬', 'Neu'),
#   ('元', 'Nf'),
#   ('的', 'DE'),
#   ('合約', 'Na'),
#   ('共識', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('今年', 'Nd'),
#   ('月薪', 'Na'),
#   ('也', 'D'),
#   ('由', 'P'),
#   ('5', 'FW'),
#   ('2萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升至', 'VHC'),
#   ('64萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('23.1%', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('期待', 'VK'),
#   ('許基宏', 'Nb'),
#   ('在', 'P'),
#   ('接下來', 'D'),
#   ('的', 'DE'),
#   ('5年', 'Neu'),
#   ('持續', 'VL'),
#   ('披上', 'VC'),
#   ('黃', 'Na'),
#   ('衫', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('為', 'P'),
#   ('中信', 'Nb'),
#   ('兄弟', 'Na'),
#   ('努力', 'VH'),
#   ('奮戰', 'VA'),
#   ('。', 'PERIODCATEGORY'),
#   ('兼', 'VG'),
#   ('俱', 'D'),
#   ('領導', 'VC'),
#   ('能力', 'Na'),
#   ('的', 'DE'),
#   ('野手', 'Na'),
#   ('王威晨', 'Nb'),
#   ('與', 'Caa'),
#   ('投手', 'Na'),
#   ('李振昌', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('今年', 'Nd'),
#   ('皆', 'D'),
#   ('與', 'P'),
#   ('球團', 'Na'),
#   ('簽訂', 'VC'),
#   ('複數年合約', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('王威晨', 'Nb'),
#   ('今年', 'Nd'),
#   ('月薪', 'Na'),
#   ('77萬元', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('李振昌', 'Nb'),
#   ('則', 'D'),
#   ('是', 'SHI'),
#   ('月薪', 'Na'),
#   ('63萬', 'Neu'),
#   ('元', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('期待', 'VK'),
#   ('兩', 'Neu'),
#   ('人', 'Na'),
#   ('持續', 'VL'),
#   ('用', 'P'),
#   ('表現', 'VC'),
#   ('帶領', 'VF'),
#   ('團隊', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('也', 'D'),
#   ('為', 'P'),
#   ('球隊', 'Na'),
#   ('帶給', 'VD'),
#   ('學弟', 'Na'),
#   ('們', 'Na'),
#   ('更多', 'Neqa'),
#   ('正面', 'Na'),
#   ('影響力', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('2019年', 'Neu'),
#   ('季中', 'Nd'),
#   ('選秀', 'Na'),
#   ('加入', 'VC'),
#   ('兄弟', 'Na'),
#   ('的', 'DE'),
#   ('曾頌恩', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('2024年', 'Neu'),
#   ('迎來', 'VC'),
#   ('個人', 'Nh'),
#   ('生涯', 'Na'),
#   ('年，', 'Nd'),
#   ('在', 'P'),
#   ('攻守', 'VA'),
#   ('兩端', 'Neu'),
#   ('都', 'D'),
#   ('呈現破繭', 'VJ'),
#   ('而出', 'Cbb'),
#   ('的', 'DE'),
#   ('佳績', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('更', 'Dfa'),
#   ('一舉', 'D'),
#   ('拿下', 'VC'),
#   ('總冠軍賽', 'Na'),
#   ('MVP', 'FW'),
#   ('的', 'DE'),
#   ('殊榮', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('入圍', 'VJ'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('年度', 'Na'),
#   ('最', 'A'),
#   ('佳', 'VH'),
#   ('進步', 'Na'),
#   ('獎」', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('兄弟', 'Na'),
#   ('球團', 'Na'),
#   ('公布，', 'VE'),
#   ('曾頌恩', 'Nb'),
#   ('今年', 'Nd'),
#   ('月薪', 'Na'),
#   ('也', 'D'),
#   ('由', 'P'),
#   ('1', 'Neu'),
#   ('3萬元', 'Neu'),
#   ('調升至', 'VHC'),
#   ('24萬元', 'Neu'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('84.6%', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('期待', 'VK'),
#   ('曾頌恩', 'Nb'),
#   ('能夠', 'D'),
#   ('繼續', 'VF'),
#   ('以高水準', 'P'),
#   ('的', 'DE'),
#   ('表現', 'Na'),
#   ('再創生涯', 'D'),
#   ('高峰', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('迎接', 'VC'),
#   ('未來', 'Nd'),
#   ('每', 'Nes'),
#   ('場', 'Nf'),
#   ('艱難', 'VH'),
#   ('戰役', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('近年', 'Nd'),
#   ('兄弟', 'Na'),
#   ('後援防線', 'Na'),
#   ('最', 'Dfa'),
#   ('倚重', 'VJ'),
#   ('的', 'DE'),
#   ('兩', 'Neu'),
#   ('名', 'Nf'),
#   ('投手', 'Na'),
#   ('呂彥青', 'Nb'),
#   ('與', 'Caa'),
#   ('吳俊偉', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('今年', 'Nd'),
#   ('也', 'D'),
#   ('雙雙', 'D'),
#   ('獲得加薪', 'VJ'),
#   ('。', 'PERIODCATEGORY'),
#   ('呂彥青', 'Nb'),
#   ('今年', 'Nd'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('50萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升', 'VC'),
#   ('至', 'P'),
#   ('62萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('24%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('吳俊偉', 'Nb'),
#   ('則', 'D'),
#   ('是', 'SHI'),
#   ('由', 'P'),
#   ('月薪', 'Na'),
#   ('38萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升至', 'VHC'),
#   ('50萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('31.6%', 'Neqa'),
#   ('。', 'PERIODCATEGORY'),
#   ('其他', 'Neqa'),
#   ('調薪', 'VH'),
#   ('部分', 'Neqa'),
#   ('，', 'COMMACATEGORY'),
#   ('野手', 'Na'),
#   ('岳東華', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('36萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升至', 'VHC'),
#   ('48萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('33.3%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('野手', 'Na'),
#   ('岳政華', 'Nb'),
#   ('月薪', 'Na'),
#   ('30萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升至', 'VC'),
#   ('42萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('40%', 'Neu'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('捕手', 'Na'),
#   ('高宇杰', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('26萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升', 'VC'),
#   ('至', 'P'),
#   ('38萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('46.2%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('野手', 'Na'),
#   ('王政順', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('16.5萬元', 'Neu'),
#   ('調升至', 'VC'),
#   ('20萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('21.2%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('捕手', 'Na'),
#   ('林吳晉瑋', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('1', 'Neu'),
#   ('1萬元', 'Neu'),
#   ('調升至', 'VC'),
#   ('15萬', 'Neu'),
#   ('元', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('調幅', 'Na'),
#   ('36.4%', 'Neu'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('投手', 'Na'),
#   ('謝榮豪', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('21', 'Neu'),
#   ('元', 'Nf'),
#   ('萬', 'VH'),
#   ('調升至', 'VC'),
#   ('28萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('33.3%', 'Neqa'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('投手', 'Na'),
#   ('黃恩賜', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('16萬', 'Neu'),
#   ('元', 'Nf'),
#   ('調升至', 'VC'),
#   ('22萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('37.5%', 'Neu'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('投手', 'Na'),
#   ('魏碩成', 'Nb'),
#   ('月薪', 'Na'),
#   ('由', 'P'),
#   ('15萬元', 'Neu'),
#   ('調升至', 'VC'),
#   ('19萬元', 'Neu'),
#   ('、', 'PAUSECATEGORY'),
#   ('調幅', 'Na'),
#   ('26.7%', 'Neu'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('野手', 'Na'),
#   ('宋晟睿', 'Nb'),
#   ('本季', 'Nes'),
#   ('也', 'D'),
#   ('獲', 'VJ'),
#   ('加薪', 'VB'),
#   ('6萬元', 'Neu'),
#   ('。', 'PERIODCATEGORY'),
#   ('兄弟', 'Na'),
#   ('球團', 'Na'),
#   ('對於', 'P'),
#   ('表現', 'VC'),
#   ('優異', 'VH'),
#   ('選手', 'Na'),
#   ('給予', 'VD'),
#   ('加薪', 'VB'),
#   ('肯定', 'VK'),
#   ('，', 'COMMACATEGORY'),
#   ('而', 'Cbb'),
#   ('表現差', 'VC'),
#   ('強人意', 'VH'),
#   ('的', 'DE'),
#   ('球員', 'Na'),
#   ('則', 'D'),
#   ('小幅', 'D'),
#   ('降薪', 'VB'),
#   ('。', 'PERIODCATEGORY'),
#   ('小幅扣薪', 'D'),
#   ('部分', 'Neqa'),
#   ('，', 'COMMACATEGORY'),
#   ('投手', 'Na'),
#   ('鄭浩均', 'Nb'),
#   ('月薪', 'Na'),
#   ('38萬元', 'Neu'),
#   ('調降至', 'VHC'),
#   ('35萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('吳哲源', 'Nb'),
#   ('月薪', 'Na'),
#   ('22萬元', 'Neu'),
#   ('調降至', 'VHC'),
#   ('20萬元', 'Neu'),
#   ('、', 'PAUSECATEGORY'),
#   ('楊志龍', 'Nb'),
#   ('月薪', 'Na'),
#   ('15萬元', 'Neu'),
#   ('調降至', 'VHC'),
#   ('12.5萬', 'Neu'),
#   ('元', 'Nf'),
#   ('、', 'PAUSECATEGORY'),
#   ('江忠城', 'Nb'),
#   ('月薪', 'Na'),
#   ('13.5萬元', 'Neu'),
#   ('調降至', 'VHC'),
#   ('1', 'Neu'),
#   ('0萬元', 'Neu'),
#   ('。', 'PERIODCATEGORY')],
#  [('美國', 'Nc'),
#   ('職棒', 'Na'),
#   ('奧克蘭', 'Nb'),
#   ('運動家隊', 'Na'),
#   ('公布', 'VE'),
#   ('大聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('名單', 'Na'),
#   ('異動', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('下放', 'Nes'),
#   ('7', 'Neu'),
#   ('名', 'Nf'),
#   ('球員', 'Na'),
#   ('包括', 'VK'),
#   ('台灣', 'Nc'),
#   ('投手', 'Na'),
#   ('莊陳仲敖', 'Nb'),
#   ('、', 'PAUSECATEGORY'),
#   ('捕手', 'Na'),
#   ('林家正', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('下放', 'A'),
#   ('球員', 'Na'),
#   ('將', 'D'),
#   ('回到', 'VCL'),
#   ('小聯盟', 'VH'),
#   ('春訓', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('24', 'Neu'),
#   ('歲', 'Nf'),
#   ('投手', 'Na'),
#   ('莊陳仲敖', 'Nb'),
#   ('為', 'P'),
#   ('今年', 'Nd'),
#   ('世界', 'Nc'),
#   ('棒球', 'Na'),
#   ('經典賽', 'Na'),
#   ('資格賽', 'Na'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('WBCQ', 'FW'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('台灣', 'Nc'),
#   ('代表隊', 'Na'),
#   ('成員', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('2月', 'Nd'),
#   ('25日', 'Nd'),
#   ('與', 'Caa'),
#   ('西班牙', 'Nc'),
#   ('決勝', 'VA'),
#   ('關鍵', 'Na'),
#   ('一', 'Neu'),
#   ('役', 'Na'),
#   ('扛', 'VC'),
#   ('先發', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('投', 'VC'),
#   ('3', 'Neu'),
#   ('局', 'Nc'),
#   ('被', 'P'),
#   ('敲', 'VC'),
#   ('4', 'Neu'),
#   ('支', 'Nf'),
#   ('安打', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('投出', 'VC'),
#   ('1', 'Neu'),
#   ('次', 'Nf'),
#   ('三振', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('失掉', 'VJ'),
#   ('2', 'Neu'),
#   ('分', 'Nf'),
#   ('責', 'Na'),
#   ('失分', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('台灣', 'Nc'),
#   ('以', 'P'),
#   ('6', 'Neu'),
#   ('比', 'Caa'),
#   ('3', 'Neu'),
#   ('獲勝', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('莊陳仲敖', 'Nb'),
#   ('為', 'VG'),
#   ('勝', 'Na'),
#   ('投', 'VC'),
#   ('。', 'PERIODCATEGORY'),
#   ('莊陳仲敖', 'Nb'),
#   ('結束', 'VHC'),
#   ('資格賽', 'Na'),
#   ('結束', 'VHC'),
#   ('隔天', 'Nd'),
#   ('返', 'VCL'),
#   ('美', 'Nc'),
#   ('投入', 'VC'),
#   ('大聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('還', 'D'),
#   ('沒', 'D'),
#   ('有', 'V_2'),
#   ('出賽', 'VA'),
#   ('紀錄', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('將', 'D'),
#   ('回到', 'VCL'),
#   ('小', 'VH'),
#   ('聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('。', 'PERIODCATEGORY'),
#   ('莊陳仲敖', 'Nb'),
#   ('去年', 'Nd'),
#   ('最', 'Dfa'),
#   ('高', 'VH'),
#   ('層級', 'Na'),
#   ('上', 'VCL'),
#   ('到', 'P'),
#   ('小', 'VH'),
#   ('聯盟', 'Na'),
#   ('2', 'Neu'),
#   ('A', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('2A', 'Neu'),
#   ('有5', 'V_2'),
#   ('場', 'Nf'),
#   ('出賽', 'VA'),
#   ('（', 'PARENTHESISCATEGORY'),
#   ('4', 'Neu'),
#   ('場', 'Nf'),
#   ('先發', 'VA'),
#   ('）', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('戰績', 'Na'),
#   ('1', 'Neu'),
#   ('勝', 'VH'),
#   ('、', 'PAUSECATEGORY'),
#   ('防禦率', 'Na'),
#   ('2.05', 'Neu'),
#   ('。', 'PERIODCATEGORY'),
#   ('捕手', 'Na'),
#   ('林家正', 'Nb'),
#   ('去年', 'Nd'),
#   ('世界', 'Nc'),
#   ('1', 'Neu'),
#   ('2', 'Neu'),
#   ('強', 'VH'),
#   ('棒球賽', 'Na'),
#   ('表現', 'VC'),
#   ('亮', 'VH'),
#   ('眼', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('今年', 'Nd'),
#   ('也', 'D'),
#   ('有', 'V_2'),
#   ('被', 'P'),
#   ('選入', 'VCL'),
#   ('世界', 'Nc'),
#   ('棒球', 'Na'),
#   ('經典賽', 'Na'),
#   ('資格賽', 'Na'),
#   ('集訓', 'Nv'),
#   ('名單', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('後來', 'Nd'),
#   ('因', 'Cbb'),
#   ('與', 'P'),
#   ('運動家隊', 'Na'),
#   ('簽約', 'VA'),
#   ('獲邀', 'VJ'),
#   ('大聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('辭退', 'VC'),
#   ('資格賽', 'Na'),
#   ('台灣隊', 'Nb'),
#   ('。', 'PERIODCATEGORY'),
#   ('林家正', 'Nc'),
#   ('在', 'P'),
#   ('大聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('熱', 'Na'),
#   ('身賽', 'Na'),
#   ('有', 'V_2'),
#   ('3', 'Neu'),
#   ('場', 'Nf'),
#   ('出賽', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('總計', 'Da'),
#   ('2打數', 'Neu'),
#   ('沒有', 'D'),
#   ('敲出', 'VC'),
#   ('安打', 'Na'),
#   ('；', 'SEMICOLONCATEGORY'),
#   ('林家正', 'Nb'),
#   ('去年', 'Nd'),
#   ('球季', 'Nd'),
#   ('最', 'Dfa'),
#   ('高', 'VH'),
#   ('層級', 'Na'),
#   ('也', 'D'),
#   ('上到', 'VCL'),
#   ('小', 'VH'),
#   ('聯盟', 'Na'),
#   ('2', 'Neu'),
#   ('A', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('2A', 'Neu'),
#   ('總計', 'Da'),
#   ('14', 'Neu'),
#   ('場', 'Nf'),
#   ('出賽', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('共', 'Da'),
#   ('4', 'Cbb'),
#   ('4', 'Cbb'),
#   ('打數', 'Na'),
#   ('敲出', 'VC'),
#   ('18', 'Neu'),
#   ('支', 'Nf'),
#   ('安打', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('包括', 'VK'),
#   ('1', 'Neu'),
#   ('發', 'Nf'),
#   ('全壘打', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('打擊率', 'Na'),
#   ('4成09', 'Neqa'),
#   ('。', 'PERIODCATEGORY'),
#   ('運動家隊', 'Na'),
#   ('大聯盟', 'Na'),
#   ('春訓', 'Na'),
#   ('除了', 'P'),
#   ('40', 'Neu'),
#   ('人', 'Na'),
#   ('名單', 'Na'),
#   ('外', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('另', 'Nes'),
#   ('有', 'V_2'),
#   ('16', 'Neu'),
#   ('名', 'Nf'),
#   ('球員', 'Na'),
#   ('受', 'P'),
#   ('邀', 'VF'),
#   ('，', 'COMMACATEGORY'),
#   ('今天', 'Nd'),
#   ('公告', 'VE'),
#   ('7', 'Neu'),
#   ('名', 'Nf'),
#   ('球員', 'Na'),
#   ('下放回', 'Ncd'),
#   ('小聯盟', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('包括', 'VK'),
#   ('台灣', 'Nc'),
#   ('球員', 'Na'),
#   ('莊陳仲敖', 'Nb'),
#   ('和', 'Caa'),
#   ('林家正', 'Nb'),
#   ('。', 'PERIODCATEGORY')]]

# %% [markdown]
# ## How does zip work?
#
# There are two zip. How does it work?
#
# list(zip(w,p)) for w, p in zip(tokens, tokens_pos)

# %%
a=[1,2,3]
b=['a','b','c']
ab=zip(a,b)
list(ab)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
# list(zip(w,p)) for w, p in zip(tokens, tokens_pos)
a=[[1,2],[3,4],[5,6]]
b=[['a','b'],['c','d'],['e','f']]
ab=zip(a,b)
list(ab)
# Out:
# [([1, 2], ['a', 'b']), ([3, 4], ['c', 'd']), ([5, 6], ['e', 'f'])]

# %%
for item1, item2 in zip(a, b):
    print(item1,'with', item2)
# Out:
# [1, 2] with ['a', 'b']
# [3, 4] with ['c', 'd']
# [5, 6] with ['e', 'f']

# %%
for item1, item2 in zip(a, b):
    print(item1,'with', item2)
    print(list(zip(item1, item2)))
    print('---')
# Out:
# [1, 2] with ['a', 'b']
# [(1, 'a'), (2, 'b')]
# ---
# [3, 4] with ['c', 'd']
# [(3, 'c'), (4, 'd')]
# ---
# [5, 6] with ['e', 'f']
# [(5, 'e'), (6, 'f')]
# ---

# %% [markdown]
# ## NER命名實體辨識

# %%
# %%time
entity_list = ner(df.content)
# Out:
# Tokenization: 100%|██████████| 12/12 [00:00<00:00, 2400.52it/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
# CPU times: total: 2.94 s
# Wall time: 252 ms

# %%
entity_list[0]
# Out:
# [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)),
#  NerToken(word='札尼', ner='PERSON', idx=(11, 13)),
#  NerToken(word='北義', ner='GPE', idx=(20, 22)),
#  NerToken(word='札尼', ner='PERSON', idx=(42, 44)),
#  NerToken(word='台灣', ner='GPE', idx=(53, 55)),
#  NerToken(word='台灣', ner='GPE', idx=(75, 77)),
#  NerToken(word='台灣', ner='GPE', idx=(96, 98)),
#  NerToken(word='札尼', ner='ORG', idx=(100, 102)),
#  NerToken(word='2023年', ner='DATE', idx=(125, 130)),
#  NerToken(word='台', ner='GPE', idx=(132, 133)),
#  NerToken(word='台灣', ner='GPE', idx=(162, 164)),
#  NerToken(word='今天', ner='DATE', idx=(172, 174)),
#  NerToken(word='北義', ner='GPE', idx=(176, 178)),
#  NerToken(word='布雷西亞', ner='ORG', idx=(180, 184)),
#  NerToken(word='4', ner='CARDINAL', idx=(194, 195)),
#  NerToken(word='羅馬', ner='GPE', idx=(200, 202)),
#  NerToken(word='台灣', ner='GPE', idx=(213, 215)),
#  NerToken(word='布雷西亞扶輪社', ner='ORG', idx=(224, 231)),
#  NerToken(word='札尼', ner='PERSON', idx=(258, 260)),
#  NerToken(word='台灣', ner='GPE', idx=(266, 268)),
#  NerToken(word='非洲', ner='GPE', idx=(288, 290)),
#  NerToken(word='2019', ner='ORG', idx=(313, 317)),
#  NerToken(word='台灣', ner='GPE', idx=(329, 331)),
#  NerToken(word='布雷西亞醫院', ner='ORG', idx=(334, 340)),
#  NerToken(word='台灣', ner='GPE', idx=(368, 370)),
#  NerToken(word='李世明', ner='PERSON', idx=(388, 391)),
#  NerToken(word='台灣', ner='GPE', idx=(395, 397)),
#  NerToken(word='川普（Donald Trum', ner='PERSON', idx=(427, 441)),
#  NerToken(word='烏克蘭', ner='PERSON', idx=(444, 447)),
#  NerToken(word='澤倫斯基', ner='PERSON', idx=(449, 453)),
#  NerToken(word='台灣', ner='GPE', idx=(519, 521)),
#  NerToken(word='3', ner='CARDINAL', idx=(543, 544)),
#  NerToken(word='李世明', ner='PERSON', idx=(552, 555)),
#  NerToken(word='台灣', ner='GPE', idx=(559, 561)),
#  NerToken(word='9', ner='CARDINAL', idx=(621, 622)),
#  NerToken(word='李世明', ner='PERSON', idx=(624, 627)),
#  NerToken(word='第三', ner='ORDINAL', idx=(630, 632)),
#  NerToken(word='台灣', ner='GPE', idx=(665, 667)),
#  NerToken(word='中國', ner='NORP', idx=(681, 683)),
#  NerToken(word='中國', ner='NORP', idx=(699, 701)),
#  NerToken(word='李世明', ner='PERSON', idx=(731, 734)),
#  NerToken(word='台灣', ner='GPE', idx=(743, 745)),
#  NerToken(word='羅馬', ner='GPE', idx=(750, 752)),
#  NerToken(word='米蘭', ner='ORG', idx=(753, 755)),
#  NerToken(word='台灣', ner='GPE', idx=(759, 761)),
#  NerToken(word='台灣扶輪社', ner='ORG', idx=(798, 803)),
#  NerToken(word='台灣', ner='GPE', idx=(846, 848))]

# %% [markdown]
# # Remove stop words and filter using POS (tokens_v2)
#
# 去除停用詞並依據詞性過濾

# %%
# with open('stops_chinese_traditional.txt', 'r', encoding='utf8') as f:
#     stops = f.read().split('\n')

# %%
# 過濾條件:兩個字以上與特定的詞性
allowPOS=['Na','Nb','Nc']

tokens_v2 =[]
for wp in word_pos_pair:
    tokens_v2.append([w for w,p in wp if (len(w) >= 2) and p in allowPOS])

# %%
tokens_v2[0]
# Out:
# ['梵蒂岡',
#  '宗座',
#  '圖書館',
#  '館長',
#  '札尼',
#  '北義',
#  '社會',
#  '菁英',
#  '教友',
#  '教廷',
#  '大使館',
#  '札尼',
#  '教友',
#  '台灣',
#  '國家',
#  '教友',
#  '台灣',
#  '地點',
#  '台灣',
#  '札尼',
#  '故宮',
#  '梵蒂岡',
#  '宗座',
#  '圖書館',
#  '宮廷',
#  '藏書',
#  '特展',
#  '台灣',
#  '印象',
#  '北義',
#  '家鄉',
#  '布雷西亞',
#  '教友',
#  '羅馬',
#  '台灣',
#  '使館',
#  '教友',
#  '布雷西亞',
#  '扶輪社',
#  '成員',
#  '職業',
#  '大學',
#  '教授',
#  '律師',
#  '憲警',
#  '札尼',
#  '台灣',
#  '教廷',
#  '人道',
#  '援助',
#  '非洲',
#  '剛果',
#  '教育',
#  '工作',
#  '冠狀',
#  '病毒',
#  '疾病',
#  '疫情',
#  '期間',
#  '台灣',
#  '布雷西亞',
#  '醫院',
#  '呼吸器',
#  '家鄉教友',
#  '台灣',
#  '機會',
#  '教廷',
#  '大使',
#  '李世明',
#  '台灣',
#  '時事哏',
#  '眾人鼓掌大笑',
#  '美國',
#  '總統',
#  '川普',
#  '烏克蘭',
#  '總統',
#  '澤倫斯基',
#  '白宮',
#  '流行語',
#  '國際社會',
#  '台灣',
#  '領土',
#  '面積',
#  '台灣',
#  '國際',
#  '重要性',
#  '方面',
#  '李世明',
#  '台灣',
#  '地緣',
#  '戰略',
#  '重要性',
#  '台灣',
#  '海峽',
#  '全球',
#  '貨運',
#  '管道',
#  '台灣',
#  '半導體',
#  '產業',
#  '世界',
#  '關鍵',
#  '地位',
#  '晶片',
#  '製程',
#  '全球',
#  '市占率',
#  '李世明',
#  '教宗方',
#  '濟各',
#  '台灣',
#  '國家',
#  '中國',
#  '威權',
#  '人民',
#  '希望',
#  '中國',
#  '人民',
#  '自由',
#  '正義',
#  '台灣',
#  '希望',
#  '角色',
#  '李世明',
#  '北義菁英',
#  '教友',
#  '台灣',
#  '羅馬',
#  '米蘭',
#  '台灣',
#  '班機',
#  '布雷西亞',
#  '扶輪社',
#  '幹部',
#  '反應',
#  '台灣',
#  '扶輪社',
#  '姊妹社',
#  '教友',
#  '使館',
#  '人員',
#  '台灣',
#  '美食',
#  '海灘',
#  '景點',
#  '義大利人',
#  '民族性']

# %% [markdown]
# # Insert tokens into dataframe (新增斷詞資料欄位)

# %%
df['tokens'] = tokens

# %%
df['tokens_v2'] = tokens_v2

# %%
df['entities'] = entity_list

# %%
df['token_pos'] = word_pos_pair

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link  \
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
#
#                                               tokens  \
# 0  [梵蒂岡, 宗座, 圖書館, 總, 館長, 札尼, 今天, 率領, 數十, 位, 北義, 的...
#
#                                            tokens_v2  \
# 0  [梵蒂岡, 宗座, 圖書館, 館長, 札尼, 北義, 社會, 菁英, 教友, 教廷, 大使館...
#
#                                             entities  \
# 0  [(梵蒂岡, GPE, (0, 3)), (札尼, PERSON, (11, 13)), (...
#
#                                            token_pos
# 0  [(梵蒂岡, Nc), (宗座, Na), (圖書館, Nc), (總, Nc), (館長,...

# %% [markdown]
# # Calculate word count (frequency) 計算字頻(次數)

# %%
# allowPOS過濾條件:兩個字以上與特定的詞性
# allowPOS=['Na','Nb','Nc','VA','VAC','VB','VC']
allowPOS=['Na','Nb','Nc']

from collections import Counter
def word_frequency( wp_pair ):
    filtered_words =[]
    for word, pos in wp_pair:
        if (pos in allowPOS) & (len(word) >= 2):
            filtered_words.append(word)
        #print('%s %s' % (word, pos))
    counter = Counter( filtered_words)
    return counter.most_common(20)

# %%
word_pos_pair[0]
# Out:
# [('梵蒂岡', 'Nc'),
#  ('宗座', 'Na'),
#  ('圖書館', 'Nc'),
#  ('總', 'Nc'),
#  ('館長', 'Na'),
#  ('札尼', 'Nb'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('數十', 'Neu'),
#  ('位', 'Nf'),
#  ('北義', 'Nc'),
#  ('的', 'DE'),
#  ('社會', 'Na'),
#  ('菁英', 'Na'),
#  ('教友', 'Na'),
#  ('拜會', 'VC'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('的', 'DE'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('向', 'P'),
#  ('教友', 'Na'),
#  ('力', 'VC'),
#  ('推', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('是', 'SHI'),
#  ('個', 'Nf'),
#  ('卓越', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('值得', 'VH'),
#  ('前往', 'VCL'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('多', 'Neqa'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('高度', 'A'),
#  ('好奇', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('熱情', 'VH'),
#  ('表示', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('旅遊', 'Nv'),
#  ('地點', 'Na'),
#  ('將', 'D'),
#  ('鎖定', 'VC'),
#  ('台灣', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Angelo Vincenzo', 'FW'),
#  (' Zani', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('於', 'P'),
#  ('2023年', 'Neu'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('參加', 'VC'),
#  ('故宮', 'Nc'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('梵蒂岡', 'Nb'),
#  ('宗座', 'Nb'),
#  ('圖書館', 'Nc'),
#  ('珍藏', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('暨', 'Caa'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('明清', 'Nd'),
#  ('宮廷', 'Nc'),
#  ('藏書', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('特展', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('留下', 'VC'),
#  ('深刻', 'VH'),
#  ('印象', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('北義', 'Nc'),
#  ('家鄉', 'Nc'),
#  ('布雷西亞', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Brescia', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('約', 'Da'),
#  ('40', 'Neu'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('羅馬', 'Nc'),
#  ('朝聖', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('特別', 'VH'),
#  ('安', 'VE'),
#  ('排教友', 'VC'),
#  ('參觀', 'VC'),
#  ('台灣', 'Nc'),
#  ('使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('這', 'Nep'),
#  ('群', 'Nf'),
#  ('教友', 'Na'),
#  ('皆', 'D'),
#  ('為', 'VG'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('成員', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('職業', 'Na'),
#  ('包括', 'VK'),
#  ('中', 'Na'),
#  ('小企業家', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('大學', 'Nc'),
#  ('教授', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('律師', 'Na'),
#  ('和', 'Caa'),
#  ('高階', 'A'),
#  ('憲警', 'Na'),
#  ('等', 'Cab'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('盛讚', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('長期', 'Nd'),
#  ('與', 'P'),
#  ('教廷', 'Nc'),
#  ('攜手', 'D'),
#  ('推動', 'VC'),
#  ('人道', 'Na'),
#  ('援助', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('包括', 'VK'),
#  ('協助', 'VC'),
#  ('他', 'Nh'),
#  ('在', 'P'),
#  ('非洲', 'Nc'),
#  ('剛果', 'Nc'),
#  ('推動', 'VC'),
#  ('的', 'DE'),
#  ('教育', 'Na'),
#  ('與', 'Caa'),
#  ('醫療', 'VC'),
#  ('工作', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('在COVID-19', 'P'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('2019', 'Neu'),
#  ('冠狀', 'Na'),
#  ('病毒', 'Na'),
#  ('疾病', 'Na'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('疫情', 'Na'),
#  ('期間', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('也', 'D'),
#  ('曾', 'D'),
#  ('向', 'P'),
#  ('布雷西亞', 'Nc'),
#  ('醫院', 'Nc'),
#  ('捐贈', 'VD'),
#  ('呼吸器', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因此', 'Cbb'),
#  ('他', 'Nh'),
#  ('一直', 'D'),
#  ('想', 'VE'),
#  ('向', 'P'),
#  ('家鄉教友', 'Nc'),
#  ('介紹', 'VE'),
#  ('開放', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('多元', 'VH'),
#  ('又', 'Caa'),
#  ('好客', 'VH'),
#  ('的', 'DE'),
#  ('台灣', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('盼', 'VK'),
#  ('促進', 'VK'),
#  ('彼此', 'Nh'),
#  ('更', 'Neqa'),
#  ('多', 'VH'),
#  ('交流', 'VH'),
#  ('機會', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使', 'Na'),
#  ('李世明', 'Nb'),
#  ('致詞', 'VA'),
#  ('介紹', 'VE'),
#  ('台灣', 'Nc'),
#  ('時', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('引用', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('時事哏', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('開場', 'VA'),
#  ('博', 'VJ'),
#  ('得', 'DE'),
#  ('眾人鼓掌大笑', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('日前', 'Nd'),
#  ('美國', 'Nc'),
#  ('總統', 'Na'),
#  ('川普', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Donald', 'FW'),
#  (' Trump', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('與', 'P'),
#  ('烏克蘭', 'Nc'),
#  ('總統', 'Na'),
#  ('澤倫斯基', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Volodymyr Zelenskyy', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('在', 'P'),
#  ('白宮', 'Nc'),
#  ('會晤', 'VC'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('有', 'V_2'),
#  ('句', 'Nf'),
#  ('流行語', 'Na'),
#  ('在', 'P'),
#  ('國際社會', 'Nc'),
#  ('很', 'Dfa'),
#  ('夯', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('就是', 'Cbb'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('你', 'Nh'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('什麼', 'Nep'),
#  ('牌', 'Na'),
#  ('可', 'D'),
#  ('打', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Na'),
#  ('論', 'VC'),
#  ('領土', 'Na'),
#  ('面積', 'Na'),
#  ('雖', 'Cbb'),
#  ('小', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('台灣', 'Nc'),
#  ('對', 'P'),
#  ('國際', 'Nc'),
#  ('很', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('可', 'D'),
#  ('說', 'VE'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('很多', 'Neqa'),
#  ('牌', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('其', 'Nep'),
#  ('重要性', 'Na'),
#  ('可', 'D'),
#  ('分', 'VC'),
#  ('3', 'Neu'),
#  ('個', 'Nf'),
#  ('主要', 'A'),
#  ('方面', 'Na'),
#  ('闡釋', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('說', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('首先', 'D'),
#  ('台灣', 'Nc'),
#  ('具有', 'VJ'),
#  ('地緣', 'Na'),
#  ('戰略', 'Na'),
#  ('重要性', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('海峽', 'Na'),
#  ('是', 'SHI'),
#  ('全球', 'Nc'),
#  ('貨運', 'Na'),
#  ('通過', 'VC'),
#  ('的', 'DE'),
#  ('重要', 'VH'),
#  ('管道', 'Na'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('第二', 'Neu'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('半導體', 'Na'),
#  ('產業', 'Na'),
#  ('位居', 'VCL'),
#  ('世界', 'Nc'),
#  ('關鍵', 'Na'),
#  ('地位', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('先進', 'VH'),
#  ('晶片', 'Na'),
#  ('製程', 'Na'),
#  ('在', 'P'),
#  ('全球', 'Nc'),
#  ('市占率', 'Na'),
#  ('超過', 'VJ'),
#  ('9成', 'Neqa'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('第三', 'Neu'),
#  ('點', 'Nf'),
#  ('最', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('教宗方', 'Na'),
#  ('濟各', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Pope', 'FW'),
#  (' ', 'WHITESPACE'),
#  ('Francis', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('說', 'VE'),
#  ('今年', 'Nd'),
#  ('是', 'SHI'),
#  ('希望', 'VK'),
#  ('禧年', 'Nd'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('作為', 'VG'),
#  ('自由', 'VH'),
#  ('民主', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('所有', 'Neqa'),
#  ('受到', 'VJ'),
#  ('中國', 'Nc'),
#  ('共產', 'A'),
#  ('威權', 'Na'),
#  ('統治', 'VC'),
#  ('下', 'Ng'),
#  ('人民', 'Na'),
#  ('的', 'DE'),
#  ('希望', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因為', 'Cbb'),
#  ('在', 'P'),
#  ('中國', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('人民', 'Na'),
#  ('無法', 'D'),
#  ('享受', 'VJ'),
#  ('自由', 'Na'),
#  ('與', 'Caa'),
#  ('公平', 'VH'),
#  ('正義', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扮演', 'VC'),
#  ('了', 'Di'),
#  ('帶來', 'VC'),
#  ('希望', 'Na'),
#  ('的', 'DE'),
#  ('角色', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('鼓勵', 'VF'),
#  ('北義菁英', 'Nb'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('台灣', 'Nc'),
#  ('訪問', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('現', 'Nd'),
#  ('在', 'P'),
#  ('羅馬', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('米蘭', 'Nc'),
#  ('都', 'D'),
#  ('有', 'V_2'),
#  ('直飛', 'VCL'),
#  ('台灣', 'Nc'),
#  ('班機', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('方便', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('在', 'VA'),
#  ('場', 'Nc'),
#  ('的', 'DE'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('幹部', 'Na'),
#  ('對', 'P'),
#  ('此', 'Nep'),
#  ('反應', 'Na'),
#  ('熱烈', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('當場', 'D'),
#  ('表示', 'VE'),
#  ('要', 'D'),
#  ('公開', 'VHC'),
#  ('徵求', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('姊妹社', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('立刻', 'D'),
#  ('安排', 'VE'),
#  ('整團', 'Neqa'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('不少', 'Neqa'),
#  ('教友', 'Na'),
#  ('也', 'D'),
#  ('直', 'D'),
#  ('喊', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('報名', 'VA'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('、', 'PAUSECATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('加', 'VC'),
#  ('一', 'Neu'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('開始', 'VL'),
#  ('向', 'P'),
#  ('使館', 'Nc'),
#  ('人員', 'Na'),
#  ('打探', 'VC'),
#  ('台灣', 'Nc'),
#  ('有', 'V_2'),
#  ('哪些', 'Neqa'),
#  ('美食', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('登山', 'VA'),
#  ('、', 'PAUSECATEGORY'),
#  ('海灘', 'Na'),
#  ('景點', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('展現', 'VC'),
#  ('義大利人', 'Na'),
#  ('熱情', 'VH'),
#  ('的', 'DE'),
#  ('民族性', 'Na'),
#  ('。', 'PERIODCATEGORY')]

# %%
word_frequency(word_pos_pair[0])
# Out:
# [('台灣', 20),
#  ('教友', 7),
#  ('札尼', 4),
#  ('布雷西亞', 4),
#  ('李世明', 4),
#  ('教廷', 3),
#  ('扶輪社', 3),
#  ('梵蒂岡', 2),
#  ('宗座', 2),
#  ('圖書館', 2),
#  ('北義', 2),
#  ('國家', 2),
#  ('羅馬', 2),
#  ('使館', 2),
#  ('總統', 2),
#  ('重要性', 2),
#  ('全球', 2),
#  ('中國', 2),
#  ('人民', 2),
#  ('希望', 2)]

# %%
word_frequency(word_pos_pair[1])
# Out:
# [('咖啡', 28),
#  ('台灣', 18),
#  ('瓜地馬拉', 9),
#  ('瓜國', 6),
#  ('中美洲', 5),
#  ('考察團', 5),
#  ('經貿', 4),
#  ('業者', 4),
#  ('價格', 4),
#  ('外交部', 3),
#  ('辦事處', 3),
#  ('貨櫃', 3),
#  ('產區', 3),
#  ('瓜地', 3),
#  ('馬拉', 3),
#  ('氣候', 3),
#  ('徐韶慧', 2),
#  ('咖啡豆', 2),
#  ('進口商', 2),
#  ('全球', 2)]

# %%
word_frequency(word_pos_pair[2])
# Out:
# [('傅崐萁', 6),
#  ('台灣', 5),
#  ('中國', 3),
#  ('官員', 3),
#  ('國民黨', 2),
#  ('行政院', 2),
#  ('香港', 2),
#  ('政府', 2),
#  ('花蓮', 2),
#  ('葉春蓮', 2),
#  ('東社', 1),
#  ('立委', 1),
#  ('外患罪', 1),
#  ('滲透法', 1),
#  ('強制罪', 1),
#  ('高檢署', 1),
#  ('告發狀', 1),
#  ('經濟', 1),
#  ('民主', 1),
#  ('連合智庫', 1)]

# %% [markdown]
# # 逐篇計算詞頻

# %%
# %%time
keyfreqs =[]
for wp in word_pos_pair:
    topwords = word_frequency(wp)
    keyfreqs.append(topwords)
# Out:
# CPU times: total: 0 ns
# Wall time: 997 μs

# %%
keyfreqs[0:2]
# Out:
# [[('台灣', 20),
#   ('教友', 7),
#   ('札尼', 4),
#   ('布雷西亞', 4),
#   ('李世明', 4),
#   ('教廷', 3),
#   ('扶輪社', 3),
#   ('梵蒂岡', 2),
#   ('宗座', 2),
#   ('圖書館', 2),
#   ('北義', 2),
#   ('國家', 2),
#   ('羅馬', 2),
#   ('使館', 2),
#   ('總統', 2),
#   ('重要性', 2),
#   ('全球', 2),
#   ('中國', 2),
#   ('人民', 2),
#   ('希望', 2)],
#  [('咖啡', 28),
#   ('台灣', 18),
#   ('瓜地馬拉', 9),
#   ('瓜國', 6),
#   ('中美洲', 5),
#   ('考察團', 5),
#   ('經貿', 4),
#   ('業者', 4),
#   ('價格', 4),
#   ('外交部', 3),
#   ('辦事處', 3),
#   ('貨櫃', 3),
#   ('產區', 3),
#   ('瓜地', 3),
#   ('馬拉', 3),
#   ('氣候', 3),
#   ('徐韶慧', 2),
#   ('咖啡豆', 2),
#   ('進口商', 2),
#   ('全球', 2)]]

# %%
df['top_key_freq'] = keyfreqs

# %%
df.head(2)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
# 1  aipl_20250304_2  2025-03-04       政治  力挺友邦瓜地馬拉  台灣採購咖啡增加5成創新高
#
#                                              content  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
# 1  由外交部中美洲經貿辦事處籌組的台灣咖啡考察團，力挺友邦瓜地馬拉，預計採購38個貨櫃、72萬公...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
# 1  /news/aipl/202503040019.aspx
#
#                                           photo_link  \
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
# 1  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
#
#                                               tokens  \
# 0  [梵蒂岡, 宗座, 圖書館, 總, 館長, 札尼, 今天, 率領, 數十, 位, 北義, 的...
# 1  [由, 外交部, 中美洲, 經貿, 辦事處, 籌組, 的, 台灣, 咖啡, 考察團, ，, ...
#
#                                            tokens_v2  \
# 0  [梵蒂岡, 宗座, 圖書館, 館長, 札尼, 北義, 社會, 菁英, 教友, 教廷, 大使館...
# 1  [外交部, 中美洲, 經貿, 辦事處, 台灣, 咖啡, 考察團, 友邦, 瓜地馬拉, 貨櫃,...
#
#                                             entities  \
# 0  [(梵蒂岡, GPE, (0, 3)), (札尼, PERSON, (11, 13)), (...
# 1  [(外交部中美洲經貿辦事處, ORG, (1, 12)), (台灣咖啡考察團, ORG, (...
#
#                                            token_pos  \
# 0  [(梵蒂岡, Nc), (宗座, Na), (圖書館, Nc), (總, Nc), (館長,...
# 1  [(由, P), (外交部, Nc), (中美洲, Nc), (經貿, Na), (辦事處,...
#
#                                         top_key_freq
# 0  [(台灣, 20), (教友, 7), (札尼, 4), (布雷西亞, 4), (李世明, ...
# 1  [(咖啡, 28), (台灣, 18), (瓜地馬拉, 9), (瓜國, 6), (中美洲,...

# %%
df.iloc[0].top_key_freq
# Out:
# [('台灣', 20),
#  ('教友', 7),
#  ('札尼', 4),
#  ('布雷西亞', 4),
#  ('李世明', 4),
#  ('教廷', 3),
#  ('扶輪社', 3),
#  ('梵蒂岡', 2),
#  ('宗座', 2),
#  ('圖書館', 2),
#  ('北義', 2),
#  ('國家', 2),
#  ('羅馬', 2),
#  ('使館', 2),
#  ('總統', 2),
#  ('重要性', 2),
#  ('全球', 2),
#  ('中國', 2),
#  ('人民', 2),
#  ('希望', 2)]

# %% [markdown]
# # Abstract (summary) and sentimental score(摘要與情緒分數)
#
# Currently we don't use abstract in our later application. However, we prepare news summary for future usage.
#
# We use snowNLP to get summary and sentimental score.

# %%
# pip install snownlp

# %%
# %%time
summary=[]
sentiment=[]
for text in df.content: # process piece by piece
    summary.append("暫無")  
    sentiment.append("暫無")
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
df['summary'] = summary

# %%
df['sentiment'] = sentiment

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link  \
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...
#
#                                               tokens  \
# 0  [梵蒂岡, 宗座, 圖書館, 總, 館長, 札尼, 今天, 率領, 數十, 位, 北義, 的...
#
#                                            tokens_v2  \
# 0  [梵蒂岡, 宗座, 圖書館, 館長, 札尼, 北義, 社會, 菁英, 教友, 教廷, 大使館...
#
#                                             entities  \
# 0  [(梵蒂岡, GPE, (0, 3)), (札尼, PERSON, (11, 13)), (...
#
#                                            token_pos  \
# 0  [(梵蒂岡, Nc), (宗座, Na), (圖書館, Nc), (總, Nc), (館長,...
#
#                                         top_key_freq summary sentiment
# 0  [(台灣, 20), (教友, 7), (札尼, 4), (布雷西亞, 4), (李世明, ...      暫無        暫無

# %% [markdown]
# # Rearrange the colmun order for readability

# %%
df.columns
# Out:
# Index(['item_id', 'date', 'category', 'title', 'content', 'link', 'photo_link',
#        'tokens', 'tokens_v2', 'entities', 'token_pos', 'top_key_freq',
#        'summary', 'sentiment'],
#       dtype='object')

# %%
# This operation is the same as slicing
df=df[['item_id', 'date', 'category', 'title', 'content','sentiment', 'summary', 'top_key_freq', 'tokens',
       'tokens_v2', 'entities', 'token_pos', 'link', 'photo_link'
       ]]

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [(台灣, 20), (教友, 7), (札尼, 4), (布雷西亞, 4), (李世明, ...
#
#                                               tokens  \
# 0  [梵蒂岡, 宗座, 圖書館, 總, 館長, 札尼, 今天, 率領, 數十, 位, 北義, 的...
#
#                                            tokens_v2  \
# 0  [梵蒂岡, 宗座, 圖書館, 館長, 札尼, 北義, 社會, 菁英, 教友, 教廷, 大使館...
#
#                                             entities  \
# 0  [(梵蒂岡, GPE, (0, 3)), (札尼, PERSON, (11, 13)), (...
#
#                                            token_pos  \
# 0  [(梵蒂岡, Nc), (宗座, Na), (圖書館, Nc), (總, Nc), (館長,...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %% [markdown]
# # Save data to disk
#
# 存檔

# %%
df.to_csv('cna_news_preprocessed.csv', sep='|', index=False)

# %% [markdown]
# ## Read it out 讀出看看

# %%
df = pd.read_csv('cna_news_preprocessed.csv', sep='|')

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %%
import pandas as pd

# %%
df = pd.read_csv('PTT_news_preprocessed.csv',sep='|')

# %%
df.head(2)
# Out:
#          item_id   date category                         title  \
# 0  Stock_04-16_1  04-16     學術股市      [新聞] 日媒：台積電將敲定面板級封裝規格 先從
# 1  Stock_04-16_2  04-16     學術股市  Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
#
#                                              content sentiment summary  \
# 0  原文標題：日媒：台積電將敲定面板級封裝規格 先從較小尺寸開始原文連結：發布時間：2025-0...        暫無      暫無
# 1  從廣場協議看2018美中貿易戰 的升級版，及這次的關稅事件，廣場協議的主因也是貿易逆差跟美元...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台積電', 5), ('原文', 3), ('技術', 3), ('日媒', 2), ...
# 1  [('中國', 36), ('美國', 30), ('國家', 21), ('技術', 13...
#
#                                               tokens  \
# 0  ['原文', '標題', '：', '日媒', '：', '台積電', '將', '敲定',...
# 1  ['從', '廣場', '協議', '看', '2018', '美中', '貿易戰 ', '...
#
#                                            tokens_v2  \
# 0  ['原文', '標題', '日媒', '台積電', '面板級', '規格', '尺寸', '...
# 1  ['廣場', '協議', '美中', '貿易戰 ', '升級版', '關稅', '事件', ...
#
#                                             entities  \
# 0  [NerToken(word='日媒', ner='NORP', idx=(5, 7)), ...
# 1  [NerToken(word='美國鋼鐵', ner='ORG', idx=(57, 61)...
#
#                                            token_pos  \
# 0  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 1  [('從', 'P'), ('廣場', 'Nc'), ('協議', 'Na'), ('看',...
#
#                                                 link  photo_link
# 0  https://www.ptt.cc/bbs/Stock/M.1744794518.A.3D...         NaN
# 1  https://www.ptt.cc/bbs/Stock/M.1744794681.A.85...         NaN

# %%
df.shape
# Out:
# (268, 14)

# %%
df.groupby('category').count()
# Out:
#           item_id  date  title  content  sentiment  summary  top_key_freq  \
# category
# 學術股市           56    56     56       56         56       56            56
# 棒球             46    46     46       46         46       46            46
# 綜合             51    51     51       51         51       51            51
# 軍事             55    55     55       55         55       55            55
# 閒談             60    60     60       60         60       60            60
#
#           tokens  tokens_v2  entities  token_pos  link  photo_link
# category
# 學術股市          56         56        56         56    56           0
# 棒球            46         46        46         46    46           0
# 綜合            51         51        51         51    51           0
# 軍事            55         55        55         55    55           0
# 閒談            60         60        60         60    60           0

# %%
# df_group = df[df.category == '政治']
df_group = df.query('category == "學術股市"')

# %%
df_group
# Out:
#            item_id   date category                             title  \
# 0    Stock_04-16_1  04-16     學術股市          [新聞] 日媒：台積電將敲定面板級封裝規格 先從
# 1    Stock_04-16_2  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 2    Stock_04-16_3  04-16     學術股市           [新聞] 川普大讚「關稅政策」有效！　發文激讚
# 3    Stock_04-16_4  04-16     學術股市  [情報] 2834 臺企銀 113年股利:現金0.2+股票0.6
# 4    Stock_04-16_5  04-16     學術股市         Re: [請益] 中國繼續擺爛是不是要害慘全世界？
# 5    Stock_04-16_6  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 6    Stock_04-16_7  04-16     學術股市         [新聞] 「中國扛不住245％關稅」大量工廠放長假
# 7    Stock_04-16_8  04-16     學術股市         [新聞] 彭博社: 如美國表現尊重, 中國願意談判
# 8    Stock_04-16_9  04-16     學術股市     Re: [新聞] 彭博社: 如美國表現尊重, 中國願意談判
# 9   Stock_04-16_10  04-16     學術股市          [新聞] 新護國3神山 劉鏡清：矽光子、量子、自
# 10  Stock_04-16_11  04-16     學術股市                  [標的] 5201 凱衛 查股多
# 11  Stock_04-16_12  04-16     學術股市          [情報] 中國表示願意與美談判，但美國必須給面子
# 12  Stock_04-16_13  04-16     學術股市     Re: [新聞] 彭双浪：啟動全球產能調整、12%營收恐受
# 13  Stock_04-16_14  04-16     學術股市                    [情報] 0416 違約交割
# 14  Stock_04-16_15  04-16     學術股市           [情報] 2323 中環 處分廣達，取得台積電
# 15  Stock_07-02_16  07-02     學術股市   [公告] 股票板板規 v4.7 (2024/10/06 修正)
# 16  Stock_02-17_17  02-17     學術股市       [公告] 4-6-1的初犯罰則在三個月內將加重至30天
# 17  Stock_04-16_18  04-16     學術股市              [閒聊] 2025/04/16 盤後閒聊
# 18  Stock_04-16_19  04-16     學術股市          [新聞] 白宮：中國輸美商品面臨最高245%關稅
# 19  Stock_04-16_20  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 20  Stock_04-16_21  04-16     學術股市        [請益] 有人也是繼續低檔投ETF？是否該調整策略?
# 21  Stock_04-16_22  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 22  Stock_04-16_23  04-16     學術股市     Re: [新聞] 贏得川普青睞！輝達躲掉關稅、不禁H20晶
# 23  Stock_04-16_24  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 24  Stock_04-16_25  04-16     學術股市           [情報] 四月第一周, 美國進口預定暴跌64%
# 25  Stock_04-16_26  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 26  Stock_04-16_27  04-16     學術股市               [情報] 0416 上市外資買賣超排行
# 27  Stock_04-16_28  04-16     學術股市          [新聞] 「產能過剩的挑戰」紐時：中國貨湧向歐洲
# 28  Stock_04-16_29  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 29  Stock_04-16_30  04-16     學術股市       [新聞] TVBS民調／反制川普關稅！46%贊成「暫緩
# 30  Stock_04-16_31  04-16     學術股市          Re: [心得] 中國不太可能拉升消費應對貿易戰
# 31  Stock_04-16_32  04-16     學術股市          [新聞] 中美關稅戰正熾 中國商務部新任命貿易談
# 32  Stock_04-16_33  04-16     學術股市          [新聞] 快訊／沒有爆艙、沒有流浪貨　美國線5月
# 33  Stock_04-16_34  04-16     學術股市         [新聞] 彭双浪：啟動全球產能調整、12%營收恐受
# 34  Stock_04-16_35  04-16     學術股市     Re: [新聞] 贏得川普青睞！輝達躲掉關稅、不禁H20晶
# 35  Stock_04-16_36  04-16     學術股市      Re: [標的] 2615萬海 今天空單82.5獲利出場
# 36  Stock_04-16_37  04-16     學術股市                [請益] 假設降息跟對等關稅同時成立
# 37  Stock_04-16_38  04-16     學術股市             [請益] 中國繼續擺爛是不是要害慘全世界？
# 38  Stock_04-16_39  04-16     學術股市                   [請益] 中國跪還是美國跪??
# 39  Stock_04-16_40  04-16     學術股市          [新聞] 川普傳打算以關稅談判孤立中國 可能要各
# 40  Stock_04-16_41  04-16     學術股市                [新聞] ASML Q1訂單不如預期
# 41  Stock_04-16_42  04-16     學術股市              [心得] 中國不太可能拉升消費應對貿易戰
# 42  Stock_04-16_43  04-16     學術股市     Re: [新聞] 放寬美國米！若低價銷售台灣 稻農嗆：不種
# 43  Stock_04-16_44  04-16     學術股市       Re: [新聞] 美國財政部考慮是否放寬對美債的資本規
# 44  Stock_04-16_45  04-16     學術股市           [標的] 4142 國光生 腸病毒 流感疫苗多
# 45  Stock_04-16_46  04-16     學術股市              [請益] 美歐貿易談判卡關..美股應聲跌
# 46  Stock_04-16_47  04-16     學術股市      Re: [請益] 由於中國反抗美國　川普關稅增至245%
# 47  Stock_04-16_48  04-16     學術股市                   [創作] 不讓我的股票陪我過夜
# 48  Stock_04-16_49  04-16     學術股市         [新聞] 贏得川普青睞！輝達躲掉關稅、不禁H20晶
# 49  Stock_04-16_50  04-16     學術股市       [新聞] 半導體景氣亮警訊？ASML首季新增訂單39.
# 50  Stock_04-16_51  04-16     學術股市          [新聞] 中國海關承認當前「出口嚴峻」 業界絕望
# 51  Stock_04-16_52  04-16     學術股市         [新聞] 林伯豐：關稅談判勿衝前鋒「會挨打」GDP
# 52  Stock_04-16_53  04-16     學術股市               [情報] 0416 上市投信買賣超排行
# 53  Stock_04-16_54  04-16     學術股市       [情報] 114年04月16日 三大法人買賣金額統計表
# 54  Stock_04-16_55  04-16     學術股市     Re: [新聞] 放寬美國米！若低價銷售台灣 稻農嗆：不種
# 55  Stock_04-16_56  04-16     學術股市      Re: [新聞] 川普傳打算以關稅談判孤立中國 可能要各
#
#                                               content sentiment summary  \
# 0   原文標題：日媒：台積電將敲定面板級封裝規格 先從較小尺寸開始原文連結：發布時間：2025-0...        暫無      暫無
# 1   從廣場協議看2018美中貿易戰 的升級版，及這次的關稅事件，廣場協議的主因也是貿易逆差跟美元...        暫無      暫無
# 2   川普大讚「關稅政策」有效！　發文激讚：美國通膨下降了ETTODAY2025年04月16日 1...        暫無      暫無
# 3   1. 標題：董事會通過擬議分派股利2. 來源：公開資訊觀測站3. 網址：4. 內文：1. 董...        暫無      暫無
# 4   感覺上你在反串不過中國的確在擺爛，而且早在川普發動關稅戰前就在擺爛中國要經濟轉型、要促進內需...        暫無      暫無
# 5   如果美國這樣搞第一個崩潰的應該是台灣的IC設計產業可以查一下 聯發科 聯詠 瑞昱這些中國的案...        暫無      暫無
# 6   原文標題：「中國扛不住245％關稅」大量工廠放長假了！2000萬人慘失業原文連結：發布時間：...        暫無      暫無
# 7   原文標題：China Open to Talks If US Shows Respect, ...        暫無      暫無
# 8   『2025.04.10』<----日期很重要外交部發言人所說的話所以,CN從沒說過不談,但談...        暫無      暫無
# 9   原文標題： 劉鏡清：原文連結：發布時間：2025/04/16 15:16記者署名：原文內容：...        暫無      暫無
# 10  標的：5201.TW 凱衛分類：多正文：前天和今天它莫名奇妙漲停，而且不是「大跌之後的漲回來...        暫無      暫無
# 11  中國表示願意與美國進行談判，但美國必須尊重其立場重點就一句話，習寶願意談，但是川寶要給習寶面...        暫無      暫無
# 12  笑死，這肥貓公司直接說一句話就好了。持有本公司股票者，務必遵守勞基法！見紅就放！繞這樣多雞掰...        暫無      暫無
# 13  標題：0416 違約交割來源：臺灣證券交易所、證券櫃檯買賣中心網址：內文：臺灣證券交易所證券...        暫無      暫無
# 14  1. 標題：2323 中環 處分廣達，取得台積電2. 來源：公開資訊觀測站3. 網址：4. ...        暫無      暫無
# 15  1. 發文規範與分類總則 2. 股票板板規執法範圍 --------------------...        暫無      暫無
# 16  主旨：4-6-1的初犯罰則在三個月內加重至30天說明：因為最近板上太多4-6-1的違規我跟其...        暫無      暫無
# 17  台指期　自營商   投信  外資 台指選　自營商  投信   外資 小台指期　自營商 投信 ...        暫無      暫無
# 18  白宮：中國輸美商品面臨最高245%關稅2025/4/16 13:52（4/16 14:38 ...        暫無      暫無
# 19  當然可以台灣出口中國的商品前30名9成都是零組件如果中國本地的手機等產品大部分都用中國國產的...        暫無      暫無
# 20  台美股相關的大型ETF像0050、00935、00757、00924基本上都持有但最近股市震...        暫無      暫無
# 21  美國國債問題是內政問題，花太兇太扯了，尤其新冠後那種十倍速的花法更誇張。 現在缺錢應該要自己...        暫無      暫無
# 22  最近老黃有點雖…H20 被美國禁運，整批晶片宛如廢鐵但NVIDIA 很乾脆，沒有扭扭捏捏，直...        暫無      暫無
# 23  為什麼你看不懂川普到底在幹什麼？因為川普就是想用賭博的方式獲得最大利益，個人特質無解。這點c...        暫無      暫無
# 24  標題：來源：Vizion貨運數據公司網址：內文：根據Vizion貨運數據公司的統計相較於3月...        暫無      暫無
# 25  我們來看看川普在說什麼舉例台灣來說中國賣給台灣=>不可以台灣賣給中國=>允許(但中國東西就比...        暫無      暫無
# 26  1. 標題：外資買賣超排行2. 來源：台灣證交所3. 網址：4. 內文：買超2       ...        暫無      暫無
# 27  「產能過剩的挑戰」紐時：中國貨湧向歐洲 恐釀經濟災難2025-04-16 02:24 中國新...        暫無      暫無
# 28  先假設川爺的目的真的是這個這得要先計算出有多少是終端市場在美國的三角貿易(應該比2018少一...        暫無      暫無
# 29  原文標題：TVBS民調／反制川普關稅！46%贊成「暫緩台積電赴美投資」作談判條件原文連結：發...        暫無      暫無
# 30  看你在那洋洋灑灑屁話一堆??怎麼不說說我們鬼島自己呢 還在那關心中國消費不消費?現在美國爸爸...        暫無      暫無
# 31  中美關稅戰正熾 中國商務部新任命貿易談判代表2025/4/16 13:47（中央社記者張淑伶...        暫無      暫無
# 32  原文標題：快訊／沒有爆艙、沒有流浪貨　美國線5月長約簽不出來估先延後半個月原文連結：發布時間...        暫無      暫無
# 33  彭双浪：啟動全球產能調整、12%營收恐受波及2025/04/16 15:41文｜楊喻斐、財訊...        暫無      暫無
# 34  時間線：川皇關稅禁H20 >老黃跑去下跪貢獻千億美金>川皇開心解禁H20>老黃公開季度因關稅...        暫無      暫無
# 35  原則上我下次會在天花板價位在空ccc有些主力在這裡都在密集出貨賺好多次了我是偏好天花板空啦畢...        暫無      暫無
# 36  假設這三個月內FED再度啟動降息舒緩川寶壓力但是對等關稅還是持續施壓台灣可能按照放出來的風聲...        暫無      暫無
# 37  雖然說美國是先開貿易戰爭的先例但其實也是希望解決貿易局勢上的不平衡畢竟世界各國一直在賺美國人...        暫無      暫無
# 38  大家好胎嘎後~本肥萬年韭菜有事請教版上專家們??乳提,大家都知道中美兩國如同兩台火車對撞到現...        暫無      暫無
# 39  原文標題：川普傳打算以關稅談判孤立中國 可能要各國選邊站原文連結：發布時間：2025/04/...        暫無      暫無
# 40  原文標題：Critical chip firm ASML flags tariff unce...        暫無      暫無
# 41  其實連小粉紅都知道無論是應對貿易戰 或是發展中國自身經濟發展消費然後利用自身大市場創新 產業...        暫無      暫無
# 42  之前進口美國豬就說美國有腥味、不好吃結果銷量年年增，然後超市看不到美國豬肉？！美國米也是同樣...        暫無      暫無
# 43  白話翻譯美國銀行持有任何資產都有其風險指標係數你有多少資本才可以持有相對應多少的風險資產這其...        暫無      暫無
# 44  標的：4142 國光生分類：多分析/正文：國光生旗下的腸病毒疫苗、流感疫苗台灣有兩個國產腸病...        暫無      暫無
# 45  歐盟現在不是跟美國在貿易談判嗎??結果現在傳出沒有進展，而且川普的官員暗示說，美國不會取消大...        暫無      暫無
# 46  美國發動關稅戰目的本來就是要全世界國家選邊站 和支那脫鉤這是從川普上任第一天宣布加關稅就知道...        暫無      暫無
# 47  你的反覆關稅 幾度讓我損益心碎毫無支撐 不知道反悔你能不能體會現金可貴沒有多單可追 台股像難...        暫無      暫無
# 48  贏得川普青睞！輝達躲掉關稅、不禁H20晶片輸中　學者稱讚：黃仁勳是策略高手風傳媒李孟恩202...        暫無      暫無
# 49  原文標題：原文連結：發布時間：2025.04.16  14:10記者署名：方明原文內容：荷蘭...        暫無      暫無
# 50  原文標題：中國海關承認當前「出口嚴峻」 業界絕望一片：天塌了原文連結：發布時間：2025/0...        暫無      暫無
# 51  原文標題：林伯豐：關稅談判勿衝前鋒「會挨打」GDP恐連1.5%都不到原文連結：發布時間：20...        暫無      暫無
# 52  1. 標題：投信買賣超排行2. 來源：富邦證券3. 網址：4. 內文：買超1       2...        暫無      暫無
# 53  114年04月16日 三大法人買賣金額統計表單位名稱        買進金額(億元)  賣出...        暫無      暫無
# 54  當大家都認為臺灣米好吃，美國米不好吃，這樣的觀念已存在許久，我們直接看司法判決就可以知道這樣...        暫無      暫無
# 55  坦白說如果目的是這個那美國之前的操作我真心看不懂有滿多國家中國仍有相當大的貿易量譬如台灣，我...        暫無      暫無
#
#                                          top_key_freq  \
# 0   [('台積電', 5), ('原文', 3), ('技術', 3), ('日媒', 2), ...
# 1   [('中國', 36), ('美國', 30), ('國家', 21), ('技術', 13...
# 2   [('關稅', 9), ('川普', 6), ('美國', 4), ('政策', 3), (...
# 3   [('盈餘', 4), ('公積', 4), ('股利', 3), ('現金', 3), (...
# 4   [('中國', 9), ('經濟', 3), ('內需', 3), ('川普', 2), (...
# 5   [('美國', 3), ('中國', 3), ('台灣', 2), ('瑞昱', 2), (...
# 6   [('中國', 21), ('經濟', 11), ('美國', 9), ('企業', 6),...
# 7   [('中國', 5), ('原文', 3), ('美國', 2), ('台灣', 2), (...
# 8   [('時間', 2), ('川皇', 2), ('市場', 2), ('日期', 1), (...
# 9   [('劉鏡清', 11), ('產業', 11), ('市場', 9), ('美國', 8)...
# 10  [('凱衛', 5), ('官方', 3), ('帳號', 3), ('公司', 2), (...
# 11  [('美國', 2), ('習寶', 2), ('中國', 1), ('立場', 1), (...
# 12      [('公司', 2), ('肥貓', 1), ('股票', 1), ('勞基法', 1)]
# 13  [('證券', 4), ('金額', 4), ('臺灣', 2), ('交易所', 2), ...
# 14  [('交易', 17), ('公司', 10), ('比例', 8), ('證券', 6),...
# 15  [('處分', 14), ('文章', 9), ('板規', 8), ('看板', 8), ...
# 16  [('罰則', 3), ('初犯', 2), ('板主', 2), ('期限', 2), (...
# 17  [('自營商', 3), ('投信', 3), ('外資', 3), ('作者', 2), ...
# 18  [('中國', 21), ('關稅', 19), ('美國', 13), ('魷魚', 9)...
# 19  [('中國', 14), ('市場', 7), ('台灣', 5), ('零組件', 2),...
# 20  [('局勢', 2), ('台美股', 1), ('基本', 1), ('股市', 1), ...
# 21  [('問題', 4), ('美國', 3), ('國債', 1), ('內政', 1), (...
# 22  [('市場', 5), ('老黃', 3), ('信心', 3), ('美國', 2), (...
# 23  [('經濟', 32), ('美國', 19), ('風險', 18), ('川普', 14...
# 24  [('總量', 4), ('貨運', 2), ('數據', 2), ('公司', 2), (...
# 25  [('台灣', 8), ('中國', 7), ('美國', 5), ('關稅', 4), (...
# 26  [('台灣', 6), ('中國', 3), ('富邦', 2), ('中信', 2), (...
# 27  [('中國', 21), ('歐洲', 13), ('關稅', 8), ('經濟', 6),...
# 28  [('中國', 15), ('美國', 10), ('台灣', 7), ('川爺', 5),...
# 29  [('關稅', 10), ('台積電', 8), ('時間', 7), ('川普', 6),...
# 30  [('中國', 3), ('東西', 3), ('鬼島', 2), ('消費', 2), (...
# 31  [('中國', 8), ('商務部', 7), ('貿易', 7), ('李成鋼', 6),...
# 32  [('公司', 7), ('關稅', 5), ('時間', 4), ('市場', 4), (...
# 33  [('彭双浪', 11), ('關稅', 11), ('友達', 5), ('產品', 5)...
# 34  [('川皇', 4), ('關稅', 4), ('老黃', 4), ('時間線', 2), ...
# 35  [('天花板', 2), ('空氣', 2), ('馬後炮', 2), ('原則上', 1)...
# 36  [('舒緩', 1), ('川寶', 1), ('壓力', 1), ('關稅', 1), (...
# 37  [('中國', 5), ('貿易', 3), ('世界', 3), ('美國', 2), (...
# 38  [('專家', 2), ('勝負', 2), ('韭菜', 1), ('乳提', 1), (...
# 39  [('中國', 14), ('美國', 14), ('關稅', 6), ('川普', 6),...
# 40  [('預期', 5), ('中國', 5), ('訂單', 4), ('關稅', 4), (...
# 41  [('中國', 23), ('消費', 8), ('美國', 6), ('國家', 5), ...
# 42  [('美國', 4), ('腥味', 1), ('結果', 1), ('銷量', 1), (...
# 43  [('銀行', 4), ('美債', 4), ('美國', 2), ('資產', 2), (...
# 44  [('疫苗', 14), ('國光', 10), ('腸病毒', 10), ('流感', 4...
# 45  [('美國', 3), ('川普', 3), ('歐盟', 2), ('關稅', 2), (...
# 46  [('美國', 9), ('關稅', 8), ('意義', 5), ('國家', 4), (...
# 47  [('股票', 3), ('台股', 2), ('關稅', 1), ('心碎', 1), (...
# 48  [('台灣', 10), ('晶片', 6), ('翁履中', 5), ('川普', 4),...
# 49  [('原文', 3), ('歐元', 3), ('半導體', 2), ('設備', 2), ...
# 50  [('中國', 14), ('工廠', 6), ('美國', 5), ('原文', 3), ...
# 51  [('美國', 10), ('關稅', 8), ('政府', 8), ('林伯豐', 7),...
# 52  [('台灣', 5), ('富邦', 2), ('標題', 1), ('投信', 1), (...
# 53  [('金額', 3), ('自營商', 2), ('外資', 2), ('法人', 1), ...
# 54  [('美國', 3), ('加州', 3), ('觀念', 2), ('阿肯色州', 2),...
# 55  [('美國', 23), ('中國', 11), ('市場', 6), ('國家', 4),...
#
#                                                tokens  \
# 0   ['原文', '標題', '：', '日媒', '：', '台積電', '將', '敲定',...
# 1   ['從', '廣場', '協議', '看', '2018', '美中', '貿易戰 ', '...
# 2   ['川普', '大讚', '「', '關稅', '政策', '」', '有效', '！', ...
# 3   ['1. ', '標題', '：', '董事會', '通過', '擬議', '分派', '股...
# 4   ['感覺', '上', '你', '在', '反串不過', '中國', '的確', '在',...
# 5   ['如果', '美國', '這樣', '搞', '第一', '個', '崩潰', '的', ...
# 6   ['原文', '標題', '：', '「', '中國', '扛', '不', '住', '2...
# 7   ['原文', '標題', '：', 'China', ' Open', ' to ', 'T...
# 8   ['『', '2025.04.10', '』', '<----', '日期', '很', '...
# 9   ['原文', '標題', '：', ' ', '劉鏡清', '：', '原文', '連結',...
# 10  ['標的：', '5201.TW ', '凱衛', '分類', '：', '多', '正文'...
# 11  ['中國', '表示', '願意', '與', '美國', '進行', '談判', '，',...
# 12  ['笑死', '，', '這', '肥貓', '公司', '直接', '說', '一', '...
# 13  ['標題', '：', '0416 ', '違約', '交割', '來源', '：', '臺...
# 14  ['1. ', '標題', '：', '2323 ', '中環', ' ', '處分', '...
# 15  ['1. ', '發文', '規範', '與', '分類', '總則', ' 2. ', '...
# 16  ['主旨', '：', '4-6-1', '的', '初犯', '罰則', '在', '三'...
# 17  ['台指期', '\u3000', '自營商', '   ', '投信', '  ', '外...
# 18  ['白宮', '：', '中國', '輸', '美', '商品', '面臨', '最', '...
# 19  ['當然', '可以', '台灣', '出口', '中國', '的', '商品', '前',...
# 20  ['台美股', '相關', '的', '大型', 'ETF', '像', '0050', '...
# 21  ['美國', '國債', '問題', '是', '內政', '問題', '，', '花', ...
# 22  ['最近', '老黃', '有點', '雖', '…H20 ', '被', '美國', '禁...
# 23  ['為什麼', '你', '看', '不', '懂', '川普', '到底', '在', '...
# 24  ['標題', '：', '來源', '：', 'Vizion', '貨運', '數據', '...
# 25  ['我們', '來', '看看', '川普', '在', '說', '什麼', '舉例', ...
# 26  ['1. ', '標題', '：', '外資', '買賣', '超', '排行', '2. ...
# 27  ['「', '產能', '過剩', '的', '挑戰', '」', '紐時', '：', '...
# 28  ['先', '假設', '川爺', '的', '目的', '真的', '是', '這', '...
# 29  ['原文', '標題', '：', 'TVBS', '民調', '／', '反制', '川普...
# 30  ['看', '你', '在', '那', '洋洋', '灑灑屁話', '一', '堆', '...
# 31  ['中', '美', '關稅', '戰正', '熾', ' ', '中國', '商務部', ...
# 32  ['原文', '標題', '：', '快訊', '／', '沒有', '爆艙', '、', ...
# 33  ['彭双浪', '：', '啟動', '全球', '產能', '調整', '、', '12%...
# 34  ['時間線', '：', '川皇', '關稅', '禁', 'H20', ' >', '老黃...
# 35  ['原則上', '我', '下', '次', '會', '在', '天花板', '價位', ...
# 36  ['假設', '這', '三', '個', '月', '內', 'FED', '再度', '...
# 37  ['雖然', '說', '美國', '是', '先', '開', '貿易', '戰爭', '...
# 38  ['大家', '好', '胎', '嘎', '後', '~', '本', '肥', '萬',...
# 39  ['原文', '標題', '：', '川普傳', '打算', '以', '關稅', '談判'...
# 40  ['原文', '標題', '：', 'Critical', ' chip', ' firm'...
# 41  ['其實', '連', '小粉紅', '都', '知道', '無論', '是', '應', ...
# 42  ['之前', '進口', '美國', '豬', '就', '說', '美國', '有', '...
# 43  ['白話', '翻譯', '美國', '銀行', '持有', '任何', '資產', '都'...
# 44  ['標的：', '4142 ', '國光', '生分類', '：', '多', '分析', ...
# 45  ['歐盟', '現在', '不', '是', '跟', '美國', '在', '貿易', '...
# 46  ['美國', '發動', '關稅戰目的', '本來', '就是', '要', '全', '世...
# 47  ['你', '的', '反覆', '關稅', ' ', '幾', '度', '讓', '我'...
# 48  ['贏得', '川普', '青睞', '！', '輝達', '躲掉', '關稅', '、',...
# 49  ['原文', '標題', '：', '原文', '連結', '：', '發布', '時間',...
# 50  ['原文', '標題', '：', '中國', '海關', '承認', '當前', '「',...
# 51  ['原文', '標題', '：', '林伯豐', '：', '關稅', '談判', '勿',...
# 52  ['1. ', '標題', '：', '投信', '買賣', '超', '排行', '2. ...
# 53  ['1', '14年', '04月', '16日', ' ', '三大', '法人', '買...
# 54  ['當', '大家', '都', '認為', '臺灣', '米', '好吃', '，', '...
# 55  ['坦白', '說', '如果', '目的', '是', '這', '個', '那', '美...
#
#                                             tokens_v2  \
# 0   ['原文', '標題', '日媒', '台積電', '面板級', '規格', '尺寸', '...
# 1   ['廣場', '協議', '美中', '貿易戰 ', '升級版', '關稅', '事件', ...
# 2   ['川普', '關稅', '政策', '美國', '通膨', '記者', '吳美依', '美...
# 3   ['標題', '董事會', '股利', '來源', '資訊', '觀測站', '網址', '...
# 4   ['感覺', '中國', '川普', '關稅戰', '中國', '經濟', '內需', '說...
# 5   ['美國', '台灣', '設計', '產業', '聯發科 ', '瑞昱', '中國', '...
# 6   ['原文', '標題', '中國', '關稅', '工廠', '長假', '原文', '時間...
# 7   ['原文', '標題', '原文', '時間', '記者', '原文', '內容', '整理...
# 8   ['日期', '外交部', '發言人', '前提', '媒體', '時間', '新聞', '...
# 9   ['原文', '標題', '劉鏡清', '原文', '時間', '記者', '原文', '內...
# 10  ['標的：', '凱衛', '分類', '正文', '台股', '官方', '帳號', '凱...
# 11  ['中國', '美國', '美國', '立場', '重點', '習寶', '川寶', '習寶...
# 12                    ['肥貓', '公司', '公司', '股票', '勞基法']
# 13  ['標題', '來源', '臺灣', '證券', '交易所', '證券', '櫃檯', '中...
# 14  ['標題', '處分', '台積電', '來源', '資訊', '觀測站', '網址', '...
# 15  ['規範', '分類', '股票板', '板規', '範圍', '辦法', '處分', '規...
# 16  ['主旨', '初犯', '罰則', '板主', '共識', '期限', '時間', '初犯...
# 17  ['台指期', '自營商', '投信', '外資', '台指', '自營商', '投信', ...
# 18  ['白宮', '中國', '商品', '關稅', '美國', '白宮', '聲明', '中國...
# 19  ['台灣', '中國', '商品', '零組件', '中國', '手機', '產品', '中...
# 20  ['台美股', '基本', '股市', '指數', '策略', '低檔', '局勢', '資...
# 21  ['美國', '國債', '問題', '內政', '問題', '新冠', '倍速', '花法...
# 22  ['老黃', '美國', '晶片', '廢鐵', '作法', '財報', '地獄', '地板...
# 23  ['川普', '川普', '方式', '利益', '特質', '回答', '川普', '人生...
# 24  ['標題', '來源', '貨運', '數據', '公司', '網址', '內文', '貨運...
# 25  ['川普', '台灣', '中國', '台灣', '台灣', '中國', '中國', '東西...
# 26  ['標題', '外資', '買賣', '來源', '台灣', '證交所', '網址', '內...
# 27  ['產能', '挑戰', '紐時', '中國', '貨湧向', '歐洲', '經濟', '災...
# 28  ['川爺', '目的', '終端', '市場', '美國', '三角', '貿易', '三角...
# 29  ['原文', '標題', '民調', '川普', '關稅', '台積電', '條件', '時...
# 30  ['鬼島', '中國', '消費', '美國', '爸爸', '中國', '貿易', '貿易...
# 31  ['關稅', '中國', '商務部', '貿易', '代表', '中央社', '記者', '...
# 32  ['原文', '標題', '快訊', '爆艙', '流浪貨', '美國線', '原文', '...
# 33  ['彭双浪', '全球', '產能', '營收', '楊喻斐', '財訊', '新聞', '...
# 34  ['時間線', '川皇', '關稅', '老黃', '美金>', '川皇', '老黃', '...
# 35  ['原則上', '天花板', '價位', '主力', '天花板', '貨櫃', '景氣', ...
# 36  ['舒緩', '川寶', '壓力', '關稅', '台灣', '風聲課', '情況', '利...
# 37  ['美國', '貿易', '戰爭', '先例', '貿易', '局勢', '世界', '美國...
# 38  ['韭菜', '專家', '乳提', '火車', '勝負', '本肥', '事情', '勝負...
# 39  ['原文', '標題', '川普傳', '關稅', '中國', '選邊站', '原文', '...
# 40  ['原文', '標題', '關鍵', '晶片', '廠商', '訂單', '預期', '關稅...
# 41  ['貿易戰', '中國', '經濟', '消費', '市場', '產業', '中國', '最...
# 42  ['美國', '美國', '腥味', '結果', '銷量', '超市', '美國', '豬肉...
# 43  ['白話', '美國', '銀行', '資產', '風險', '指標', '係數', '資本...
# 44  ['標的：', '國光', '正文', '國光生', '旗下', '腸病毒', '疫苗', ...
# 45  ['歐盟', '美國', '貿易', '進展', '川普', '官員', '美國', '關稅...
# 46  ['美國', '關稅戰目的', '世界', '國家', '選邊站', '支那', '川普',...
# 47  ['關稅', '心碎', '現金', '台股', '苦水', '股票', '曾經', '股票...
# 48  ['川普', '關稅', '晶片', '學者', '黃仁勳', '策略', '高手', '傳...
# 49  ['原文', '標題', '原文', '時間', '記者', '方明', '原文', '內容...
# 50  ['原文', '標題', '中國', '海關', '業界', '原文', '時間', '記者...
# 51  ['原文', '標題', '林伯豐', '關稅', '原文', '時間', '記者', '徐...
# 52  ['標題', '投信', '買賣', '來源', '富邦', '證券', '網址', '內文...
# 53  ['法人', '金額', '統計表', '單位', '名稱', '金額', '金額', '差...
# 54  ['臺灣', '美國', '觀念', '司法', '觀念', '判決書', '加州', '一...
# 55  ['目的', '美國', '國家', '中國', '貿易量', '台灣', '出口國', '...
#
#                                              entities  \
# 0   [NerToken(word='日媒', ner='NORP', idx=(5, 7)), ...
# 1   [NerToken(word='美國鋼鐵', ner='ORG', idx=(57, 61)...
# 2   [NerToken(word='川', ner='PERSON', idx=(0, 1)),...
# 3   [NerToken(word=' 年度3.', ner='DATE', idx=(79, 8...
# 4   [NerToken(word='中國', ner='GPE', idx=(9, 11)), ...
# 5   [NerToken(word='美國', ner='GPE', idx=(2, 4)), N...
# 6   [NerToken(word='中國', ner='GPE', idx=(6, 8)), N...
# 7   [NerToken(word='中國', ner='GPE', idx=(4473, 447...
# 8   [NerToken(word='外交部', ner='ORG', idx=(22, 25))...
# 9   [NerToken(word='劉鏡清', ner='PERSON', idx=(6, 9)...
# 10  [NerToken(word='凱衛', ner='PERSON', idx=(11, 13...
# 11  [NerToken(word='中國', ner='GPE', idx=(0, 2)), N...
# 12  [NerToken(word='肥貓公司', ner='ORG', idx=(4, 8)),...
# 13  [NerToken(word='臺灣證券交易所', ner='ORG', idx=(15, ...
# 14  [NerToken(word='111', ner='CARDINAL', idx=(113...
# 15  [NerToken(word='中國', ner='NORP', idx=(1204, 12...
# 16  [NerToken(word='4', ner='CARDINAL', idx=(3, 4)...
# 17        [NerToken(word='台', ner='GPE', idx=(0, 1))]
# 18  [NerToken(word='白宮', ner='ORG', idx=(0, 2)), N...
# 19  [NerToken(word='台灣', ner='GPE', idx=(4, 6)), N...
# 20  [NerToken(word='美股', ner='ORG', idx=(1, 3)), N...
# 21  [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# 22  [NerToken(word='美國', ner='GPE', idx=(13, 15)),...
# 23  [NerToken(word='川普', ner='PERSON', idx=(7, 9))...
# 24  [NerToken(word='Vizion貨運數據公司', ner='ORG', idx=...
# 25  [NerToken(word='川普', ner='PERSON', idx=(5, 7))...
# 26  [NerToken(word='台灣', ner='GPE', idx=(54, 56)),...
# 27  [NerToken(word='中國', ner='GPE', idx=(12, 14)),...
# 28  [NerToken(word='美國', ner='GPE', idx=(29, 31)),...
# 29  [NerToken(word='川普', ner='PERSON', idx=(14, 16...
# 30  [NerToken(word='鬼島', ner='LOC', idx=(21, 23)),...
# 31  [NerToken(word='美', ner='GPE', idx=(1, 2)), Ne...
# 32  [NerToken(word='5月長約', ner='ORG', idx=(22, 26)...
# 33  [NerToken(word='彭双浪', ner='PERSON', idx=(0, 3)...
# 34  [NerToken(word='川皇', ner='PERSON', idx=(4, 6))...
# 35  [NerToken(word='那天', ner='DATE', idx=(68, 70))...
# 36  [NerToken(word='這三個月', ner='DATE', idx=(2, 6))...
# 37  [NerToken(word='美國', ner='GPE', idx=(3, 5)), N...
# 38  [NerToken(word='中', ner='GPE', idx=(32, 33)), ...
# 39  [NerToken(word='中國', ner='GPE', idx=(17, 19)),...
# 40  [NerToken(word='2025', ner='CARDINAL', idx=(53...
# 41  [NerToken(word='中國', ner='GPE', idx=(22, 24)),...
# 42  [NerToken(word='美國', ner='GPE', idx=(4, 6)), N...
# 43  [NerToken(word='美債', ner='ORG', idx=(47, 49)),...
# 44  [NerToken(word='台灣', ner='GPE', idx=(37, 39)),...
# 45  [NerToken(word='歐盟', ner='ORG', idx=(0, 2)), N...
# 46  [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# 47   [NerToken(word='台股', ner='GPE', idx=(167, 169))]
# 48  [NerToken(word='川普', ner='PERSON', idx=(2, 4))...
# 49  [NerToken(word='艾司摩爾', ner='ORG', idx=(53, 57)...
# 50  [NerToken(word='海關', ner='ORG', idx=(7, 9)), N...
# 51  [NerToken(word='林伯豐', ner='PERSON', idx=(5, 8)...
# 52  [NerToken(word='2', ner='CARDINAL', idx=(13, 1...
# 53  [NerToken(word='114年04月16日', ner='DATE', idx=(...
# 54  [NerToken(word='O鮮', ner='GPE', idx=(70, 72)),...
# 55  [NerToken(word='美國', ner='GPE', idx=(11, 13)),...
#
#                                             token_pos  \
# 0   [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 1   [('從', 'P'), ('廣場', 'Nc'), ('協議', 'Na'), ('看',...
# 2   [('川普', 'Nb'), ('大讚', 'VC'), ('「', 'PARENTHESI...
# 3   [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 4   [('感覺', 'Na'), ('上', 'Ng'), ('你', 'Nh'), ('在',...
# 5   [('如果', 'Cbb'), ('美國', 'Nc'), ('這樣', 'VH'), ('...
# 6   [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 7   [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 8   [('『', 'PARENTHESISCATEGORY'), ('2025.04.10', ...
# 9   [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 10  [('標的：', 'Na'), ('5201.TW ', 'FW'), ('凱衛', 'Nb...
# 11  [('中國', 'Nc'), ('表示', 'VE'), ('願意', 'VK'), ('與...
# 12  [('笑死', 'VH'), ('，', 'COMMACATEGORY'), ('這', '...
# 13  [('標題', 'Na'), ('：', 'COLONCATEGORY'), ('0416 ...
# 14  [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 15  [('1. ', 'Neu'), ('發文', 'Nv'), ('規範', 'Na'), (...
# 16  [('主旨', 'Na'), ('：', 'COLONCATEGORY'), ('4-6-1...
# 17  [('台指期', 'Na'), ('\u3000', 'WHITESPACE'), ('自營...
# 18  [('白宮', 'Nc'), ('：', 'COLONCATEGORY'), ('中國', ...
# 19  [('當然', 'D'), ('可以', 'D'), ('台灣', 'Nc'), ('出口'...
# 20  [('台美股', 'Nc'), ('相關', 'VH'), ('的', 'DE'), ('大...
# 21  [('美國', 'Nc'), ('國債', 'Na'), ('問題', 'Na'), ('是...
# 22  [('最近', 'Nd'), ('老黃', 'Nb'), ('有點', 'Dfa'), ('...
# 23  [('為什麼', 'D'), ('你', 'Nh'), ('看', 'VJ'), ('不',...
# 24  [('標題', 'Na'), ('：', 'COLONCATEGORY'), ('來源', ...
# 25  [('我們', 'Nh'), ('來', 'D'), ('看看', 'VC'), ('川普'...
# 26  [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 27  [('「', 'PARENTHESISCATEGORY'), ('產能', 'Na'), (...
# 28  [('先', 'D'), ('假設', 'VE'), ('川爺', 'Nb'), ('的',...
# 29  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 30  [('看', 'VC'), ('你', 'Nh'), ('在', 'P'), ('那', '...
# 31  [('中', 'Nc'), ('美', 'Nc'), ('關稅', 'Na'), ('戰正'...
# 32  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 33  [('彭双浪', 'Nb'), ('：', 'COLONCATEGORY'), ('啟動',...
# 34  [('時間線', 'Na'), ('：', 'COLONCATEGORY'), ('川皇',...
# 35  [('原則上', 'Na'), ('我', 'Nh'), ('下', 'Nes'), ('次...
# 36  [('假設', 'VE'), ('這', 'Nep'), ('三', 'Neu'), ('個...
# 37  [('雖然', 'Cbb'), ('說', 'VE'), ('美國', 'Nc'), ('是...
# 38  [('大家', 'Nh'), ('好', 'VH'), ('胎', 'Na'), ('嘎',...
# 39  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 40  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 41  [('其實', 'D'), ('連', 'Cbb'), ('小粉紅', 'VH'), ('都...
# 42  [('之前', 'Nd'), ('進口', 'VC'), ('美國', 'Nc'), ('豬...
# 43  [('白話', 'Na'), ('翻譯', 'VC'), ('美國', 'Nc'), ('銀...
# 44  [('標的：', 'Na'), ('4142 ', 'Neu'), ('國光', 'Na')...
# 45  [('歐盟', 'Nb'), ('現在', 'Nd'), ('不', 'D'), ('是',...
# 46  [('美國', 'Nc'), ('發動', 'VC'), ('關稅戰目的', 'Na'), ...
# 47  [('你', 'Nh'), ('的', 'DE'), ('反覆', 'D'), ('關稅',...
# 48  [('贏得', 'VJ'), ('川普', 'Nb'), ('青睞', 'VI'), ('！...
# 49  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 50  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 51  [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 52  [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 53  [('1', 'Neu'), ('14年', 'Neu'), ('04月', 'Nd'), ...
# 54  [('當', 'P'), ('大家', 'Nh'), ('都', 'D'), ('認為', ...
# 55  [('坦白', 'VH'), ('說', 'VE'), ('如果', 'Cbb'), ('目...
#
#                                                  link  photo_link
# 0   https://www.ptt.cc/bbs/Stock/M.1744794518.A.3D...         NaN
# 1   https://www.ptt.cc/bbs/Stock/M.1744794681.A.85...         NaN
# 2   https://www.ptt.cc/bbs/Stock/M.1744794813.A.00...         NaN
# 3   https://www.ptt.cc/bbs/Stock/M.1744795089.A.D4...         NaN
# 4   https://www.ptt.cc/bbs/Stock/M.1744795403.A.4D...         NaN
# 5   https://www.ptt.cc/bbs/Stock/M.1744795527.A.AD...         NaN
# 6   https://www.ptt.cc/bbs/Stock/M.1744795590.A.9E...         NaN
# 7   https://www.ptt.cc/bbs/Stock/M.1744795603.A.94...         NaN
# 8   https://www.ptt.cc/bbs/Stock/M.1744796688.A.23...         NaN
# 9   https://www.ptt.cc/bbs/Stock/M.1744796866.A.2B...         NaN
# 10  https://www.ptt.cc/bbs/Stock/M.1744797457.A.8C...         NaN
# 11  https://www.ptt.cc/bbs/Stock/M.1744798337.A.C8...         NaN
# 12  https://www.ptt.cc/bbs/Stock/M.1744798797.A.2B...         NaN
# 13  https://www.ptt.cc/bbs/Stock/M.1744799085.A.32...         NaN
# 14  https://www.ptt.cc/bbs/Stock/M.1744799205.A.CC...         NaN
# 15  https://www.ptt.cc/bbs/Stock/M.1719872231.A.9B...         NaN
# 16  https://www.ptt.cc/bbs/Stock/M.1739730011.A.26...         NaN
# 17  https://www.ptt.cc/bbs/Stock/M.1744783205.A.45...         NaN
# 18  https://www.ptt.cc/bbs/Stock/M.1744788378.A.D1...         NaN
# 19  https://www.ptt.cc/bbs/Stock/M.1744788919.A.6C...         NaN
# 20  https://www.ptt.cc/bbs/Stock/M.1744789544.A.5C...         NaN
# 21  https://www.ptt.cc/bbs/Stock/M.1744789548.A.0C...         NaN
# 22  https://www.ptt.cc/bbs/Stock/M.1744790227.A.1A...         NaN
# 23  https://www.ptt.cc/bbs/Stock/M.1744790468.A.84...         NaN
# 24  https://www.ptt.cc/bbs/Stock/M.1744790486.A.6F...         NaN
# 25  https://www.ptt.cc/bbs/Stock/M.1744790630.A.0A...         NaN
# 26  https://www.ptt.cc/bbs/Stock/M.1744791155.A.50...         NaN
# 27  https://www.ptt.cc/bbs/Stock/M.1744791254.A.B6...         NaN
# 28  https://www.ptt.cc/bbs/Stock/M.1744791954.A.A7...         NaN
# 29  https://www.ptt.cc/bbs/Stock/M.1744791972.A.6C...         NaN
# 30  https://www.ptt.cc/bbs/Stock/M.1744792149.A.17...         NaN
# 31  https://www.ptt.cc/bbs/Stock/M.1744792305.A.75...         NaN
# 32  https://www.ptt.cc/bbs/Stock/M.1744792757.A.3B...         NaN
# 33  https://www.ptt.cc/bbs/Stock/M.1744793247.A.0D...         NaN
# 34  https://www.ptt.cc/bbs/Stock/M.1744793486.A.08...         NaN
# 35  https://www.ptt.cc/bbs/Stock/M.1744793510.A.85...         NaN
# 36  https://www.ptt.cc/bbs/Stock/M.1744793817.A.DA...         NaN
# 37  https://www.ptt.cc/bbs/Stock/M.1744794193.A.C1...         NaN
# 38  https://www.ptt.cc/bbs/Stock/M.1744783227.A.DA...         NaN
# 39  https://www.ptt.cc/bbs/Stock/M.1744783800.A.40...         NaN
# 40  https://www.ptt.cc/bbs/Stock/M.1744783810.A.75...         NaN
# 41  https://www.ptt.cc/bbs/Stock/M.1744783894.A.2B...         NaN
# 42  https://www.ptt.cc/bbs/Stock/M.1744784009.A.EA...         NaN
# 43  https://www.ptt.cc/bbs/Stock/M.1744784055.A.A1...         NaN
# 44  https://www.ptt.cc/bbs/Stock/M.1744784623.A.55...         NaN
# 45  https://www.ptt.cc/bbs/Stock/M.1744784628.A.58...         NaN
# 46  https://www.ptt.cc/bbs/Stock/M.1744784657.A.E4...         NaN
# 47  https://www.ptt.cc/bbs/Stock/M.1744784683.A.BB...         NaN
# 48  https://www.ptt.cc/bbs/Stock/M.1744785004.A.3C...         NaN
# 49  https://www.ptt.cc/bbs/Stock/M.1744785304.A.63...         NaN
# 50  https://www.ptt.cc/bbs/Stock/M.1744785578.A.01...         NaN
# 51  https://www.ptt.cc/bbs/Stock/M.1744785961.A.1E...         NaN
# 52  https://www.ptt.cc/bbs/Stock/M.1744786585.A.DD...         NaN
# 53  https://www.ptt.cc/bbs/Stock/M.1744787037.A.D7...         NaN
# 54  https://www.ptt.cc/bbs/Stock/M.1744787290.A.3D...         NaN
# 55  https://www.ptt.cc/bbs/Stock/M.1744787337.A.5E...         NaN

# %%
df_group['token_pos']
# Out:
# 0     [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 1     [('從', 'P'), ('廣場', 'Nc'), ('協議', 'Na'), ('看',...
# 2     [('川普', 'Nb'), ('大讚', 'VC'), ('「', 'PARENTHESI...
# 3     [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 4     [('感覺', 'Na'), ('上', 'Ng'), ('你', 'Nh'), ('在',...
# 5     [('如果', 'Cbb'), ('美國', 'Nc'), ('這樣', 'VH'), ('...
# 6     [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 7     [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 8     [('『', 'PARENTHESISCATEGORY'), ('2025.04.10', ...
# 9     [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 10    [('標的：', 'Na'), ('5201.TW ', 'FW'), ('凱衛', 'Nb...
# 11    [('中國', 'Nc'), ('表示', 'VE'), ('願意', 'VK'), ('與...
# 12    [('笑死', 'VH'), ('，', 'COMMACATEGORY'), ('這', '...
# 13    [('標題', 'Na'), ('：', 'COLONCATEGORY'), ('0416 ...
# 14    [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 15    [('1. ', 'Neu'), ('發文', 'Nv'), ('規範', 'Na'), (...
# 16    [('主旨', 'Na'), ('：', 'COLONCATEGORY'), ('4-6-1...
# 17    [('台指期', 'Na'), ('\u3000', 'WHITESPACE'), ('自營...
# 18    [('白宮', 'Nc'), ('：', 'COLONCATEGORY'), ('中國', ...
# 19    [('當然', 'D'), ('可以', 'D'), ('台灣', 'Nc'), ('出口'...
# 20    [('台美股', 'Nc'), ('相關', 'VH'), ('的', 'DE'), ('大...
# 21    [('美國', 'Nc'), ('國債', 'Na'), ('問題', 'Na'), ('是...
# 22    [('最近', 'Nd'), ('老黃', 'Nb'), ('有點', 'Dfa'), ('...
# 23    [('為什麼', 'D'), ('你', 'Nh'), ('看', 'VJ'), ('不',...
# 24    [('標題', 'Na'), ('：', 'COLONCATEGORY'), ('來源', ...
# 25    [('我們', 'Nh'), ('來', 'D'), ('看看', 'VC'), ('川普'...
# 26    [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 27    [('「', 'PARENTHESISCATEGORY'), ('產能', 'Na'), (...
# 28    [('先', 'D'), ('假設', 'VE'), ('川爺', 'Nb'), ('的',...
# 29    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 30    [('看', 'VC'), ('你', 'Nh'), ('在', 'P'), ('那', '...
# 31    [('中', 'Nc'), ('美', 'Nc'), ('關稅', 'Na'), ('戰正'...
# 32    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 33    [('彭双浪', 'Nb'), ('：', 'COLONCATEGORY'), ('啟動',...
# 34    [('時間線', 'Na'), ('：', 'COLONCATEGORY'), ('川皇',...
# 35    [('原則上', 'Na'), ('我', 'Nh'), ('下', 'Nes'), ('次...
# 36    [('假設', 'VE'), ('這', 'Nep'), ('三', 'Neu'), ('個...
# 37    [('雖然', 'Cbb'), ('說', 'VE'), ('美國', 'Nc'), ('是...
# 38    [('大家', 'Nh'), ('好', 'VH'), ('胎', 'Na'), ('嘎',...
# 39    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 40    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 41    [('其實', 'D'), ('連', 'Cbb'), ('小粉紅', 'VH'), ('都...
# 42    [('之前', 'Nd'), ('進口', 'VC'), ('美國', 'Nc'), ('豬...
# 43    [('白話', 'Na'), ('翻譯', 'VC'), ('美國', 'Nc'), ('銀...
# 44    [('標的：', 'Na'), ('4142 ', 'Neu'), ('國光', 'Na')...
# 45    [('歐盟', 'Nb'), ('現在', 'Nd'), ('不', 'D'), ('是',...
# 46    [('美國', 'Nc'), ('發動', 'VC'), ('關稅戰目的', 'Na'), ...
# 47    [('你', 'Nh'), ('的', 'DE'), ('反覆', 'D'), ('關稅',...
# 48    [('贏得', 'VJ'), ('川普', 'Nb'), ('青睞', 'VI'), ('！...
# 49    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 50    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 51    [('原文', 'Na'), ('標題', 'Na'), ('：', 'COLONCATEG...
# 52    [('1. ', 'Neu'), ('標題', 'Na'), ('：', 'COLONCAT...
# 53    [('1', 'Neu'), ('14年', 'Neu'), ('04月', 'Nd'), ...
# 54    [('當', 'P'), ('大家', 'Nh'), ('都', 'D'), ('認為', ...
# 55    [('坦白', 'VH'), ('說', 'VE'), ('如果', 'Cbb'), ('目...
# Name: token_pos, dtype: object

# %%
len(df_group['token_pos'])
# Out:
# 56

# %%
from collections import Counter

# %%
news_links =['Stock', 'Gossiping', 'C_Chat', 'Baseball','Military']
news_categories=['學術股市','綜合','閒談','棒球','軍事']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
top_cate_words={} # final result
counter_all = Counter() # counter for category '全部'
for category in news_categories:
    
    # df yesterday-->This is your homework
    # df=df[(df.date >= start_date) & (df.date <= end_date)]
    
    # df category
    df_group = df[df.category == category]
    
    # concatenate all filtered words in the same category
    words_group = []
    for row in df_group.token_pos:
        
        # filter words for each news
        filtered_words =[]
        for (word, pos) in eval(row):
            if (len(word) >= 2) & (pos in allowedPOS):
                filtered_words.append(word)
                
        # concatenate filtered words  
        words_group += filtered_words

    # now we can count word frequency
    counter = Counter( words_group )
    
    # concatenate all counters 
    counter_all += counter
    topwords = counter.most_common(10)

    # store topwords
    top_cate_words[category]= topwords

# Process category '全部'
top_cate_words['全部'] = counter_all.most_common(10)

# %%
words_group
# Out:
# ['原文',
#  '來源',
#  '原文',
#  '摘要',
#  '聯合報',
#  '記者',
#  '李人岳',
#  '國安會',
#  '秘書長',
#  '吳釗燮',
#  '外交部',
#  '時期',
#  '幕僚',
#  '何仁傑',
#  '共諜案',
#  '總統府',
#  '憲兵',
#  '國防部長',
#  '顧立雄',
#  '何仁傑',
#  '國安會',
#  '國防部',
#  '國防部',
#  '國防部',
#  '人員',
#  '案子',
#  '顧立雄',
#  '何仁傑',
#  '國安會',
#  '國防部',
#  '司法',
#  '程序',
#  '個案',
#  '國防部',
#  '國防部',
#  '人員',
#  '案子',
#  '海測',
#  '動靜',
#  '顧立雄',
#  '缺失',
#  '狀態',
#  '媒體',
#  '兩岸關',
#  '影響',
#  '年限',
#  '軍官',
#  '年班',
#  '國軍',
#  '幹部',
#  '狀況',
#  '官兵',
#  '情況',
#  '情況',
#  '情況',
#  '人數',
#  '營率',
#  '人數也',
#  '思惟下',
#  '退伍潮',
#  '成效',
#  '方面',
#  '心得',
#  '感想',
#  '何仁傑',
#  '共諜案',
#  '吳釗燮',
#  '外交部長',
#  '任內',
#  '外交',
#  '情資',
#  '吳釗燮',
#  '海測',
#  '消息',
#  '顧立雄',
#  '說法',
#  '事項',
#  '版規',
#  '內容',
#  '人機',
#  '國防部',
#  '後備旅',
#  '小型',
#  '國防部',
#  '記者會',
#  '義務役',
#  '狀況',
#  '無人',
#  '刺針',
#  '飛彈',
#  '武器',
#  '裝備',
#  '訓練',
#  '課程',
#  '媒體',
#  '部隊',
#  '器材',
#  '師資',
#  '情況',
#  '新訓',
#  '國防部',
#  '小型',
#  '人機',
#  '國防部',
#  '人數',
#  '內政部',
#  '義務役',
#  '國防部',
#  '內政部',
#  '學制',
#  '役男',
#  '流路',
#  '梯次',
#  '內政部',
#  '役政司役男兵籍',
#  '狀況',
#  '役男',
#  '人數',
#  '訓練',
#  '規劃',
#  '方面',
#  '月份',
#  '民進黨',
#  '立委',
#  '陳俊宇',
#  '立法院',
#  '國軍',
#  '人機',
#  '器材',
#  '師資',
#  '師資',
#  '量能',
#  '訓練',
#  '比例',
#  '全動署',
#  '署長',
#  '李定中',
#  '師資',
#  '縣市',
#  '師資',
#  '梯次',
#  '無人機',
#  '師資',
#  '李定中',
#  '裝備',
#  '月分',
#  '梯次',
#  '小型監偵',
#  '人機',
#  '師資',
#  '營區',
#  '訓練',
#  '場地',
#  '裝備',
#  '陳俊宇',
#  '師資',
#  '民間',
#  '李定中',
#  '民航局',
#  '訓練',
#  '陸軍',
#  '中心',
#  '基礎',
#  '民航局',
#  '措施',
#  '步槍兵',
#  '人機',
#  '敵特',
#  '份子',
#  '國家',
#  '觀念',
#  '國家',
#  '生命',
#  '家人',
#  '東西',
#  '土壤',
#  '地方',
#  '爆退伍潮',
#  '國防部',
#  '真相',
#  '人數',
#  '新聞網',
#  '記者',
#  '邱璽臣',
#  '台北',
#  '國軍',
#  '軍官',
#  '申請潮',
#  '國防部',
#  '人數',
#  '常數',
#  '人數',
#  '媒體',
#  '內容',
#  '事實',
#  '國防部',
#  '國軍',
#  '危機',
#  '企業',
#  '衝擊',
#  '哲學',
#  '政策',
#  '管理',
#  '形式',
#  '主義',
#  '作業',
#  '效率',
#  '待遇',
#  '志願役',
#  '人才',
#  '國軍',
#  '人力',
#  '戰力',
#  '效益',
#  '國防部',
#  '官兵',
#  '裝備',
#  '防部',
#  '步槍',
#  '抗彈板',
#  '營區',
#  '設施',
#  '生活',
#  '環境',
#  '興安',
#  '專案',
#  '眷屬',
#  '職務',
#  '宿舍',
#  '階段',
#  '規劃',
#  '國防部',
#  '政策',
#  '作為',
#  '人力',
#  '成效',
#  '人數',
#  '人數',
#  '國軍',
#  '官兵',
#  '環境',
#  '國軍',
#  '官兵',
#  '國家',
#  '家園',
#  '職責',
#  '國防部',
#  '威脅',
#  '官兵',
#  '戰備',
#  '訓練',
#  '媒體',
#  '內容',
#  '心得',
#  '感想',
#  '國家',
#  '軍隊',
#  '職業',
#  '軍人',
#  '戰鬥',
#  '後勤',
#  '保養戰時',
#  '幹部',
#  '訓練',
#  '人嘴',
#  '戰時',
#  '戰場',
#  '幹部',
#  '訓練',
#  '武器',
#  '戰術',
#  '英國',
#  '老人',
#  '海關',
#  '護照',
#  '動作',
#  '海關',
#  '法國',
#  '英國',
#  '老頭',
#  '海關',
#  '護照',
#  '老頭',
#  '護照',
#  '女海關',
#  '英國佬',
#  '法國',
#  '護照',
#  '老頭',
#  '時候',
#  '法國人',
#  '德國',
#  '老頭',
#  '法國人',
#  '顧立雄',
#  '國軍',
#  '志願役',
#  '新聞',
#  '林朝億',
#  '國防部',
#  '志願役',
#  '退營率',
#  '國防部',
#  '顧立雄',
#  '國軍',
#  '情況',
#  '常態',
#  '分布',
#  '狀況',
#  '顧立雄',
#  '立法院',
#  '外交',
#  '國防',
#  '委員會',
#  '活動',
#  '顧立雄',
#  '國軍',
#  '情況',
#  '常態',
#  '分布',
#  '狀況',
#  '人員',
#  '留營率',
#  '顧立雄',
#  '狀況',
#  '成效',
#  '人才',
#  '國軍',
#  '人數',
#  '情況',
#  '人數',
#  '德國',
#  '出訪會',
#  '烏克蘭',
#  '證實',
#  '共識',
#  '牛座',
#  '飛彈',
#  '烏克蘭',
#  '德國',
#  '難民',
#  '德國',
#  '國防',
#  '部長',
#  '官僚',
#  '成效',
#  '報導',
#  '政府',
#  '官員',
#  '美國',
#  '政府',
#  '政策',
#  '窘境',
#  '官員',
#  '國安',
#  '顧問',
#  '蘇利文',
#  '政府',
#  '法規',
#  '印尼',
#  '媒體',
#  '俄軍',
#  '基地歐盟',
#  '執委會',
#  '主席',
#  '馮德萊恩',
#  '地緣',
#  '戰略',
#  '世界',
#  '世界',
#  '歐盟須',
#  '全球',
#  '夥伴',
#  '沙烏地阿拉伯',
#  '敘利亞',
#  '世界',
#  '銀行',
#  '債款',
#  '敘利亞',
#  '國際',
#  '款項',
#  '敘利亞',
#  '衝突',
#  '派系',
#  '領袖',
#  '下野',
#  '美國',
#  '國防部長',
#  '巴拿馬',
#  '共產主義',
#  '巴拿馬',
#  '執政黨',
#  '右翼',
#  '政黨',
#  '川普',
#  '政府',
#  '共產黨',
#  '法國',
#  '法國',
#  '媒體',
#  '法國',
#  '情報局',
#  '報導',
#  '法國',
#  '以色列',
#  '敘利亞',
#  '行動',
#  '特務',
#  '經濟學人',
#  '以色列',
#  '軍隊',
#  '加薩',
#  '以色列',
#  '官員',
#  '加薩',
#  '拉法',
#  '區域',
#  '空川普',
#  '精力',
#  '以色列',
#  '以色列',
#  '國防軍',
#  '參謀',
#  '總長',
#  '總理',
#  '納坦雅胡',
#  '政策',
#  '以色列',
#  '國防軍',
#  '兵力',
#  '問題',
#  '政治',
#  '哈瑪斯',
#  '方案',
#  '軍事',
#  '泥淖',
#  '軍人',
#  '猶太教',
#  '教義派',
#  '兵役',
#  '戰略',
#  '效率',
#  '哈瑪斯',
#  '以色列',
#  '士兵',
#  '加薩',
#  '人員',
#  '事件',
#  '俄國',
#  '庫斯克州',
#  '居民',
#  '俄國',
#  '政府',
#  '戰區',
#  '民眾',
#  '俄軍',
#  '影片',
#  '英國',
#  '法國',
#  '川普',
#  '法國',
#  '法漁權',
#  '議為',
#  '籌碼',
#  '英國',
#  '歐盟',
#  '英國',
#  '歐盟',
#  '食品',
#  '法規',
#  '歐盟',
#  '政治',
#  '領袖',
#  '俄國',
#  '慶典',
#  '歐盟',
#  '塞爾維亞',
#  '總統',
#  '俄國',
#  '歐盟',
#  '斯洛伐克',
#  '總理',
#  '俄國',
#  '俄國',
#  '地已',
#  '俄國傭兵',
#  '社群平台',
#  '方式',
#  '金融管道',
#  '泰晤士',
#  '英國',
#  '方高層',
#  '烏克蘭',
#  '照片',
#  '俄軍',
#  '新銳',
#  '自走炮',
#  '雷射',
#  '武器',
#  '烏克蘭',
#  '軍火業',
#  '西班牙',
#  '廠商',
#  '烏克蘭',
#  '輪車',
#  '智庫',
#  '報告',
#  '俄國',
#  '無人',
#  '機據',
#  '法國',
#  '軍火商',
#  '產能',
#  '效率',
#  '法國',
#  '義大利',
#  '北約',
#  '軍事',
#  '計畫',
#  '工具',
#  '川普',
#  '命令',
#  '美國',
#  '海軍',
#  '艦艇',
#  '川普',
#  '船艦',
#  '計畫',
#  '基本',
#  '實質',
#  '川普',
#  '高層',
#  '會議',
#  '伊朗',
#  '策略',
#  '川普',
#  '協議',
#  '威脅',
#  '伊朗',
#  '水準',
#  '伊朗',
#  '核能',
#  '計畫',
#  '伊朗',
#  '濃縮鈾',
#  '川普',
#  '伊朗',
#  '川普',
#  '伊朗',
#  '問題',
#  '政府',
#  '伊朗',
#  '川普',
#  '政府',
#  '伊朗',
#  '濃縮鈾',
#  '俄國',
#  '伊朗',
#  '羅馬',
#  '義大利為首',
#  '歐洲',
#  '國家',
#  '伊朗',
#  '英法德',
#  '地位',
#  '伊朗',
#  '聯合國',
#  '學者',
#  '消息',
#  '伊朗',
#  '政府',
#  '川普',
#  '媒體',
#  '卡達',
#  '川普',
#  '政府',
#  '官員',
#  '川普',
#  '政府',
#  '以色列',
#  '美軍',
#  '敘利亞',
#  '以色列',
#  '計畫',
#  '川普',
#  '心意',
#  '美國',
#  '軍火',
#  '以色列',
#  '伊朗',
#  '情報',
#  '美軍',
#  '中東',
#  '胡塞',
#  '報導',
#  '美軍',
#  '葉門',
#  '政府軍',
#  '約旦',
#  '報稱',
#  '哈瑪斯',
#  '成員',
#  '哈瑪斯',
#  '人員',
#  '約旦',
#  '火箭',
#  '習近',
#  '越南',
#  '中越共謀',
#  '美國',
#  '澤倫斯基',
#  '烏克蘭',
#  '烏克蘭',
#  '衛隊',
#  '單位',
#  '軍級',
#  '民衛隊',
#  '旅"',
#  '亞速旅"',
#  '國民',
#  '衛隊',
#  '烏克蘭國',
#  '民衛隊',
#  '旅"',
#  '憲章"',
#  '軍烏軍',
#  '突擊營',
#  '達文西"',
#  '團烏軍',
#  '山地',
#  '旅長',
#  '烏軍',
#  '火箭',
#  '旅長',
#  '俄軍',
#  '飛彈',
#  '蘇梅時',
#  '蘇梅州',
#  '軍政',
#  '長官',
#  '理由',
#  '官兵授勳',
#  '典禮',
#  '俄軍',
#  '飛彈',
#  '官員',
#  '指控',
#  '挪威',
#  '北歐與波海各國',
#  '烏軍',
#  '編裝訓',
#  '計畫',
#  '單位，',
#  '強烏軍',
#  '旅有',
#  '傳聞',
#  '烏軍',
#  '部隊',
#  '指揮官',
#  '軍銜',
#  '軍長',
#  '烏軍',
#  '官方',
#  '美國',
#  '參議院',
#  '美國',
#  '國務院',
#  '軍武管制',
#  '國務次卿',
#  '俄國',
#  '核彈頭',
#  '資料',
#  '英國',
#  '烏克蘭',
#  '俄國',
#  '資產',
#  '利息',
#  '日本',
#  '大臣',
#  '美國',
#  '東亞',
#  '印太',
#  '一體',
#  '戰區',
#  '菲律賓',
#  '海軍稱',
#  '人艇',
#  '機率',
#  '中國',
#  '川普',
#  '政府',
#  '拿大據報',
#  '川普',
#  '政府',
#  '計畫',
#  '國務院',
#  '經費',
#  '經費',
#  '國際',
#  '組織',
#  '預算',
#  '合國',
#  '北約',
#  '歐洲',
#  '購星鏈',
#  '川普',
#  '政府',
#  '歐洲',
#  '中國',
#  '美國',
#  '川普',
#  '政府',
#  '美聯社',
#  '白宮',
#  '記者',
#  '川普稱',
#  '美國',
#  '公民',
#  '薩爾瓦多',
#  '監獄',
#  '川普正',
#  '程序',
#  '移民到',
#  '薩爾瓦多',
#  '高法院',
#  '憲政',
#  '危機',
#  '川普',
#  '政府',
#  '薩爾瓦多',
#  '黑幫',
#  '成員',
#  '川普遣送',
#  '移民',
#  '美國',
#  '衛生部長',
#  '疫苗',
#  '組織',
#  '成員',
#  '次女',
#  '麻疹',
#  '信念',
#  '美國',
#  '月份',
#  '海外',
#  '旅客',
#  '川普',
#  '政府',
#  '媒體',
#  '民調',
#  '專家',
#  '分析',
#  '川普',
#  '政府',
#  '政策',
#  '派系',
#  '川普',
#  '親信',
#  '科技',
#  '右翼',
#  '共和黨',
#  '建制派',
#  '軀殼',
#  '禮拜',
#  '事件',
#  '證據',
#  '美國',
#  '國防部',
#  '顧問',
#  '幕僚長',
#  '理由',
#  '消息',
#  '媒體',
#  '過程',
#  '五角大廈',
#  '公司',
#  '員工',
#  '川普',
#  '政府',
#  '美軍',
#  '新聞',
#  '馬斯克',
#  '五角',
#  '大廈',
#  '紅海',
#  '巴拿馬',
#  '計畫',
#  '川普',
#  '政府',
#  '部會',
#  '官員',
#  '媒體',
#  '消息',
#  '美國',
#  '國防部長',
#  '麾下',
#  '要員',
#  '主義',
#  '親俄親伊朗',
#  '人士',
#  '信號門',
#  '事件',
#  '聯絡人',
#  '局長',
#  '手機',
#  '川普政府',
#  '高層',
#  '聊天室',
#  '群組',
#  '內容',
#  '公務',
#  '紀錄',
#  '美國',
#  '法律',
#  '權限',
#  '部會',
#  '電腦',
#  '部會',
#  '資訊',
#  '系統',
#  '機密',
#  '資料',
#  '美國',
#  '國防部',
#  '資訊處',
#  '成員',
#  '業務',
#  '上級',
#  '五角大廈',
#  '資訊處',
#  '國防部',
#  '資訊',
#  '科技',
#  '科技業',
#  '風氣',
#  '派系內鬥',
#  '資源',
#  '問題',
#  '成員',
#  '美國',
#  '政府',
#  '總務部',
#  '資訊',
#  '單位',
#  '美國',
#  '部會',
#  '資訊',
#  '系統',
#  '權限',
#  '勞工會',
#  '機密',
#  '資料',
#  '痕跡',
#  '權限',
#  '勞工',
#  '俄國',
#  '網路',
#  '疑慮',
#  '美國',
#  '勢力',
#  '資安',
#  '漏洞',
#  '機密',
#  '資料',
#  '共和黨',
#  '建制派',
#  '理由',
#  '節錄',
#  '歐盟',
#  '間諜',
#  '美國',
#  '人員',
#  '手機',
#  '歐盟',
#  '官員',
#  '國際',
#  '貨幣',
#  '基金',
#  '世界',
#  '銀行',
#  '會議',
#  '裝置',
#  '歐洲',
#  '聯盟',
#  '委員會',
#  '美國',
#  '人員',
#  '手機',
#  '筆電',
#  '間諜',
#  '風險',
#  '措施',
#  '中國',
#  '人士',
#  '國際',
#  '貨幣',
#  '基金',
#  '組織',
#  '世界',
#  '銀行',
#  '會議',
#  '執委',
#  '官員',
#  '措施',
#  '歐盟',
#  '官員',
#  '烏克蘭',
#  '中國',
#  '俄羅斯',
#  '中國',
#  '標準',
#  '資訊',
#  '設備',
#  '國家',
#  '美國會',
#  '委會',
#  '系統',
#  '官員',
#  '美國',
#  '風險',
#  '川普',
#  '總統',
#  '職位',
#  '程度',
#  '我國',
#  '官員',
#  '手段',
#  '方式',
#  '原文',
#  '來源',
#  '原文',
#  '摘要',
#  '國軍',
#  '漢光',
#  '四十一號',
#  '演習',
#  '兵推',
#  '台美',
#  '軍事',
#  '模式',
#  '權威',
#  '管道',
#  '兵推',
#  '美方',
#  '韓聯軍',
#  '司令',
#  '陸軍',
#  '上將',
#  '羅伯特',
#  '艾布蘭',
#  '漢光',
#  '兵棋',
#  '觀察員',
#  '艾布蘭',
#  '漢光',
#  '兵推',
#  '參謀',
#  '參謀',
#  '總長',
#  '梅家樹',
#  '顧問',
#  '模式',
#  '可能性',
#  '羅伯特',
#  '美國',
#  '陸軍',
#  '裝甲兵',
#  '名將',
#  '威廉斯．艾布蘭',
#  '西點',
#  '軍校',
#  '裝甲兵科',
#  '羅伯特',
#  '美軍',
#  '司令',
#  '聯合國軍司令官',
#  '陸軍',
#  '戰車',
#  '我國',
#  '戰車',
#  '漢光四十一兵推將',
#  '戰車',
#  '參數',
#  '艾布蘭',
#  '聯戰',
#  '指揮官',
#  '背景',
#  '裝甲兵',
#  '專長',
#  '新型',
#  '戰車',
#  '建議',
#  '國防部',
#  '月間',
#  '漢光四十一號',
#  '幹部圖上',
#  '兵推',
#  '美軍',
#  '印太',
#  '司令部聯五',
#  ...]

# %%
top_cate_words
# Out:
# {'學術股市': [('中國', 259),
#   ('美國', 224),
#   ('關稅', 128),
#   ('台灣', 75),
#   ('經濟', 75),
#   ('市場', 69),
#   ('川普', 56),
#   ('國家', 54),
#   ('貿易', 45),
#   ('產業', 35)],
#  '綜合': [('新聞', 96),
#   ('文章', 73),
#   ('板主', 53),
#   ('中國', 47),
#   ('水桶', 47),
#   ('台灣', 39),
#   ('帳號', 34),
#   ('內容', 33),
#   ('八卦', 32),
#   ('神韻', 30)],
#  '閒談': [('板主', 61),
#   ('水桶', 53),
#   ('文章', 50),
#   ('活動', 26),
#   ('內容', 25),
#   ('人員', 21),
#   ('回文', 21),
#   ('作品', 20),
#   ('規定', 20),
#   ('時間', 16)],
#  '棒球': [('體育', 34),
#   ('投手', 26),
#   ('徐若熙', 24),
#   ('比賽', 22),
#   ('緯來', 22),
#   ('主場', 21),
#   ('文章', 20),
#   ('巨蛋', 20),
#   ('板主', 19),
#   ('職棒', 18)],
#  '軍事': [('烏克蘭', 122),
#   ('美國', 109),
#   ('川普', 74),
#   ('俄羅斯', 71),
#   ('政府', 54),
#   ('俄軍', 48),
#   ('中國', 46),
#   ('戰爭', 45),
#   ('軍事', 38),
#   ('人員', 33)],
#  '全部': [('美國', 356),
#   ('中國', 353),
#   ('文章', 160),
#   ('台灣', 158),
#   ('板主', 148),
#   ('新聞', 139),
#   ('川普', 134),
#   ('關稅', 133),
#   ('烏克蘭', 124),
#   ('水桶', 119)]}

# %%
list(top_cate_words.items())
# Out:
# [('學術股市',
#   [('中國', 259),
#    ('美國', 224),
#    ('關稅', 128),
#    ('台灣', 75),
#    ('經濟', 75),
#    ('市場', 69),
#    ('川普', 56),
#    ('國家', 54),
#    ('貿易', 45),
#    ('產業', 35)]),
#  ('綜合',
#   [('新聞', 96),
#    ('文章', 73),
#    ('板主', 53),
#    ('中國', 47),
#    ('水桶', 47),
#    ('台灣', 39),
#    ('帳號', 34),
#    ('內容', 33),
#    ('八卦', 32),
#    ('神韻', 30)]),
#  ('閒談',
#   [('板主', 61),
#    ('水桶', 53),
#    ('文章', 50),
#    ('活動', 26),
#    ('內容', 25),
#    ('人員', 21),
#    ('回文', 21),
#    ('作品', 20),
#    ('規定', 20),
#    ('時間', 16)]),
#  ('棒球',
#   [('體育', 34),
#    ('投手', 26),
#    ('徐若熙', 24),
#    ('比賽', 22),
#    ('緯來', 22),
#    ('主場', 21),
#    ('文章', 20),
#    ('巨蛋', 20),
#    ('板主', 19),
#    ('職棒', 18)]),
#  ('軍事',
#   [('烏克蘭', 122),
#    ('美國', 109),
#    ('川普', 74),
#    ('俄羅斯', 71),
#    ('政府', 54),
#    ('俄軍', 48),
#    ('中國', 46),
#    ('戰爭', 45),
#    ('軍事', 38),
#    ('人員', 33)]),
#  ('全部',
#   [('美國', 356),
#    ('中國', 353),
#    ('文章', 160),
#    ('台灣', 158),
#    ('板主', 148),
#    ('新聞', 139),
#    ('川普', 134),
#    ('關稅', 133),
#    ('烏克蘭', 124),
#    ('水桶', 119)])]

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
counter_all = Counter([1,2,3]) + Counter([1,2,5])
counter_all
# Out:
# Counter({1: 2, 2: 2, 3: 1, 5: 1})

# %%
from collections import Counter

# %%
news_links =['Stock', 'Gossiping', 'C_Chat', 'Baseball','Military']
news_categories=['學術股市','綜合','閒談','棒球','軍事']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
allowedPOS=['Na','Nb','Nc']

# %%
# All-in-one function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(10)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(10)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# %%
# %%time
result = get_top_words()
# Out:
# CPU times: total: 375 ms
# Wall time: 522 ms

# %%
result[0:3]
# Out:
# [('學術股市',
#   [('中國', 259),
#    ('美國', 224),
#    ('關稅', 128),
#    ('台灣', 75),
#    ('經濟', 75),
#    ('市場', 69),
#    ('川普', 56),
#    ('國家', 54),
#    ('貿易', 45),
#    ('產業', 35)]),
#  ('綜合',
#   [('新聞', 96),
#    ('文章', 73),
#    ('板主', 53),
#    ('中國', 47),
#    ('水桶', 47),
#    ('台灣', 39),
#    ('帳號', 34),
#    ('內容', 33),
#    ('八卦', 32),
#    ('神韻', 30)]),
#  ('閒談',
#   [('板主', 61),
#    ('水桶', 53),
#    ('文章', 50),
#    ('活動', 26),
#    ('內容', 25),
#    ('人員', 21),
#    ('回文', 21),
#    ('作品', 20),
#    ('規定', 20),
#    ('時間', 16)])]

# %%
import pandas as pd

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#   category                                           top_keys
# 0     學術股市  [(中國, 259), (美國, 224), (關稅, 128), (台灣, 75), (經...
# 1       綜合  [(新聞, 96), (文章, 73), (板主, 53), (中國, 47), (水桶, ...
# 2       閒談  [(板主, 61), (水桶, 53), (文章, 50), (活動, 26), (內容, ...
# 3       棒球  [(體育, 34), (投手, 26), (徐若熙, 24), (比賽, 22), (緯來,...
# 4       軍事  [(烏克蘭, 122), (美國, 109), (川普, 74), (俄羅斯, 71), (...
# 5       全部  [(美國, 356), (中國, 353), (文章, 160), (台灣, 158), (...

# %%
df_top_group_words.to_csv('PTT_news_topkey_with_category_via_token_pos.csv', index=False)

# %%
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']
from collections import Counter

def word_frequency( token_pos_list ):
    filtered_words =[]
    for word, pos in token_pos_list:
        if (pos in allowedPOS) & (len(word) >= 2):
            filtered_words.append(word)
        #print('%s %s' % (word, pos))
    counter = Counter( filtered_words )
    return counter.most_common( 200 )

# %%
# %%time
top_words_group=[]
group_token_pos_all=[]
for category in news_categories:
    df_group = df[df.category == category]
    group_token_pos =[]
    
    for gtp in df_group.token_pos:
        group_token_pos += eval(gtp)
    
    group_token_pos_all += group_token_pos
    
    topwords = word_frequency( group_token_pos )
    d = pd.DataFrame(topwords, columns = ['key','freq'])
    top_words_group.append([category, topwords])
# Out:
# CPU times: total: 406 ms
# Wall time: 401 ms

# %% [markdown]
# news_links =['Stock', 'Gossiping', 'C_Chat', 'Baseball','Military']
# news_categories=['學術股市','綜合','閒談','棒球','軍事']

# %%
from collections import Counter
import pandas as pd

# 
df = pd.read_csv('PTT_news_preprocessed.csv',sep='|')
news_categories=['學術股市','綜合','閒談','棒球','軍事']
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# 
# get topk keyword function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(100)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(100)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# Save top 20 word frequency for each category
top_group_words = get_top_words()
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])
df_top_group_words.to_csv('PTT_news_topkey_with_category_via_token_pos.csv', index=False)

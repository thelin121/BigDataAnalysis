# %%
#抓取PTT電影版
import urllib.request as req
url="https://www.ptt.cc/bbs/movie/index.html"
#建立一個Request物件，附加Request Headers的資訊 
request=req.Request(url,headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
})
#發送請求並取得回應 
with req.urlopen(request) as response:
    data=response.read().decode("utf-8")
print(data) #印出網頁的原始碼
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 movie 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/movie/index.html"><span class="board-label">看板 </span>movie</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
import bs4
root=bs4.BeautifulSoup(data,"html.parser")
print(root.title) #印出網頁標題
print(root.title.string) #印出網頁標題
# Out:
# <title>看板 movie 文章列表 - 批踢踢實業坊</title>
# 看板 movie 文章列表 - 批踢踢實業坊

# %%
titles=root.find("div",class_="title") #尋找所有class屬性為title的div標籤
titles
# Out:
# <div class="title">
# <a href="/bbs/movie/M.1744625981.A.09A.html">[情報] iTunes多部$80起 失控危城.偶然與想像</a>
# </div>

# %%
titles=root.find("div",class_="title") #尋找所有class屬性為title的div標籤
print(titles.a.string) #印出所有標題
# Out:
# [情報] iTunes多部$80起 失控危城.偶然與想像

# %%
titles=root.find_all("div",class_="title") #尋找所有class屬性為title的div標籤
print(titles) #印出所有標題
# Out:
# [<div class="title">
# <a href="/bbs/movie/M.1744625981.A.09A.html">[情報] iTunes多部$80起 失控危城.偶然與想像</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744631169.A.61C.html">[新聞] 《星際寶貝：史迪奇》有望拯救迪士尼！</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744631405.A.901.html">[新聞] 影迷瘋傳「《蝙蝠俠》續集已遭取消！」</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744631601.A.250.html">[問片] 片尾打人蛋蛋然後說:「you know why」</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744632011.A.FBA.html">[請益] 電影片尾為什麼可以拍照</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744633313.A.C44.html">[問片] 很久以前的港片 鬼片</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744634459.A.F76.html">[普雷] 器子</a>
# </div>, <div class="title">
#
# 				(本文已被刪除) [Sango]
#
# 			</div>, <div class="title">
# <a href="/bbs/movie/M.1744637738.A.1D7.html">Re: [討論] 怎麼培養看電影的品味？</a>
# </div>, <div class="title">
# <a href="/bbs/movie/M.1744639369.A.9BC.html">[新聞] 《復仇者聯盟5》和《超少女》等片場遭空</a>
# ...

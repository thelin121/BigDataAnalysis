# %%
import pandas as pd

# %%
df = pd.read_csv('sportsv_preprocessed.csv',sep='|')

# %%
df.head(2)
# Out:
#               item_id        date category  \
# 0  sportsv_20250319_1  2025-03-19      MLB
# 1  sportsv_20250319_2  2025-03-19      MLB
#
#                                          title  \
# 0      【MLB25:東京系列賽】道奇強火援護佐佐木朗希，大谷翔平炸裂首轟助隊再斬小熊
# 1  芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊
#
#                                              content sentiment summary  \
# 0  《看看MLB25-05》國聯雙雄的東京系列賽第二回合，除了小熊企圖想扳回一城外，更是佐佐木朗...        暫無      暫無
# 1  2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('道奇', 4), ('威力', 4), ('東京', 3), ('佐佐木朗希', 3)...
# 1  [('日本', 4), ('大聯盟', 3), ('東京', 2), ('巨蛋', 2), ...
#
#                                               tokens  \
# 0  ['《', '看看', 'MLB25-05', '》', '國聯', '雙雄', '的', ...
# 1  ['2025 ', '大聯盟', '賽季', '在', '昨日', '（', '3/19',...
#
#                                            tokens_v2  \
# 0  ['國聯', '雙雄', '東京', '系列賽', '回合', '佐佐木朗希', '大聯盟'...
# 1  ['大聯盟', '東京', '巨蛋', '帷幕', '大聯盟', '歷史', '日本', '...
#
#                                             entities  \
# 0  [NerToken(word='第二', ner='ORDINAL', idx=(22, 2...
# 1  [NerToken(word='昨日', ner='DATE', idx=(11, 13))...
#
#                                            token_pos  \
# 0  [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# 1  [('2025 ', 'Neu'), ('大聯盟', 'Na'), ('賽季', 'Nd')...
#
#                                       link  \
# 0  https://www.sportsv.net/articles/118239
# 1  https://www.sportsv.net/articles/118233
#
#                                           photo_link
# 0  https://bucket-image.inkmaginecms.com/version/...
# 1  https://bucket-image.inkmaginecms.com/version/...

# %%
df.shape
# Out:
# (290, 14)

# %%
df.groupby('category').count()
# Out:
#           item_id  date  title  content  sentiment  summary  top_key_freq  \
# category
# MLB            81    81     81       81         81       81            81
# 三級棒球           65    65     65       65         65       65            65
# 中職             72    72     72       72         72       72            72
# 日職             72    72     72       72         72       72            72
#
#           tokens  tokens_v2  entities  token_pos  link  photo_link
# category
# MLB           81         81        81         81    81          81
# 三級棒球          65         65        65         65    65          65
# 中職            72         72        72         72    72          72
# 日職            72         72        72         72    72          72

# %%
# df_group = df[df.category == '政治']
df_group = df.query('category == "MLB"')

# %%
df_group
# Out:
#                 item_id        date category  \
# 0    sportsv_20250319_1  2025-03-19      MLB
# 1    sportsv_20250319_2  2025-03-19      MLB
# 2    sportsv_20210429_3  2021-04-29      MLB
# 3    sportsv_20250319_4  2025-03-19      MLB
# 4    sportsv_20250319_5  2025-03-19      MLB
# ..                  ...         ...      ...
# 265  sportsv_20250413_5  2025-04-13      MLB
# 266  sportsv_20250413_6  2025-04-13      MLB
# 267  sportsv_20250413_7  2025-04-13      MLB
# 268  sportsv_20250413_8  2025-04-13      MLB
# 269  sportsv_20250412_9  2025-04-12      MLB
#
#                                                 title  \
# 0             【MLB25:東京系列賽】道奇強火援護佐佐木朗希，大谷翔平炸裂首轟助隊再斬小熊
# 1         芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊
# 2               棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗
# 3     「未達到指定局數就取消指定打擊」，Max Scherzer 提出當今先發投手局數過短的解決方案
# 4                          與山本由伸聯手貢獻關鍵戰力 大谷翔平坦言難得感到緊張
# ..                                                ...
# 265                      沙子宸首場先發6局奪9K 林維恩驚人表現獲教練團正面肯定
# 266                      年紀與合約到期的緊迫感，今年會是費城人的「最後一舞」嗎？
# 267  兼具頂尖揮棒速度與擊球初速，Kristian Campbell 成為紅襪隊「打擊革命」的最新產物
# 268                  【MLB2025】把不可能化為可能，新賽季值得期待的7大驚奇時刻
# 269       【MLB2025】山本由伸絕好調的完美狀態，Tommy Edman一錘定音轟走小熊來犯
#
#                                                content sentiment summary  \
# 0    《看看MLB25-05》國聯雙雄的東京系列賽第二回合，除了小熊企圖想扳回一城外，更是佐佐木朗...        暫無      暫無
# 1    2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本...        暫無      暫無
# 2    約莫在2005年，王建民在大聯盟的表現開始加溫，從2005年的8勝到2006年、2007年的...        暫無      暫無
# 3    此文編譯自To Save Starting Pitching, Max Scherzer T...        暫無      暫無
# 4    美國職棒大聯盟（MLB）新球季揭幕戰登場，3月18日晚間在東京巨蛋由洛杉磯道奇對決芝加哥小熊...        暫無      暫無
# ..                                                 ...       ...     ...
# 265  奧克蘭運動家隊台灣投手沙子宸今天在小聯盟1A本季首場先發出賽展現壓制力，繳出6局無失分的內容...        暫無      暫無
# 266  此文編譯自Why Phillies ran it back instead of going...        暫無      暫無
# 267  此文編譯自This top prospect is already validating t...        暫無      暫無
# 268  《看看MLB25-29》MLB除了場上交鋒令人血脈賁張外，球員與紀錄間的相互競逐也非常值得關...        暫無      暫無
# 269  《看看MLB25-28》在東京系列賽結束一個月後，小熊與道奇於今日開始二度交戰，首戰快節奏的...        暫無      暫無
#
#                                           top_key_freq  \
# 0    [('道奇', 4), ('威力', 4), ('東京', 3), ('佐佐木朗希', 3)...
# 1    [('日本', 4), ('大聯盟', 3), ('東京', 2), ('巨蛋', 2), ...
# 2    [('遊戲', 15), ('玩家', 13), ('職棒', 9), ('棒球', 8),...
# 3    [('投手', 18), ('任務', 11), ('球隊', 8), ('問題', 4),...
# 4    [('比賽', 10), ('大谷', 9), ('大谷翔平', 7), ('投手', 7)...
# ..                                                 ...
# 265  [('投手', 10), ('沙子宸', 10), ('安打', 10), ('比賽', 9...
# 266  [('費城人', 9), ('球隊', 9), ('陣容', 5), ('球員', 5), ...
# 267  [('新秀', 5), ('全壘打', 5), ('速度', 5), ('數據', 5), ...
# 268  [('比賽', 10), ('球員', 8), ('歷史', 6), ('紀錄', 4), ...
# 269  [('道奇', 5), ('打者', 5), ('比賽', 3), ('機會', 3), (...
#
#                                                 tokens  \
# 0    ['《', '看看', 'MLB25-05', '》', '國聯', '雙雄', '的', ...
# 1    ['2025 ', '大聯盟', '賽季', '在', '昨日', '（', '3/19',...
# 2    ['約莫', '在', '2005年', '，', '王建民', '在', '大聯盟', '...
# 3    ['此', '文', '編譯', '自', 'To ', 'Save', ' Startin...
# 4    ['美國', '職棒', '大聯盟', '（', 'MLB', '）', '新', '球季'...
# ..                                                 ...
# 265  ['奧克蘭', '運動家隊', '台灣', '投手', '沙子宸', '今天', '在', ...
# 266  ['此', '文', '編譯', '自', 'Why', ' ', 'Phillies', ...
# 267  ['此', '文', '編譯', '自', 'This', ' top', ' prospe...
# 268  ['《', '看看', 'MLB25-29', '》', 'MLB', '除了', '場',...
# 269  ['《', '看看', 'MLB25-28', '》', '在', '東京', '系列賽',...
#
#                                              tokens_v2  \
# 0    ['國聯', '雙雄', '東京', '系列賽', '回合', '佐佐木朗希', '大聯盟'...
# 1    ['大聯盟', '東京', '巨蛋', '帷幕', '大聯盟', '歷史', '日本', '...
# 2    ['王建民', '大聯盟', '表現', '台灣', '棒球迷', '情緒', '廠商', ...
# 3    ['投手', '問題', '球隊', '任務', '概念', '任務', '標準', '任務...
# 4    ['美國', '職棒', '大聯盟', '揭幕戰', '東京', '巨蛋', '洛杉磯', ...
# ..                                                 ...
# 265  ['奧克蘭', '運動家隊', '台灣', '投手', '沙子宸', '聯盟', '壓制力'...
# 266  ['聯盟', '市場', '錢搶人', '費城', '費城人', '話題', '費城人', ...
# 267  ['新秀', '順位', '大物', '球隊', '珍珠', '人物', '生涯', '大聯...
# 268  ['血脈賁張', '球員', '紀錄', '歷史', '成就', '時候', '歷史', '...
# 269  ['東京', '系列賽', '道奇', '節奏', '投手', '錘定', '比賽', '勝...
#
#                                               entities  \
# 0    [NerToken(word='第二', ner='ORDINAL', idx=(22, 2...
# 1    [NerToken(word='昨日', ner='DATE', idx=(11, 13))...
# 2    [NerToken(word='2005年', ner='DATE', idx=(3, 8)...
# 3    [NerToken(word=' Max Scher', ner='ORG', idx=(3...
# 4    [NerToken(word='美國職棒大聯盟', ner='ORG', idx=(0, 7...
# ..                                                 ...
# 265  [NerToken(word='奧克蘭運動家隊', ner='ORG', idx=(0, 7...
# 266  [NerToken(word='三年', ner='DATE', idx=(310, 312...
# 267  [NerToken(word='今天', ner='DATE', idx=(82, 84))...
# 268  [NerToken(word='2025', ner='DATE', idx=(102, 1...
# 269  [NerToken(word='東京系列賽', ner='EVENT', idx=(13, ...
#
#                                              token_pos  \
# 0    [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# 1    [('2025 ', 'Neu'), ('大聯盟', 'Na'), ('賽季', 'Nd')...
# 2    [('約莫', 'Da'), ('在', 'P'), ('2005年', 'Neu'), (...
# 3    [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 4    [('美國', 'Nc'), ('職棒', 'Na'), ('大聯盟', 'Na'), ('...
# ..                                                 ...
# 265  [('奧克蘭', 'Nc'), ('運動家隊', 'Na'), ('台灣', 'Nc'), ...
# 266  [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 267  [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 268  [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# 269  [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
#
#                                         link  \
# 0    https://www.sportsv.net/articles/118239
# 1    https://www.sportsv.net/articles/118233
# 2     https://www.sportsv.net/articles/83288
# 3    https://www.sportsv.net/articles/118203
# 4    https://www.sportsv.net/articles/118229
# ..                                       ...
# 265  https://www.sportsv.net/articles/118737
# 266  https://www.sportsv.net/articles/118699
# 267  https://www.sportsv.net/articles/118649
# 268  https://www.sportsv.net/articles/118636
# 269  https://www.sportsv.net/articles/118721
#
#                                             photo_link
# 0    https://bucket-image.inkmaginecms.com/version/...
# 1    https://bucket-image.inkmaginecms.com/version/...
# 2    https://bucket-image.inkmaginecms.com/version/...
# 3    https://bucket-image.inkmaginecms.com/version/...
# 4    https://bucket-image.inkmaginecms.com/version/...
# ..                                                 ...
# 265  https://bucket-image.inkmaginecms.com/version/...
# 266  https://bucket-image.inkmaginecms.com/version/...
# 267  https://bucket-image.inkmaginecms.com/version/...
# 268  https://bucket-image.inkmaginecms.com/version/...
# 269  https://bucket-image.inkmaginecms.com/version/...
#
# [81 rows x 14 columns]

# %%
df_group['token_pos']
# Out:
# 0      [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# 1      [('2025 ', 'Neu'), ('大聯盟', 'Na'), ('賽季', 'Nd')...
# 2      [('約莫', 'Da'), ('在', 'P'), ('2005年', 'Neu'), (...
# 3      [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 4      [('美國', 'Nc'), ('職棒', 'Na'), ('大聯盟', 'Na'), ('...
#                              ...
# 265    [('奧克蘭', 'Nc'), ('運動家隊', 'Na'), ('台灣', 'Nc'), ...
# 266    [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 267    [('此', 'Nep'), ('文', 'Na'), ('編譯', 'VC'), ('自'...
# 268    [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# 269    [('《', 'PARENTHESISCATEGORY'), ('看看', 'VE'), (...
# Name: token_pos, Length: 81, dtype: object

# %%
len(df_group['token_pos'])
# Out:
# 81

# %%
from collections import Counter

# %%
news_categories=['MLB','中職','日職','三級棒球']

# %%
allowedPOS=['Na','Nb','Nc']

# %%
top_cate_words={} # final result
counter_all = Counter() # counter for category '全部'
for category in news_categories:

    # df yesterday-->This is your homework
    # df=df[(df.date >= start_date) & (df.date <= end_date)]

    # df category
    df_group = df[df.category == category]

    # concatenate all filtered words in the same category
    words_group = []
    for row in df_group.token_pos:

        # filter words for each news
        filtered_words =[]
        for (word, pos) in eval(row):
            if (len(word) >= 2) & (pos in allowedPOS):
                filtered_words.append(word)

        # concatenate filtered words
        words_group += filtered_words

    # now we can count word frequency
    counter = Counter( words_group )

    # concatenate all counters
    counter_all += counter
    topwords = counter.most_common(10)

    # store topwords
    top_cate_words[category]= topwords

# Process category '全部'
top_cate_words['全部'] = counter_all.most_common(10)

# %%
words_group
# Out:
# ['總統',
#  '馬英九',
#  '總統府',
#  '官員',
#  '球界',
#  '代表',
#  '棒球',
#  '國是',
#  '會議',
#  '棒球',
#  '風氣',
#  '行政院',
#  '棒運',
#  '專案',
#  '小組',
#  '方案',
#  '教育部',
#  '棒球',
#  '運動',
#  '計畫',
#  '棒球',
#  '運動',
#  '方案',
#  '計畫',
#  '計畫',
#  '預算',
#  '國內',
#  '棒球',
#  '運動',
#  '教育部',
#  '後繼',
#  '強棒',
#  '計畫',
#  '計畫',
#  '教育部',
#  '體育署',
#  '經費來',
#  '縣市',
#  '小學',
#  '社區',
#  '學生',
#  '棒球',
#  '計畫',
#  '棒球',
#  '運動',
#  '計畫',
#  '強棒',
#  '計畫',
#  '經費',
#  '內容',
#  '山包海',
#  '大學',
#  '社會',
#  '甲組',
#  '職業',
#  '棒球',
#  '國家隊',
#  '政府',
#  '時間',
#  '經費',
#  '棒球',
#  '運動',
#  '棒球',
#  '國是會議',
#  '臺灣',
#  '棒球',
#  '變化',
#  '棒球',
#  '校隊',
#  '數量',
#  '種類',
#  '變化',
#  '棒球',
#  '變化',
#  '統計',
#  '數據',
#  '國內',
#  '棒球',
#  '棒球',
#  '國小',
#  '高中',
#  '學生',
#  '棒球運動',
#  '棒球隊',
#  '種類',
#  '訓練',
#  '目標',
#  '賽事',
#  '縣市',
#  '分類',
#  '補助',
#  '分類',
#  '校隊',
#  '型態',
#  '狀況',
#  '體育班',
#  '學校',
#  '規定',
#  '棒球',
#  '聯賽',
#  '聯賽',
#  '體育班',
#  '聯賽',
#  '學校',
#  '體育班',
#  '國家',
#  '代表權',
#  '假設',
#  '原因',
#  '方式',
#  '學校',
#  '科班',
#  '球隊',
#  '長短',
#  '長期',
#  '挫折感',
#  '棒球',
#  '好事',
#  '訓練',
#  '窟窿',
#  '印象',
#  '報告',
#  '訓練',
#  '影響',
#  '日本學',
#  '野球',
#  '數據',
#  '球隊',
#  '球隊',
#  '量為硬式',
#  '棒球',
#  '地位',
#  '學生',
#  '棒球',
#  '社區',
#  '棒球',
#  '比賽',
#  '比賽',
#  '教練',
#  '中華民國',
#  '棒球',
#  '協會',
#  '教練證',
#  '契機',
#  '教練證',
#  '講習',
#  '文章',
#  '電機系',
#  '大學生',
#  '角度',
#  '教練證',
#  '過程',
#  '心得',
#  '中華民國',
#  '棒球',
#  '協會',
#  '中華棒協',
#  '網站',
#  '教練',
#  '講習',
#  '價格',
#  '中華民國籍',
#  '價錢',
#  '資格',
#  '規定',
#  '中華棒協',
#  '基本',
#  '講習',
#  '單位',
#  '中華棒協',
#  '單位',
#  '單位',
#  '地方',
#  '棒協',
#  '學生',
#  '棒球',
#  '聯盟',
#  '大專體',
#  '教練',
#  '講習',
#  '手刀搶快',
#  '公告',
#  '訣竅',
#  '良民證',
#  '課程',
#  '室內課',
#  '室外課',
#  '學科',
#  '考試',
#  '術科',
#  '考試',
#  '課表',
#  '教練',
#  '老師',
#  '時候',
#  '名牌',
#  '講義',
#  '資料',
#  '衣服',
#  '筆記本',
#  '筆記',
#  '睡眠',
#  '體力',
#  '時間',
#  '動作',
#  '體能',
#  '訓練',
#  '訓練',
#  '訓練',
#  '訓練',
#  '戰術',
#  '捕手',
#  '訓練',
#  '運動',
#  '倫理',
#  '道德',
#  '課程',
#  '理論',
#  '室外',
#  '教練',
#  '課程',
#  '天氣',
#  '頭大汗',
#  '教練',
#  '棒球',
#  '規則',
#  '規則',
#  '講義',
#  '老師',
#  '學生',
#  '現場',
#  '比賽',
#  '情況',
#  '教練',
#  '講習',
#  '老師',
#  '老師',
#  '棒協',
#  '小時',
#  '老師',
#  '教練',
#  '決定',
#  '權利',
#  '運動',
#  '傷害',
#  '運動',
#  '傷害',
#  '課程',
#  '運動',
#  '傷害',
#  '運動',
#  '傷害',
#  '成因',
#  '運動',
#  '傷害',
#  '運動',
#  '傷害',
#  '運動',
#  '傷害',
#  '共鳴',
#  '現場',
#  '球員',
#  '運動',
#  '傷害',
#  '球員',
#  '身份',
#  '教練',
#  '旋轉肌',
#  '韌帶',
#  '背部',
#  '肌群',
#  '球員',
#  '課程',
#  '傷害',
#  '運動',
#  '傷害',
#  '後遺症',
#  '球員',
#  '肌群',
#  '運動',
#  '營養',
#  '禁藥',
#  '小時',
#  '運動',
#  '營養',
#  '學問',
#  '課程',
#  '運動',
#  '營養',
#  '賽期',
#  '飲食',
#  '營養',
#  '增補劑',
#  '禁藥',
#  '運動',
#  '禁藥',
#  '世界',
#  '組織',
#  '禁藥',
#  '運動員',
#  '運動',
#  '禁藥',
#  '運動',
#  '倫理',
#  '議題',
#  '體育圈',
#  '政治圈',
#  '演藝圈',
#  '話題',
#  '重要性',
#  '兩性',
#  '課程',
#  '教練',
#  '球員',
#  '案例',
#  '術科',
#  '考試',
#  '術科',
#  '考試',
#  '內野',
#  '地球',
#  '外野',
#  '飛球',
#  '捕手',
#  '飛球',
#  '難事',
#  '方向',
#  '捕手',
#  '飛球可',
#  '底子',
#  '學員',
#  '基本功',
#  '技巧',
#  '學科',
#  '考試',
#  '學科',
#  '考試',
#  '選擇題',
#  '填空題',
#  '題目',
#  '老師',
#  '重點',
#  '學科',
#  '駕照',
#  '朋友們',
#  '課後',
#  '筆記',
#  '考試',
#  '文具',
#  '台灣',
#  '社會',
#  '音樂',
#  '繪畫',
#  '舞蹈',
#  '才藝',
#  '課程',
#  '小學生',
#  '活動',
#  '靜態',
#  '圍棋',
#  '樂高',
#  '桌遊',
#  '程式',
#  '設計',
#  '動態',
#  '武術',
#  '排輪',
#  '球類',
#  '運動',
#  '小朋友',
#  '場地',
#  '限制',
#  '主角',
#  '棒球',
#  '運動',
#  '小朋友',
#  '活動',
#  '選項',
#  '台灣',
#  '社區',
#  '棒球',
#  '俱樂部',
#  '前輩',
#  '大德',
#  '鄰國',
#  '日本',
#  '我國',
#  '社區',
#  '棒球',
#  '運動',
#  '階段',
#  '附近',
#  '社區',
#  '棒球',
#  '俱樂部',
#  '活動',
#  '朋友',
#  '學校',
#  '少棒球隊',
#  '家長',
#  '孩子',
#  '棒球',
#  '運動',
#  '機會',
#  '家長',
#  '孩子',
#  '機會',
#  '學區',
#  '學校',
#  '少棒',
#  '校隊',
#  '團隊',
#  '生活',
#  '挫折',
#  '棒球',
#  '態度',
#  '知識與',
#  '技術',
#  '文章',
#  '球爸',
#  '球媽',
#  '心得',
#  '文章',
#  '小孩子',
#  '棒球',
#  '運動',
#  '錢耶......',
#  '家長',
#  '費用',
#  '問題',
#  '費用可分為',
#  '裝備',
#  '費用',
#  '校隊',
#  '隊費',
#  '社區',
#  '球隊',
#  '學費',
#  '隊費',
#  '社區',
#  '球隊',
#  '學費',
#  '地區',
#  '狀況',
#  '專文',
#  '費用',
#  '棒球',
#  '運動',
#  '種類',
#  '價格',
#  '排輪',
#  '足球',
#  '羽毛球',
#  '桌球',
#  '副球拍',
#  '運動',
#  '棒球',
#  '台灣',
#  '棒球',
#  '用品',
#  '專賣店',
#  '運動',
#  '棒球',
#  '裝備',
#  '店員',
#  '消費者',
#  '裝備',
#  '門檻',
#  '小學',
#  '三年級',
#  '棒球',
#  '運動',
#  '小朋友',
#  '裝備',
#  '價格',
#  '商網站',
#  '產品',
#  '實體',
#  '商店',
#  '售價',
#  '價格：',
#  '小朋友',
#  '棒球手套哩',
#  '類型',
#  '品牌',
#  '棒球',
#  '裝備',
#  '產品',
#  '學齡',
#  '孩子',
#  '玩具',
#  '棒球',
#  '運動',
#  '實手套',
#  '學校',
#  '時間',
#  '校隊',
#  '數量',
#  '學長',
#  '裝備',
#  '家長',
#  '校隊',
#  '孩子',
#  '棒球',
#  '訓練',
#  '手套',
#  '建議',
#  '豬皮',
#  '牛皮',
#  '皮革',
#  '皮革',
#  '手套',
#  '裂痕',
#  '教練',
#  '孩子',
#  '牛皮',
#  '手套',
#  '價格',
#  '區間',
#  '牛皮',
#  '牛皮',
#  '豬皮',
#  '手套',
#  '差異',
#  '牛皮',
#  '豬皮',
#  '材質',
#  '手套',
#  '教練',
#  '時期',
#  '孩子',
#  '位置',
#  '小朋友',
#  '興趣',
#  '球員',
#  '棒球',
#  '比賽',
#  '一壘',
#  '捕手',
#  '手套',
#  '通用型',
#  '球隊會',
#  '捕手手套',
#  '球員',
#  '小學',
#  '年級',
#  '孩子',
#  '手掌',
#  '手部',
#  '肌肉',
#  '尺寸',
#  '兒童',
#  '棒球手套',
#  '產品',
#  '手套尺',
#  '小朋友',
#  '小朋友',
#  '棒球',
#  '技術',
#  '興趣依然不減時',
#  '手套',
#  '尺寸',
#  '類型',
#  '孩子',
#  '產品',
#  '凡球',
#  '外型',
#  '手套',
#  '顏色',
#  '小朋友們',
#  '試手型',
#  '實體店家',
#  '需求',
#  '手套',
#  '整形',
#  '棒球',
#  '聯盟',
#  '運動',
#  '運動',
#  '球類',
#  '田徑',
#  '運動',
#  '運動',
#  '運動',
#  '意外',
#  '運動',
#  '運動',
#  '棒球',
#  '運動',
#  '學校',
#  '學生',
#  '校園',
#  '棒球傷',
#  '措施',
#  '台灣',
#  '學校',
#  '運動',
#  '日本',
#  '學校',
#  '辦法',
#  '運動',
#  '學校',
#  '教育',
#  '學生',
#  '運動習慣',
#  '台灣',
#  '口號',
#  '學校',
#  '教育',
#  '騙術',
#  '日本',
#  '學校',
#  '運動',
#  '運動',
#  '方面',
#  '措施',
#  '台灣',
#  '高架',
#  '護網',
#  '日本',
#  '高校',
#  '高架網',
#  '功能',
#  '飛球',
#  '民宅',
#  '教室',
#  '人車',
#  '跑道',
#  '日本',
#  '高中',
#  '國中',
#  '學校',
#  '跑道',
#  '運動場',
#  '校地',
#  '可能',
#  '田徑場',
#  '運動場',
#  '運動場',
#  '運動',
#  '活動',
#  '球類',
#  '運動場地',
#  '規格',
#  '運動',
#  '運動場',
#  '跑道',
#  '日本',
#  '學校',
#  '主流',
#  '原因',
#  '田徑賽',
#  '運動',
#  '場地',
#  '日本',
#  '沖繩',
#  '內山',
#  '小學',
#  '操場',
#  '日本',
#  '山口',
#  '國府',
#  '中學',
#  '操場',
#  '社團',
#  '活動',
#  '時間',
#  '空間',
#  '球場',
#  '日本人',
#  '日本',
#  '漫畫',
#  '操場',
#  '棒球',
#  '足球',
#  '日本',
#  '現象',
#  '空間',
#  '民眾',
#  '時間',
#  '運動',
#  '社團',
#  '場地',
#  '運動',
#  '因子',
#  '棒球',
#  '石頭',
#  '棒球',
#  '日本人',
#  '日本',
#  '國中',
#  '高中',
#  '棒球場',
#  '措施',
#  '棒球',
#  '校園',
#  '棒球',
#  '日本',
#  '校園',
#  '棒球運動',
#  '師資',
#  '日本',
#  '學校',
#  '球隊',
#  '學校',
#  '教練',
#  '國小',
#  '家長',
#  '主體',
#  '家長',
#  '學生',
#  '時代',
#  '棒球',
#  '隊員',
#  '國中',
#  '學校正式',
#  '社團',
#  '老師',
#  '老師',
#  '運動教練',
#  '學校',
#  '老師',
#  '體育',
#  '老師',
#  '少棒',
#  '附中',
#  '附中田中',
#  '教練',
#  '社會科',
#  '老師',
#  '山口大賽',
#  '冠軍',
#  '高中',
#  '運動',
#  '教練',
#  '學校',
#  '教師',
#  '比例',
#  '日本',
#  '大學',
#  '宮崎',
#  '分部',
#  '棒球部',
#  '教練',
#  '木神原總一郎',
#  '廣島',
#  '鯉魚隊',
#  '球員',
#  '教練',
#  '教練',
#  '學校',
#  '社會科',
#  '老師',
#  '谷山',
#  '修一',
#  '菊池正敏',
#  '日本',
#  '棒球',
#  '運動',
#  '棒球',
#  '學校',
#  '公司',
#  '行號',
#  '教練',
#  '工作',
#  '棒球',
#  '運動',
#  '運動',
#  '日大',
#  '宮崎',
#  '教練團',
#  '台灣',
#  '棒球',
#  '運動',
#  '棒球',
#  '教育',
#  '工作者',
#  '教育',
#  '環境',
#  '學校',
#  '教育',
#  '精神',
#  '日本',
#  '沖繩興南高校',
#  '日本',
#  '沖繩內山',
#  '小學',
#  '操場',
#  '桃源雅',
#  '運動場',
#  '棒球',
#  '田徑',
#  '運動場',
#  '阿宏',
#  '叔叔',
#  '壘球場',
#  '阿宏',
#  '叔叔',
#  '棒球',
#  '觀念',
#  '棒球',
#  '棒球',
#  '台灣',
#  '學校',
#  '操場為甚麼',
#  '體壇',
#  '時光機',
#  '三重',
#  '棒球場',
#  '黑豹旗',
#  '賽事',
#  '台中市',
#  '興大',
#  '附農',
#  '穀保',
#  '家商',
#  '興大附農',
#  '投手丘',
#  '穀保',
#  '家商',
#  '高三',
#  '王牌',
#  '玉米',
#  '林昱珉',
#  '玉米',
#  '壓力',
#  '打者',
#  '戴永韋',
#  '時候',
#  '眼神',
#  '王牌',
#  '球迷',
#  '職業',
#  '棒球',
#  '賽事',
#  '林昱珉',
#  '反應',
#  '穀保',
#  '家商',
#  '林昱珉',
#  '同學',
#  '黑豹',
#  '冠軍',
#  '比賽',
#  '球員',
#  '穀保家商',
#  '投手',
#  '林昱珉',
#  '聊天室',
#  '主播說玉米',
#  '留言',
#  '霸凌',
#  '幫兇',
#  '狀況',
#  '聊天室',
#  '球迷',
#  '留言，從',
#  '穀保8+9',
#  '林昱珉',
#  '聊天室',
#  '正義必勝',
#  '留言',
#  '球迷',
#  '觀眾',
#  '球迷',
#  '事件',
#  '冠軍',
#  '戰賽',
#  '棒協',
#  '穀保',
#  '教練團',
#  '強戰對',
#  '興大',
#  '附農',
#  '事件',
#  '始末',
#  '林昱珉',
#  '表情',
#  '自信',
#  '興大',
#  '附農',
#  '休息室',
#  '林昱珉',
#  '垃圾話',
#  '球速',
#  '時候',
#  '林昱珉',
#  '表情',
#  '影片',
#  '打席',
#  '戴永韋',
#  '林昱珉',
#  '內角',
#  '壞球',
#  '打者',
#  '外野',
#  '記分板',
#  '球速',
#  '投手',
#  '情況',
#  '林昱珉',
#  '玉米',
#  '經典',
#  '場面',
#  '玉米',
#  '始末',
#  '興大',
#  '附農',
#  '垃圾話',
#  '事件',
#  '起因',
#  '針對',
#  '人身攻擊',
#  '場面',
#  '比數',
#  '垃圾話',
#  '球員',
#  '興大附農',
#  '教練團',
#  '球員',
#  '地方',
#  '球員',
#  '精神',
#  '鬥志',
#  '興大',
#  '教練團',
#  '球員',
#  '品格教育會',
#  '興大',
#  '球隊',
#  '球員',
#  '勁旅',
#  '教練團',
#  '興大',
#  '附農',
#  '球隊',
#  '黑豹旗',
#  '打擊',
#  '穀保',
#  '拉鋸戰',
#  '球員',
#  '拚勁',
#  '垃圾話',
#  '興大',
#  '附農',
#  '投手',
#  '環節',
#  '資源',
#  '資質',
#  '情況',
#  '木棒',
#  '勁旅',
#  '機會',
#  '黑豹旗',
#  '冠軍戰',
#  '穀保',
#  '林昱珉',
#  '同學',
#  '對手',
#  '垃圾話',
#  '三振',
#  '球評',
#  '鄭景益',
#  '冠軍戰',
#  '休息室',
#  '天空',
#  '球迷',
#  '當天賽後',
#  '穀保總教練',
#  '周宗志',
#  '領隊',
#  '蔡明堂',
#  '主委',
#  '林昱珉',
#  '舉動',
#  '情緒',
#  '球場',
#  '霸氣',
#  '球迷',
#  '對手',
#  '玉米進入職業',
#  '舞台',
#  '國家隊',
#  '地方',
#  '球技',
#  '職業',
#  '水準',
#  '心態',
#  '職業',
#  '選手',
#  '素質',
#  '林昱珉',
#  '單位',
#  '棒協',
#  '方式',
#  '棒協',
#  '人員',
#  '事件',
#  '林昱珉',
#  '機會',
#  ...]

# %%
top_cate_words
# Out:
# {'MLB': [('球員', 262),
#   ('投手', 202),
#   ('球隊', 171),
#   ('聯盟', 147),
#   ('大聯盟', 145),
#   ('遊戲', 135),
#   ('比賽', 127),
#   ('棒球', 119),
#   ('玩家', 117),
#   ('職棒', 99)],
#  '中職': [('投手', 174),
#   ('兄弟', 156),
#   ('富邦', 152),
#   ('安打', 128),
#   ('成績', 111),
#   ('比賽', 111),
#   ('中信', 99),
#   ('球隊', 98),
#   ('打者', 97),
#   ('詹子賢', 93)],
#  '日職': [('日本', 280),
#   ('安打', 238),
#   ('投手', 205),
#   ('比賽', 170),
#   ('球隊', 146),
#   ('聯盟', 135),
#   ('打擊', 107),
#   ('軟銀', 105),
#   ('打數', 99),
#   ('火腿', 93)],
#  '三級棒球': [('棒球', 591),
#   ('孩子', 253),
#   ('運動', 252),
#   ('球員', 245),
#   ('教練', 221),
#   ('球隊', 181),
#   ('比賽', 142),
#   ('能力', 138),
#   ('訓練', 135),
#   ('學校', 105)],
#  '全部': [('棒球', 826),
#   ('球員', 652),
#   ('投手', 612),
#   ('球隊', 596),
#   ('比賽', 550),
#   ('安打', 477),
#   ('日本', 418),
#   ('運動', 363),
#   ('聯盟', 361),
#   ('教練', 310)]}

# %%
list(top_cate_words.items())
# Out:
# [('MLB',
#   [('球員', 262),
#    ('投手', 202),
#    ('球隊', 171),
#    ('聯盟', 147),
#    ('大聯盟', 145),
#    ('遊戲', 135),
#    ('比賽', 127),
#    ('棒球', 119),
#    ('玩家', 117),
#    ('職棒', 99)]),
#  ('中職',
#   [('投手', 174),
#    ('兄弟', 156),
#    ('富邦', 152),
#    ('安打', 128),
#    ('成績', 111),
#    ('比賽', 111),
#    ('中信', 99),
#    ('球隊', 98),
#    ('打者', 97),
#    ('詹子賢', 93)]),
#  ('日職',
#   [('日本', 280),
#    ('安打', 238),
#    ('投手', 205),
#    ('比賽', 170),
#    ('球隊', 146),
#    ('聯盟', 135),
#    ('打擊', 107),
#    ('軟銀', 105),
#    ('打數', 99),
#    ('火腿', 93)]),
#  ('三級棒球',
#   [('棒球', 591),
#    ('孩子', 253),
#    ('運動', 252),
#    ('球員', 245),
#    ('教練', 221),
#    ('球隊', 181),
#    ('比賽', 142),
#    ('能力', 138),
#    ('訓練', 135),
#    ('學校', 105)]),
#  ('全部',
#   [('棒球', 826),
#    ('球員', 652),
#    ('投手', 612),
#    ('球隊', 596),
#    ('比賽', 550),
#    ('安打', 477),
#    ('日本', 418),
#    ('運動', 363),
#    ('聯盟', 361),
#    ('教練', 310)])]

# %%
from collections import Counter

# %%
news_categories=['MLB','中職','日職','三級棒球']

# %%
allowedPOS=['Na','Nb','Nc']

# %%
# All-in-one function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter
        counter_all += counter
        topwords = counter.most_common(10)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(10)

    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# %%
# %%time
result = get_top_words()
# Out:
# CPU times: total: 1.22 s
# Wall time: 1.33 s

# %%
result[0:3]
# Out:
# [('MLB',
#   [('球員', 262),
#    ('投手', 202),
#    ('球隊', 171),
#    ('聯盟', 147),
#    ('大聯盟', 145),
#    ('遊戲', 135),
#    ('比賽', 127),
#    ('棒球', 119),
#    ('玩家', 117),
#    ('職棒', 99)]),
#  ('中職',
#   [('投手', 174),
#    ('兄弟', 156),
#    ('富邦', 152),
#    ('安打', 128),
#    ('成績', 111),
#    ('比賽', 111),
#    ('中信', 99),
#    ('球隊', 98),
#    ('打者', 97),
#    ('詹子賢', 93)]),
#  ('日職',
#   [('日本', 280),
#    ('安打', 238),
#    ('投手', 205),
#    ('比賽', 170),
#    ('球隊', 146),
#    ('聯盟', 135),
#    ('打擊', 107),
#    ('軟銀', 105),
#    ('打數', 99),
#    ('火腿', 93)])]

# %%
import pandas as pd

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#   category                                           top_keys
# 0      MLB  [(球員, 262), (投手, 202), (球隊, 171), (聯盟, 147), (...
# 1       中職  [(投手, 174), (兄弟, 156), (富邦, 152), (安打, 128), (...
# 2       日職  [(日本, 280), (安打, 238), (投手, 205), (比賽, 170), (...
# 3     三級棒球  [(棒球, 591), (孩子, 253), (運動, 252), (球員, 245), (...
# 4       全部  [(棒球, 826), (球員, 652), (投手, 612), (球隊, 596), (...

# %%
df_top_group_words.to_csv('sport_baseball_topkey.csv', index=False)

# %%
from collections import Counter
import pandas as pd

#
df = pd.read_csv('sportsv_preprocessed.csv',sep='|')
news_categories=['MLB','中職','日職','三級棒球']
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

#
# get topk keyword function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter
        counter_all += counter
        topwords = counter.most_common(100)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(100)

    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# Save top 200 word frequency for each category
top_group_words = get_top_words()
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])
df_top_group_words.to_csv('sport_baseball_topkey.csv', index=False)

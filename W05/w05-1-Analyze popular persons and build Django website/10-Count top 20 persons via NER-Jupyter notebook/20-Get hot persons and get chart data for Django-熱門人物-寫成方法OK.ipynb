# %% [markdown]
# # Get popular persons and draw chart
#
# 熱門人物、類別新聞熱門關鍵字寫成方法呼叫

# %% [markdown]
# # Read top person data

# %%
import pandas as pd

# %%
df_data = pd.read_csv('PTTnews_top_person_by_category_via_ner.csv')

# %%
df_data.head(12)
# Out:
#   category                                           top_keys
# 0     學術股市  [('川普', 44), ('劉鏡清', 10), ('彭双浪', 8), ('林伯豐', ...
# 1       綜合  [('邱議瑩', 8), ('波特王', 8), ('朱立倫', 8), ('吐瓦魯', 5...
# 2       閒談  [('青山', 6), ('長谷川', 4), ('谷川', 3), ('阿音', 3), ...
# 3       棒球  [('徐若熙', 21), ('呂詠臻', 16), ('蔣少宏', 14), ('葉君璋'...
# 4       軍事  [('川普', 56), ('顧立雄', 13), ('澤倫斯基', 13), ('萬斯',...
# 5       全部  [('川普', 103), ('徐若熙', 21), ('呂詠臻', 16), ('蔣少宏'...

# %%
data={}
for idx, row in df_data.iterrows():
    data[row['category']]= eval(row['top_keys'])

# %%
data
# Out:
# {'學術股市': [('川普', 44),
#   ('劉鏡清', 10),
#   ('彭双浪', 8),
#   ('林伯豐', 8),
#   ('李成鋼', 5),
#   ('貝森特', 4),
#   ('黃仁勳', 4),
#   ('凱衛', 3),
#   ('川皇', 3),
#   ('聯詠', 2),
#   ('習寶', 2),
#   ('林恩如', 2),
#   ('劉庭宇', 2),
#   ('袁詩羽', 2),
#   ('王受文', 2),
#   ('劉忠勇', 1),
#   ('吳美依', 1),
#   ('川普發文', 1),
#   ('薩爾瓦多', 1),
#   ('布格磊', 1),
#   ('鮑爾', 1),
#   ('胡錦濤', 1),
#   ('瑞昱', 1),
#   ('林瑩真', 1),
#   ('王曉萍', 1),
#   ('彭博', 1),
#   ('吳欣恬', 1),
#   ('郭智輝', 1),
#   ('李慶華', 1),
#   ('輝達', 1),
#   ('川寶', 1),
#   ('5. ', 1),
#   ('佩珊', 1),
#   ('張曉雯', 1),
#   ('老川寶', 1),
#   ('阿川', 1),
#   ('chatgpt', 1),
#   ('川普式', 1),
#   ('范德賴恩', 1),
#   ('施凱爾', 1),
#   ('川爺', 1),
#   ('張淑伶', 1),
#   ('陳鎧妤', 1),
#   ('川寶投', 1),
#   ('張佩芬', 1),
#   ('楊喻斐', 1),
#   ('柯富仁', 1),
#   ('彭双', 1),
#   ('9萬多', 1),
#   ('黃淑玲', 1),
#   ('習近平', 1),
#   ('貝森', 1),
#   ('李維特', 1),
#   ('陳清', 1),
#   ('清楚川普', 1),
#   ('李孟恩', 1),
#   ('Fouquet', 1),
#   ('徐筱嵐', 1),
#   ('川普宣布', 1),
#   ('白蘭氏', 1),
#   ('桂格', 1),
#   ('老協', 1),
#   ('保守', 1)],
#  '綜合': [('邱議瑩', 8),
#   ('波特王', 8),
#   ('朱立倫', 8),
#   ('吐瓦魯', 5),
#   (' ‧ ', 3),
#   ('王阿平', 3),
#   ('川普', 3),
#   ('蔣萬安', 3),
#   ('柴柴', 3),
#   ('宋建樑', 3),
#   ('戴斐立', 3),
#   ('李永得', 2),
#   ('賴瑞隆', 2),
#   ('羅瑞勳', 2),
#   ('黃柏瀚', 2),
#   ('陳麗娜', 2),
#   ('王佩翊', 2),
#   ('王浩宇', 2),
#   ('梅瑟', 2),
#   ('李熙', 2),
#   ('福清', 2),
#   ('王愛英', 2),
#   ('蔣琬', 2),
#   ('黃皓', 2),
#   ('李坤城', 2),
#   ('鄧凱勛', 2),
#   ('瓦魯', 2),
#   ('川寶', 1),
#   ('施慕羽', 1),
#   ('陳竺君', 1),
#   ('包正宇', 1),
#   ('林岱樺', 1),
#   ('鄭順利', 1),
#   ('慕羽', 1),
#   ('祝大地', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('東森', 1),
#   ('壹蘋新聞', 1),
#   ('yoyo', 1),
#   ('舍友', 1),
#   ('新接龍', 1),
#   ('大紀元', 1),
#   ('林進英', 1),
#   ('陳道財', 1),
#   ('訪民', 1),
#   ('林多圳', 1),
#   ('余愛明', 1),
#   ('莫義奎', 1),
#   ('黃金龍', 1),
#   ('薛寶珠', 1),
#   ('魏英', 1),
#   ('高靜', 1),
#   ('kitty', 1),
#   ('皇帝', 1),
#   ('曹爽', 1),
#   ('王平', 1),
#   ('周毓翔', 1),
#   ('林寬裕', 1),
#   ('布丁', 1),
#   ('劉備', 1),
#   ('am', 1),
#   ('杜冠霖', 1),
#   ('柯文哲', 1),
#   ('葉元之', 1),
#   ('羅明才', 1),
#   ('廖先翔', 1),
#   ('林德福', 1),
#   ('王世堅', 1),
#   ('本魯', 1),
#   ('瓦伊阿庫村（Vaiaku', 1)],
#  '閒談': [('青山', 6),
#   ('長谷川', 4),
#   ('谷川', 3),
#   ('阿音', 3),
#   ('柯南', 3),
#   ('羽香里', 2),
#   ('卡卡羅', 2),
#   ('AveMujica', 1),
#   ('Oblivionis小祥', 1),
#   ('鬱金', 1),
#   ('鬱金香王', 1),
#   ('ra', 1),
#   ('富野', 1),
#   ('戸\u3000キシリアはかなり', 1),
#   ('庵野', 1),
#   ('谷川育美 ', 1),
#   ('谷川家', 1),
#   ('尼特美', 1),
#   ('林野民', 1),
#   ('二聖', 1),
#   ('金兀朮', 1),
#   ('傳國', 1),
#   ('姆咪', 1),
#   ('別西卜', 1),
#   ('aka', 1),
#   ('瑪琪娜', 1),
#   ('安妮‧雪利', 1),
#   ('宮崎駿', 1),
#   ('李依', 1),
#   ('鳥山明', 1),
#   ('庵野秀明', 1),
#   ('高橋李依 ', 1),
#   ('高橋李依"', 1),
#   ('愛莉莎南十字星', 1),
#   ('琳芙斯', 1),
#   ('奈葉', 1),
#   ('カノ', 1),
#   ('唐音', 1),
#   ('かわいいです ', 1),
#   ('布蘭特', 1),
#   ('布蘭', 1),
#   ('卡提希婭', 1),
#   ('巴哈姆特', 1),
#   ('夏亞', 1),
#   ('愛莉', 1),
#   ('沙織', 1),
#   ('4雷', 1),
#   ('holo', 1),
#   ('鯊皇', 1),
#   ('GPT', 1),
#   ('小鳩', 1),
#   ('senzawa', 1),
#   ('莎莎醬', 1),
#   ('莎醬', 1)],
#  '棒球': [('徐若熙', 21),
#   ('呂詠臻', 16),
#   ('蔣少宏', 14),
#   ('葉君璋', 10),
#   ('廖健富', 8),
#   ('李凱威', 8),
#   ('郭泰源', 6),
#   ('張志豪', 6),
#   ('曾頌恩', 5),
#   ('張育成', 5),
#   ('梁家榮', 4),
#   ('陳立勳', 4),
#   ('曾豪駒', 4),
#   ('古久保健', 3),
#   ('林安可', 3),
#   ('陳金鋒', 3),
#   ('陳傑憲', 3),
#   ('林宥辰', 2),
#   ('曾子祐', 2),
#   ('李秉昇', 2),
#   ('龔乃玠', 2),
#   ('若熙', 2),
#   ('馬查多', 2),
#   ('杜家明', 2),
#   ('石翔宇', 2),
#   ('李宗賢', 2),
#   ('范國宸', 2),
#   ('閔勛', 2),
#   ('亞瑞納', 2),
#   ('卡貝吉', 2),
#   ('西武', 2),
#   ('曾頌', 1),
#   ('古久保健二', 1),
#   ('陳晨威', 1),
#   ('林立', 1),
#   ('林子偉', 1),
#   ('林泓育', 1),
#   ('李勛傑', 1),
#   ('林智平', 1),
#   ('蕭保祥', 1),
#   ('克里夫蘭', 1),
#   ('陳宛晶', 1),
#   ('陳真', 1),
#   ('鄭宗哲', 1),
#   ('海耶斯', 1),
#   ('史肯斯', 1),
#   ('林祖傑', 1),
#   ('林岳平', 1),
#   ('林泓弦', 1),
#   ('楊竣翔', 1),
#   ('蒙德茲', 1),
#   (' 葉', 1),
#   ('吳清正', 1),
#   ('味全龍', 1),
#   ('胡冠辰', 1),
#   ('沃特曼', 1),
#   ('阿姆斯壯', 1),
#   ('宋晟睿', 1),
#   ('y   葉', 1),
#   ('王維', 1),
#   ('曹祐齊', 1),
#   ('吳俊杰', 1),
#   ('林智勝', 1),
#   ('李惠洲', 1),
#   ('春訓', 1),
#   ('池恩', 1),
#   ('林岳谷', 1),
#   ('軟銀上沢', 1),
#   ('陳愷佑', 1),
#   ('曾鈞威', 1),
#   ('姚恩多', 1),
#   (' 林恩鈺', 1),
#   ('陳柏翰', 1),
#   ('樂天桃猿', 1),
#   ('桃猿', 1),
#   ('Machad', 1),
#   ('Tucker', 1),
#   ('Workman', 1),
#   ('西武獅', 1),
#   ('潘威倫', 1),
#   ('潘傑楷', 1),
#   ('孫易磊', 1),
#   ('聯盟', 1),
#   ('古林睿煬', 1),
#   ('鄭凱文富邦', 1),
#   ('布里', 1),
#   ('高國', 1),
#   ('劉基鴻', 1),
#   ('郭天信', 1),
#   ('吳東融', 1),
#   ('裡20', 1),
#   ('謝葆錡', 1),
#   ('王躍霖', 1),
#   ('雷公', 1),
#   ('塔克', 1),
#   ('亞瑞納多', 1),
#   ('r Valdez', 1),
#   ('普雷斯利', 1),
#   ('沃克', 1),
#   ('蘇嘉偉', 1),
#   ('阿部慎', 1),
#   ('吉川光夫', 1),
#   ('付費)', 1),
#   ('堀内謙伍', 1),
#   ('杉本裕太郎', 1)],
#  '軍事': [('川普', 56),
#   ('顧立雄', 13),
#   ('澤倫斯基', 13),
#   ('萬斯', 7),
#   ('普丁', 6),
#   ('何仁傑', 4),
#   ('哈瑪斯', 4),
#   ('王廣軍', 4),
#   ('吳釗燮', 3),
#   ('李慧馨', 3),
#   ('洛克希德', 3),
#   ('李定中', 2),
#   ('Merz', 2),
#   ('Witcoff', 2),
#   ('羅伯特．艾布蘭', 2),
#   ('艾布蘭', 2),
#   ('羅伯特', 2),
#   ('拜登', 2),
#   ('澤連斯基', 2),
#   ('弗拉迪米爾·澤倫斯基', 2),
#   ('李員', 2),
#   ('彭男', 2),
#   ('張仁波', 2),
#   ('王某', 2),
#   ('立雄', 1),
#   ('陳俊宇', 1),
#   ('邱璽臣', 1),
#   ('林朝億', 1),
#   ('蘇利文', 1),
#   ('馮德萊恩', 1),
#   ('空川普', 1),
#   ('納坦雅胡', 1),
#   ('Robert Fico', 1),
#   ('itcoff', 1),
#   ('達文西', 1),
#   ('蘇梅時', 1),
#   ('ate Silver', 1),
#   ('馬斯克', 1),
#   ('Hegseth', 1),
#   ('梅家樹', 1),
#   ('威廉斯．艾布蘭', 1),
#   ('蘇紫雲', 1),
#   ('和澤倫斯基', 1),
#   ('澤倫斯', 1),
#   ('Vanc', 1),
#   ('卡姆揚斯凱', 1),
#   ('班森特', 1),
#   ('利潤', 1),
#   ('李人岳', 1),
#   ('羅美玲', 1),
#   ('尤里·布什科夫斯基', 1),
#   ('戈夫', 1),
#   ('Kirill Rogov', 1),
#   ('徐源傑', 1),
#   ('李靖棠', 1),
#   ('蘇比安托', 1),
#   ('艾爾多安', 1),
#   ('馬可·魯比歐', 1),
#   ('羅納德·紐曼', 1),
#   ('布雷特·布魯恩', 1),
#   ('史密斯', 1),
#   ('普丁至', 1),
#   ('凱洛格', 1),
#   ('魯比歐', 1),
#   ('賽·葛瑞姆', 1),
#   ('葛瑞姆', 1),
#   ('基里爾·德米特里耶夫', 1),
#   ('威特科夫', 1),
#   ('湯瑪斯·葛拉漢', 1),
#   ('吳政峰', 1),
#   ('清德', 1),
#   ('陳姓', 1),
#   ('錢澤倫斯基', 1),
#   ('克里姆林', 1),
#   ('九地危', 1),
#   ('凱斯', 1),
#   ('舒夫', 1),
#   ('史蒂夫', 1),
#   ('大衛・希默', 1),
#   ('Davi', 1),
#   ('希默', 1),
#   ('海馬斯', 1),
#   ('洪哲政', 1),
#   ('王鴻薇', 1),
#   ('翁曉玲', 1),
#   ('TWZ', 1),
#   ('雷松', 1),
#   ('戴明', 1),
#   ('Waltz', 1),
#   ('蘇梅"', 1),
#   ('烏克蘭戒', 1),
#   ('吳銘峯', 1),
#   ('劉男', 1),
#   ('吳男', 1),
#   ('張姓', 1),
#   ('林姓', 1),
#   ('星星', 1),
#   ('莫斯科 頓河', 1),
#   ('羅斯托夫', 1),
#   ('頓內茨克', 1),
#   ('蒲亭', 1),
#   ('Vladimir Putin', 1),
#   ('紀錦玲', 1),
#   ('蔡佳敏', 1),
#   ('羅斯福', 1),
#   ('莫希奇茨基', 1),
#   ('邱吉爾', 1),
#   ('鄭喆煥', 1),
#   ('涅茨克', 1),
#   ('TikTok', 1),
#   ('”王某', 1),
#   ('張某', 1)],
#  '全部': [('川普', 103),
#   ('徐若熙', 21),
#   ('呂詠臻', 16),
#   ('蔣少宏', 14),
#   ('顧立雄', 13),
#   ('澤倫斯基', 13),
#   ('劉鏡清', 10),
#   ('葉君璋', 10),
#   ('彭双浪', 8),
#   ('林伯豐', 8),
#   ('邱議瑩', 8),
#   ('波特王', 8),
#   ('朱立倫', 8),
#   ('廖健富', 8),
#   ('李凱威', 8),
#   ('萬斯', 7),
#   ('青山', 6),
#   ('郭泰源', 6),
#   ('張志豪', 6),
#   ('普丁', 6),
#   ('李成鋼', 5),
#   ('吐瓦魯', 5),
#   ('曾頌恩', 5),
#   ('張育成', 5),
#   ('貝森特', 4),
#   ('黃仁勳', 4),
#   ('長谷川', 4),
#   ('梁家榮', 4),
#   ('陳立勳', 4),
#   ('曾豪駒', 4),
#   ('何仁傑', 4),
#   ('哈瑪斯', 4),
#   ('王廣軍', 4),
#   ('凱衛', 3),
#   ('川皇', 3),
#   (' ‧ ', 3),
#   ('王阿平', 3),
#   ('蔣萬安', 3),
#   ('柴柴', 3),
#   ('宋建樑', 3),
#   ('戴斐立', 3),
#   ('谷川', 3),
#   ('阿音', 3),
#   ('柯南', 3),
#   ('古久保健', 3),
#   ('林安可', 3),
#   ('陳金鋒', 3),
#   ('陳傑憲', 3),
#   ('吳釗燮', 3),
#   ('李慧馨', 3),
#   ('洛克希德', 3),
#   ('聯詠', 2),
#   ('習寶', 2),
#   ('川寶', 2),
#   ('林恩如', 2),
#   ('劉庭宇', 2),
#   ('袁詩羽', 2),
#   ('王受文', 2),
#   ('李永得', 2),
#   ('賴瑞隆', 2),
#   ('羅瑞勳', 2),
#   ('黃柏瀚', 2),
#   ('陳麗娜', 2),
#   ('王佩翊', 2),
#   ('王浩宇', 2),
#   ('梅瑟', 2),
#   ('李熙', 2),
#   ('福清', 2),
#   ('王愛英', 2),
#   ('蔣琬', 2),
#   ('黃皓', 2),
#   ('李坤城', 2),
#   ('鄧凱勛', 2),
#   ('瓦魯', 2),
#   ('羽香里', 2),
#   ('卡卡羅', 2),
#   ('林宥辰', 2),
#   ('曾子祐', 2),
#   ('李秉昇', 2),
#   ('龔乃玠', 2),
#   ('若熙', 2),
#   ('馬查多', 2),
#   ('杜家明', 2),
#   ('石翔宇', 2),
#   ('李宗賢', 2),
#   ('范國宸', 2),
#   ('閔勛', 2),
#   ('亞瑞納', 2),
#   ('卡貝吉', 2),
#   ('西武', 2),
#   ('李定中', 2),
#   ('Merz', 2),
#   ('Witcoff', 2),
#   ('羅伯特．艾布蘭', 2),
#   ('艾布蘭', 2),
#   ('羅伯特', 2),
#   ('拜登', 2),
#   ('澤連斯基', 2),
#   ('弗拉迪米爾·澤倫斯基', 2),
#   ('李員', 2),
#   ('彭男', 2),
#   ('張仁波', 2),
#   ('王某', 2),
#   ('劉忠勇', 1),
#   ('吳美依', 1),
#   ('川普發文', 1),
#   ('薩爾瓦多', 1),
#   ('布格磊', 1),
#   ('鮑爾', 1),
#   ('胡錦濤', 1),
#   ('瑞昱', 1),
#   ('林瑩真', 1),
#   ('王曉萍', 1),
#   ('彭博', 1),
#   ('吳欣恬', 1),
#   ('郭智輝', 1),
#   ('李慶華', 1),
#   ('輝達', 1),
#   ('5. ', 1),
#   ('佩珊', 1),
#   ('張曉雯', 1),
#   ('老川寶', 1),
#   ('阿川', 1),
#   ('chatgpt', 1),
#   ('川普式', 1),
#   ('范德賴恩', 1),
#   ('施凱爾', 1),
#   ('川爺', 1),
#   ('張淑伶', 1),
#   ('陳鎧妤', 1),
#   ('川寶投', 1),
#   ('張佩芬', 1),
#   ('楊喻斐', 1),
#   ('柯富仁', 1),
#   ('彭双', 1),
#   ('9萬多', 1),
#   ('黃淑玲', 1),
#   ('習近平', 1),
#   ('貝森', 1),
#   ('李維特', 1),
#   ('陳清', 1),
#   ('清楚川普', 1),
#   ('李孟恩', 1),
#   ('Fouquet', 1),
#   ('徐筱嵐', 1),
#   ('川普宣布', 1),
#   ('白蘭氏', 1),
#   ('桂格', 1),
#   ('老協', 1),
#   ('保守', 1),
#   ('施慕羽', 1),
#   ('陳竺君', 1),
#   ('包正宇', 1),
#   ('林岱樺', 1),
#   ('鄭順利', 1),
#   ('慕羽', 1),
#   ('祝大地', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('東森', 1),
#   ('壹蘋新聞', 1),
#   ('yoyo', 1),
#   ('舍友', 1),
#   ('新接龍', 1),
#   ('大紀元', 1),
#   ('林進英', 1),
#   ('陳道財', 1),
#   ('訪民', 1),
#   ('林多圳', 1),
#   ('余愛明', 1),
#   ('莫義奎', 1),
#   ('黃金龍', 1),
#   ('薛寶珠', 1),
#   ('魏英', 1),
#   ('高靜', 1),
#   ('kitty', 1),
#   ('皇帝', 1),
#   ('曹爽', 1),
#   ('王平', 1),
#   ('周毓翔', 1),
#   ('林寬裕', 1),
#   ('布丁', 1),
#   ('劉備', 1),
#   ('am', 1),
#   ('杜冠霖', 1),
#   ('柯文哲', 1),
#   ('葉元之', 1),
#   ('羅明才', 1),
#   ('廖先翔', 1),
#   ('林德福', 1),
#   ('王世堅', 1),
#   ('本魯', 1),
#   ('瓦伊阿庫村（Vaiaku', 1),
#   ('AveMujica', 1),
#   ('Oblivionis小祥', 1),
#   ('鬱金', 1),
#   ('鬱金香王', 1),
#   ('ra', 1),
#   ('富野', 1),
#   ('戸\u3000キシリアはかなり', 1)]}

# %%
data['學術股市']
# Out:
# [('川普', 44),
#  ('劉鏡清', 10),
#  ('彭双浪', 8),
#  ('林伯豐', 8),
#  ('李成鋼', 5),
#  ('貝森特', 4),
#  ('黃仁勳', 4),
#  ('凱衛', 3),
#  ('川皇', 3),
#  ('聯詠', 2),
#  ('習寶', 2),
#  ('林恩如', 2),
#  ('劉庭宇', 2),
#  ('袁詩羽', 2),
#  ('王受文', 2),
#  ('劉忠勇', 1),
#  ('吳美依', 1),
#  ('川普發文', 1),
#  ('薩爾瓦多', 1),
#  ('布格磊', 1),
#  ('鮑爾', 1),
#  ('胡錦濤', 1),
#  ('瑞昱', 1),
#  ('林瑩真', 1),
#  ('王曉萍', 1),
#  ('彭博', 1),
#  ('吳欣恬', 1),
#  ('郭智輝', 1),
#  ('李慶華', 1),
#  ('輝達', 1),
#  ('川寶', 1),
#  ('5. ', 1),
#  ('佩珊', 1),
#  ('張曉雯', 1),
#  ('老川寶', 1),
#  ('阿川', 1),
#  ('chatgpt', 1),
#  ('川普式', 1),
#  ('范德賴恩', 1),
#  ('施凱爾', 1),
#  ('川爺', 1),
#  ('張淑伶', 1),
#  ('陳鎧妤', 1),
#  ('川寶投', 1),
#  ('張佩芬', 1),
#  ('楊喻斐', 1),
#  ('柯富仁', 1),
#  ('彭双', 1),
#  ('9萬多', 1),
#  ('黃淑玲', 1),
#  ('習近平', 1),
#  ('貝森', 1),
#  ('李維特', 1),
#  ('陳清', 1),
#  ('清楚川普', 1),
#  ('李孟恩', 1),
#  ('Fouquet', 1),
#  ('徐筱嵐', 1),
#  ('川普宣布', 1),
#  ('白蘭氏', 1),
#  ('桂格', 1),
#  ('老協', 1),
#  ('保守', 1)]

# %%
data['學術股市'][0:3]
# Out:
# [('川普', 44), ('劉鏡清', 10), ('彭双浪', 8)]

# %% [markdown]
# # Define functions to be used in Django

# %% [markdown]
# ## Load data and prepare chart data dict

# %%
# Load data and prepare chart data dict
df_data = pd.read_csv('PTTnews_top_person_by_category_via_ner.csv')

# Prepare top keys data with dictionary format
data={}
for idx, row in df_data.iterrows():
    data[row['category']]= eval(row['top_keys'])

# %%
'''
the format of data:
{'政治': [('韓國瑜', 6344),
  ('蔡英文', 2114),
  ('賴清德', 1480),
  ...
  }
'''

# load data and prepare chart data dict
def load_data_topPerson():
    # read df
    #df_topPerson = pd.read_csv('app_top_person/dataset/news_top_person_by_category_via_ner.csv')
    df_topPerson = pd.read_csv('PTTnews_top_person_by_category_via_ner.csv')
    # refresh data
    global data
    data = {}
    for idx, row in df_topPerson.iterrows():
        data[row['category']] = eval(row['top_keys'])

# Load data first when starting server.
load_data_topPerson()

# %%
data
# Out:
# {'學術股市': [('川普', 44),
#   ('劉鏡清', 10),
#   ('彭双浪', 8),
#   ('林伯豐', 8),
#   ('李成鋼', 5),
#   ('貝森特', 4),
#   ('黃仁勳', 4),
#   ('凱衛', 3),
#   ('川皇', 3),
#   ('聯詠', 2),
#   ('習寶', 2),
#   ('林恩如', 2),
#   ('劉庭宇', 2),
#   ('袁詩羽', 2),
#   ('王受文', 2),
#   ('劉忠勇', 1),
#   ('吳美依', 1),
#   ('川普發文', 1),
#   ('薩爾瓦多', 1),
#   ('布格磊', 1),
#   ('鮑爾', 1),
#   ('胡錦濤', 1),
#   ('瑞昱', 1),
#   ('林瑩真', 1),
#   ('王曉萍', 1),
#   ('彭博', 1),
#   ('吳欣恬', 1),
#   ('郭智輝', 1),
#   ('李慶華', 1),
#   ('輝達', 1),
#   ('川寶', 1),
#   ('5. ', 1),
#   ('佩珊', 1),
#   ('張曉雯', 1),
#   ('老川寶', 1),
#   ('阿川', 1),
#   ('chatgpt', 1),
#   ('川普式', 1),
#   ('范德賴恩', 1),
#   ('施凱爾', 1),
#   ('川爺', 1),
#   ('張淑伶', 1),
#   ('陳鎧妤', 1),
#   ('川寶投', 1),
#   ('張佩芬', 1),
#   ('楊喻斐', 1),
#   ('柯富仁', 1),
#   ('彭双', 1),
#   ('9萬多', 1),
#   ('黃淑玲', 1),
#   ('習近平', 1),
#   ('貝森', 1),
#   ('李維特', 1),
#   ('陳清', 1),
#   ('清楚川普', 1),
#   ('李孟恩', 1),
#   ('Fouquet', 1),
#   ('徐筱嵐', 1),
#   ('川普宣布', 1),
#   ('白蘭氏', 1),
#   ('桂格', 1),
#   ('老協', 1),
#   ('保守', 1)],
#  '綜合': [('邱議瑩', 8),
#   ('波特王', 8),
#   ('朱立倫', 8),
#   ('吐瓦魯', 5),
#   (' ‧ ', 3),
#   ('王阿平', 3),
#   ('川普', 3),
#   ('蔣萬安', 3),
#   ('柴柴', 3),
#   ('宋建樑', 3),
#   ('戴斐立', 3),
#   ('李永得', 2),
#   ('賴瑞隆', 2),
#   ('羅瑞勳', 2),
#   ('黃柏瀚', 2),
#   ('陳麗娜', 2),
#   ('王佩翊', 2),
#   ('王浩宇', 2),
#   ('梅瑟', 2),
#   ('李熙', 2),
#   ('福清', 2),
#   ('王愛英', 2),
#   ('蔣琬', 2),
#   ('黃皓', 2),
#   ('李坤城', 2),
#   ('鄧凱勛', 2),
#   ('瓦魯', 2),
#   ('川寶', 1),
#   ('施慕羽', 1),
#   ('陳竺君', 1),
#   ('包正宇', 1),
#   ('林岱樺', 1),
#   ('鄭順利', 1),
#   ('慕羽', 1),
#   ('祝大地', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('東森', 1),
#   ('壹蘋新聞', 1),
#   ('yoyo', 1),
#   ('舍友', 1),
#   ('新接龍', 1),
#   ('大紀元', 1),
#   ('林進英', 1),
#   ('陳道財', 1),
#   ('訪民', 1),
#   ('林多圳', 1),
#   ('余愛明', 1),
#   ('莫義奎', 1),
#   ('黃金龍', 1),
#   ('薛寶珠', 1),
#   ('魏英', 1),
#   ('高靜', 1),
#   ('kitty', 1),
#   ('皇帝', 1),
#   ('曹爽', 1),
#   ('王平', 1),
#   ('周毓翔', 1),
#   ('林寬裕', 1),
#   ('布丁', 1),
#   ('劉備', 1),
#   ('am', 1),
#   ('杜冠霖', 1),
#   ('柯文哲', 1),
#   ('葉元之', 1),
#   ('羅明才', 1),
#   ('廖先翔', 1),
#   ('林德福', 1),
#   ('王世堅', 1),
#   ('本魯', 1),
#   ('瓦伊阿庫村（Vaiaku', 1)],
#  '閒談': [('青山', 6),
#   ('長谷川', 4),
#   ('谷川', 3),
#   ('阿音', 3),
#   ('柯南', 3),
#   ('羽香里', 2),
#   ('卡卡羅', 2),
#   ('AveMujica', 1),
#   ('Oblivionis小祥', 1),
#   ('鬱金', 1),
#   ('鬱金香王', 1),
#   ('ra', 1),
#   ('富野', 1),
#   ('戸\u3000キシリアはかなり', 1),
#   ('庵野', 1),
#   ('谷川育美 ', 1),
#   ('谷川家', 1),
#   ('尼特美', 1),
#   ('林野民', 1),
#   ('二聖', 1),
#   ('金兀朮', 1),
#   ('傳國', 1),
#   ('姆咪', 1),
#   ('別西卜', 1),
#   ('aka', 1),
#   ('瑪琪娜', 1),
#   ('安妮‧雪利', 1),
#   ('宮崎駿', 1),
#   ('李依', 1),
#   ('鳥山明', 1),
#   ('庵野秀明', 1),
#   ('高橋李依 ', 1),
#   ('高橋李依"', 1),
#   ('愛莉莎南十字星', 1),
#   ('琳芙斯', 1),
#   ('奈葉', 1),
#   ('カノ', 1),
#   ('唐音', 1),
#   ('かわいいです ', 1),
#   ('布蘭特', 1),
#   ('布蘭', 1),
#   ('卡提希婭', 1),
#   ('巴哈姆特', 1),
#   ('夏亞', 1),
#   ('愛莉', 1),
#   ('沙織', 1),
#   ('4雷', 1),
#   ('holo', 1),
#   ('鯊皇', 1),
#   ('GPT', 1),
#   ('小鳩', 1),
#   ('senzawa', 1),
#   ('莎莎醬', 1),
#   ('莎醬', 1)],
#  '棒球': [('徐若熙', 21),
#   ('呂詠臻', 16),
#   ('蔣少宏', 14),
#   ('葉君璋', 10),
#   ('廖健富', 8),
#   ('李凱威', 8),
#   ('郭泰源', 6),
#   ('張志豪', 6),
#   ('曾頌恩', 5),
#   ('張育成', 5),
#   ('梁家榮', 4),
#   ('陳立勳', 4),
#   ('曾豪駒', 4),
#   ('古久保健', 3),
#   ('林安可', 3),
#   ('陳金鋒', 3),
#   ('陳傑憲', 3),
#   ('林宥辰', 2),
#   ('曾子祐', 2),
#   ('李秉昇', 2),
#   ('龔乃玠', 2),
#   ('若熙', 2),
#   ('馬查多', 2),
#   ('杜家明', 2),
#   ('石翔宇', 2),
#   ('李宗賢', 2),
#   ('范國宸', 2),
#   ('閔勛', 2),
#   ('亞瑞納', 2),
#   ('卡貝吉', 2),
#   ('西武', 2),
#   ('曾頌', 1),
#   ('古久保健二', 1),
#   ('陳晨威', 1),
#   ('林立', 1),
#   ('林子偉', 1),
#   ('林泓育', 1),
#   ('李勛傑', 1),
#   ('林智平', 1),
#   ('蕭保祥', 1),
#   ('克里夫蘭', 1),
#   ('陳宛晶', 1),
#   ('陳真', 1),
#   ('鄭宗哲', 1),
#   ('海耶斯', 1),
#   ('史肯斯', 1),
#   ('林祖傑', 1),
#   ('林岳平', 1),
#   ('林泓弦', 1),
#   ('楊竣翔', 1),
#   ('蒙德茲', 1),
#   (' 葉', 1),
#   ('吳清正', 1),
#   ('味全龍', 1),
#   ('胡冠辰', 1),
#   ('沃特曼', 1),
#   ('阿姆斯壯', 1),
#   ('宋晟睿', 1),
#   ('y   葉', 1),
#   ('王維', 1),
#   ('曹祐齊', 1),
#   ('吳俊杰', 1),
#   ('林智勝', 1),
#   ('李惠洲', 1),
#   ('春訓', 1),
#   ('池恩', 1),
#   ('林岳谷', 1),
#   ('軟銀上沢', 1),
#   ('陳愷佑', 1),
#   ('曾鈞威', 1),
#   ('姚恩多', 1),
#   (' 林恩鈺', 1),
#   ('陳柏翰', 1),
#   ('樂天桃猿', 1),
#   ('桃猿', 1),
#   ('Machad', 1),
#   ('Tucker', 1),
#   ('Workman', 1),
#   ('西武獅', 1),
#   ('潘威倫', 1),
#   ('潘傑楷', 1),
#   ('孫易磊', 1),
#   ('聯盟', 1),
#   ('古林睿煬', 1),
#   ('鄭凱文富邦', 1),
#   ('布里', 1),
#   ('高國', 1),
#   ('劉基鴻', 1),
#   ('郭天信', 1),
#   ('吳東融', 1),
#   ('裡20', 1),
#   ('謝葆錡', 1),
#   ('王躍霖', 1),
#   ('雷公', 1),
#   ('塔克', 1),
#   ('亞瑞納多', 1),
#   ('r Valdez', 1),
#   ('普雷斯利', 1),
#   ('沃克', 1),
#   ('蘇嘉偉', 1),
#   ('阿部慎', 1),
#   ('吉川光夫', 1),
#   ('付費)', 1),
#   ('堀内謙伍', 1),
#   ('杉本裕太郎', 1)],
#  '軍事': [('川普', 56),
#   ('顧立雄', 13),
#   ('澤倫斯基', 13),
#   ('萬斯', 7),
#   ('普丁', 6),
#   ('何仁傑', 4),
#   ('哈瑪斯', 4),
#   ('王廣軍', 4),
#   ('吳釗燮', 3),
#   ('李慧馨', 3),
#   ('洛克希德', 3),
#   ('李定中', 2),
#   ('Merz', 2),
#   ('Witcoff', 2),
#   ('羅伯特．艾布蘭', 2),
#   ('艾布蘭', 2),
#   ('羅伯特', 2),
#   ('拜登', 2),
#   ('澤連斯基', 2),
#   ('弗拉迪米爾·澤倫斯基', 2),
#   ('李員', 2),
#   ('彭男', 2),
#   ('張仁波', 2),
#   ('王某', 2),
#   ('立雄', 1),
#   ('陳俊宇', 1),
#   ('邱璽臣', 1),
#   ('林朝億', 1),
#   ('蘇利文', 1),
#   ('馮德萊恩', 1),
#   ('空川普', 1),
#   ('納坦雅胡', 1),
#   ('Robert Fico', 1),
#   ('itcoff', 1),
#   ('達文西', 1),
#   ('蘇梅時', 1),
#   ('ate Silver', 1),
#   ('馬斯克', 1),
#   ('Hegseth', 1),
#   ('梅家樹', 1),
#   ('威廉斯．艾布蘭', 1),
#   ('蘇紫雲', 1),
#   ('和澤倫斯基', 1),
#   ('澤倫斯', 1),
#   ('Vanc', 1),
#   ('卡姆揚斯凱', 1),
#   ('班森特', 1),
#   ('利潤', 1),
#   ('李人岳', 1),
#   ('羅美玲', 1),
#   ('尤里·布什科夫斯基', 1),
#   ('戈夫', 1),
#   ('Kirill Rogov', 1),
#   ('徐源傑', 1),
#   ('李靖棠', 1),
#   ('蘇比安托', 1),
#   ('艾爾多安', 1),
#   ('馬可·魯比歐', 1),
#   ('羅納德·紐曼', 1),
#   ('布雷特·布魯恩', 1),
#   ('史密斯', 1),
#   ('普丁至', 1),
#   ('凱洛格', 1),
#   ('魯比歐', 1),
#   ('賽·葛瑞姆', 1),
#   ('葛瑞姆', 1),
#   ('基里爾·德米特里耶夫', 1),
#   ('威特科夫', 1),
#   ('湯瑪斯·葛拉漢', 1),
#   ('吳政峰', 1),
#   ('清德', 1),
#   ('陳姓', 1),
#   ('錢澤倫斯基', 1),
#   ('克里姆林', 1),
#   ('九地危', 1),
#   ('凱斯', 1),
#   ('舒夫', 1),
#   ('史蒂夫', 1),
#   ('大衛・希默', 1),
#   ('Davi', 1),
#   ('希默', 1),
#   ('海馬斯', 1),
#   ('洪哲政', 1),
#   ('王鴻薇', 1),
#   ('翁曉玲', 1),
#   ('TWZ', 1),
#   ('雷松', 1),
#   ('戴明', 1),
#   ('Waltz', 1),
#   ('蘇梅"', 1),
#   ('烏克蘭戒', 1),
#   ('吳銘峯', 1),
#   ('劉男', 1),
#   ('吳男', 1),
#   ('張姓', 1),
#   ('林姓', 1),
#   ('星星', 1),
#   ('莫斯科 頓河', 1),
#   ('羅斯托夫', 1),
#   ('頓內茨克', 1),
#   ('蒲亭', 1),
#   ('Vladimir Putin', 1),
#   ('紀錦玲', 1),
#   ('蔡佳敏', 1),
#   ('羅斯福', 1),
#   ('莫希奇茨基', 1),
#   ('邱吉爾', 1),
#   ('鄭喆煥', 1),
#   ('涅茨克', 1),
#   ('TikTok', 1),
#   ('”王某', 1),
#   ('張某', 1)],
#  '全部': [('川普', 103),
#   ('徐若熙', 21),
#   ('呂詠臻', 16),
#   ('蔣少宏', 14),
#   ('顧立雄', 13),
#   ('澤倫斯基', 13),
#   ('劉鏡清', 10),
#   ('葉君璋', 10),
#   ('彭双浪', 8),
#   ('林伯豐', 8),
#   ('邱議瑩', 8),
#   ('波特王', 8),
#   ('朱立倫', 8),
#   ('廖健富', 8),
#   ('李凱威', 8),
#   ('萬斯', 7),
#   ('青山', 6),
#   ('郭泰源', 6),
#   ('張志豪', 6),
#   ('普丁', 6),
#   ('李成鋼', 5),
#   ('吐瓦魯', 5),
#   ('曾頌恩', 5),
#   ('張育成', 5),
#   ('貝森特', 4),
#   ('黃仁勳', 4),
#   ('長谷川', 4),
#   ('梁家榮', 4),
#   ('陳立勳', 4),
#   ('曾豪駒', 4),
#   ('何仁傑', 4),
#   ('哈瑪斯', 4),
#   ('王廣軍', 4),
#   ('凱衛', 3),
#   ('川皇', 3),
#   (' ‧ ', 3),
#   ('王阿平', 3),
#   ('蔣萬安', 3),
#   ('柴柴', 3),
#   ('宋建樑', 3),
#   ('戴斐立', 3),
#   ('谷川', 3),
#   ('阿音', 3),
#   ('柯南', 3),
#   ('古久保健', 3),
#   ('林安可', 3),
#   ('陳金鋒', 3),
#   ('陳傑憲', 3),
#   ('吳釗燮', 3),
#   ('李慧馨', 3),
#   ('洛克希德', 3),
#   ('聯詠', 2),
#   ('習寶', 2),
#   ('川寶', 2),
#   ('林恩如', 2),
#   ('劉庭宇', 2),
#   ('袁詩羽', 2),
#   ('王受文', 2),
#   ('李永得', 2),
#   ('賴瑞隆', 2),
#   ('羅瑞勳', 2),
#   ('黃柏瀚', 2),
#   ('陳麗娜', 2),
#   ('王佩翊', 2),
#   ('王浩宇', 2),
#   ('梅瑟', 2),
#   ('李熙', 2),
#   ('福清', 2),
#   ('王愛英', 2),
#   ('蔣琬', 2),
#   ('黃皓', 2),
#   ('李坤城', 2),
#   ('鄧凱勛', 2),
#   ('瓦魯', 2),
#   ('羽香里', 2),
#   ('卡卡羅', 2),
#   ('林宥辰', 2),
#   ('曾子祐', 2),
#   ('李秉昇', 2),
#   ('龔乃玠', 2),
#   ('若熙', 2),
#   ('馬查多', 2),
#   ('杜家明', 2),
#   ('石翔宇', 2),
#   ('李宗賢', 2),
#   ('范國宸', 2),
#   ('閔勛', 2),
#   ('亞瑞納', 2),
#   ('卡貝吉', 2),
#   ('西武', 2),
#   ('李定中', 2),
#   ('Merz', 2),
#   ('Witcoff', 2),
#   ('羅伯特．艾布蘭', 2),
#   ('艾布蘭', 2),
#   ('羅伯特', 2),
#   ('拜登', 2),
#   ('澤連斯基', 2),
#   ('弗拉迪米爾·澤倫斯基', 2),
#   ('李員', 2),
#   ('彭男', 2),
#   ('張仁波', 2),
#   ('王某', 2),
#   ('劉忠勇', 1),
#   ('吳美依', 1),
#   ('川普發文', 1),
#   ('薩爾瓦多', 1),
#   ('布格磊', 1),
#   ('鮑爾', 1),
#   ('胡錦濤', 1),
#   ('瑞昱', 1),
#   ('林瑩真', 1),
#   ('王曉萍', 1),
#   ('彭博', 1),
#   ('吳欣恬', 1),
#   ('郭智輝', 1),
#   ('李慶華', 1),
#   ('輝達', 1),
#   ('5. ', 1),
#   ('佩珊', 1),
#   ('張曉雯', 1),
#   ('老川寶', 1),
#   ('阿川', 1),
#   ('chatgpt', 1),
#   ('川普式', 1),
#   ('范德賴恩', 1),
#   ('施凱爾', 1),
#   ('川爺', 1),
#   ('張淑伶', 1),
#   ('陳鎧妤', 1),
#   ('川寶投', 1),
#   ('張佩芬', 1),
#   ('楊喻斐', 1),
#   ('柯富仁', 1),
#   ('彭双', 1),
#   ('9萬多', 1),
#   ('黃淑玲', 1),
#   ('習近平', 1),
#   ('貝森', 1),
#   ('李維特', 1),
#   ('陳清', 1),
#   ('清楚川普', 1),
#   ('李孟恩', 1),
#   ('Fouquet', 1),
#   ('徐筱嵐', 1),
#   ('川普宣布', 1),
#   ('白蘭氏', 1),
#   ('桂格', 1),
#   ('老協', 1),
#   ('保守', 1),
#   ('施慕羽', 1),
#   ('陳竺君', 1),
#   ('包正宇', 1),
#   ('林岱樺', 1),
#   ('鄭順利', 1),
#   ('慕羽', 1),
#   ('祝大地', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('  ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣ ‧ ', 1),
#   ('東森', 1),
#   ('壹蘋新聞', 1),
#   ('yoyo', 1),
#   ('舍友', 1),
#   ('新接龍', 1),
#   ('大紀元', 1),
#   ('林進英', 1),
#   ('陳道財', 1),
#   ('訪民', 1),
#   ('林多圳', 1),
#   ('余愛明', 1),
#   ('莫義奎', 1),
#   ('黃金龍', 1),
#   ('薛寶珠', 1),
#   ('魏英', 1),
#   ('高靜', 1),
#   ('kitty', 1),
#   ('皇帝', 1),
#   ('曹爽', 1),
#   ('王平', 1),
#   ('周毓翔', 1),
#   ('林寬裕', 1),
#   ('布丁', 1),
#   ('劉備', 1),
#   ('am', 1),
#   ('杜冠霖', 1),
#   ('柯文哲', 1),
#   ('葉元之', 1),
#   ('羅明才', 1),
#   ('廖先翔', 1),
#   ('林德福', 1),
#   ('王世堅', 1),
#   ('本魯', 1),
#   ('瓦伊阿庫村（Vaiaku', 1),
#   ('AveMujica', 1),
#   ('Oblivionis小祥', 1),
#   ('鬱金', 1),
#   ('鬱金香王', 1),
#   ('ra', 1),
#   ('富野', 1),
#   ('戸\u3000キシリアはかなり', 1)]}

# %% [markdown]
# ## Get categorical topkeys

# %%
# Django views.py needs this function
def get_category_topkey(cate, topk=10):
    wf_pairs = data[cate][0:topk]
    words = [w for w, f in wf_pairs]
    freqs = [f for w, f in wf_pairs]
    chart_data = {
        "category": cate,
        "labels": words,
        "values": freqs}
    return chart_data, wf_pairs

# %%
get_category_topkey('學術股市',3)
# Out:
# ({'category': '學術股市', 'labels': ['川普', '劉鏡清', '彭双浪'], 'values': [44, 10, 8]},
#  [('川普', 44), ('劉鏡清', 10), ('彭双浪', 8)])

# %% [markdown]
# # Django views.py

# %%
from django.shortcuts import render
import pandas as pd

from django.http import JsonResponse
from django.views.decorators.csrf import csrf_exempt

'''
the format of data:
{'政治': [('韓國瑜', 6344),
  ('蔡英文', 2114),
  ('賴清德', 1480),
  ...
  }
'''

# load data
def load_data_topPerson():
    # read df
    df_topPerson = pd.read_csv(
        'PTTnews_top_person_by_category_via_ner.csv')
    # refresh data
    global data
    data = {}
    for idx, row in df_topPerson.iterrows():
        data[row['category']] = eval(row['top_keys'])


# Load data first when starting server.
load_data_topPerson()

def home(request):
    return render(request, 'app_top_person/home.html')

# csrf_exempt is used for POST
# 單獨指定這一支程式忽略csrf驗證
@csrf_exempt
def api_get_topPerson(request):

    # chart_data, wf_pairs = get_category_topkey("科技", 10) #先做簡單的測試

    cate = request.POST.get('news_category')
    topk = request.POST.get('topk')
    topk = int(topk)
    #print(cate, topk)

    chart_data, wf_pairs = get_category_topPerson(cate, topk)

    # print(chart_data)
    response = {'chart_data':  chart_data,
                'wf_pairs': wf_pairs,
                }
    return JsonResponse(response)


def get_category_topPerson(cate, topk):
    wf_pairs = data[cate][0:topk]
    words = [w for w, f in wf_pairs]
    freqs = [f for w, f in wf_pairs]
    chart_data = {
        "category": cate,
        "labels": words,
        "values": freqs}
    return chart_data, wf_pairs  # chart_data is for charting


print("app_news_analysis--類別熱門人物載入成功!")
# Out:
# app_news_analysis--類別熱門人物載入成功!

# %% [raw]
# # For your reference
# # Alternative code for the same function
# def get_category_topkey(cate, topk=10):
#     keys = df_data.loc[df_data['category'] == cate]
#     wf_pairs = eval(keys['top_keys'].values[0])
#     wf_pairs = wf_pairs[0:topk]
#     words = [w for w, f in wf_pairs]
#     freqs = [f for w, f in wf_pairs]
#     chart_data = {
#         "category": cate,
#         "labels": words,
#         "values": freqs}
#     return chart_data, wf_pairs
